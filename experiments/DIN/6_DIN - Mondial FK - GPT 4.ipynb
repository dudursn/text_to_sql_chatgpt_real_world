# %% [markdown]
# # Experimento: DIN - Mondial - Foreign Key - GPT 4

# %%
from langchain.chat_models import ChatOpenAI
from urllib.parse import quote  

from dotenv import load_dotenv
import time
import os
import sys
import json
load_dotenv()


from din_schema_linking import schema_linking_module
from din_classification import classification_module
from din_generating_sql_by_type import generating_sql_by_type_module
from din_self_correction import self_correction_module

experiment_path = '..\..'
path = os.path.abspath('')
module_path = os.path.join(path, experiment_path)
print(module_path)
if module_path not in sys.path:
    sys.path.append(module_path+"\\functions")

from sqldatabase_langchain_utils import SQLDatabaseLangchainUtils

# %%
SCHEMA = 'mondial_gpt'
PREFIX = 'mondial'
FILE_NAME_RESULT = f"results/6_din_queries_chatgpt4_{SCHEMA}_fk.json"

# %%
def save_queries(queries):
    data = {"queries":queries}
    with open(FILE_NAME_RESULT, "w") as arquivo_json:
        json.dump(data, arquivo_json, indent=4) 
        
def read_queries():
    with open(FILE_NAME_RESULT, encoding='utf-8', errors='ignore') as json_data:
        data = json.load(json_data, strict=False)
    queries = data["queries"]
    return queries

# %% [markdown]
# ## Conexão com o banco

# %%
json_file_path = f"{experiment_path}/datasets/{SCHEMA}_db_connection.json"
with open(json_file_path, encoding='utf-8', errors='ignore') as json_data:
    db_connection = json.load(json_data, strict=False)
db_connection

# %%
db = SQLDatabaseLangchainUtils(db_connection=db_connection)

exclusao = [
    f"{SCHEMA}_tmdp",
    f"{SCHEMA}_tmdpmap",
    f"{SCHEMA}_tmds",
    f"{SCHEMA}_tmjmap",
    f"{SCHEMA}_tpv",
    f"{SCHEMA}_tmdc",
    f"{SCHEMA}_tmdcmap",
    f"{SCHEMA}_tmdej",
    f"{SCHEMA}_log_action",
    f"{SCHEMA}_log_error",
    f"{SCHEMA}_favorite_item", 
    f"{SCHEMA}_favorite_query",
    f"{SCHEMA}_favorite_tag",
    f"{SCHEMA}_favorite_tag_item",
    f"{SCHEMA}_favorite_visualization",
    f"{SCHEMA}_dashboard",
    f"{SCHEMA}_history",
    "teste_cliente",
    "teste_fornecedor",
    "teste_funcionario"
]

include_tables = [s for s in db.get_table_names() if not s.startswith(PREFIX) and s not in exclusao]
db = SQLDatabaseLangchainUtils(db_connection=db_connection, include_tables=include_tables)
db.get_table_names()
# Out:
# c:\Users\rogerrsn\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain\utilities\sql_database.py:112: SAWarning: Did not recognize type 'GEOCOORD' of column 'coordinates'
#   self._metadata.reflect(
# c:\Users\rogerrsn\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain\utilities\sql_database.py:112: SAWarning: Did not recognize type 'GEOCOORD' of column 'source'
#   self._metadata.reflect(
# c:\Users\rogerrsn\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain\utilities\sql_database.py:112: SAWarning: Did not recognize type 'GEOCOORD' of column 'estuary'
#   self._metadata.reflect(
# ['airport',
#  'borders',
#  'city',
#  'citylocalname',
#  'cityothername',
#  'citypops',
#  'continent',
#  'country',
#  'countrylocalname',
#  'countryothername',
#  'countrypops',
#  'desert',
#  'economy',
#  'encompasses',
#  'ethnicgroup',
#  'geo_desert',
#  'geo_estuary',
#  'geo_island',
#  'geo_lake',
#  'geo_mountain',
#  'geo_river',
#  'geo_sea',
#  'geo_source',
#  'island',
#  'islandin',
#  'ismember',
#  'lake',
#  'lakeonisland',
#  'language',
#  'located',
#  'locatedon',
#  'mergeswith',
#  'mountain',
#  'mountainonisland',
#  'organization',
#  'politics',
#  'population',
#  'province',
#  'provincelocalname',
#  'provinceothername',
#  'provpops',
#  'religion',
#  'river',
#  'riveronisland',
#  'riverthrough',
#  'sea']

# %% [markdown]
# ## DIN - Function

# %%
def run_din(question, db, model_name = 'gpt-4', debbug = False, callback=None):
    
    model_kwargs = {'top_p':1.0, 'frequency_penalty':0.0, 'presence_penalty':0.0, 'stop':['Q:']}
    llm = ChatOpenAI(model_name = model_name, temperature=0.0, n=1, max_tokens=600, model_kwargs = model_kwargs)

    model_kwargs['stop'] = ['#', ';','\n\n']
    llm_fix = ChatOpenAI(model_name = model_name, temperature=0.0, n=1, max_tokens=350, model_kwargs = model_kwargs)
    
    schema_links = schema_linking_module(db, llm, question, callback=callback)
   
    classification = classification_module(db, llm, question, schema_links, callback=callback)
    
    SQL = generating_sql_by_type_module(db, llm, question, schema_links, classification, callback=callback)
   
    SQL_FINAL = self_correction_module(db, llm_fix, question, SQL, callback=callback)
    
    if debbug == True:
        print("Schema Links =", schema_links)
        print('Class: ', classification['predicted_class'])
        print('SQL >', SQL)
        print('SQL Final >', SQL_FINAL)
        print()
        print('-------')
    return SQL_FINAL

# %% [markdown]
# ## Preparando as consultas

# %%
json_file_path = f"../../datasets/{PREFIX}/queries_{PREFIX}.json"
with open(json_file_path, encoding='utf-8', errors='ignore') as json_data:
    queries = json.load(json_data, strict=False)
queries = queries['queries']
queries
# Out:
# [{'id': '1',
#   'question': 'What is the area of Thailand?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '2',
#   'question': 'What are the provinces with an area greater than 10000?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '3',
#   'question': 'What are the languages spoken in Poland?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '4',
#   'question': 'How deep is Lake Kariba?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '5',
#   'question': 'What is the total of provinces of Netherlands?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '6',
#   'question': 'What is the percentage of religious people are hindu in thailand?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '7',
#   'question': 'List the number of provinces each river flows through.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '8',
#   'question': 'Find all countries that became independent between 8/1/1910 and 8/1/1950.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '9',
#   'question': 'What are the cities of Cuba?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '10',
#   'question': 'What is the capital of Georgia?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '11',
#   'question': 'How many provinces have areas greater than 1000 in Niger?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '12',
#   'question': 'Tell me about the country with the area largest.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '13',
#   'question': 'What is the host province and year of establishment of the organization "International Energy Agency"?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '14',
#   'question': 'Find the name of all mountains whose elevation is higher than 1000.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '15',
#   'question': 'Tell me the economy of the Caribbean Sea.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '16',
#   'question': 'Show the cities with longitude between 0 and 6.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '17',
#   'question': 'Select cities whose population is greater than 100000, altitude greater than 2500, and the country you belong to has population growth greater than 1.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '18',
#   'question': 'Show all the different types of government.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '19',
#   'question': 'List all provinces in Germany',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '20',
#   'question': 'What is the percentage of mulatto ethnicity in Brazil?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '21',
#   'question': 'How many cities have populations less than 1000?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '22',
#   'question': 'What is the average elevation of airports in America?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '23',
#   'question': 'How many countries are adjacent to (or ecompassed by) the Caribbean Sea?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '24',
#   'question': 'How much area do the countries that are adjacent to (or encompassed by) the Caribbean Sea cover in total?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '25',
#   'question': 'For all countries, give the sum of the population of all its neighbors',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '26',
#   'question': 'What mountains are on the island of Borneo?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '27',
#   'question': 'Provide the name and total population of the country with the smallest area.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '28',
#   'question': 'The codes of all countries for which at least one river that originates in this country has its estuary in a neighboring country.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '29',
#   'question': 'The codes of all countries where at least one mountain is located in each of their provinces',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '30',
#   'question': 'The code and total border lengths of all countries with at least one border.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '31',
#   'question': 'The names and codes of all countries in which at least one river originates.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '32',
#   'question': 'What is the area and country of the Chatanga River?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '33',
#   'question': 'Show the Airports with elevation more than 3000',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '34',
#   'question': 'What are the religions practiced in Mexico?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '35',
#   'question': 'Show all rivers that do not flow into the sea.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '36',
#   'question': 'List African countries by number of neighbors.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '37',
#   'question': 'What is the average infant mortality rate for each continent?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '38',
#   'question': 'What is the average mortality rate of the countries in America without considering Brazil?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '39',
#   'question': 'List seas with area greater than 8000 and depth less than 100.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '40',
#   'question': 'How many mountains are there in Asia?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '41',
#   'question': 'How many countries that are close to the Mediterranean Sea?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '42',
#   'question': 'Show the total for each type of government.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '43',
#   'question': 'Which province has the largest desert in the world?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '44',
#   'question': 'What is the largest desert in the world?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '45',
#   'question': 'List, for all continents, the amount of deserts on each.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '46',
#   'question': 'What are the neighboring seas of the Banda Sea?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '47',
#   'question': 'List all the capitals of European countries.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '48',
#   'question': 'What percentage of people speak French in Andorra?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '49',
#   'question': 'Which rivers are longer than 1000 kilometers?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '50',
#   'question': 'Which country had the lowest population growth?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '51',
#   'question': 'List the name of capital cities for which we do not have data about the city in located',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '52',
#   'question': 'What is the capital of the provice Andaluc�a?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '53',
#   'question': 'What is the abbreviation for the organization whose name is "General Confederation of Trade Unions"?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '54',
#   'question': 'In which city is the organization with the abbreviation "UPU" ?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '55',
#   'question': 'List the names of countries which are members of only one organization',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '56',
#   'question': 'List the name of countries which are not a member of NATO.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '57',
#   'question': 'List the name of countries which are a member of NATO.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '58',
#   'question': 'List the rivers with length less than 50',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '59',
#   'question': 'What are the area, elevation and type of lakes in country Italy?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '60',
#   'question': ' List the names of capital cities which are the base for organizations in alphabetical order',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '61',
#   'question': 'List the name of organizations that do not have countries with an area smaller than 4000 and of the member type',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '62',
#   'question': 'List the name of organizations that do not have countries with  an area greater than 10000 and population smaller than 3000 and of the member type',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '63',
#   'question': 'Show the inflation rate of countries that are washed by the Arabian Sea',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '64',
#   'question': 'List all the capitals of the countries that belong to the continent Africa?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '65',
#   'question': 'Show the inflation rate of the countries bathed by the Arabian Sea and there is no inflation with null value',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '66',
#   'question': 'How many countries are in Africa?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '67',
#   'question': 'List the name of countries that are not members of NATO and UNESCO',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '68',
#   'question': 'What is the area of the continent Europe?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '69',
#   'question': 'What is the area of continent America?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '70',
#   'question': 'What is the area of continent Asia?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '71',
#   'question': 'What is the area of Africa?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '72',
#   'question': 'How many countries are in America?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '73',
#   'question': 'What area is the largest continent?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '74',
#   'question': 'List the countries that belong to the continent with the largest area',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '75',
#   'question': 'List the countries that belong to the continent with the largest area and whose language is English',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '76',
#   'question': 'List the names of cities, along with the name of their country for cities with a population greater than 5 million.  Display the results in descending order by population.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '77',
#   'question': 'Show the name of the deserts in the province of Algeria',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '78',
#   'question': 'Show the name and area of the deserts in the province of California',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '79',
#   'question': 'List the country names and percentage of use of language where  French are used as languages.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '80',
#   'question': 'What are the cities where �Portuguese� is spoken?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '81',
#   'question': 'What is the total area of the provinces in Canada?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '82',
#   'question': 'What is the length of the Tigres River?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '83',
#   'question': 'List the Airports with elevation more than 1000',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '84',
#   'question': 'List airports in the United States with an elevation below 200 feet',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '85',
#   'question': 'What are the mountains with altitudes above 8000 meters?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '86',
#   'question': 'What are the 3 airports with the largest name?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '87',
#   'question': 'List lakes with an area of less than 5000 square kilometers.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '88',
#   'question': 'What is the total area of the seas with a depth greater than 1000 meters?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '89',
#   'question': 'Find the countries whose name starts with the letter "B" and have a population greater than 10 million',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '90',
#   'question': 'List cities with another name in Brazil',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '91',
#   'question': 'List all cities that are at a latitude greater than 45 degrees.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '92',
#   'question': 'Show the number of cities with another name in countries with an area greater than 30000',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '93',
#   'question': 'Show the deserts with area greater than 10000',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '94',
#   'question': 'List the islands that belong to a lake with an elevation greater than 100',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '95',
#   'question': 'List all mountains located on islands with an area greater than 100,000 square kilometers',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '96',
#   'question': 'List the countries and the sum of their provincial areas.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '97',
#   'question': 'Show the name of the countries, the average elevation and sum of the population of their cities',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '98',
#   'question': "What was Germany's inflation?",
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '99',
#   'question': 'What type of government is Iran?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '100',
#   'question': "What is the percentage of industries in relation to Japan's economy?",
#   'query_string': '',
#   'type': 'medium'}]

# %% [markdown]
# ## Tracking token usage

# %%
track_token = [] 
def tracking_token(cb =None, reset = False):
    global track_token
    track_token.append(cb)
    if reset:
        track_token = []

# %%
def convert_to_dict_tracking_token():
    token_usage = {}
    for e in track_token:
        for key in e.keys():
            token_usage[key] = {}
            token_usage[key]['total_tokens'] = e[key].total_tokens
            token_usage[key]['total_cost'] = e[key].total_cost
            token_usage[key]['prompt_tokens'] = e[key].prompt_tokens
            token_usage[key]['completion_tokens'] = e[key].completion_tokens 
    return token_usage

# %% [markdown]
# ## Executando o método

# %%
tracking_token(reset=True)
errors = []
query_index = -1
for instance in queries:
    query_index +=1
    try:
        start_time = time.time()
        sql = run_din(instance["question"], db, debbug=False, callback=tracking_token)
        end_time = time.time()
        instance["query_string"] = sql
        instance["token_usage"] = convert_to_dict_tracking_token()
        instance['time'] = end_time - start_time
        print(instance['id'], instance['question'], instance["query_string"], instance['time'])
        save_queries(queries)
    except:
        print("Error")
        errors.append(query_index)
        pass
    finally:
        tracking_token(reset=True)
        time.sleep(2)

# %%
# tracking_token(reset=True)
# errors = []
# query_index = 0
# count = 0
# queries = read_queries()
# start = 84
# end = len(queries)
# for i in range(start, end):
#     instance = queries[i]
#     try:
#         start_time = time.time()
#         sql = run_din(instance["question"], db, debbug=False, callback=tracking_token)
#         end_time = time.time()
#         instance["query_string"] = sql
#         instance["token_usage"] = convert_to_dict_tracking_token()
#         instance['time'] = end_time - start_time
#         print(instance['id'], instance['question'], instance["query_string"], instance['time'])
#         save_queries(queries)
#     except:
#         print("Error")
#         errors.append(query_index)
#         pass
#     finally:
#         tracking_token(reset=True)
#         time.sleep(2)

# %% [markdown]
# #### Fixing query

# %%
pos = 40
instance = queries[pos]
q = read_queries()
start_time = time.time()
sql = run_din(instance["question"], db, callback=tracking_token)
end_time = time.time()
instance["query_string"] = sql
instance["token_usage"] = convert_to_dict_tracking_token()
instance['time'] = end_time - start_time
q[pos] = instance
save_queries(q)
print(instance['id'], instance['question'], instance["query_string"], instance['time'])

# %%
to_fix = [59,62,72,85,99]
for pos in to_fix:
    instance = queries[pos]
    q = read_queries()
    start_time = time.time()
    sql = run_din(instance["question"], db, callback=tracking_token)
    end_time = time.time()
    instance["query_string"] = sql
    instance["token_usage"] = convert_to_dict_tracking_token()
    instance['time'] = end_time - start_time
    q[pos] = instance
    save_queries(q)
    print(instance['id'], instance['question'], instance["query_string"], instance['time'])
# Out:
# -- Classification --
# generations=[[ChatGeneration(text='The SQL query for the question "List the names of capital cities which are the base for organizations in alphabetical order" needs these tables = [city, organization], so we need JOIN.\nPlus, it doesn\'t require nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = [""].\nSo, we need JOIN and don\'t need nested queries, then the the SQL query can be classified as "NON-NESTED".\nLabel: "NON-NESTED"', generation_info={'finish_reason': 'stop'}, message=AIMessage(content='The SQL query for the question "List the names of capital cities which are the base for organizations in alphabetical order" needs these tables = [city, organization], so we need JOIN.\nPlus, it doesn\'t require nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = [""].\nSo, we need JOIN and don\'t need nested queries, then the the SQL query can be classified as "NON-NESTED".\nLabel: "NON-NESTED"', additional_kwargs={}, example=False))]] llm_output={'token_usage': {'prompt_tokens': 3592, 'completion_tokens': 110, 'total_tokens': 3702}, 'model_name': 'gpt-4'} run=[RunInfo(run_id=UUID('2ebc2da3-4cf7-4bec-ab58-59f0398ddcbe'))]
# NON-NESTED
# SELECT DISTINCT T1.name FROM city T1 JOIN organization T2 ON T1.name = T2.city ORDER BY T1.name ASC
# 60  List the names of capital cities which are the base for organizations in alphabetical order SELECT DISTINCT T1.name  FROM city T1  JOIN organization T2  ON T1.name = T2.city  WHERE T1.name = T1.capital ORDER BY T1.name ASC 35.24527978897095
# -- Classification --
# generations=[[ChatGeneration(text='The SQL query for the question "Show the inflation rate of countries that are washed by the Arabian Sea" needs these tables = [economy, geo_sea], so we need JOIN.\nPlus, it doesn\'t require nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = [""].\nSo, we need JOIN and don\'t need nested queries, then the the SQL query can be classified as "NON-NESTED".\nLabel: "NON-NESTED"', generation_info={'finish_reason': 'stop'}, message=AIMessage(content='The SQL query for the question "Show the inflation rate of countries that are washed by the Arabian Sea" needs these tables = [economy, geo_sea], so we need JOIN.\nPlus, it doesn\'t require nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = [""].\nSo, we need JOIN and don\'t need nested queries, then the the SQL query can be classified as "NON-NESTED".\nLabel: "NON-NESTED"', additional_kwargs={}, example=False))]] llm_output={'token_usage': {'prompt_tokens': 3604, 'completion_tokens': 111, 'total_tokens': 3715}, 'model_name': 'gpt-4'} run=[RunInfo(run_id=UUID('9bfb06ce-b58e-49f9-98c3-c8b1c2763552'))]
# NON-NESTED
# SELECT T1.inflation FROM economy T1 JOIN geo_sea T2 ON T1.country = T2.country WHERE T2.sea = 'Arabian Sea'
# 63 Show the inflation rate of countries that are washed by the Arabian Sea SELECT T1.inflation  FROM  economy T1  JOIN  geo_sea T2  ON  T1.country = T2.country  WHERE  T2.sea = 'Arabian Sea' 30.1931369304657
# -- Classification --
# generations=[[ChatGeneration(text='The SQL query for the question "What area is the largest continent?" needs these tables = [continent], so we don\'t need JOIN.\nPlus, it doesn\'t require nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = [""].\nSo, we don\'t need JOIN and don\'t need nested queries, then the the SQL query can be classified as "EASY".\nLabel: "EASY"', generation_info={'finish_reason': 'stop'}, message=AIMessage(content='The SQL query for the question "What area is the largest continent?" needs these tables = [continent], so we don\'t need JOIN.\nPlus, it doesn\'t require nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = [""].\nSo, we don\'t need JOIN and don\'t need nested queries, then the the SQL query can be classified as "EASY".\nLabel: "EASY"', additional_kwargs={}, example=False))]] llm_output={'token_usage': {'prompt_tokens': 3579, 'completion_tokens': 97, 'total_tokens': 3676}, 'model_name': 'gpt-4'} run=[RunInfo(run_id=UUID('bb7db796-63ed-4830-b0fd-a52578e0751a'))]
# EASY
# SELECT name FROM continent ORDER BY area DESC FETCH FIRST 1 ROWS ONLY
# 73 What area is the largest continent? SELECT name  FROM  continent  ORDER BY  area DESC  FETCH FIRST 1 ROWS ONLY 21.583374500274658
# -- Classification --
# generations=[[ChatGeneration(text='The SQL query for the question "What are the 3 airports with the largest name?" needs these tables = [airport], so we don\'t need JOIN.\nPlus, it doesn\'t require nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = [""].\nSo, we don\'t need JOIN and don\'t need nested queries, then the the SQL query can be classified as "EASY".\nLabel: "EASY"', generation_info={'finish_reason': 'stop'}, message=AIMessage(content='The SQL query for the question "What are the 3 airports with the largest name?" needs these tables = [airport], so we don\'t need JOIN.\nPlus, it doesn\'t require nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = [""].\nSo, we don\'t need JOIN and don\'t need nested queries, then the the SQL query can be classified as "EASY".\nLabel: "EASY"', additional_kwargs={}, example=False))]] llm_output={'token_usage': {'prompt_tokens': 3582, 'completion_tokens': 101, 'total_tokens': 3683}, 'model_name': 'gpt-4'} run=[RunInfo(run_id=UUID('5b8ed7fa-3339-4c56-8674-4b9066115223'))]
# EASY
# SELECT name FROM airport ORDER BY LENGTH(name) DESC FETCH FIRST 3 ROWS ONLY
# 86 What are the 3 airports with the largest name? SELECT name  FROM airport  ORDER BY LENGTH(name) DESC  FETCH FIRST 3 ROWS ONLY 16.889836072921753
# -- Classification --
# generations=[[ChatGeneration(text='The SQL query for the question "What is the percentage of industries in relation to Japan\'s economy?" needs these tables = [economy], so we don\'t need JOIN.\nPlus, it doesn\'t require nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = [""].\nSo, we don\'t need JOIN and don\'t need nested queries, then the the SQL query can be classified as "EASY".\nLabel: "EASY"', generation_info={'finish_reason': 'stop'}, message=AIMessage(content='The SQL query for the question "What is the percentage of industries in relation to Japan\'s economy?" needs these tables = [economy], so we don\'t need JOIN.\nPlus, it doesn\'t require nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = [""].\nSo, we don\'t need JOIN and don\'t need nested queries, then the the SQL query can be classified as "EASY".\nLabel: "EASY"', additional_kwargs={}, example=False))]] llm_output={'token_usage': {'prompt_tokens': 3589, 'completion_tokens': 104, 'total_tokens': 3693}, 'model_name': 'gpt-4'} run=[RunInfo(run_id=UUID('22222622-9e0c-49d2-917f-62b3f159ca5f'))]
# EASY
# SELECT industry FROM economy WHERE country = 'Japan'
# 100 What is the percentage of industries in relation to Japan's economy? SELECT industry  FROM  economy  WHERE  country = (SELECT code FROM country WHERE name = 'Japan') 18.88984751701355

# %%
errors
# Out:
# []

# %%
# queries = read_queries()
# errors = []
# query_index = 22
# for i in range(query_index, len(queries)):
#     instance = queries[i]
#     query_index +=1
#     try:
#         sql = run_din(instance["question"], db, debbug=True)
#         instance["query_string"] = sql
#         save_queries(queries)
#         print(instance["id"], instance["question"], sql)
#         time.sleep(5)
#     except:
#         print("Error")
#         errors.append(query_index)
#         pass

# %%
queries
# Out:
# [{'id': '1',
#   'question': 'What is the area of Thailand?',
#   'query_string': "SELECT area  FROM  mondial_country  WHERE  name = 'Thailand'",
#   'type': 'simple'},
#  {'id': '2',
#   'question': 'What are the provinces with an area more than 10000?',
#   'query_string': 'SELECT name  FROM  mondial_province  WHERE  area > 10000',
#   'type': 'simple'},
#  {'id': '3',
#   'question': 'What are the languages spoken in Poland?',
#   'query_string': "SELECT name  FROM  mondial_language  WHERE  country = 'Poland'",
#   'type': 'medium'},
#  {'id': '4',
#   'question': 'How deep is Lake Kariba?',
#   'query_string': "SELECT depth  FROM  mondial_lake  WHERE  name = 'Lake Kariba'",
#   'type': 'simple'},
#  {'id': '5',
#   'question': 'What is the total of provinces of Netherlands?',
#   'query_string': "SELECT COUNT(DISTINCT province)  FROM mondial_province  WHERE country = 'Netherlands'",
#   'type': 'medium'},
#  {'id': '6',
#   'question': 'What percentage of religious people are hindu in thailand?',
#   'query_string': "SELECT percentage  FROM  mondial_religion  WHERE  country = 'Thailand'  AND  name = 'Hindu'",
#   'type': 'medium'},
#  {'id': '7',
#   'question': 'List the number of provinces each river flows through.',
#   'query_string': 'SELECT river, COUNT(DISTINCT province)  FROM mondial_geo_river  GROUP BY river',
#   'type': 'complex'},
#  {'id': '8',
#   'question': 'Find all countries that became independent between 8/1/1910 and 8/1/1950.',
#   'query_string': "SELECT T1.name  FROM mondial_country T1  JOIN mondial_politics T2  ON T1.code = T2.country  WHERE T2.independence BETWEEN '1910-08-01' AND '1950-08-01'",
#   'type': 'medium'},
#  {'id': '9',
#   'question': 'Tell me about cities of Cuba',
#   'query_string': "SELECT *  FROM mondial_city  WHERE country = 'Cuba'",
#   'type': 'medium'},
#  {'id': '10',
#   'question': 'What is the capital of Georgia?',
#   'query_string': "SELECT capital  FROM  mondial_country  WHERE  name = 'Georgia'",
#   'type': 'simple'},
#  {'id': '11',
#   'question': 'How many provinces have areas greater than 1000 in Niger?',
#   'query_string': "SELECT COUNT(*)  FROM  mondial_province  WHERE  country = 'Niger'  AND  area > 1000",
#   'type': 'medium'},
#  {'id': '12',
#   'question': 'Tell me about the country with the area largest.',
#   'query_string': 'SELECT *  FROM mondial_country  ORDER BY area DESC  LIMIT 1',
#   'type': 'medium'},
#  {'id': '13',
#   'question': 'What is the host province and year of establishment of the organization "International Energy Agency"?',
#   'query_string': "SELECT province, established  FROM  mondial_organization  WHERE  name = 'International Energy Agency'",
#   'type': 'simple'},
#  {'id': '14',
#   'question': 'Find the name of all mountains whose elevation is higher than 1000.',
#   'query_string': 'SELECT name  FROM  mondial_mountain  WHERE  elevation > 1000',
#   'type': 'simple'},
#  {'id': '15',
#   'question': 'Tell me about the economy of the Caribbean Sea.',
#   'query_string': "SELECT *  FROM mondial_economy  WHERE country IN (     SELECT country      FROM mondial_geo_sea      WHERE sea = 'Caribbean Sea' )",
#   'type': 'complex'},
#  {'id': '16',
#   'question': 'Shows me cities with longitude between 0 and 6.',
#   'query_string': 'SELECT name  FROM  mondial_city  WHERE  longitude BETWEEN 0 AND 6',
#   'type': 'simple'},
#  {'id': '17',
#   'question': 'Select cities whose population is greater than 100000, altitude greater than 2500, and the country you belong to has population growth greater than 1.',
#   'query_string': 'SELECT T1.name  FROM  mondial_city T1  JOIN  mondial_population T2  ON  T1.country = T2.country  WHERE  T1.population > 100000  AND  T1.elevation > 2500  AND  T2.population_growth > 1',
#   'type': 'complex'},
#  {'id': '18',
#   'question': 'Show all the different types of government.',
#   'query_string': 'SELECT DISTINCT government  FROM mondial_politics',
#   'type': 'simple'},
#  {'id': '19',
#   'question': 'List all provinces in Germany',
#   'query_string': "SELECT DISTINCT province  FROM  mondial_city  WHERE  country = 'Germany'",
#   'type': 'medium'},
#  {'id': '20',
#   'question': 'What is the percentage of mulatto ethnicity in Brazil?',
#   'query_string': "SELECT percentage  FROM  mondial_ethnicgroup  WHERE  country = 'Brazil'  AND  name = 'Mulatto'",
#   'type': 'medium'},
#  {'id': '21',
#   'question': 'How many cities have populations less than 1000?',
#   'query_string': 'SELECT COUNT(*)  FROM  mondial_city  WHERE  population < 1000',
#   'type': 'simple'},
#  {'id': '22',
#   'question': 'What is the average elevation of airports in America?',
#   'query_string': "SELECT AVG(elevation)  FROM  mondial_airport  WHERE  country = 'USA'",
#   'type': 'complex'},
#  {'id': '23',
#   'question': 'How many countries are adjacent to (or ecompassed by) the the Caribbean Sea?',
#   'query_string': "SELECT count(distinct country)  FROM mondial_geo_sea  WHERE sea = 'Caribbean Sea'",
#   'type': 'medium'},
#  {'id': '24',
#   'question': 'How much area do the countries that are adjacent to (or encompassed by) the Caribbean Sea cover in total?',
#   'query_string': "SELECT sum(area)  FROM mondial_country  WHERE name IN (     SELECT country      FROM mondial_geo_sea      WHERE sea = 'Caribbean Sea' )",
#   'type': 'complex'},
#  {'id': '25',
#   'question': 'For all countries, give the sum of the population of all its neighbors',
#   'query_string': 'SELECT T1.name, sum(T2.population)  FROM  mondial_country T1  JOIN  mondial_country T2  ON  T1.code = T2.code  GROUP BY  T1.name',
#   'type': 'complex'},
#  {'id': '26',
#   'question': 'What mountains are on the island of Borneo?',
#   'query_string': "SELECT name  FROM  mondial_mountainonisland  WHERE  island = 'Borneo'",
#   'type': 'simple'},
#  {'id': '27',
#   'question': 'Provide the name and total population of the country with the smallest area.',
#   'query_string': 'SELECT name, population  FROM  mondial_country  WHERE  area = (SELECT MIN(area) FROM mondial_country)',
#   'type': 'simple'},
#  {'id': '28',
#   'question': 'The codes of all countries for which at least one river that originates in this country has its estuary in a neighboring country.',
#   'query_string': 'SELECT T1.code  FROM mondial_country T1  JOIN mondial_geo_river T2 ON T1.code = T2.country  WHERE T2.estuary IN (SELECT country2 FROM mondial_borders WHERE country1 = T1.code)',
#   'type': 'complex'},
#  {'id': '29',
#   'question': 'The codes of all countries where at least one mountain is located in each of their provinces',
#   'query_string': 'SELECT T1.code  FROM  mondial_country T1  WHERE  NOT EXISTS (     SELECT *      FROM mondial_province T2      WHERE      T1.code = T2.country      AND NOT EXISTS (         SELECT *          FROM mondial_geo_mountain T3          WHERE          T2.name = T3.province          AND T1.code = T3.country     ) )',
#   'type': 'complex'},
#  {'id': '30',
#   'question': 'The code and total border lengths of all countries with at least one border.',
#   'query_string': 'SELECT T1.code, sum(T2.length)  FROM mondial_country T1  JOIN mondial_borders T2  ON T1.code = T2.country1  WHERE T2.length >= 1  GROUP BY T1.code',
#   'type': 'complex'},
#  {'id': '31',
#   'question': 'The names and codes of all countries in which at least one river originates.',
#   'query_string': 'SELECT name, code  FROM mondial_country  WHERE EXISTS (SELECT * FROM mondial_geo_source WHERE country = code)',
#   'type': 'medium'},
#  {'id': '32',
#   'question': 'What is the area and country of the Chatanga River?',
#   'query_string': "SELECT area, country  FROM  mondial_river  WHERE  name = 'Chatanga River'",
#   'type': 'complex'},
#  {'id': '33',
#   'question': 'Shows me Airports with elevation more than 3000',
#   'query_string': 'SELECT name  FROM  mondial_airport  WHERE  elevation > 3000',
#   'type': 'simple'},
#  {'id': '34',
#   'question': 'What religions are practiced in Mexico?',
#   'query_string': "SELECT name  FROM  mondial_religion  WHERE  country = 'Mexico'",
#   'type': 'medium'},
#  {'id': '35',
#   'question': 'Show all rivers that do not flow into the sea.',
#   'query_string': 'SELECT name  FROM  mondial_river  WHERE  sea IS NULL',
#   'type': 'simple'},
#  {'id': '36',
#   'question': 'List African countries by number of neighbors.',
#   'query_string': "SELECT T1.name, COUNT(T2.country2)  FROM mondial_country T1  JOIN mondial_borders T2  ON T1.code = T2.country1  WHERE T1.name IN (SELECT name FROM mondial_country WHERE code IN (SELECT country FROM mondial_encompasses WHERE continent = 'Africa'))  GROUP BY T1.name  ORDER BY COUNT(T2.country2) DESC",
#   'type': 'complex'},
#  {'id': '37',
#   'question': 'What is the average infant mortality rate for each continent?',
#   'query_string': 'SELECT avg(T1.infant_mortality), T2.continent  FROM mondial_population T1  JOIN mondial_encompasses T2  ON T1.country = T2.country  GROUP BY T2.continent',
#   'type': 'complex'},
#  {'id': '38',
#   'question': 'What is the average mortality rate of the countries in America without considering Brazil?',
#   'query_string': "SELECT AVG(T1.infant_mortality)  FROM mondial_population T1  JOIN mondial_encompasses T2 ON T1.country = T2.country  WHERE T2.continent = 'America' AND T1.country != 'Brazil'",
#   'type': 'complex'},
#  {'id': '39',
#   'question': 'List seas with area greater than 8000 and depth less than 100.',
#   'query_string': 'SELECT name  FROM  mondial_sea  WHERE  area > 8000  AND  depth < 100',
#   'type': 'simple'},
#  {'id': '40',
#   'question': 'How many mountains are there in Asia?',
#   'query_string': "SELECT COUNT(*)  FROM  mondial_geo_mountain  JOIN  mondial_encompasses  ON  mondial_geo_mountain.country = mondial_encompasses.country  WHERE  mondial_encompasses.continent = 'Asia'",
#   'type': 'complex'},
#  {'id': '41',
#   'question': 'What are the countries that are close to the Mediterranean Sea?',
#   'query_string': "SELECT DISTINCT country  FROM mondial_geo_sea  WHERE sea = 'Mediterranean Sea'",
#   'type': 'complex'},
#  {'id': '42',
#   'question': 'Show the total for each type of government.',
#   'query_string': 'SELECT government, COUNT(*)  FROM mondial_politics  GROUP BY government',
#   'type': 'medium'},
#  {'id': '43',
#   'question': 'Which province has the largest desert in the world?',
#   'query_string': 'SELECT province  FROM mondial_geo_desert  JOIN mondial_desert  ON mondial_geo_desert.desert = mondial_desert.name  ORDER BY mondial_desert.area DESC  LIMIT 1',
#   'type': 'medium'},
#  {'id': '44',
#   'question': 'What is the largest desert in the world?',
#   'query_string': 'SELECT name  FROM  mondial_desert  ORDER BY  area DESC  LIMIT 1',
#   'type': 'simple'},
#  {'id': '45',
#   'question': 'List, for all continents, the amount of deserts on each.',
#   'query_string': 'SELECT T1.name, COUNT(T2.desert) FROM mondial_continent T1 JOIN mondial_encompasses T3 ON T1.name = T3.continent JOIN mondial_geo_desert T2 ON T3.country = T2.country GROUP BY T1.name',
#   'type': 'complex'},
#  {'id': '46',
#   'question': 'What are the neighboring seas of the Banda Sea?',
#   'query_string': "SELECT sea2  FROM  mondial_mergeswith  WHERE  sea1 = 'Banda Sea'",
#   'type': 'simple'},
#  {'id': '47',
#   'question': 'List all the capitals of European countries.',
#   'query_string': "SELECT T1.capital  FROM  mondial_country T1  JOIN  mondial_encompasses T2  ON  T1.code = T2.country  WHERE  T2.continent = 'Europe'",
#   'type': 'complex'},
#  {'id': '48',
#   'question': 'What percentage of people speak French in Andorra?',
#   'query_string': "SELECT percentage  FROM  mondial_language  WHERE  country = 'Andorra'  AND  name = 'French'",
#   'type': 'medium'},
#  {'id': '49',
#   'question': 'Which rivers are longer than 1000 kilometers?',
#   'query_string': 'SELECT name  FROM  mondial_river  WHERE  length > 1000',
#   'type': 'simple'},
#  {'id': '50',
#   'question': 'Which country had the lowest population growth?',
#   'query_string': 'SELECT country  FROM mondial_population  ORDER BY population_growth ASC  LIMIT 1',
#   'type': 'medium'}]

# %% [markdown]
# ## Testando o DIN para uma consulta sem FK no Mondial

# %% [markdown]
# ### LLM

# %%
model_name = 'gpt-4'

question = ""

model_kwargs = {'top_p':1.0, 'frequency_penalty':0.0, 'presence_penalty':0.0, 'stop':['Q:']}
llm = ChatOpenAI(model_name = model_name, temperature=0.0, n=1, max_tokens=600, model_kwargs = model_kwargs)

model_kwargs['stop'] = ['#', ';','\n\n']
llm_fix = ChatOpenAI(model_name = model_name, temperature=0.0, n=1, max_tokens=350, model_kwargs = model_kwargs)

# %% [markdown]
# ### Schema Linking

# %%
schema_links = schema_linking_module(db, llm, question)
print("Schema Links =", schema_links)
# Out:
# Schema Links = [mondial_country.area]

# %% [markdown]
# ### Classification

# %%
classification = classification_module(db, llm, question, schema_links)
print(classification)
# Out:
# {'predicted_class': '"EASY"', 'classification_label': 'The SQL query for the question "What is the area of Thailand?" needs the table [mondial_country], so we don\'t need JOIN.\nPlus, it doesn\'t require nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = [""].\nSo, we don\'t need JOIN and don\'t need nested queries, then the SQL query can be classified as "EASY".\nLabel: "EASY"'}

# %% [markdown]
# ### Generate SQL

# %%
SQL = generating_sql_by_type_module(db, llm, question, schema_links, classification)
print(SQL)
# Out:
# SELECT area FROM mondial_country WHERE name = 'Thailand'
# SELECT area FROM mondial_country WHERE name = 'Thailand'

# %% [markdown]
# ### Self-Correction

# %%
SQL_FINAL = self_correction_module(db, llm, question, SQL)
print(SQL_FINAL)
# Out:
# SELECT area FROM mondial_country WHERE name = 'Thailand'
# SELECT area FROM mondial_country WHERE name = 'Thailand'
