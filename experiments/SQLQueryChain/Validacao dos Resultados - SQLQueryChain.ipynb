# %%
from dotenv import load_dotenv
import os
import sys
import json
import pandas as pd
import time
import datetime
load_dotenv()

path = os.path.abspath('')
module_path = os.path.join(path,'..\..')
print(module_path)
if module_path not in sys.path:
    sys.path.append(module_path+"\\functions")


from dataset_utils import DatasetEvaluator

# %%
DEFAULT_PATH = "results/"
EXPERIMENT_RESULT_PATH = f"{DEFAULT_PATH}sql_query_chain_result_files.txt"
EXPERIMENT = "SQLQueryChain"
TARGET_PATH = f"evaluator_results/{EXPERIMENT}_results.csv"
TARGET_PATH_FK = f"evaluator_results/{EXPERIMENT}_foreign_key_results.csv"

# %% [markdown]
# Funções úteis

# %%
def save_queries(queries, FILE_NAME_PATH):
    data = {"queries":queries}
    with open(FILE_NAME_PATH, "w") as arquivo_json:
        json.dump(data, arquivo_json, indent=4) 

def read_queries(FILE_NAME_PATH):
    with open(FILE_NAME_PATH, encoding="utf-8", errors="ignore") as json_data:
        data = json.load(json_data, strict=False)
    queries = data["queries"]
    return queries

def read_files():
    with open(EXPERIMENT_RESULT_PATH, "r") as f:
        files = f.readlines()
    files = [f"{DEFAULT_PATH}{x.strip()}" for x in files]
    return files

def get_schema(FILE_NAME_PATH):
    if "mondial_gpt" in FILE_NAME_PATH:
        return "mondial_gpt"
    elif "mondial" in FILE_NAME_PATH:
        return "mondial"

    return ""

def get_count_query_type(queries):
    count_types = {}
    for item in queries:
        type = item["type"]
        if type in count_types:
            count_types[type] += 1
        else:
            count_types[type] = 1
    count_types['total'] = len(queries)
    return count_types

def get_dataset_evaluator(FILE_NAME_PATH):
    SCHEMA = get_schema(FILE_NAME_PATH)  
    PREFIX = SCHEMA  
    if SCHEMA == "mondial_gpt":
        PREFIX = "mondial"
    print(PREFIX)
    print(SCHEMA)
    dataset_eval = DatasetEvaluator(dataset_file_path=f"../../datasets/{PREFIX}/{PREFIX}_dataset.json",
                                dataset_tables_path=f"../../datasets/{PREFIX}/result_tables/",
                                db_connection_file=f"../../datasets/{SCHEMA}_db_connection.json",
                                dataset_name=SCHEMA)
    return dataset_eval

def get_files_in_folder():
    files = []
    for r, d, f in os.walk(DEFAULT_PATH):
        for file in f:
            if '.json' in file and 'erro' not in file:
                files.append(os.path.join(r, file))
    return sorted(files)

def evaluate_query(queries, dataset_eval, FILE_NAME_PATH):
    result = {'simple': 0, 'medium': 0, 'complex': 0, 'total': 0}

    for q in queries:
        evaluate_result = False
        q['similarity'] = 0
        try:
            if q["query_string"].strip() != "":
                evaluate_result, similarity, column_matching_index = dataset_eval.evaluate_dataset_query(q["query_string"], q["id"], query_type="sql")
                q['column_matching_index'] = column_matching_index
                q['similarity']=similarity
            
        except Exception as e:
            print(str(e))
            
        q['result'] = evaluate_result
        
        if evaluate_result==True:
            result['total'] += 1
            result[q["type"]] += 1
        
    save_queries(queries, FILE_NAME_PATH)   
    return result

def get_file_name(FILE_NAME_PATH):
    parts = FILE_NAME_PATH.split("/")
    last_element = parts[-1]
    file_name = last_element.replace(".json", "")
    return file_name

def get_experiment_name(filename):
    schema = get_schema(filename).upper()
    experiment_name = f"{EXPERIMENT} - {schema}"
    if "chatgpt4" in filename:
        experiment_name += " - GPT-4"
    elif "chatgpt_" in filename:
        experiment_name += " - GPT-3.5"
    elif "llama" in filename:
        experiment_name += " - LLAMA"
    
    if "rag" in filename:
        experiment_name += " - RAG"
        
    if "turbo" in filename:
        experiment_name += " - Turbo"
                        
    if "instances" in filename:
        experiment_name += " - Passing database instances"
        
    if "_fk" in filename:
        experiment_name += " - FK"
        
    return experiment_name


def compute_cost(filename):
    queries = read_queries(filename)
    total_costs = 0
    total_tokens = 0
    input_tokens = 0
    output_tokens = 0
    for q in queries:
        total_tokens += q.get('total_tokens', 0)
        total_costs += q.get('total_cost', 0)
        input_tokens += q.get('prompt_tokens', 0)
        output_tokens += q.get('completion_tokens', 0)

    print(total_tokens)
    print(round(total_costs, 2))
    print(input_tokens, output_tokens)
    return total_tokens, round(total_costs, 2), input_tokens, output_tokens

def compute_time(filename):
    queries = read_queries(filename)
    total_time = 0
    for q in queries:
        total_time += q.get('time', 0)
    print(total_time)
    return str(datetime.timedelta(seconds=round(total_time)))

# %%
def run(result_files = [], result_final = [], compute_costs = True):
    
    if result_files == [] :
        result_files = get_files_in_folder()
    else:
        result_files = sorted(result_files)
        
    
    for file in result_files:
        queries = read_queries(file)
        dataset_eval = get_dataset_evaluator(file)
        count_query_type = get_count_query_type(queries)
        result = evaluate_query(queries, dataset_eval, file)
        
        overall_by_type = {}
        for item in result:
            overall_by_type[f"overall_{item}"] = round(result[item] / count_query_type[item], 4)
        
        result['experiment'] = get_file_name(file)
        result = {**result, **overall_by_type}
        result['total_tokens'], result['total_cost'], result['average_tokens_by_query'] = 0, 0, 0
        if compute_costs:
            result['total_tokens'], result['total_cost'], result['input_tokens'], result['output_tokens'] = compute_cost(file)

        result['total_time'] = compute_time(file)
        
        result_final.append(result)
        time.sleep(5)
    return result_final

# %% [markdown]
# ## Validação com o mondial - Foreign Keys

# %%
results_fk = run([ 'results/9_sql_queries_chatgpt_mondial_gpt_fk.json',
 'results/10_sql_queries_chatgpt_mondial_gpt_fk_instances.json',
 'results/11_sql_queries_chatgpt4_mondial_gpt_fk_instances.json',
 'results/12_sql_queries_chatgpt4_mondial_gpt_fk.json'], [])
# Out:
# mondial
# mondial_gpt
# SELECT max(area) FROM mondial_country where name  = 'Thailand'
# SELECT area FROM country WHERE name = 'Thailand'
# True cols: Index(['MAX(AREA)'], dtype='object')
# Adj. True cols: Index(['MAX(AREA)'], dtype='object')
# Predicted cols: Index(['AREA'], dtype='object')
# Adj. Predicted cols: Index(['AREA'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name FROM mondial_province where area > 10000
# SELECT name
# FROM province
# WHERE area > 10000
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT mondial_language.name FROM mondial_language INNER JOIN mondial_country ON mondial_language.country = mondial_country.code WHERE mondial_country.name = 'Poland'
# SELECT name
# FROM language
# WHERE country = 'PL'
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT depth FROM mondial_lake where name LIKE '%Lake Kariba%'
# SELECT depth FROM lake WHERE name = 'Lake Kariba'
# True cols: Index(['DEPTH'], dtype='object')
# Adj. True cols: Index(['DEPTH'], dtype='object')
# Predicted cols: Index(['DEPTH'], dtype='object')
# Adj. Predicted cols: Index(['DEPTH'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT count(*) FROM mondial_province p INNER JOIN mondial_country c ON p.country = c.code WHERE c.name = 'Netherlands'
# SELECT COUNT(*) FROM province WHERE country = 'NL'
# True cols: Index(['COUNT(*)'], dtype='object')
# Adj. True cols: Index(['COUNT(*)'], dtype='object')
# Predicted cols: Index(['COUNT(*)'], dtype='object')
# Adj. Predicted cols: Index(['COUNT(*)'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT r.percentage FROM mondial_religion r INNER JOIN mondial_country c ON r.country = c.code WHERE c.name = 'Thailand' AND r.name LIKE '%Hindu%'
# SELECT percentage
# FROM religion
# WHERE country = 'TH' AND name = 'Hindu'
# True cols: Index(['PERCENTAGE'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['PERCENTAGE'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT river.name, COUNT(DISTINCT geo_river.province) FROM river JOIN geo_river ON river.name = geo_river.river GROUP BY river.name
# SELECT r.name, COUNT(DISTINCT rt.province) AS num_provinces
# FROM river r
# JOIN riverthrough rt ON r.name = rt.river
# GROUP BY r.name
# Error: Execution failed on sql 'SELECT r.name, COUNT(DISTINCT rt.province) AS num_provinces
# FROM river r
# JOIN riverthrough rt ON r.name = rt.river
# GROUP BY r.name': ORA-00904: "RT"."PROVINCE": invalid identifier
# SELECT c.name FROM mondial_country c
# INNER JOIN mondial_politics p ON c.code = p.country
# WHERE independence > DATE '1910-08-01' AND independence < DATE '1950-08-01'
# SELECT name
# FROM politics
# WHERE independence BETWEEN TO_DATE('8/1/1910', 'MM/DD/YYYY') AND TO_DATE('8/1/1950', 'MM/DD/YYYY')
# Error: Execution failed on sql 'SELECT name
# FROM politics
# WHERE independence BETWEEN TO_DATE('8/1/1910', 'MM/DD/YYYY') AND TO_DATE('8/1/1950', 'MM/DD/YYYY')': ORA-00904: "NAME": invalid identifier
# SELECT * FROM mondial_city ci INNER JOIN mondial_country c on ci.country = c.code where c.name = 'Cuba'
# SELECT name
# FROM city
# WHERE country = 'CUB'
# True cols: Index(['NAME', 'COUNTRY', 'PROVINCE', 'POPULATION', 'LATITUDE', 'LONGITUDE',
#        'ELEVATION', 'META_REPCOL', 'NAME', 'CODE', 'CAPITAL', 'PROVINCE',
#        'AREA', 'POPULATION', 'META_REPCOL'],
#       dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT capital FROM mondial_country WHERE name = 'Georgia'
# SELECT capital FROM country WHERE name = 'Georgia'
# True cols: Index(['CAPITAL'], dtype='object')
# Adj. True cols: Index(['CAPITAL'], dtype='object')
# Predicted cols: Index(['CAPITAL'], dtype='object')
# Adj. Predicted cols: Index(['CAPITAL'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT count(p.name) FROM mondial_province p INNER JOIN mondial_country c on p.country = c.code where c.name = 'Niger' AND p.area > 1000
# SELECT COUNT(*) FROM province WHERE country = 'NER' AND area > 1000
# True cols: Index(['COUNT(P.NAME)'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['COUNT(*)'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT name FROM mondial_country GROUP BY name ORDER BY max(area) DESC FETCH FIRST 1 ROWS ONLY;
# SELECT name, area
# FROM country
# ORDER BY area DESC
# FETCH FIRST 1 ROWS ONLY
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME', 'AREA'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT o.province, o.established  FROM mondial_organization o WHERE o.name LIKE '%International Energy Agency%'
# SELECT province, established
# FROM organization
# WHERE name = 'International Energy Agency'
# True cols: Index(['PROVINCE', 'ESTABLISHED'], dtype='object')
# Adj. True cols: Index(['PROVINCE', 'ESTABLISHED'], dtype='object')
# Predicted cols: Index(['PROVINCE', 'ESTABLISHED'], dtype='object')
# Adj. Predicted cols: Index(['PROVINCE', 'ESTABLISHED'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name FROM mondial_mountain WHERE elevation > 1000.0
# SELECT name
# FROM mountain
# WHERE elevation > 1000
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT DISTINCT e.* FROM mondial_economy e
# INNER JOIN mondial_country c ON e.country = c.code
# INNER JOIN mondial_geo_sea gs ON gs.country = c.code
# INNER JOIN mondial_sea s ON s.name = gs.sea
# WHERE s.name LIKE '%Caribbean Sea%'
# SELECT e.gdp, e.agriculture, e.service, e.industry, e.inflation, e.unemployment
# FROM economy e
# JOIN sea s ON e.country = s.name
# WHERE s.name = 'Caribbean Sea'
# True cols: Index(['COUNTRY', 'GDP', 'AGRICULTURE', 'SERVICE', 'INDUSTRY', 'INFLATION',
#        'UNEMPLOYMENT', 'META_REPCOL'],
#       dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['GDP', 'AGRICULTURE', 'SERVICE', 'INDUSTRY', 'INFLATION',
#        'UNEMPLOYMENT'],
#       dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT name FROM mondial_city WHERE longitude BETWEEN 0 AND 6
# SELECT name, longitude
# FROM city
# WHERE longitude BETWEEN 0 AND 6
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME', 'LONGITUDE'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT ci.name FROM mondial_city ci
# INNER JOIN mondial_country c ON c.code = ci.country
# INNER JOIN mondial_population p ON p.country = c.code
# WHERE ci.population > 100000 AND ci.elevation > 2500 AND
# p.population_growth > 1
# SELECT city.name, city.population, city.elevation, country.population_growth
# FROM city
# JOIN country ON city.country = country.code
# WHERE city.population > 100000
# AND city.elevation > 2500
# AND country.population_growth > 1
# Error: Execution failed on sql 'SELECT city.name, city.population, city.elevation, country.population_growth
# FROM city
# JOIN country ON city.country = country.code
# WHERE city.population > 100000
# AND city.elevation > 2500
# AND country.population_growth > 1': ORA-00904: "COUNTRY"."POPULATION_GROWTH": invalid identifier
# SELECT DISTINCT government FROM mondial_politics
# SELECT DISTINCT government FROM politics
# True cols: Index(['GOVERNMENT'], dtype='object')
# Adj. True cols: Index(['GOVERNMENT'], dtype='object')
# Predicted cols: Index(['GOVERNMENT'], dtype='object')
# Adj. Predicted cols: Index(['GOVERNMENT'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT p.name FROM mondial_province p INNER JOIN mondial_country c ON p.country = c.code  WHERE c.name = 'Germany'
# SELECT name
# FROM province
# WHERE country = 'DE'
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT eg.percentage FROM mondial_ethnicgroup eg INNER JOIN mondial_country c ON c.code = eg.country WHERE c.name = 'Brazil' AND eg.name LIKE '%Mulatto%'
# SELECT percentage
# FROM ethnicgroup
# WHERE country = 'BR' AND name = 'Mulatto'
# True cols: Index(['PERCENTAGE'], dtype='object')
# Adj. True cols: Index(['PERCENTAGE'], dtype='object')
# Predicted cols: Index(['PERCENTAGE'], dtype='object')
# Adj. Predicted cols: Index(['PERCENTAGE'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT count(*) FROM mondial_city WHERE population < 1000
# SELECT COUNT(*) FROM city WHERE population < 1000
# True cols: Index(['COUNT(*)'], dtype='object')
# Adj. True cols: Index(['COUNT(*)'], dtype='object')
# Predicted cols: Index(['COUNT(*)'], dtype='object')
# Adj. Predicted cols: Index(['COUNT(*)'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT avg(a.elevation) FROM mondial_airport a
# INNER JOIN mondial_country c ON c.code = a.country
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# WHERE co.name = 'America'
# SELECT AVG(elevation) FROM airport WHERE country = 'USA'
# True cols: Index(['AVG(A.ELEVATION)'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['AVG(ELEVATION)'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT COUNT(DISTINCT ec.country) AS number_of_countries
# FROM mondial_geo_sea gs
# JOIN mondial_encompasses ec ON gs.country = ec.country
# WHERE gs.sea = 'Caribbean Sea';
# SELECT COUNT(*)
# FROM encompasses
# WHERE sea1 = 'Caribbean Sea' OR sea2 = 'Caribbean Sea'
# Error: Execution failed on sql 'SELECT COUNT(*)
# FROM encompasses
# WHERE sea1 = 'Caribbean Sea' OR sea2 = 'Caribbean Sea'': ORA-00904: "SEA2": invalid identifier
# SELECT SUM(DISTINCT c.area) AS total_area
# FROM mondial_Country c
# JOIN mondial_encompasses e ON c.code = e.country
# JOIN mondial_geo_sea gs ON e.country = gs.country
# WHERE gs.sea = 'Caribbean Sea';
# SELECT SUM(c.area)
# FROM country c
# JOIN encompasses e ON c.code = e.country
# JOIN sea s ON e.continent = s.name
# WHERE s.name = 'Caribbean Sea'
# True cols: Index(['TOTAL_AREA'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['SUM(C.AREA)'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT c.name AS country_name, SUM(c1.population) AS total_neighbor_population
# FROM mondial_Country c
# JOIN mondial_Borders b ON c.code = b.country1
# JOIN mondial_Country c1 ON b.country2 = c1.code
# GROUP BY c.name;
# SELECT c1.name AS country, SUM(c2.population) AS neighbor_population
# FROM country c1
# JOIN borders b ON c1.code = b.country1
# JOIN country c2 ON b.country2 = c2.code
# GROUP BY c1.name
# ORDER BY c1.name ASC
# True cols: Index(['COUNTRY_NAME', 'TOTAL_NEIGHBOR_POPULATION'], dtype='object')
# Adj. True cols: Index(['COUNTRY_NAME', 'TOTAL_NEIGHBOR_POPULATION'], dtype='object')
# Predicted cols: Index(['COUNTRY', 'NEIGHBOR_POPULATION'], dtype='object')
# Adj. Predicted cols: Index(['COUNTRY', 'NEIGHBOR_POPULATION'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT mountain FROM mondial_mountainonisland WHERE island LIKE '%Borneo%'
# SELECT mountain
# FROM mountainonisland
# WHERE island = 'Borneo'
# True cols: Index(['MOUNTAIN'], dtype='object')
# Adj. True cols: Index(['MOUNTAIN'], dtype='object')
# Predicted cols: Index(['MOUNTAIN'], dtype='object')
# Adj. Predicted cols: Index(['MOUNTAIN'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name, population FROM mondial_country ORDER BY area ASC FETCH FIRST 1 ROWS ONLY;
# SELECT name, population
# FROM country
# WHERE area = (SELECT MIN(area) FROM country)
# True cols: Index(['NAME', 'POPULATION'], dtype='object')
# Adj. True cols: Index(['NAME', 'POPULATION'], dtype='object')
# Predicted cols: Index(['NAME', 'POPULATION'], dtype='object')
# Adj. Predicted cols: Index(['NAME', 'POPULATION'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT DISTINCT s.country
# FROM mondial_geo_estuary e, mondial_borders b, mondial_geo_source s
# WHERE ((e.country = b.country1 AND s.country = b.country2)
# OR (e.country = b.country2 AND s.country = b.country1))
# AND e.river = s.river;
# SELECT DISTINCT c.code
# FROM country c
# JOIN river r ON c.code = r.country
# JOIN geo_estuary ge ON r.name = ge.river
# JOIN country nc ON ge.country = nc.code
# WHERE c.code <> nc.code
# ORDER BY c.code
# Error: Execution failed on sql 'SELECT DISTINCT c.code
# FROM country c
# JOIN river r ON c.code = r.country
# JOIN geo_estuary ge ON r.name = ge.river
# JOIN country nc ON ge.country = nc.code
# WHERE c.code <> nc.code
# ORDER BY c.code': ORA-00904: "R"."COUNTRY": invalid identifier
# SELECT code FROM mondial_country
# WHERE code NOT IN (
# SELECT p.country FROM (
# SELECT name, country
# FROM mondial_province
# WHERE (name, country) NOT IN (SELECT province, country FROM mondial_geo_mountain)) p);
# SELECT DISTINCT c.code
# FROM country c
# JOIN province p ON c.code = p.country
# JOIN geo_mountain gm ON p.name = gm.province AND c.code = gm.country
# GROUP BY c.code
# HAVING COUNT(DISTINCT p.name) = (SELECT COUNT(DISTINCT province) FROM geo_mountain)
# True cols: Index(['CODE'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['CODE'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT b.country1, sum(b.length)
# FROM (SELECT country1, length FROM mondial_borders
# UNION ALL
# SELECT country2, length FROM mondial_borders
# ) b
# GROUP BY b.country1;
# SELECT c.name, SUM(b.length) AS total_border_length
# FROM country c
# JOIN borders b ON c.code = b.country1
# GROUP BY c.name
# True cols: Index(['COUNTRY1', 'SUM(B.LENGTH)'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME', 'TOTAL_BORDER_LENGTH'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT DISTINCT c.name, c.code
# FROM mondial_country c, mondial_geo_source g
# WHERE c.code = g.country;
# SELECT c.name, c.code
# FROM country c
# JOIN river r ON c.code = r.country
# WHERE r.river IS NOT NULL
# GROUP BY c.name, c.code
# ORDER BY c.name ASC
# Error: Execution failed on sql 'SELECT c.name, c.code
# FROM country c
# JOIN river r ON c.code = r.country
# WHERE r.river IS NOT NULL
# GROUP BY c.name, c.code
# ORDER BY c.name ASC': ORA-00904: "R"."COUNTRY": invalid identifier
# SELECT c.name, r.area FROM mondial_geo_river gr
# INNER JOIN mondial_country c ON c.code = gr.country
# INNER JOIN mondial_river r ON r.name = gr.river
# WHERE r.name = 'Chatanga'
# SELECT area, country
# FROM river
# WHERE name = 'Chatanga'
# Error: Execution failed on sql 'SELECT area, country
# FROM river
# WHERE name = 'Chatanga'': ORA-00904: "COUNTRY": invalid identifier
# SELECT name FROM mondial_airport WHERE elevation > 3000.0
# SELECT name, elevation
# FROM airport
# WHERE elevation > 3000
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME', 'ELEVATION'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT r.name FROM mondial_religion r INNER JOIN mondial_country c ON c.code = r.country WHERE c.name = 'Mexico'
# SELECT name
# FROM religion
# WHERE country = 'MEX'
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name FROM mondial_River WHERE sea IS NULL;
# SELECT name
# FROM river
# WHERE sea IS NULL
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT c.name, COUNT(b.country2) AS num_neighbors FROM mondial_country c INNER JOIN mondial_borders b ON c.code = b.country1
# INNER JOIN mondial_encompasses e ON c.code = e.country
# INNER JOIN mondial_continent co ON e.continent = co.name
# WHERE co.name = 'Africa' GROUP BY c.name ORDER BY num_neighbors DESC;
# SELECT c.name, COUNT(b.country2) AS num_neighbors
# FROM country c
# JOIN borders b ON c.code = b.country1
# GROUP BY c.name
# ORDER BY num_neighbors DESC;
# True cols: Index(['NAME', 'NUM_NEIGHBORS'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME', 'NUM_NEIGHBORS'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT c.name AS continent, AVG(p.infant_mortality) AS avg_infant_mortality
# FROM mondial_continent c
# JOIN mondial_encompasses e ON c.name = e.continent
# JOIN mondial_population p ON e.country = p.country
# GROUP BY c.name;
# SELECT c.name, AVG(p.infant_mortality) AS average_infant_mortality
# FROM continent c
# JOIN country co ON c.name = co.continent
# JOIN population p ON co.code = p.country
# GROUP BY c.name
# Error: Execution failed on sql 'SELECT c.name, AVG(p.infant_mortality) AS average_infant_mortality
# FROM continent c
# JOIN country co ON c.name = co.continent
# JOIN population p ON co.code = p.country
# GROUP BY c.name': ORA-00904: "CO"."CONTINENT": invalid identifier
# SELECT AVG(p.infant_mortality) AS avg_infant_mortality
# FROM mondial_Country c
# JOIN mondial_Population p ON c.code = p.country
# JOIN mondial_encompasses e ON c.code = e.country
# JOIN mondial_Continent ct ON e.continent = ct.name
# WHERE ct.name = 'America' AND c.name != 'Brazil';
# SELECT AVG(infant_mortality)
# FROM population
# WHERE country IN (
#     SELECT code
#     FROM country
#     WHERE continent = 'America'
#     AND code != 'BRA'
# )
# Error: Execution failed on sql 'SELECT AVG(infant_mortality)
# FROM population
# WHERE country IN (
#     SELECT code
#     FROM country
#     WHERE continent = 'America'
#     AND code != 'BRA'
# )': ORA-00904: "CONTINENT": invalid identifier
# SELECT name FROM mondial_sea WHERE area > 8000 AND depth < 100
# SELECT name
# FROM sea
# WHERE area > 8000 AND depth < 100
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT count(DISTINCT m.name) FROM mondial_mountain m
# INNER JOIN mondial_geo_mountain gm ON m.name = gm.mountain
# INNER JOIN mondial_country c ON c.code = gm.country
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# WHERE co.name = 'Asia'
# SELECT COUNT(*) FROM mountain
# JOIN mountainonisland ON mountain.name = mountainonisland.mountain
# JOIN island ON mountainonisland.island = island.name
# JOIN geo_island ON island.name = geo_island.island
# JOIN country ON geo_island.country = country.code
# JOIN continent ON country.continent = continent.name
# WHERE continent.name = 'Asia'
# Error: Execution failed on sql 'SELECT COUNT(*) FROM mountain
# JOIN mountainonisland ON mountain.name = mountainonisland.mountain
# JOIN island ON mountainonisland.island = island.name
# JOIN geo_island ON island.name = geo_island.island
# JOIN country ON geo_island.country = country.code
# JOIN continent ON country.continent = continent.name
# WHERE continent.name = 'Asia'': ORA-00904: "COUNTRY"."CONTINENT": invalid identifier
# SELECT count(DISTINCT c.name) FROM mondial_country c
# INNER JOIN mondial_geo_sea gs ON gs.country = c.code
# INNER JOIN mondial_sea s ON gs.sea = s.name
# WHERE s.name = 'Mediterranean Sea'
# SELECT COUNT(*) FROM encompasses WHERE continent = 'Europe' AND percentage = 100
# True cols: Index(['COUNT(DISTINCTC.NAME)'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['COUNT(*)'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT government, count(government) FROM mondial_politics GROUP BY government
# SELECT government, COUNT(*) AS total
# FROM politics
# GROUP BY government
# True cols: Index(['GOVERNMENT', 'COUNT(GOVERNMENT)'], dtype='object')
# Adj. True cols: Index(['GOVERNMENT', 'COUNT(GOVERNMENT)'], dtype='object')
# Predicted cols: Index(['GOVERNMENT', 'TOTAL'], dtype='object')
# Adj. Predicted cols: Index(['GOVERNMENT', 'TOTAL'], dtype='object')
# True: query matches sql (Similarity: 0.975609756097561, column match: 1.0)
# SELECT province FROM mondial_geo_desert gd
# INNER JOIN mondial_desert d ON gd.desert = d.name ORDER BY d.area DESC FETCH FIRST 1 ROWS ONLY;
# SELECT province
# FROM geo_desert
# GROUP BY province
# HAVING MAX(area) = (SELECT MAX(area) FROM desert)
# Error: Execution failed on sql 'SELECT province
# FROM geo_desert
# GROUP BY province
# HAVING MAX(area) = (SELECT MAX(area) FROM desert)': ORA-06553: PLS-306: wrong number or types of arguments in call to 'OGC_AREA'
# SELECT name FROM mondial_desert ORDER BY area DESC FETCH FIRST 1 ROWS ONLY;
# SELECT name, area
# FROM desert
# ORDER BY area DESC
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME', 'AREA'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT co.name, count(gd.desert) FROM mondial_geo_desert gd
# INNER JOIN mondial_country c ON c.code = gd.country
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# GROUP BY co.name
# SELECT c.name AS continent, COUNT(d.name) AS desert_count
# FROM continent c
# JOIN geo_desert gd ON c.name = gd.country
# JOIN desert d ON gd.desert = d.name
# GROUP BY c.name
# True cols: Index(['NAME', 'COUNT(GD.DESERT)'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['CONTINENT', 'DESERT_COUNT'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT sea2 FROM mergeswith WHERE sea1 = 'Banda Sea' UNION SELECT sea1 FROM mergeswith WHERE sea2 = 'Banda Sea'
# SELECT sea
# FROM geo_sea
# WHERE sea2 = 'Banda Sea'
# Error: Execution failed on sql 'SELECT sea
# FROM geo_sea
# WHERE sea2 = 'Banda Sea'': ORA-00904: "SEA2": invalid identifier
# SELECT c.capital FROM mondial_country c
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# WHERE co.name = 'Europe'
# SELECT capital
# FROM country
# WHERE code IN (
#     SELECT country
#     FROM encompasses
#     WHERE continent = 'Europe'
# )
# True cols: Index(['CAPITAL'], dtype='object')
# Adj. True cols: Index(['CAPITAL'], dtype='object')
# Predicted cols: Index(['CAPITAL'], dtype='object')
# Adj. Predicted cols: Index(['CAPITAL'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT l.percentage FROM mondial_language l
# INNER JOIN mondial_country c ON l.country = c.code
# WHERE l.name LIKE '%French%' AND c.name = 'Andorra'
# SELECT percentage
# FROM language
# WHERE country = 'AND' AND name = 'French'
# True cols: Index(['PERCENTAGE'], dtype='object')
# Adj. True cols: Index(['PERCENTAGE'], dtype='object')
# Predicted cols: Index(['PERCENTAGE'], dtype='object')
# Adj. Predicted cols: Index(['PERCENTAGE'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name FROM mondial_river WHERE length > 1000
# SELECT name
# FROM river
# WHERE length > 1000
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT c.name FROM mondial_country c
# INNER JOIN mondial_population p ON p.country = c.code
# ORDER BY p.population_growth ASC FETCH FIRST 1 ROWS ONLY
# SELECT country
# FROM population
# WHERE population_growth = (SELECT MIN(population_growth) FROM population)
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['COUNTRY'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT c.capital FROM mondial_country c WHERE c.capital NOT IN (SELECT lo.city FROM mondial_located lo )
# SELECT c.capital
# FROM country c
# LEFT JOIN located l ON c.capital = l.city
# WHERE l.city IS NULL
# True cols: Index(['CAPITAL'], dtype='object')
# Adj. True cols: Index(['CAPITAL'], dtype='object')
# Predicted cols: Index(['CAPITAL'], dtype='object')
# Adj. Predicted cols: Index(['CAPITAL'], dtype='object')
# True: query matches sql (Similarity: 0.9846153846153847, column match: 1.0)
# SELECT p.CAPITAL
# FROM MONDIAL_PROVINCE p
# WHERE p.name like '%Andalucía%'
# SELECT capital
# FROM province
# WHERE name = 'Andalucía'
# True cols: Index(['CAPITAL'], dtype='object')
# Adj. True cols: Index(['CAPITAL'], dtype='object')
# Predicted cols: Index(['CAPITAL'], dtype='object')
# Adj. Predicted cols: Index(['CAPITAL'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT abbreviation FROM mondial_organization WHERE name='General Confederation of Trade Unions'
# SELECT abbreviation FROM organization WHERE name = 'General Confederation of Trade Unions'
# True cols: Index(['ABBREVIATION'], dtype='object')
# Adj. True cols: Index(['ABBREVIATION'], dtype='object')
# Predicted cols: Index(['ABBREVIATION'], dtype='object')
# Adj. Predicted cols: Index(['ABBREVIATION'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT city FROM mondial_organization WHERE abbreviation='UPU'
# SELECT city
# FROM organization
# WHERE abbreviation = 'UPU'
# True cols: Index(['CITY'], dtype='object')
# Adj. True cols: Index(['CITY'], dtype='object')
# Predicted cols: Index(['CITY'], dtype='object')
# Adj. Predicted cols: Index(['CITY'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT c.name
# FROM mondial_country c
# JOIN mondial_ismember m
# ON c.code=m.country
# WHERE m.organization=ALL(SELECT organization
# FROM mondial_ismember m
# WHERE
# m.country=c.code)
# SELECT c.name
# FROM country c
# JOIN ismember i ON c.code = i.country
# GROUP BY c.name
# HAVING COUNT(i.organization) = 1
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT c.name
# FROM mondial_country c
# WHERE c.code NOT IN (SELECT m.country
# FROM mondial_ismember m
# WHERE organization='NATO')
# SELECT name
# FROM country
# WHERE code NOT IN (SELECT country FROM ismember WHERE organization = 'NATO')
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT c.name
# FROM mondial_country c
# JOIN mondial_ismember m
# ON c.code=m.country
# WHERE organization='NATO'
# SELECT name
# FROM country
# WHERE code IN (SELECT country
#                FROM ismember
#                WHERE organization = 'NATO')
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name FROM mondial_river WHERE length < 50
# SELECT name
# FROM river
# WHERE length < 50
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT l.area, l.elevation, l.type FROM MONDIAL_GEO_LAKE gl , MONDIAL_LAKE l, MONDIAL_COUNTRY c
# WHERE (gl.LAKE = l.NAME)
# AND (gl.COUNTRY = c.CODE)
# AND  c.name = 'Italy'
# SELECT name, area, elevation, type
# FROM lake
# WHERE country = 'IT'
# Error: Execution failed on sql 'SELECT name, area, elevation, type
# FROM lake
# WHERE country = 'IT'': ORA-00904: "COUNTRY": invalid identifier
# SELECT c.capital
# FROM mondial_country c
# WHERE c.capital IN (SELECT o.city
# FROM mondial_organization o) ORDER BY c.capital ASC
# SELECT city.name
# FROM city
# JOIN organization ON city.name = organization.city
# ORDER BY city.name ASC
# True cols: Index(['CAPITAL'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT o.name
# FROM mondial_organization o
# WHERE NOT EXISTS (SELECT *
# FROM mondial_ismember m
# JOIN mondial_country c
# ON m.country=c.code
# WHERE m.organization=o.abbreviation
# AND c.area <=4000
# AND m.type= 'member')
# SELECT name
# FROM organization
# WHERE abbreviation NOT IN (
#     SELECT country
#     FROM country
#     WHERE area < 4000
# )
# AND type = 'member'
# Error: Execution failed on sql 'SELECT name
# FROM organization
# WHERE abbreviation NOT IN (
#     SELECT country
#     FROM country
#     WHERE area < 4000
# )
# AND type = 'member'': ORA-00904: "TYPE": invalid identifier
# SELECT o.name
# FROM mondial_organization o
# WHERE NOT EXISTS (SELECT *
# FROM mondial_ismember m
# JOIN mondial_country c
# ON m.country=c.code
# WHERE m.organization=o.abbreviation
# AND c.area > 10000
# AND c.population < 3000
# AND m.type= 'member')
# SELECT name
# FROM organization
# WHERE abbreviation NOT IN (
#     SELECT country
#     FROM country
#     WHERE area > 10000 AND population < 3000
# ) AND type = 'member'
# Error: Execution failed on sql 'SELECT name
# FROM organization
# WHERE abbreviation NOT IN (
#     SELECT country
#     FROM country
#     WHERE area > 10000 AND population < 3000
# ) AND type = 'member'': ORA-00904: "TYPE": invalid identifier
# SELECT DISTINCT e.inflation FROM mondial_economy e
# INNER JOIN mondial_country c ON e.country = c.code
# INNER JOIN mondial_geo_sea gs ON gs.country = c.code
# INNER JOIN mondial_sea s ON s.name = gs.sea
# WHERE s.name LIKE '%Arabian Sea%' ORDER BY e.inflation
# SELECT c.name, e.inflation
# FROM country c
# JOIN geo_sea gs ON c.code = gs.country
# JOIN sea s ON gs.sea = s.name
# JOIN economy e ON c.code = e.country
# WHERE s.name = 'Arabian Sea'
# True cols: Index(['INFLATION'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME', 'INFLATION'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT c.capital FROM mondial_country c
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# WHERE co.name = 'Africa'
# SELECT c.capital
# FROM country c
# JOIN encompasses e ON c.code = e.country
# JOIN continent co ON e.continent = co.name
# WHERE co.name = 'Africa'
# True cols: Index(['CAPITAL'], dtype='object')
# Adj. True cols: Index(['CAPITAL'], dtype='object')
# Predicted cols: Index(['CAPITAL'], dtype='object')
# Adj. Predicted cols: Index(['CAPITAL'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT DISTINCT e.inflation FROM mondial_economy e
# INNER JOIN mondial_country c ON e.country = c.code
# INNER JOIN mondial_geo_sea gs ON gs.country = c.code
# INNER JOIN mondial_sea s ON s.name = gs.sea
# WHERE s.name LIKE '%Arabian Sea%' AND e.INFLATION IS NOT NULL
# SELECT c.name, e.inflation
# FROM country c
# JOIN economy e ON c.code = e.country
# JOIN geo_sea gs ON c.code = gs.country
# JOIN sea s ON gs.sea = s.name
# WHERE s.name = 'Arabian Sea' AND e.inflation IS NOT NULL
# True cols: Index(['INFLATION'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME', 'INFLATION'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT count(*) FROM mondial_country c
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# WHERE co.name = 'Africa'
# SELECT COUNT(*) FROM country WHERE code IN (SELECT country FROM encompasses WHERE continent = 'Africa')
# True cols: Index(['COUNT(*)'], dtype='object')
# Adj. True cols: Index(['COUNT(*)'], dtype='object')
# Predicted cols: Index(['COUNT(*)'], dtype='object')
# Adj. Predicted cols: Index(['COUNT(*)'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name FROM country WHERE code NOT IN (SELECT country FROM ismember WHERE organization = 'NATO')
# INTERSECT SELECT name FROM country WHERE code NOT IN (SELECT country FROM ismember WHERE organization = 'UNESCO')
# SELECT name
# FROM country
# WHERE code NOT IN (SELECT country FROM ismember WHERE organization = 'NATO')
# AND code NOT IN (SELECT country FROM ismember WHERE organization = 'UNESCO')
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT area FROM mondial_continent WHERE name = 'Europe'
# SELECT area FROM continent WHERE name = 'Europe'
# True cols: Index(['AREA'], dtype='object')
# Adj. True cols: Index(['AREA'], dtype='object')
# Predicted cols: Index(['AREA'], dtype='object')
# Adj. Predicted cols: Index(['AREA'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT area FROM mondial_continent WHERE name = 'America'
# SELECT area FROM continent WHERE name = 'America'
# True cols: Index(['AREA'], dtype='object')
# Adj. True cols: Index(['AREA'], dtype='object')
# Predicted cols: Index(['AREA'], dtype='object')
# Adj. Predicted cols: Index(['AREA'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT area FROM mondial_continent WHERE name = 'Asia'
# SELECT area FROM continent WHERE name = 'Asia'
# True cols: Index(['AREA'], dtype='object')
# Adj. True cols: Index(['AREA'], dtype='object')
# Predicted cols: Index(['AREA'], dtype='object')
# Adj. Predicted cols: Index(['AREA'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT area FROM mondial_continent WHERE name = 'Africa'
# SELECT area FROM continent WHERE name = 'Africa'
# True cols: Index(['AREA'], dtype='object')
# Adj. True cols: Index(['AREA'], dtype='object')
# Predicted cols: Index(['AREA'], dtype='object')
# Adj. Predicted cols: Index(['AREA'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT count(*) FROM mondial_country c
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# WHERE co.name = 'America'
# SELECT COUNT(*) FROM country WHERE code IN (SELECT country FROM encompasses WHERE continent = 'America')
# True cols: Index(['COUNT(*)'], dtype='object')
# Adj. True cols: Index(['COUNT(*)'], dtype='object')
# Predicted cols: Index(['COUNT(*)'], dtype='object')
# Adj. Predicted cols: Index(['COUNT(*)'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT max(area) FROM mondial_continent
# SELECT name, area FROM continent ORDER BY area DESC
# True cols: Index(['MAX(AREA)'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME', 'AREA'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT c.name
# FROM mondial_country c
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# WHERE e.continent = (
#     SELECT name
#     FROM mondial_continent
#     GROUP BY name
#     ORDER BY MAX(area) DESC
#     FETCH FIRST 1 ROWS ONLY
# );
# SELECT c.name
# FROM country c
# JOIN encompasses e ON c.code = e.country
# JOIN continent ct ON e.continent = ct.name
# WHERE ct.area = (SELECT MAX(area) FROM continent)
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT c.name
# FROM mondial_country c
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# INNER JOIN mondial_language l ON l.country = c.code
# WHERE e.continent = (
#     SELECT name
#     FROM mondial_continent
#     GROUP BY name
#     ORDER BY MAX(area) DESC
#     FETCH FIRST 1 ROWS ONLY
# ) AND l.name='English';
# SELECT c.name
# FROM country c
# JOIN encompasses e ON c.code = e.country
# JOIN continent co ON e.continent = co.name
# JOIN language l ON c.code = l.country
# WHERE co.area = (SELECT MAX(area) FROM continent)
# AND l.name = 'English'
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT ci.name AS cityname, c.name AS countryname
# FROM mondial_city ci
# JOIN mondial_country c ON ci.country = c.code
# WHERE ci.population > 5000000
# ORDER BY ci.population DESC;
# SELECT c.name, co.name
# FROM city c
# JOIN country co ON c.country = co.code
# WHERE c.population > 5000000
# ORDER BY c.population DESC
# True cols: Index(['CITYNAME', 'COUNTRYNAME'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME', 'NAME'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT d.name FROM mondial_desert d
# INNER JOIN mondial_geo_desert gd ON gd.desert = d.name
# WHERE gd.province='Algeria'
# SELECT d.name
# FROM desert d
# JOIN geo_desert gd ON d.name = gd.desert
# JOIN province p ON gd.province = p.name AND gd.country = p.country
# WHERE p.country = 'AL'
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT d.name, d.area FROM mondial_desert d
# INNER JOIN mondial_geo_desert gd ON gd.desert = d.name
# WHERE gd.province='California'
# SELECT d.name, d.area
# FROM desert d
# JOIN geo_desert gd ON d.name = gd.desert
# JOIN province p ON gd.province = p.name
# WHERE p.name = 'California'
# True cols: Index(['NAME', 'AREA'], dtype='object')
# Adj. True cols: Index(['NAME', 'AREA'], dtype='object')
# Predicted cols: Index(['NAME', 'AREA'], dtype='object')
# Adj. Predicted cols: Index(['NAME', 'AREA'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT c.name, l.percentage FROM mondial_language l INNER JOIN mondial_country c
# ON l.country = c.code WHERE l.name = 'French'
# SELECT c.name, l.percentage
# FROM country c
# JOIN language l ON c.code = l.country
# WHERE l.name = 'French'
# True cols: Index(['NAME', 'PERCENTAGE'], dtype='object')
# Adj. True cols: Index(['NAME', 'PERCENTAGE'], dtype='object')
# Predicted cols: Index(['NAME', 'PERCENTAGE'], dtype='object')
# Adj. Predicted cols: Index(['NAME', 'PERCENTAGE'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT ci.name
# FROM mondial_city ci
# INNER JOIN mondial_country co
# ON co.code = ci.country
# INNER JOIN mondial_language l
# ON l.country = co.code
# WHERE l.name = 'Portuguese';
# SELECT city.name
# FROM city
# JOIN country ON city.country = country.code
# JOIN language ON country.code = language.country
# WHERE language.name = 'Portuguese'
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT SUM(p.area)
# FROM mondial_province p
# INNER JOIN mondial_country c
# ON p.country = c.code
# WHERE c.name = 'Canada';
# SELECT SUM(area) FROM province WHERE country = 'CAN'
# True cols: Index(['SUM(P.AREA)'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['SUM(AREA)'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT length FROM mondial_river WHERE name LIKE '%Tigris%'
# SELECT length
# FROM river
# WHERE name = 'Tigres'
# True cols: Index(['LENGTH'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['LENGTH'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT name
# FROM mondial_airport
# WHERE elevation > 1000.0;
# SELECT name
# FROM airport
# WHERE elevation > 1000
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT a.name
# FROM mondial_airport a
# INNER JOIN mondial_country c
# ON c.code = a.country
# WHERE c.name = 'United States' AND a.elevation <200;
# SELECT name
# FROM airport
# WHERE country = 'US' AND elevation < 200
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT name
# FROM mondial_mountain
# WHERE elevation > 8000;
# SELECT name
# FROM mountain
# WHERE elevation > 8000
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name
# FROM mondial_airport
# ORDER BY LENGTH(name) DESC
# FETCH FIRST 3 ROWS ONLY;
# SELECT name
# FROM airport
# ORDER BY LENGTH(name) DESC
# FETCH FIRST 3 ROWS ONLY
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name
# FROM mondial_lake
# WHERE area < 5000;
# SELECT name
# FROM lake
# WHERE area < 5000
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT SUM(area)
# FROM mondial_sea
# WHERE depth > 1000;
# SELECT SUM(area)
# FROM sea
# WHERE depth > 1000
# True cols: Index(['SUM(AREA)'], dtype='object')
# Adj. True cols: Index(['SUM(AREA)'], dtype='object')
# Predicted cols: Index(['SUM(AREA)'], dtype='object')
# Adj. Predicted cols: Index(['SUM(AREA)'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name
# FROM mondial_country
# WHERE name LIKE 'B%' AND population > 10000000;
# SELECT name
# FROM country
# WHERE name LIKE 'B%' AND population > 10000000
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT cio.othername
# FROM mondial_cityothername cio
# INNER JOIN mondial_country c
# ON cio.country = c.code
# WHERE c.name = 'Brazil'
# SELECT city.name, cityothername.othername
# FROM city
# JOIN cityothername ON city.name = cityothername.city
# WHERE city.country = 'BR'
# True cols: Index(['OTHERNAME'], dtype='object')
# Adj. True cols: Index(['OTHERNAME'], dtype='object')
# Predicted cols: Index(['NAME', 'OTHERNAME'], dtype='object')
# Adj. Predicted cols: Index(['OTHERNAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name
# FROM mondial_city
# WHERE latitude > 45;
# SELECT name
# FROM city
# WHERE latitude > 45
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT count(DISTINCT cio.city)
# FROM mondial_cityothername cio
# INNER JOIN mondial_country c
# ON cio.country = c.code
# WHERE c.area >30000
# SELECT COUNT(DISTINCT city)
# FROM cityothername co
# JOIN city c ON co.city = c.name AND co.country = c.country
# JOIN country cn ON c.country = cn.code
# WHERE cn.area > 30000
# True cols: Index(['COUNT(DISTINCTCIO.CITY)'], dtype='object')
# Adj. True cols: Index(['COUNT(DISTINCTCIO.CITY)'], dtype='object')
# Predicted cols: Index(['COUNT(DISTINCTCITY)'], dtype='object')
# Adj. Predicted cols: Index(['COUNT(DISTINCTCITY)'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name
# FROM mondial_desert
# WHERE area > 10000;
# SELECT name, area
# FROM desert
# WHERE area > 10000
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME', 'AREA'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT island.name
# FROM island
# JOIN lakeonisland ON island.name = lakeonisland.island
# JOIN lake ON lake.name = lakeonisland.lake
# WHERE lake.elevation > 100;
# SELECT i.name
# FROM island i
# JOIN lakeonisland loi ON i.name = loi.island
# JOIN lake l ON loi.lake = l.name
# WHERE l.elevation > 100
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT moi.mountain
# FROM mondial_mountainonisland moi
# INNER JOIN mondial_island isl
# ON moi.island = isl.name
# WHERE isl.area > 100000
# SELECT m.name
# FROM mountain m
# JOIN mountainonisland mi ON m.name = mi.mountain
# JOIN island i ON mi.island = i.name
# WHERE i.area > 100000
# True cols: Index(['MOUNTAIN'], dtype='object')
# Adj. True cols: Index(['MOUNTAIN'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT c.name AS country, SUM(p.area) AS total_province_area
# FROM mondial_country c
# INNER JOIN mondial_province p
# ON c.code = p.country
# GROUP BY c.name;
# SELECT c.name AS country, SUM(p.area) AS total_area
# FROM country c
# JOIN province p ON c.code = p.country
# GROUP BY c.name
# True cols: Index(['COUNTRY', 'TOTAL_PROVINCE_AREA'], dtype='object')
# Adj. True cols: Index(['COUNTRY', 'TOTAL_PROVINCE_AREA'], dtype='object')
# Predicted cols: Index(['COUNTRY', 'TOTAL_AREA'], dtype='object')
# Adj. Predicted cols: Index(['COUNTRY', 'TOTAL_AREA'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT c.name AS country, AVG(ci.elevation) AS average_city_population, SUM(ci.population) AS total_city_area
# FROM mondial_country c
# INNER JOIN mondial_city ci
# ON c.code = ci.country
# GROUP BY c.name;
# SELECT c.name, AVG(ci.elevation), SUM(ci.population)
# FROM country c
# JOIN city ci ON c.code = ci.country
# GROUP BY c.name
# True cols: Index(['COUNTRY', 'AVERAGE_CITY_POPULATION', 'TOTAL_CITY_AREA'], dtype='object')
# Adj. True cols: Index(['COUNTRY', 'AVERAGE_CITY_POPULATION', 'TOTAL_CITY_AREA'], dtype='object')
# Predicted cols: Index(['NAME', 'AVG(CI.ELEVATION)', 'SUM(CI.POPULATION)'], dtype='object')
# Adj. Predicted cols: Index(['NAME', 'AVG(CI.ELEVATION)', 'SUM(CI.POPULATION)'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT e.inflation FROM mondial_country c JOIN mondial_economy e ON c.code=e.country WHERE c.name LIKE '%Germany%'
# SELECT inflation FROM economy WHERE country = 'DE'
# True cols: Index(['INFLATION'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['INFLATION'], dtype='object')
# ...
# INTERSECT SELECT name FROM country WHERE code NOT IN (SELECT country FROM ismember WHERE organization = 'UNESCO')
# SELECT name
# FROM country
# WHERE code NOT IN (
#     SELECT country
#     FROM ismember
#     WHERE organization IN ('NATO', 'UNESCO')
# )
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT area FROM mondial_continent WHERE name = 'Europe'
# SELECT area FROM continent WHERE name = 'Europe'
# True cols: Index(['AREA'], dtype='object')
# Adj. True cols: Index(['AREA'], dtype='object')
# Predicted cols: Index(['AREA'], dtype='object')
# Adj. Predicted cols: Index(['AREA'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT area FROM mondial_continent WHERE name = 'America'
# SELECT area FROM continent WHERE name = 'America'
# True cols: Index(['AREA'], dtype='object')
# Adj. True cols: Index(['AREA'], dtype='object')
# Predicted cols: Index(['AREA'], dtype='object')
# Adj. Predicted cols: Index(['AREA'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT area FROM mondial_continent WHERE name = 'Asia'
# SELECT area FROM continent WHERE name = 'Asia'
# True cols: Index(['AREA'], dtype='object')
# Adj. True cols: Index(['AREA'], dtype='object')
# Predicted cols: Index(['AREA'], dtype='object')
# Adj. Predicted cols: Index(['AREA'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT area FROM mondial_continent WHERE name = 'Africa'
# SELECT area FROM continent WHERE name = 'Africa'
# True cols: Index(['AREA'], dtype='object')
# Adj. True cols: Index(['AREA'], dtype='object')
# Predicted cols: Index(['AREA'], dtype='object')
# Adj. Predicted cols: Index(['AREA'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT count(*) FROM mondial_country c
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# WHERE co.name = 'America'
# SELECT COUNT(*) FROM continent WHERE name = 'America'
# True cols: Index(['COUNT(*)'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['COUNT(*)'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT max(area) FROM mondial_continent
# SELECT name, area FROM continent ORDER BY area DESC
# True cols: Index(['MAX(AREA)'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME', 'AREA'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT c.name
# FROM mondial_country c
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# WHERE e.continent = (
#     SELECT name
#     FROM mondial_continent
#     GROUP BY name
#     ORDER BY MAX(area) DESC
#     FETCH FIRST 1 ROWS ONLY
# );
# SELECT c.name
# FROM country c
# JOIN encompasses e ON c.code = e.country
# JOIN continent co ON e.continent = co.name
# WHERE co.area = (SELECT MAX(area) FROM continent)
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT c.name
# FROM mondial_country c
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# INNER JOIN mondial_language l ON l.country = c.code
# WHERE e.continent = (
#     SELECT name
#     FROM mondial_continent
#     GROUP BY name
#     ORDER BY MAX(area) DESC
#     FETCH FIRST 1 ROWS ONLY
# ) AND l.name='English';
# SELECT c.name
# FROM country c
# JOIN encompasses e ON c.code = e.country
# JOIN continent con ON e.continent = con.name
# JOIN language l ON c.code = l.country
# WHERE con.area = (SELECT MAX(area) FROM continent)
# AND l.name = 'English'
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT ci.name AS cityname, c.name AS countryname
# FROM mondial_city ci
# JOIN mondial_country c ON ci.country = c.code
# WHERE ci.population > 5000000
# ORDER BY ci.population DESC;
# SELECT c.name AS city, co.name AS country
# FROM city c
# JOIN country co ON c.country = co.code
# WHERE c.population > 5000000
# ORDER BY c.population DESC
# True cols: Index(['CITYNAME', 'COUNTRYNAME'], dtype='object')
# Adj. True cols: Index(['CITYNAME', 'COUNTRYNAME'], dtype='object')
# Predicted cols: Index(['CITY', 'COUNTRY'], dtype='object')
# Adj. Predicted cols: Index(['CITY', 'COUNTRY'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT d.name FROM mondial_desert d
# INNER JOIN mondial_geo_desert gd ON gd.desert = d.name
# WHERE gd.province='Algeria'
# SELECT d.name
# FROM desert d
# JOIN geo_desert gd ON d.name = gd.desert
# JOIN province p ON gd.province = p.name
# JOIN country c ON p.country = c.code
# WHERE c.name = 'Algeria'
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT d.name, d.area FROM mondial_desert d
# INNER JOIN mondial_geo_desert gd ON gd.desert = d.name
# WHERE gd.province='California'
# SELECT name, area
# FROM desert
# JOIN geo_desert ON desert.name = geo_desert.desert
# JOIN province ON geo_desert.province = province.name
# WHERE province.name = 'California'
# Error: Execution failed on sql 'SELECT name, area
# FROM desert
# JOIN geo_desert ON desert.name = geo_desert.desert
# JOIN province ON geo_desert.province = province.name
# WHERE province.name = 'California'': ORA-00918: column ambiguously defined
# SELECT c.name, l.percentage FROM mondial_language l INNER JOIN mondial_country c
# ON l.country = c.code WHERE l.name = 'French'
# SELECT c.name, l.percentage
# FROM country c
# JOIN language l ON c.code = l.country
# WHERE l.name = 'French'
# True cols: Index(['NAME', 'PERCENTAGE'], dtype='object')
# Adj. True cols: Index(['NAME', 'PERCENTAGE'], dtype='object')
# Predicted cols: Index(['NAME', 'PERCENTAGE'], dtype='object')
# Adj. Predicted cols: Index(['NAME', 'PERCENTAGE'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT ci.name
# FROM mondial_city ci
# INNER JOIN mondial_country co
# ON co.code = ci.country
# INNER JOIN mondial_language l
# ON l.country = co.code
# WHERE l.name = 'Portuguese';
# SELECT city.name
# FROM city
# JOIN language ON city.country = language.country
# WHERE language.name = 'Portuguese'
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT SUM(p.area)
# FROM mondial_province p
# INNER JOIN mondial_country c
# ON p.country = c.code
# WHERE c.name = 'Canada';
# SELECT SUM(area) FROM province WHERE country = 'CAN'
# True cols: Index(['SUM(P.AREA)'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['SUM(AREA)'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT length FROM mondial_river WHERE name LIKE '%Tigris%'
# SELECT length FROM river WHERE name = 'Tigres'
# True cols: Index(['LENGTH'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['LENGTH'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT name
# FROM mondial_airport
# WHERE elevation > 1000.0;
# SELECT name, elevation
# FROM airport
# WHERE elevation > 1000
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME', 'ELEVATION'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT a.name
# FROM mondial_airport a
# INNER JOIN mondial_country c
# ON c.code = a.country
# WHERE c.name = 'United States' AND a.elevation <200;
# SELECT name
# FROM airport
# WHERE country = 'USA' AND elevation < 200
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name
# FROM mondial_mountain
# WHERE elevation > 8000;
# SELECT name
# FROM mountain
# WHERE elevation > 8000
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name
# FROM mondial_airport
# ORDER BY LENGTH(name) DESC
# FETCH FIRST 3 ROWS ONLY;
# SELECT name FROM airport ORDER BY LENGTH(name) DESC FETCH FIRST 3 ROWS ONLY
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name
# FROM mondial_lake
# WHERE area < 5000;
# SELECT name
# FROM lake
# WHERE area < 5000
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT SUM(area)
# FROM mondial_sea
# WHERE depth > 1000;
# SELECT SUM(area)
# FROM sea
# WHERE depth > 1000
# True cols: Index(['SUM(AREA)'], dtype='object')
# Adj. True cols: Index(['SUM(AREA)'], dtype='object')
# Predicted cols: Index(['SUM(AREA)'], dtype='object')
# Adj. Predicted cols: Index(['SUM(AREA)'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name
# FROM mondial_country
# WHERE name LIKE 'B%' AND population > 10000000;
# SELECT name
# FROM country
# WHERE name LIKE 'B%' AND population > 10000000
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT cio.othername
# FROM mondial_cityothername cio
# INNER JOIN mondial_country c
# ON cio.country = c.code
# WHERE c.name = 'Brazil'
# SELECT city.name, cityothername.othername
# FROM city
# JOIN cityothername ON city.name = cityothername.city AND city.country = cityothername.country
# WHERE city.country = 'BRAZ'
# True cols: Index(['OTHERNAME'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME', 'OTHERNAME'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT name
# FROM mondial_city
# WHERE latitude > 45;
# SELECT name
# FROM city
# WHERE latitude > 45
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT count(DISTINCT cio.city)
# FROM mondial_cityothername cio
# INNER JOIN mondial_country c
# ON cio.country = c.code
# WHERE c.area >30000
# SELECT COUNT(DISTINCT city)
# FROM cityothername co
# JOIN city c ON co.city = c.name AND co.country = c.country
# JOIN country cn ON c.country = cn.code
# WHERE cn.area > 30000
# True cols: Index(['COUNT(DISTINCTCIO.CITY)'], dtype='object')
# Adj. True cols: Index(['COUNT(DISTINCTCIO.CITY)'], dtype='object')
# Predicted cols: Index(['COUNT(DISTINCTCITY)'], dtype='object')
# Adj. Predicted cols: Index(['COUNT(DISTINCTCITY)'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name
# FROM mondial_desert
# WHERE area > 10000;
# SELECT name
# FROM desert
# WHERE area > 10000
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT island.name
# FROM island
# JOIN lakeonisland ON island.name = lakeonisland.island
# JOIN lake ON lake.name = lakeonisland.lake
# WHERE lake.elevation > 100;
# SELECT i.name
# FROM island i
# JOIN lakeonisland loi ON i.name = loi.island
# JOIN lake l ON loi.lake = l.name
# WHERE l.elevation > 100
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT moi.mountain
# FROM mondial_mountainonisland moi
# INNER JOIN mondial_island isl
# ON moi.island = isl.name
# WHERE isl.area > 100000
# SELECT m.name
# FROM mountain m
# JOIN mountainonisland moi ON m.name = moi.mountain
# JOIN island i ON moi.island = i.name
# WHERE i.area > 100000
# True cols: Index(['MOUNTAIN'], dtype='object')
# Adj. True cols: Index(['MOUNTAIN'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT c.name AS country, SUM(p.area) AS total_province_area
# FROM mondial_country c
# INNER JOIN mondial_province p
# ON c.code = p.country
# GROUP BY c.name;
# SELECT country, SUM(area) AS total_area
# FROM province
# GROUP BY country
# True cols: Index(['COUNTRY', 'TOTAL_PROVINCE_AREA'], dtype='object')
# Adj. True cols: Index(['TOTAL_PROVINCE_AREA'], dtype='object')
# Predicted cols: Index(['COUNTRY', 'TOTAL_AREA'], dtype='object')
# Adj. Predicted cols: Index(['TOTAL_AREA'], dtype='object')
# False: no match found
# SELECT c.name AS country, AVG(ci.elevation) AS average_city_population, SUM(ci.population) AS total_city_area
# FROM mondial_country c
# INNER JOIN mondial_city ci
# ON c.code = ci.country
# GROUP BY c.name;
# SELECT c.name AS country_name, AVG(ci.elevation) AS average_elevation, SUM(ci.population) AS total_population
# FROM country c
# JOIN city ci ON c.code = ci.country
# GROUP BY c.name
# True cols: Index(['COUNTRY', 'AVERAGE_CITY_POPULATION', 'TOTAL_CITY_AREA'], dtype='object')
# Adj. True cols: Index(['COUNTRY', 'AVERAGE_CITY_POPULATION', 'TOTAL_CITY_AREA'], dtype='object')
# Predicted cols: Index(['COUNTRY_NAME', 'AVERAGE_ELEVATION', 'TOTAL_POPULATION'], dtype='object')
# Adj. Predicted cols: Index(['COUNTRY_NAME', 'AVERAGE_ELEVATION', 'TOTAL_POPULATION'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT e.inflation FROM mondial_country c JOIN mondial_economy e ON c.code=e.country WHERE c.name LIKE '%Germany%'
# SELECT inflation FROM economy WHERE country = 'DEU'
# True cols: Index(['INFLATION'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['INFLATION'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT p.government
# FROM mondial_country c
# INNER JOIN mondial_politics p
# ON p.country = c.code
# WHERE c.name = 'Iran'
# SELECT government
# FROM politics
# WHERE country = 'IRN'
# True cols: Index(['GOVERNMENT'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['GOVERNMENT'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT e.industry
# FROM mondial_economy e
# INNER JOIN mondial_country c
# ON c.code = e.country
# WHERE c.name = 'Japan'
# SELECT industry FROM economy WHERE country = 'JPN'
# True cols: Index(['INDUSTRY'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['INDUSTRY'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# 572276
# 1.72
# 569713 2563
# 134.60434341430664

# %%
df = pd.DataFrame(results_fk, columns=['experiment', 'simple', 'medium', 'complex', 'total', 'overall_simple', 'overall_medium', 'overall_complex', 'overall_total','input_tokens', 'output_tokens', 'total_tokens','total_cost', 'total_time'])
df['experiment'] = df['experiment'].apply(get_experiment_name)
df = df.sort_values(by='overall_total', ascending=False)
df
# Out:
#                                           experiment  simple  medium  complex  \
# 1  SQLQueryChain - MONDIAL_GPT - GPT-4 - Passing ...      27      28       15
# 2           SQLQueryChain - MONDIAL_GPT - GPT-4 - FK      27      26       16
# 0  SQLQueryChain - MONDIAL_GPT - GPT-3.5 - Passin...      25      22       13
# 3         SQLQueryChain - MONDIAL_GPT - GPT-3.5 - FK      25      19       11
#
#    total  overall_simple  overall_medium  overall_complex  overall_total  \
# 1     70          0.8182          0.8485           0.4412           0.70
# 2     69          0.8182          0.7879           0.4706           0.69
# 0     60          0.7576          0.6667           0.3824           0.60
# 3     55          0.7576          0.5758           0.3235           0.55
#
#    input_tokens  output_tokens  total_tokens  total_cost total_time
# 1        782624           2527        785151       23.63    0:09:20
# 2        569713           2643        572356       17.25    0:05:28
# 0        782813           2501        785314        2.36    0:06:47
# 3        569713           2563        572276        1.72    0:02:15

# %%
df.to_csv(TARGET_PATH_FK)

# %% [markdown]
# ## Validação com o mondial - Foreign Keys + RAG

# %%
results_fk = run(['results/13_sql_queries_rag_chatgpt_mondial_gpt.json',
                  'results/14_sql_queries_rag_chatgpt4_mondial_gpt.json'], [])
# Out:
# mondial
# mondial_gpt
# SELECT max(area) FROM mondial_country where name  = 'Thailand'
# SELECT area FROM mondial_country WHERE name = 'Thailand'
# True cols: Index(['MAX(AREA)'], dtype='object')
# Adj. True cols: Index(['MAX(AREA)'], dtype='object')
# Predicted cols: Index(['AREA'], dtype='object')
# Adj. Predicted cols: Index(['AREA'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name FROM mondial_province where area > 10000
# SELECT name
# FROM mondial_province
# WHERE area > 10000;
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT mondial_language.name FROM mondial_language INNER JOIN mondial_country ON mondial_language.country = mondial_country.code WHERE mondial_country.name = 'Poland'
# SELECT l.name
# FROM mondial_language l
# INNER JOIN mondial_country c ON l.country = c.code
# WHERE c.name = 'Poland'
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT depth FROM mondial_lake where name LIKE '%Lake Kariba%'
# SELECT depth
# FROM mondial_lake
# WHERE name = 'Kariba'
# True cols: Index(['DEPTH'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['DEPTH'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT count(*) FROM mondial_province p INNER JOIN mondial_country c ON p.country = c.code WHERE c.name = 'Netherlands'
# SELECT COUNT(*)
# FROM mondial_province
# WHERE country = 'NLD'
# True cols: Index(['COUNT(*)'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['COUNT(*)'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT r.percentage FROM mondial_religion r INNER JOIN mondial_country c ON r.country = c.code WHERE c.name = 'Thailand' AND r.name LIKE '%Hindu%'
# SELECT r.percentage
# FROM mondial_religion r
# INNER JOIN mondial_country c
# ON r.country = c.code
# WHERE r.name = 'Hindu' AND c.name = 'Thailand'
# True cols: Index(['PERCENTAGE'], dtype='object')
# Adj. True cols: Index(['PERCENTAGE'], dtype='object')
# Predicted cols: Index(['PERCENTAGE'], dtype='object')
# Adj. Predicted cols: Index(['PERCENTAGE'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT river.name, COUNT(DISTINCT geo_river.province) FROM river JOIN geo_river ON river.name = geo_river.river GROUP BY river.name
# SELECT r.name, COUNT(DISTINCT p.name) AS num_provinces
# FROM mondial_river r
# JOIN mondial_riverthrough rt ON r.name = rt.river
# JOIN mondial_province p ON rt.province = p.name
# GROUP BY r.name;
# Error: Execution failed on sql 'SELECT r.name, COUNT(DISTINCT p.name) AS num_provinces
# FROM mondial_river r
# JOIN mondial_riverthrough rt ON r.name = rt.river
# JOIN mondial_province p ON rt.province = p.name
# GROUP BY r.name': ORA-00904: "RT"."PROVINCE": invalid identifier
# SELECT c.name FROM mondial_country c
# INNER JOIN mondial_politics p ON c.code = p.country
# WHERE independence > DATE '1910-08-01' AND independence < DATE '1950-08-01'
# SELECT name
# FROM mondial_politics
# WHERE independence BETWEEN TO_DATE('8/1/1910', 'MM/DD/YYYY') AND TO_DATE('8/1/1950', 'MM/DD/YYYY');
# Error: Execution failed on sql 'SELECT name
# FROM mondial_politics
# WHERE independence BETWEEN TO_DATE('8/1/1910', 'MM/DD/YYYY') AND TO_DATE('8/1/1950', 'MM/DD/YYYY')': ORA-00904: "NAME": invalid identifier
# SELECT * FROM mondial_city ci INNER JOIN mondial_country c on ci.country = c.code where c.name = 'Cuba'
# SELECT name
# FROM mondial_city
# WHERE country = 'CUB'
# True cols: Index(['NAME', 'COUNTRY', 'PROVINCE', 'POPULATION', 'LATITUDE', 'LONGITUDE',
#        'ELEVATION', 'META_REPCOL', 'NAME', 'CODE', 'CAPITAL', 'PROVINCE',
#        'AREA', 'POPULATION', 'META_REPCOL'],
#       dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT capital FROM mondial_country WHERE name = 'Georgia'
# SELECT capital FROM mondial_country WHERE name = 'Georgia'
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT count(p.name) FROM mondial_province p INNER JOIN mondial_country c on p.country = c.code where c.name = 'Niger' AND p.area > 1000
# SELECT COUNT(*)
# FROM mondial_province
# WHERE country = 'NER' AND area > 1000;
# True cols: Index(['COUNT(P.NAME)'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['COUNT(*)'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT name FROM mondial_country GROUP BY name ORDER BY max(area) DESC FETCH FIRST 1 ROWS ONLY;
# SELECT name, capital, population, gdp, agriculture, service, industry, inflation, unemployment
# FROM mondial_country
# WHERE area = (
#     SELECT MAX(area)
#     FROM mondial_country
# )
# Error: Execution failed on sql 'SELECT name, capital, population, gdp, agriculture, service, industry, inflation, unemployment
# FROM mondial_country
# WHERE area = (
#     SELECT MAX(area)
#     FROM mondial_country
# )': ORA-00904: "UNEMPLOYMENT": invalid identifier
# SELECT o.province, o.established  FROM mondial_organization o WHERE o.name LIKE '%International Energy Agency%'
# SELECT o.province, o.established
# FROM mondial_organization o
# WHERE o.name = 'International Energy Agency'
# True cols: Index(['PROVINCE', 'ESTABLISHED'], dtype='object')
# Adj. True cols: Index(['PROVINCE', 'ESTABLISHED'], dtype='object')
# Predicted cols: Index(['PROVINCE', 'ESTABLISHED'], dtype='object')
# Adj. Predicted cols: Index(['PROVINCE', 'ESTABLISHED'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name FROM mondial_mountain WHERE elevation > 1000.0
# SELECT name
# FROM mondial_mountain
# WHERE elevation > 1000;
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT DISTINCT e.* FROM mondial_economy e
# INNER JOIN mondial_country c ON e.country = c.code
# INNER JOIN mondial_geo_sea gs ON gs.country = c.code
# INNER JOIN mondial_sea s ON s.name = gs.sea
# WHERE s.name LIKE '%Caribbean Sea%'
# SELECT e.*
# FROM mondial_economy e
# INNER JOIN mondial_country c
# ON c.code = e.country
# INNER JOIN mondial_geo_sea gs
# ON gs.country = c.code
# INNER JOIN mondial_sea s
# ON s.name = gs.sea
# WHERE s.name = 'Caribbean Sea'
# True cols: Index(['COUNTRY', 'GDP', 'AGRICULTURE', 'SERVICE', 'INDUSTRY', 'INFLATION',
#        'UNEMPLOYMENT', 'META_REPCOL'],
#       dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['COUNTRY', 'GDP', 'AGRICULTURE', 'SERVICE', 'INDUSTRY', 'INFLATION',
#        'UNEMPLOYMENT', 'META_REPCOL'],
#       dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT name FROM mondial_city WHERE longitude BETWEEN 0 AND 6
# SELECT name
# FROM mondial_city
# WHERE longitude BETWEEN 0 AND 6;
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT ci.name FROM mondial_city ci
# INNER JOIN mondial_country c ON c.code = ci.country
# INNER JOIN mondial_population p ON p.country = c.code
# WHERE ci.population > 100000 AND ci.elevation > 2500 AND
# p.population_growth > 1
# SELECT c.name AS cityname, c.population, c.elevation, co.population_growth
# FROM mondial_city c
# JOIN mondial_country co ON c.country = co.code
# WHERE c.population > 100000 AND c.elevation > 2500 AND co.population_growth > 1;
# Error: Execution failed on sql 'SELECT c.name AS cityname, c.population, c.elevation, co.population_growth
# FROM mondial_city c
# JOIN mondial_country co ON c.country = co.code
# WHERE c.population > 100000 AND c.elevation > 2500 AND co.population_growth > 1': ORA-00904: "CO"."POPULATION_GROWTH": invalid identifier
# SELECT DISTINCT government FROM mondial_politics
# SELECT DISTINCT government FROM mondial_politics
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT p.name FROM mondial_province p INNER JOIN mondial_country c ON p.country = c.code  WHERE c.name = 'Germany'
# SELECT name FROM mondial_province WHERE country = 'DEU'
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT eg.percentage FROM mondial_ethnicgroup eg INNER JOIN mondial_country c ON c.code = eg.country WHERE c.name = 'Brazil' AND eg.name LIKE '%Mulatto%'
# SELECT e.percentage
# FROM mondial_ethnicgroup e
# INNER JOIN mondial_country c
# ON e.country = c.code
# WHERE e.name = 'Mulatto' AND c.name = 'Brazil'
# True cols: Index(['PERCENTAGE'], dtype='object')
# Adj. True cols: Index(['PERCENTAGE'], dtype='object')
# Predicted cols: Index(['PERCENTAGE'], dtype='object')
# Adj. Predicted cols: Index(['PERCENTAGE'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT count(*) FROM mondial_city WHERE population < 1000
# SELECT COUNT(*)
# FROM mondial_city
# WHERE population < 1000
# True cols: Index(['COUNT(*)'], dtype='object')
# Adj. True cols: Index(['COUNT(*)'], dtype='object')
# Predicted cols: Index(['COUNT(*)'], dtype='object')
# Adj. Predicted cols: Index(['COUNT(*)'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT avg(a.elevation) FROM mondial_airport a
# INNER JOIN mondial_country c ON c.code = a.country
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# WHERE co.name = 'America'
# SELECT AVG(elevation)
# FROM mondial_airport a
# INNER JOIN mondial_country c
# ON c.code = a.country
# WHERE c.name = 'America';
# True cols: Index(['AVG(A.ELEVATION)'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['AVG(ELEVATION)'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT COUNT(DISTINCT ec.country) AS number_of_countries
# FROM mondial_geo_sea gs
# JOIN mondial_encompasses ec ON gs.country = ec.country
# WHERE gs.sea = 'Caribbean Sea';
# SELECT COUNT(DISTINCT c.code)
# FROM mondial_country c
# JOIN mondial_geo_sea gs ON c.code = gs.country
# JOIN mondial_sea s ON gs.sea = s.name
# WHERE s.name = 'Caribbean Sea'
# True cols: Index(['NUMBER_OF_COUNTRIES'], dtype='object')
# Adj. True cols: Index(['NUMBER_OF_COUNTRIES'], dtype='object')
# Predicted cols: Index(['COUNT(DISTINCTC.CODE)'], dtype='object')
# Adj. Predicted cols: Index(['COUNT(DISTINCTC.CODE)'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT SUM(DISTINCT c.area) AS total_area
# FROM mondial_Country c
# JOIN mondial_encompasses e ON c.code = e.country
# JOIN mondial_geo_sea gs ON e.country = gs.country
# WHERE gs.sea = 'Caribbean Sea';
# SELECT SUM(c.area)
# FROM mondial_country c
# INNER JOIN mondial_geo_sea gs ON gs.country = c.code
# INNER JOIN mondial_sea s ON gs.sea = s.name
# WHERE s.name = 'Caribbean Sea'
# True cols: Index(['TOTAL_AREA'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['SUM(C.AREA)'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT c.name AS country_name, SUM(c1.population) AS total_neighbor_population
# FROM mondial_Country c
# JOIN mondial_Borders b ON c.code = b.country1
# JOIN mondial_Country c1 ON b.country2 = c1.code
# GROUP BY c.name;
# SELECT c.name AS country, SUM(cp.population) AS total_neighbor_population
# FROM mondial_country c
# INNER JOIN mondial_borders b ON c.code = b.country1
# INNER JOIN mondial_countrypops cp ON b.country2 = cp.country
# GROUP BY c.name;
# True cols: Index(['COUNTRY_NAME', 'TOTAL_NEIGHBOR_POPULATION'], dtype='object')
# Adj. True cols: Index(['COUNTRY_NAME'], dtype='object')
# Predicted cols: Index(['COUNTRY', 'TOTAL_NEIGHBOR_POPULATION'], dtype='object')
# Adj. Predicted cols: Index(['COUNTRY'], dtype='object')
# False: no match found
# SELECT mountain FROM mondial_mountainonisland WHERE island LIKE '%Borneo%'
# SELECT mm.name
# FROM mondial_mountainonisland mmoi
# JOIN mondial_mountain mm ON mmoi.mountain = mm.name
# JOIN mondial_island mi ON mmoi.island = mi.name
# WHERE mi.name = 'Borneo'
# True cols: Index(['MOUNTAIN'], dtype='object')
# Adj. True cols: Index(['MOUNTAIN'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name, population FROM mondial_country ORDER BY area ASC FETCH FIRST 1 ROWS ONLY;
# SELECT name, population
# FROM mondial_country
# WHERE area = (SELECT MIN(area) FROM mondial_country)
# True cols: Index(['NAME', 'POPULATION'], dtype='object')
# Adj. True cols: Index(['NAME', 'POPULATION'], dtype='object')
# Predicted cols: Index(['NAME', 'POPULATION'], dtype='object')
# Adj. Predicted cols: Index(['NAME', 'POPULATION'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT DISTINCT s.country
# FROM mondial_geo_estuary e, mondial_borders b, mondial_geo_source s
# WHERE ((e.country = b.country1 AND s.country = b.country2)
# OR (e.country = b.country2 AND s.country = b.country1))
# AND e.river = s.river;
# SELECT DISTINCT c.code
# FROM mondial_country c
# JOIN mondial_river r ON c.code = r.country
# JOIN mondial_geo_river gr ON r.name = gr.river
# JOIN mondial_country c1 ON gr.country = c1.code
# WHERE c1.code <> c.code;
# Error: Execution failed on sql 'SELECT DISTINCT c.code
# FROM mondial_country c
# JOIN mondial_river r ON c.code = r.country
# JOIN mondial_geo_river gr ON r.name = gr.river
# JOIN mondial_country c1 ON gr.country = c1.code
# WHERE c1.code <> c.code': ORA-00904: "R"."COUNTRY": invalid identifier
# SELECT code FROM mondial_country
# WHERE code NOT IN (
# SELECT p.country FROM (
# SELECT name, country
# FROM mondial_province
# WHERE (name, country) NOT IN (SELECT province, country FROM mondial_geo_mountain)) p);
# SELECT DISTINCT c.code
# FROM mondial_country c
# INNER JOIN mondial_province p
# ON c.code = p.country
# INNER JOIN mondial_mountainonisland moi
# ON p.name = moi.island
# GROUP BY c.code
# HAVING COUNT(DISTINCT p.name) = (SELECT COUNT(DISTINCT province) FROM mondial_province WHERE country = c.code)
# Error: Execution failed on sql 'SELECT DISTINCT c.code
# FROM mondial_country c
# INNER JOIN mondial_province p
# ON c.code = p.country
# INNER JOIN mondial_mountainonisland moi
# ON p.name = moi.island
# GROUP BY c.code
# HAVING COUNT(DISTINCT p.name) = (SELECT COUNT(DISTINCT province) FROM mondial_province WHERE country = c.code)': ORA-01427: single-row subquery returns more than one row
# SELECT b.country1, sum(b.length)
# FROM (SELECT country1, length FROM mondial_borders
# UNION ALL
# SELECT country2, length FROM mondial_borders
# ) b
# GROUP BY b.country1;
# SELECT c.code AS country_code, SUM(b.length) AS total_border_length
# FROM mondial_country c
# JOIN mondial_borders b ON c.code = b.country1
# GROUP BY c.code;
# True cols: Index(['COUNTRY1', 'SUM(B.LENGTH)'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['COUNTRY_CODE', 'TOTAL_BORDER_LENGTH'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT DISTINCT c.name, c.code
# FROM mondial_country c, mondial_geo_source g
# WHERE c.code = g.country;
# SELECT DISTINCT c.name, c.code
# FROM mondial_country c
# JOIN mondial_river r ON r.country = c.code
# WHERE r.river IS NOT NULL
# Error: Execution failed on sql 'SELECT DISTINCT c.name, c.code
# FROM mondial_country c
# JOIN mondial_river r ON r.country = c.code
# WHERE r.river IS NOT NULL': ORA-00904: "R"."COUNTRY": invalid identifier
# SELECT c.name, r.area FROM mondial_geo_river gr
# INNER JOIN mondial_country c ON c.code = gr.country
# INNER JOIN mondial_river r ON r.name = gr.river
# WHERE r.name = 'Chatanga'
# SELECT r.area, r.country
# FROM mondial_river r
# WHERE r.name = 'Chatanga River'
# Error: Execution failed on sql 'SELECT r.area, r.country
# FROM mondial_river r
# WHERE r.name = 'Chatanga River'': ORA-00904: "R"."COUNTRY": invalid identifier
# SELECT name FROM mondial_airport WHERE elevation > 3000.0
# SELECT name
# FROM mondial_airport
# WHERE elevation > 3000.0
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT r.name FROM mondial_religion r INNER JOIN mondial_country c ON c.code = r.country WHERE c.name = 'Mexico'
# SELECT r.name FROM mondial_religion r
# INNER JOIN mondial_country c ON r.country = c.code
# WHERE c.name = 'Mexico'
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name FROM mondial_River WHERE sea IS NULL;
# SELECT name
# FROM mondial_river
# WHERE name NOT IN (SELECT river FROM mondial_geo_sea)
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT c.name, COUNT(b.country2) AS num_neighbors FROM mondial_country c INNER JOIN mondial_borders b ON c.code = b.country1
# INNER JOIN mondial_encompasses e ON c.code = e.country
# INNER JOIN mondial_continent co ON e.continent = co.name
# WHERE co.name = 'Africa' GROUP BY c.name ORDER BY num_neighbors DESC;
# SELECT c.name AS country_name, COUNT(b.country2) AS number_of_neighbors
# FROM mondial_country c
# JOIN mondial_borders b ON c.code = b.country1
# JOIN mondial_encompasses e ON c.code = e.country
# JOIN mondial_continent co ON e.continent = co.name
# WHERE co.name = 'Africa'
# GROUP BY c.name
# ORDER BY number_of_neighbors DESC
# True cols: Index(['NAME', 'NUM_NEIGHBORS'], dtype='object')
# Adj. True cols: Index(['NAME', 'NUM_NEIGHBORS'], dtype='object')
# Predicted cols: Index(['COUNTRY_NAME', 'NUMBER_OF_NEIGHBORS'], dtype='object')
# Adj. Predicted cols: Index(['COUNTRY_NAME', 'NUMBER_OF_NEIGHBORS'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT c.name AS continent, AVG(p.infant_mortality) AS avg_infant_mortality
# FROM mondial_continent c
# JOIN mondial_encompasses e ON c.name = e.continent
# JOIN mondial_population p ON e.country = p.country
# GROUP BY c.name;
# SELECT co.name, AVG(p.infant_mortality)
# FROM mondial_continent co
# JOIN mondial_country c ON co.name = c.province
# JOIN mondial_population p ON c.code = p.country
# GROUP BY co.name
# True cols: Index(['CONTINENT', 'AVG_INFANT_MORTALITY'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME', 'AVG(P.INFANT_MORTALITY)'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT AVG(p.infant_mortality) AS avg_infant_mortality
# FROM mondial_Country c
# JOIN mondial_Population p ON c.code = p.country
# JOIN mondial_encompasses e ON c.code = e.country
# JOIN mondial_Continent ct ON e.continent = ct.name
# WHERE ct.name = 'America' AND c.name != 'Brazil';
# SELECT AVG(p.infant_mortality)
# FROM mondial_population p
# JOIN mondial_country c ON p.country = c.code
# JOIN mondial_encompasses e ON c.code = e.country
# JOIN mondial_continent co ON e.continent = co.name
# WHERE co.name = 'America' AND c.name != 'Brazil'
# True cols: Index(['AVG_INFANT_MORTALITY'], dtype='object')
# Adj. True cols: Index(['AVG_INFANT_MORTALITY'], dtype='object')
# Predicted cols: Index(['AVG(P.INFANT_MORTALITY)'], dtype='object')
# Adj. Predicted cols: Index(['AVG(P.INFANT_MORTALITY)'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name FROM mondial_sea WHERE area > 8000 AND depth < 100
# SELECT name
# FROM mondial_sea
# WHERE area > 8000 AND depth < 100;
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT count(DISTINCT m.name) FROM mondial_mountain m
# INNER JOIN mondial_geo_mountain gm ON m.name = gm.mountain
# INNER JOIN mondial_country c ON c.code = gm.country
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# WHERE co.name = 'Asia'
# SELECT count(*)
# FROM mondial_mountainonisland moi
# INNER JOIN mondial_island isl
# ON moi.island = isl.name
# INNER JOIN mondial_continent co
# ON isl.islands = co.name
# WHERE co.name = 'Asia'
# True cols: Index(['COUNT(DISTINCTM.NAME)'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['COUNT(*)'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT count(DISTINCT c.name) FROM mondial_country c
# INNER JOIN mondial_geo_sea gs ON gs.country = c.code
# INNER JOIN mondial_sea s ON gs.sea = s.name
# WHERE s.name = 'Mediterranean Sea'
# SELECT COUNT(DISTINCT gs.country) AS number_of_countries
# FROM mondial_geo_sea gs
# JOIN mondial_encompasses ec ON gs.country = ec.country
# WHERE gs.sea = 'Mediterranean Sea';
# True cols: Index(['COUNT(DISTINCTC.NAME)'], dtype='object')
# Adj. True cols: Index(['COUNT(DISTINCTC.NAME)'], dtype='object')
# Predicted cols: Index(['NUMBER_OF_COUNTRIES'], dtype='object')
# Adj. Predicted cols: Index(['NUMBER_OF_COUNTRIES'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT government, count(government) FROM mondial_politics GROUP BY government
# SELECT government, COUNT(*) AS total
# FROM mondial_politics
# GROUP BY government
# True cols: Index(['GOVERNMENT', 'COUNT(GOVERNMENT)'], dtype='object')
# Adj. True cols: Index(['GOVERNMENT', 'COUNT(GOVERNMENT)'], dtype='object')
# Predicted cols: Index(['GOVERNMENT', 'TOTAL'], dtype='object')
# Adj. Predicted cols: Index(['GOVERNMENT', 'TOTAL'], dtype='object')
# True: query matches sql (Similarity: 0.975609756097561, column match: 1.0)
# SELECT province FROM mondial_geo_desert gd
# INNER JOIN mondial_desert d ON gd.desert = d.name ORDER BY d.area DESC FETCH FIRST 1 ROWS ONLY;
# SELECT p.name
# FROM mondial_province p
# JOIN mondial_geo_desert gd ON p.name = gd.province
# JOIN mondial_desert d ON gd.desert = d.name
# WHERE d.area = (SELECT max(area) FROM mondial_desert)
# True cols: Index(['PROVINCE'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT name FROM mondial_desert ORDER BY area DESC FETCH FIRST 1 ROWS ONLY;
# SELECT name FROM mondial_desert ORDER BY area DESC FETCH FIRST 1 ROWS ONLY
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT co.name, count(gd.desert) FROM mondial_geo_desert gd
# INNER JOIN mondial_country c ON c.code = gd.country
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# GROUP BY co.name
# SELECT c.name, COUNT(d.name) AS desert_count
# FROM mondial_continent c
# LEFT JOIN mondial_desert d ON d.meta_repcol LIKE '%' || c.name || '%'
# GROUP BY c.name;
# True cols: Index(['NAME', 'COUNT(GD.DESERT)'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME', 'DESERT_COUNT'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# False: no match found
# SELECT sea2 FROM mergeswith WHERE sea1 = 'Banda Sea' UNION SELECT sea1 FROM mergeswith WHERE sea2 = 'Banda Sea'
# SELECT gs2.sea
# FROM mondial_geo_sea gs1
# JOIN mondial_mergeswith mw ON gs1.sea = mw.sea1
# JOIN mondial_geo_sea gs2 ON mw.sea2 = gs2.sea
# WHERE gs1.sea = 'Banda Sea';
# True cols: Index(['SEA2'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['SEA'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT c.capital FROM mondial_country c
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# WHERE co.name = 'Europe'
# SELECT c.capital
# FROM mondial_country c
# JOIN mondial_encompasses e ON c.code = e.country
# JOIN mondial_continent co ON e.continent = co.name
# WHERE co.name = 'Europe'
# True cols: Index(['CAPITAL'], dtype='object')
# Adj. True cols: Index(['CAPITAL'], dtype='object')
# Predicted cols: Index(['CAPITAL'], dtype='object')
# Adj. Predicted cols: Index(['CAPITAL'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT l.percentage FROM mondial_language l
# INNER JOIN mondial_country c ON l.country = c.code
# WHERE l.name LIKE '%French%' AND c.name = 'Andorra'
# SELECT l.percentage
# FROM mondial_language l
# INNER JOIN mondial_country c
# ON l.country = c.code
# WHERE c.name = 'Andorra'
# AND l.name = 'French'
# True cols: Index(['PERCENTAGE'], dtype='object')
# Adj. True cols: Index(['PERCENTAGE'], dtype='object')
# Predicted cols: Index(['PERCENTAGE'], dtype='object')
# Adj. Predicted cols: Index(['PERCENTAGE'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name FROM mondial_river WHERE length > 1000
# SELECT name
# FROM mondial_river
# WHERE length > 1000;
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT c.name FROM mondial_country c
# INNER JOIN mondial_population p ON p.country = c.code
# ORDER BY p.population_growth ASC FETCH FIRST 1 ROWS ONLY
# SELECT country FROM mondial_population GROUP BY country ORDER BY population_growth ASC FETCH FIRST 1 ROWS ONLY;
# Error: Execution failed on sql 'SELECT country FROM mondial_population GROUP BY country ORDER BY population_growth ASC FETCH FIRST 1 ROWS ONLY': ORA-00979: not a GROUP BY expression
# SELECT c.capital FROM mondial_country c WHERE c.capital NOT IN (SELECT lo.city FROM mondial_located lo )
# SELECT c.capital
# FROM mondial_country c
# LEFT JOIN mondial_located l ON c.capital = l.city
# WHERE l.city IS NULL
# True cols: Index(['CAPITAL'], dtype='object')
# Adj. True cols: Index(['CAPITAL'], dtype='object')
# Predicted cols: Index(['CAPITAL'], dtype='object')
# Adj. Predicted cols: Index(['CAPITAL'], dtype='object')
# True: query matches sql (Similarity: 0.9846153846153847, column match: 1.0)
# SELECT p.CAPITAL
# FROM MONDIAL_PROVINCE p
# WHERE p.name like '%Andalucía%'
# SELECT capital FROM mondial_province WHERE name = 'Andalucía'
# True cols: Index(['CAPITAL'], dtype='object')
# Adj. True cols: Index(['CAPITAL'], dtype='object')
# Predicted cols: Index(['CAPITAL'], dtype='object')
# Adj. Predicted cols: Index(['CAPITAL'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT abbreviation FROM mondial_organization WHERE name='General Confederation of Trade Unions'
# SELECT abbreviation FROM mondial_organization WHERE name = 'General Confederation of Trade Unions'
# True cols: Index(['ABBREVIATION'], dtype='object')
# Adj. True cols: Index(['ABBREVIATION'], dtype='object')
# Predicted cols: Index(['ABBREVIATION'], dtype='object')
# Adj. Predicted cols: Index(['ABBREVIATION'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT city FROM mondial_organization WHERE abbreviation='UPU'
# SELECT o.city
# FROM mondial_organization o
# WHERE o.abbreviation = 'UPU'
# True cols: Index(['CITY'], dtype='object')
# Adj. True cols: Index(['CITY'], dtype='object')
# Predicted cols: Index(['CITY'], dtype='object')
# Adj. Predicted cols: Index(['CITY'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT c.name
# FROM mondial_country c
# JOIN mondial_ismember m
# ON c.code=m.country
# WHERE m.organization=ALL(SELECT organization
# FROM mondial_ismember m
# WHERE
# m.country=c.code)
# SELECT c.name
# FROM mondial_country c
# INNER JOIN mondial_ismember i ON c.code = i.country
# GROUP BY c.name
# HAVING COUNT(i.organization) = 1
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT c.name
# FROM mondial_country c
# WHERE c.code NOT IN (SELECT m.country
# FROM mondial_ismember m
# WHERE organization='NATO')
# SELECT name
# FROM mondial_country
# WHERE code NOT IN (
# SELECT country
# FROM mondial_ismember
# WHERE organization = 'NATO'
# )
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT c.name
# FROM mondial_country c
# JOIN mondial_ismember m
# ON c.code=m.country
# WHERE organization='NATO'
# SELECT c.name
# FROM mondial_country c
# INNER JOIN mondial_ismember i ON c.code = i.country
# WHERE i.organization = 'NATO'
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name FROM mondial_river WHERE length < 50
# SELECT name FROM mondial_river WHERE length < 50
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT l.area, l.elevation, l.type FROM MONDIAL_GEO_LAKE gl , MONDIAL_LAKE l, MONDIAL_COUNTRY c
# WHERE (gl.LAKE = l.NAME)
# AND (gl.COUNTRY = c.CODE)
# AND  c.name = 'Italy'
# SELECT l.area, l.elevation, l.type
# FROM mondial_lake l
# JOIN mondial_lakein li ON l.name = li.lake
# JOIN mondial_country c ON li.country = c.code
# WHERE c.name = 'Italy'
# Error: Execution failed on sql 'SELECT l.area, l.elevation, l.type
# FROM mondial_lake l
# JOIN mondial_lakein li ON l.name = li.lake
# JOIN mondial_country c ON li.country = c.code
# WHERE c.name = 'Italy'': ORA-00942: table or view does not exist
# SELECT c.capital
# FROM mondial_country c
# WHERE c.capital IN (SELECT o.city
# FROM mondial_organization o) ORDER BY c.capital ASC
# SELECT c.capital
# FROM mondial_country c
# JOIN mondial_organization o ON c.capital = o.city
# ORDER BY c.capital ASC
# True cols: Index(['CAPITAL'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['CAPITAL'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT o.name
# FROM mondial_organization o
# WHERE NOT EXISTS (SELECT *
# FROM mondial_ismember m
# JOIN mondial_country c
# ON m.country=c.code
# WHERE m.organization=o.abbreviation
# AND c.area <=4000
# AND m.type= 'member')
# SELECT name
# FROM mondial_organization
# WHERE abbreviation IN (
#     SELECT organization
#     FROM mondial_ismember
#     WHERE type = 'member'
#     GROUP BY organization
#     HAVING MIN(country) NOT IN (
#         SELECT code
#         FROM mondial_country
#         WHERE area < 4000
#     )
# )
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT o.name
# FROM mondial_organization o
# WHERE NOT EXISTS (SELECT *
# FROM mondial_ismember m
# JOIN mondial_country c
# ON m.country=c.code
# WHERE m.organization=o.abbreviation
# AND c.area > 10000
# AND c.population < 3000
# AND m.type= 'member')
# SELECT o.name
# FROM mondial_organization o
# WHERE NOT EXISTS (
#     SELECT 1
#     FROM mondial_country c
#     WHERE c.area > 10000 AND c.population < 3000
#     AND c.code = o.country
# )
# AND o.type = 'member'
# Error: Execution failed on sql 'SELECT o.name
# FROM mondial_organization o
# WHERE NOT EXISTS (
#     SELECT 1
#     FROM mondial_country c
#     WHERE c.area > 10000 AND c.population < 3000
#     AND c.code = o.country
# )
# AND o.type = 'member'': ORA-00904: "O"."TYPE": invalid identifier
# SELECT DISTINCT e.inflation FROM mondial_economy e
# INNER JOIN mondial_country c ON e.country = c.code
# INNER JOIN mondial_geo_sea gs ON gs.country = c.code
# INNER JOIN mondial_sea s ON s.name = gs.sea
# WHERE s.name LIKE '%Arabian Sea%' ORDER BY e.inflation
# SELECT e.inflation
# FROM mondial_economy e
# JOIN mondial_country c ON e.country = c.code
# JOIN mondial_geo_sea gs ON gs.country = c.code
# JOIN mondial_sea s ON gs.sea = s.name
# WHERE s.name = 'Arabian Sea'
# True cols: Index(['INFLATION'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['INFLATION'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT c.capital FROM mondial_country c
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# WHERE co.name = 'Africa'
# SELECT c.capital
# FROM mondial_country c
# JOIN mondial_encompasses e ON c.code = e.country
# JOIN mondial_continent co ON e.continent = co.name
# WHERE co.name = 'Africa'
# True cols: Index(['CAPITAL'], dtype='object')
# Adj. True cols: Index(['CAPITAL'], dtype='object')
# Predicted cols: Index(['CAPITAL'], dtype='object')
# Adj. Predicted cols: Index(['CAPITAL'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT DISTINCT e.inflation FROM mondial_economy e
# INNER JOIN mondial_country c ON e.country = c.code
# INNER JOIN mondial_geo_sea gs ON gs.country = c.code
# INNER JOIN mondial_sea s ON s.name = gs.sea
# WHERE s.name LIKE '%Arabian Sea%' AND e.INFLATION IS NOT NULL
# SELECT e.inflation
# FROM mondial_economy e
# JOIN mondial_country c ON e.country = c.code
# JOIN mondial_geo_sea gs ON c.code = gs.country
# JOIN mondial_sea s ON gs.sea = s.name
# WHERE s.name = 'Arabian Sea' AND e.inflation IS NOT NULL
# True cols: Index(['INFLATION'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['INFLATION'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT count(*) FROM mondial_country c
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# WHERE co.name = 'Africa'
# SELECT COUNT(*) FROM mondial_encompasses WHERE continent = 'Africa'
# True cols: Index(['COUNT(*)'], dtype='object')
# Adj. True cols: Index(['COUNT(*)'], dtype='object')
# Predicted cols: Index(['COUNT(*)'], dtype='object')
# Adj. Predicted cols: Index(['COUNT(*)'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name FROM country WHERE code NOT IN (SELECT country FROM ismember WHERE organization = 'NATO')
# INTERSECT SELECT name FROM country WHERE code NOT IN (SELECT country FROM ismember WHERE organization = 'UNESCO')
# SELECT name
# FROM mondial_country
# WHERE code NOT IN (
# SELECT country
# FROM mondial_ismember
# WHERE organization IN ('NATO', 'UNESCO')
# );
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT area FROM mondial_continent WHERE name = 'Europe'
# SELECT area
# FROM mondial_continent
# WHERE name = 'Europe'
# True cols: Index(['AREA'], dtype='object')
# Adj. True cols: Index(['AREA'], dtype='object')
# Predicted cols: Index(['AREA'], dtype='object')
# Adj. Predicted cols: Index(['AREA'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT area FROM mondial_continent WHERE name = 'America'
# SELECT area
# FROM mondial_continent
# WHERE name = 'America'
# True cols: Index(['AREA'], dtype='object')
# Adj. True cols: Index(['AREA'], dtype='object')
# Predicted cols: Index(['AREA'], dtype='object')
# Adj. Predicted cols: Index(['AREA'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT area FROM mondial_continent WHERE name = 'Asia'
# SELECT area
# FROM mondial_continent
# WHERE name = 'Asia'
# True cols: Index(['AREA'], dtype='object')
# Adj. True cols: Index(['AREA'], dtype='object')
# Predicted cols: Index(['AREA'], dtype='object')
# Adj. Predicted cols: Index(['AREA'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT area FROM mondial_continent WHERE name = 'Africa'
# SELECT area FROM mondial_continent WHERE name = 'Africa'
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT count(*) FROM mondial_country c
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# WHERE co.name = 'America'
# SELECT COUNT(*) AS number_of_countries
# FROM mondial_continent c
# JOIN mondial_encompasses e ON c.name = e.continent
# WHERE c.name = 'America'
# True cols: Index(['COUNT(*)'], dtype='object')
# Adj. True cols: Index(['COUNT(*)'], dtype='object')
# Predicted cols: Index(['NUMBER_OF_COUNTRIES'], dtype='object')
# Adj. Predicted cols: Index(['NUMBER_OF_COUNTRIES'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT max(area) FROM mondial_continent
# SELECT name, area FROM mondial_continent ORDER BY area DESC FETCH FIRST 1 ROWS ONLY;
# True cols: Index(['MAX(AREA)'], dtype='object')
# Adj. True cols: Index(['MAX(AREA)'], dtype='object')
# Predicted cols: Index(['NAME', 'AREA'], dtype='object')
# Adj. Predicted cols: Index(['AREA'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT c.name
# FROM mondial_country c
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# WHERE e.continent = (
#     SELECT name
#     FROM mondial_continent
#     GROUP BY name
#     ORDER BY MAX(area) DESC
#     FETCH FIRST 1 ROWS ONLY
# );
# SELECT c.name
# FROM mondial_country c
# JOIN mondial_encompasses e ON c.code = e.country
# JOIN mondial_continent co ON e.continent = co.name
# WHERE co.area = (SELECT MAX(area) FROM mondial_continent)
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT c.name
# FROM mondial_country c
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# INNER JOIN mondial_language l ON l.country = c.code
# WHERE e.continent = (
#     SELECT name
#     FROM mondial_continent
#     GROUP BY name
#     ORDER BY MAX(area) DESC
#     FETCH FIRST 1 ROWS ONLY
# ) AND l.name='English';
# SELECT c.name
# FROM mondial_country c
# INNER JOIN mondial_encompasses e ON c.code = e.country
# INNER JOIN mondial_continent co ON e.continent = co.name
# INNER JOIN mondial_language l ON c.code = l.country
# WHERE co.area = (SELECT MAX(area) FROM mondial_continent)
# AND l.name = 'English'
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT ci.name AS cityname, c.name AS countryname
# FROM mondial_city ci
# JOIN mondial_country c ON ci.country = c.code
# WHERE ci.population > 5000000
# ORDER BY ci.population DESC;
# SELECT ci.name, co.name
# FROM mondial_city ci
# JOIN mondial_country co ON ci.country = co.code
# WHERE ci.population > 5000000
# ORDER BY ci.population DESC
# True cols: Index(['CITYNAME', 'COUNTRYNAME'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME', 'NAME'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT d.name FROM mondial_desert d
# INNER JOIN mondial_geo_desert gd ON gd.desert = d.name
# WHERE gd.province='Algeria'
# SELECT d.name FROM mondial_geo_desert gd
# INNER JOIN mondial_desert d ON gd.desert = d.name
# WHERE gd.country = 'DZA'
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT d.name, d.area FROM mondial_desert d
# INNER JOIN mondial_geo_desert gd ON gd.desert = d.name
# WHERE gd.province='California'
# SELECT d.name, d.area FROM mondial_desert d
# JOIN mondial_geo_desert gd ON d.name = gd.desert
# WHERE gd.province = 'California'
# True cols: Index(['NAME', 'AREA'], dtype='object')
# Adj. True cols: Index(['NAME', 'AREA'], dtype='object')
# Predicted cols: Index(['NAME', 'AREA'], dtype='object')
# Adj. Predicted cols: Index(['NAME', 'AREA'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT c.name, l.percentage FROM mondial_language l INNER JOIN mondial_country c
# ON l.country = c.code WHERE l.name = 'French'
# SELECT c.name, l.percentage
# FROM mondial_country c
# INNER JOIN mondial_language l ON c.code = l.country
# WHERE l.name LIKE '%French%'
# True cols: Index(['NAME', 'PERCENTAGE'], dtype='object')
# Adj. True cols: Index(['NAME', 'PERCENTAGE'], dtype='object')
# Predicted cols: Index(['NAME', 'PERCENTAGE'], dtype='object')
# Adj. Predicted cols: Index(['NAME', 'PERCENTAGE'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT ci.name
# FROM mondial_city ci
# INNER JOIN mondial_country co
# ON co.code = ci.country
# INNER JOIN mondial_language l
# ON l.country = co.code
# WHERE l.name = 'Portuguese';
# SELECT c.name
# FROM mondial_city c
# INNER JOIN mondial_language l ON c.country = l.country
# WHERE l.name = 'Portuguese'
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT SUM(p.area)
# FROM mondial_province p
# INNER JOIN mondial_country c
# ON p.country = c.code
# WHERE c.name = 'Canada';
# SELECT SUM(area) FROM mondial_province WHERE country = 'CAN'
# True cols: Index(['SUM(P.AREA)'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['SUM(AREA)'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT length FROM mondial_river WHERE name LIKE '%Tigris%'
# SELECT length FROM mondial_river WHERE name = 'Tigris'
# True cols: Index(['LENGTH'], dtype='object')
# Adj. True cols: Index(['LENGTH'], dtype='object')
# Predicted cols: Index(['LENGTH'], dtype='object')
# Adj. Predicted cols: Index(['LENGTH'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name
# FROM mondial_airport
# WHERE elevation > 1000.0;
# SELECT name FROM mondial_airport WHERE elevation > 1000
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT a.name
# FROM mondial_airport a
# INNER JOIN mondial_country c
# ON c.code = a.country
# WHERE c.name = 'United States' AND a.elevation <200;
# SELECT name FROM mondial_airport WHERE elevation < 200 AND country = 'USA'
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name
# FROM mondial_mountain
# WHERE elevation > 8000;
# SELECT name FROM mondial_mountain WHERE elevation > 8000.0
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name
# FROM mondial_airport
# ORDER BY LENGTH(name) DESC
# FETCH FIRST 3 ROWS ONLY;
# SELECT name FROM mondial_airport ORDER BY LENGTH(name) DESC FETCH FIRST 3 ROWS ONLY
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name
# FROM mondial_lake
# WHERE area < 5000;
# SELECT name FROM mondial_lake WHERE area < 5000
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT SUM(area)
# FROM mondial_sea
# WHERE depth > 1000;
# SELECT SUM(area) AS total_area
# FROM mondial_sea
# WHERE depth > 1000
# True cols: Index(['SUM(AREA)'], dtype='object')
# Adj. True cols: Index(['SUM(AREA)'], dtype='object')
# Predicted cols: Index(['TOTAL_AREA'], dtype='object')
# Adj. Predicted cols: Index(['TOTAL_AREA'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name
# FROM mondial_country
# WHERE name LIKE 'B%' AND population > 10000000;
# SELECT name FROM mondial_country WHERE name LIKE 'B%' AND population > 10000000
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT cio.othername
# FROM mondial_cityothername cio
# INNER JOIN mondial_country c
# ON cio.country = c.code
# WHERE c.name = 'Brazil'
# SELECT ci.name FROM mondial_cityothername co
# INNER JOIN mondial_city ci ON ci.name = co.city
# INNER JOIN mondial_country c ON c.code = ci.country
# WHERE c.name = 'Brazil'
# True cols: Index(['OTHERNAME'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT name
# FROM mondial_city
# WHERE latitude > 45;
# SELECT name FROM mondial_city WHERE latitude > 45
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT count(DISTINCT cio.city)
# FROM mondial_cityothername cio
# INNER JOIN mondial_country c
# ON cio.country = c.code
# WHERE c.area >30000
# SELECT count(*)
# FROM mondial_cityothername co
# JOIN mondial_country c ON co.country = c.code
# WHERE c.area > 30000
# True cols: Index(['COUNT(DISTINCTCIO.CITY)'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['COUNT(*)'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT name
# FROM mondial_desert
# WHERE area > 10000;
# SELECT name FROM mondial_desert WHERE area > 10000
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT island.name
# FROM island
# JOIN lakeonisland ON island.name = lakeonisland.island
# JOIN lake ON lake.name = lakeonisland.lake
# WHERE lake.elevation > 100;
# SELECT island FROM mondial_islandin WHERE lake IN (SELECT name FROM mondial_lake WHERE elevation > 100)
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['ISLAND'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT moi.mountain
# FROM mondial_mountainonisland moi
# INNER JOIN mondial_island isl
# ON moi.island = isl.name
# WHERE isl.area > 100000
# SELECT m.name
# FROM mondial_mountain m
# JOIN mondial_mountainonisland mi ON m.name = mi.mountain
# JOIN mondial_island i ON mi.island = i.name
# WHERE i.area > 100000
# True cols: Index(['MOUNTAIN'], dtype='object')
# Adj. True cols: Index(['MOUNTAIN'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# ...
# ) AND code NOT IN (
#     SELECT country FROM mondial_ismember WHERE organization = 'UNESCO'
# );
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT area FROM mondial_continent WHERE name = 'Europe'
# SELECT area FROM mondial_continent WHERE name = 'Europe'
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT area FROM mondial_continent WHERE name = 'America'
# SELECT area FROM mondial_continent WHERE name = 'America'
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT area FROM mondial_continent WHERE name = 'Asia'
# SELECT area FROM mondial_continent WHERE name = 'Asia'
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT area FROM mondial_continent WHERE name = 'Africa'
# SELECT area FROM mondial_continent WHERE name = 'Africa'
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT count(*) FROM mondial_country c
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# WHERE co.name = 'America'
# SELECT COUNT(DISTINCT country) FROM mondial_encompasses WHERE continent = 'America';
# True cols: Index(['COUNT(*)'], dtype='object')
# Adj. True cols: Index(['COUNT(*)'], dtype='object')
# Predicted cols: Index(['COUNT(DISTINCTCOUNTRY)'], dtype='object')
# Adj. Predicted cols: Index(['COUNT(DISTINCTCOUNTRY)'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT max(area) FROM mondial_continent
# SELECT name FROM mondial_continent ORDER BY area DESC FETCH FIRST 1 ROWS ONLY;
# True cols: Index(['MAX(AREA)'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT c.name
# FROM mondial_country c
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# WHERE e.continent = (
#     SELECT name
#     FROM mondial_continent
#     GROUP BY name
#     ORDER BY MAX(area) DESC
#     FETCH FIRST 1 ROWS ONLY
# );
# SELECT c.name FROM mondial_country c
# JOIN mondial_encompasses e ON c.code = e.country
# JOIN mondial_continent co ON co.name = e.continent
# WHERE co.area = (SELECT MAX(area) FROM mondial_continent);
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT c.name
# FROM mondial_country c
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# INNER JOIN mondial_language l ON l.country = c.code
# WHERE e.continent = (
#     SELECT name
#     FROM mondial_continent
#     GROUP BY name
#     ORDER BY MAX(area) DESC
#     FETCH FIRST 1 ROWS ONLY
# ) AND l.name='English';
# SELECT DISTINCT c.name
# FROM mondial_country c
# JOIN mondial_language l ON c.code = l.country
# JOIN mondial_encompasses e ON c.code = e.country
# JOIN mondial_continent co ON e.continent = co.name
# WHERE l.name = 'English' AND co.name = (
#   SELECT name FROM mondial_continent ORDER BY area DESC FETCH FIRST 1 ROWS ONLY
# )
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT ci.name AS cityname, c.name AS countryname
# FROM mondial_city ci
# JOIN mondial_country c ON ci.country = c.code
# WHERE ci.population > 5000000
# ORDER BY ci.population DESC;
# SELECT ci.name AS city_name, co.name AS country_name
# FROM mondial_city ci
# JOIN mondial_country co ON ci.country = co.code
# WHERE ci.population > 5000000
# ORDER BY ci.population DESC
# True cols: Index(['CITYNAME', 'COUNTRYNAME'], dtype='object')
# Adj. True cols: Index(['CITYNAME', 'COUNTRYNAME'], dtype='object')
# Predicted cols: Index(['CITY_NAME', 'COUNTRY_NAME'], dtype='object')
# Adj. Predicted cols: Index(['CITY_NAME', 'COUNTRY_NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT d.name FROM mondial_desert d
# INNER JOIN mondial_geo_desert gd ON gd.desert = d.name
# WHERE gd.province='Algeria'
# SELECT d.name FROM mondial_geo_desert gd
# INNER JOIN mondial_desert d ON gd.desert = d.name
# WHERE gd.province = 'Algeria';
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT d.name, d.area FROM mondial_desert d
# INNER JOIN mondial_geo_desert gd ON gd.desert = d.name
# WHERE gd.province='California'
# SELECT d.name, d.area FROM mondial_geo_desert gd
# INNER JOIN mondial_desert d ON gd.desert = d.name
# WHERE gd.province = 'California';
# True cols: Index(['NAME', 'AREA'], dtype='object')
# Adj. True cols: Index(['NAME', 'AREA'], dtype='object')
# Predicted cols: Index(['NAME', 'AREA'], dtype='object')
# Adj. Predicted cols: Index(['NAME', 'AREA'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT c.name, l.percentage FROM mondial_language l INNER JOIN mondial_country c
# ON l.country = c.code WHERE l.name = 'French'
# SELECT c.name, l.percentage FROM mondial_language l INNER JOIN mondial_country c ON l.country = c.code WHERE l.name LIKE '%French%'
# True cols: Index(['NAME', 'PERCENTAGE'], dtype='object')
# Adj. True cols: Index(['NAME', 'PERCENTAGE'], dtype='object')
# Predicted cols: Index(['NAME', 'PERCENTAGE'], dtype='object')
# Adj. Predicted cols: Index(['NAME', 'PERCENTAGE'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT ci.name
# FROM mondial_city ci
# INNER JOIN mondial_country co
# ON co.code = ci.country
# INNER JOIN mondial_language l
# ON l.country = co.code
# WHERE l.name = 'Portuguese';
# SELECT DISTINCT ci.name
# FROM mondial_city ci
# JOIN mondial_country co ON ci.country = co.code
# JOIN mondial_language l ON co.code = l.country
# WHERE l.name = 'Portuguese'
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT SUM(p.area)
# FROM mondial_province p
# INNER JOIN mondial_country c
# ON p.country = c.code
# WHERE c.name = 'Canada';
# SELECT SUM(area) FROM mondial_province WHERE country = (SELECT code FROM mondial_country WHERE name = 'Canada')
# True cols: Index(['SUM(P.AREA)'], dtype='object')
# Adj. True cols: Index(['SUM(P.AREA)'], dtype='object')
# Predicted cols: Index(['SUM(AREA)'], dtype='object')
# Adj. Predicted cols: Index(['SUM(AREA)'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT length FROM mondial_river WHERE name LIKE '%Tigris%'
# SELECT length FROM mondial_river WHERE name = 'Tigris'
# True cols: Index(['LENGTH'], dtype='object')
# Adj. True cols: Index(['LENGTH'], dtype='object')
# Predicted cols: Index(['LENGTH'], dtype='object')
# Adj. Predicted cols: Index(['LENGTH'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name
# FROM mondial_airport
# WHERE elevation > 1000.0;
# SELECT name FROM mondial_airport WHERE elevation > 1000.0
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT a.name
# FROM mondial_airport a
# INNER JOIN mondial_country c
# ON c.code = a.country
# WHERE c.name = 'United States' AND a.elevation <200;
# SELECT name FROM mondial_airport WHERE country = 'USA' AND elevation < 200
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name
# FROM mondial_mountain
# WHERE elevation > 8000;
# SELECT name FROM mondial_mountain WHERE elevation > 8000.0
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name
# FROM mondial_airport
# ORDER BY LENGTH(name) DESC
# FETCH FIRST 3 ROWS ONLY;
# SELECT name FROM mondial_airport ORDER BY LENGTH(name) DESC FETCH FIRST 3 ROWS ONLY;
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name
# FROM mondial_lake
# WHERE area < 5000;
# SELECT name FROM mondial_lake WHERE area < 5000
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT SUM(area)
# FROM mondial_sea
# WHERE depth > 1000;
# SELECT SUM(area) AS total_area FROM mondial_sea WHERE depth > 1000
# True cols: Index(['SUM(AREA)'], dtype='object')
# Adj. True cols: Index(['SUM(AREA)'], dtype='object')
# Predicted cols: Index(['TOTAL_AREA'], dtype='object')
# Adj. Predicted cols: Index(['TOTAL_AREA'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name
# FROM mondial_country
# WHERE name LIKE 'B%' AND population > 10000000;
# SELECT name FROM mondial_country WHERE name LIKE 'B%' AND population > 10000000
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT cio.othername
# FROM mondial_cityothername cio
# INNER JOIN mondial_country c
# ON cio.country = c.code
# WHERE c.name = 'Brazil'
# SELECT con.othername FROM mondial_cityothername con INNER JOIN mondial_country c ON con.country = c.code WHERE c.name = 'Brazil'
# True cols: Index(['OTHERNAME'], dtype='object')
# Adj. True cols: Index(['OTHERNAME'], dtype='object')
# Predicted cols: Index(['OTHERNAME'], dtype='object')
# Adj. Predicted cols: Index(['OTHERNAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name
# FROM mondial_city
# WHERE latitude > 45;
# SELECT name FROM mondial_city WHERE latitude > 45
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT count(DISTINCT cio.city)
# FROM mondial_cityothername cio
# INNER JOIN mondial_country c
# ON cio.country = c.code
# WHERE c.area >30000
# SELECT COUNT(*) FROM mondial_cityothername con
# JOIN mondial_country c ON con.country = c.code
# WHERE c.area > 30000
# True cols: Index(['COUNT(DISTINCTCIO.CITY)'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['COUNT(*)'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT name
# FROM mondial_desert
# WHERE area > 10000;
# SELECT name FROM mondial_desert WHERE area > 10000
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT island.name
# FROM island
# JOIN lakeonisland ON island.name = lakeonisland.island
# JOIN lake ON lake.name = lakeonisland.lake
# WHERE lake.elevation > 100;
# SELECT DISTINCT island FROM mondial_islandin i JOIN mondial_lake l ON i.lake = l.name WHERE l.elevation > 100
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['ISLAND'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT moi.mountain
# FROM mondial_mountainonisland moi
# INNER JOIN mondial_island isl
# ON moi.island = isl.name
# WHERE isl.area > 100000
# SELECT DISTINCT m.name
# FROM mondial_mountain m
# JOIN mondial_mountainonisland mmi ON m.name = mmi.mountain
# JOIN mondial_island i ON mmi.island = i.name
# WHERE i.area > 100000
# True cols: Index(['MOUNTAIN'], dtype='object')
# Adj. True cols: Index(['MOUNTAIN'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT c.name AS country, SUM(p.area) AS total_province_area
# FROM mondial_country c
# INNER JOIN mondial_province p
# ON c.code = p.country
# GROUP BY c.name;
# SELECT c.name, SUM(p.area) AS total_provincial_area
# FROM mondial_country c
# JOIN mondial_province p ON c.code = p.country
# GROUP BY c.name;
# True cols: Index(['COUNTRY', 'TOTAL_PROVINCE_AREA'], dtype='object')
# Adj. True cols: Index(['COUNTRY', 'TOTAL_PROVINCE_AREA'], dtype='object')
# Predicted cols: Index(['NAME', 'TOTAL_PROVINCIAL_AREA'], dtype='object')
# Adj. Predicted cols: Index(['NAME', 'TOTAL_PROVINCIAL_AREA'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT c.name AS country, AVG(ci.elevation) AS average_city_population, SUM(ci.population) AS total_city_area
# FROM mondial_country c
# INNER JOIN mondial_city ci
# ON c.code = ci.country
# GROUP BY c.name;
# SELECT c.name AS country_name, AVG(ci.elevation) AS average_elevation, SUM(ci.population) AS total_population
# FROM mondial_country c
# JOIN mondial_city ci ON c.code = ci.country
# GROUP BY c.name;
# True cols: Index(['COUNTRY', 'AVERAGE_CITY_POPULATION', 'TOTAL_CITY_AREA'], dtype='object')
# Adj. True cols: Index(['COUNTRY', 'AVERAGE_CITY_POPULATION', 'TOTAL_CITY_AREA'], dtype='object')
# Predicted cols: Index(['COUNTRY_NAME', 'AVERAGE_ELEVATION', 'TOTAL_POPULATION'], dtype='object')
# Adj. Predicted cols: Index(['COUNTRY_NAME', 'AVERAGE_ELEVATION', 'TOTAL_POPULATION'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT e.inflation FROM mondial_country c JOIN mondial_economy e ON c.code=e.country WHERE c.name LIKE '%Germany%'
# SELECT e.inflation FROM mondial_economy e
# INNER JOIN mondial_country c ON e.country = c.code
# WHERE c.name = 'Germany'
# True cols: Index(['INFLATION'], dtype='object')
# Adj. True cols: Index(['INFLATION'], dtype='object')
# Predicted cols: Index(['INFLATION'], dtype='object')
# Adj. Predicted cols: Index(['INFLATION'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT p.government
# FROM mondial_country c
# INNER JOIN mondial_politics p
# ON p.country = c.code
# WHERE c.name = 'Iran'
# SELECT government FROM mondial_politics WHERE country = (SELECT code FROM mondial_country WHERE name = 'Iran')
# True cols: Index(['GOVERNMENT'], dtype='object')
# Adj. True cols: Index(['GOVERNMENT'], dtype='object')
# Predicted cols: Index(['GOVERNMENT'], dtype='object')
# Adj. Predicted cols: Index(['GOVERNMENT'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT e.industry
# FROM mondial_economy e
# INNER JOIN mondial_country c
# ON c.code = e.country
# WHERE c.name = 'Japan'
# SELECT e.industry FROM mondial_economy e INNER JOIN mondial_country c ON e.country = c.code WHERE c.name = 'Japan'
# True cols: Index(['INDUSTRY'], dtype='object')
# Adj. True cols: Index(['INDUSTRY'], dtype='object')
# Predicted cols: Index(['INDUSTRY'], dtype='object')
# Adj. Predicted cols: Index(['INDUSTRY'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# 247462
# 0.0
# 243519 3943
# 337.63931608200073

# %%
df_rag = pd.DataFrame(results_fk, columns=['experiment', 'simple', 'medium', 'complex', 'total', 'overall_simple', 'overall_medium', 'overall_complex', 'overall_total','input_tokens', 'output_tokens', 'total_tokens','total_cost', 'total_time'])
df_rag['experiment'] = df_rag['experiment'].apply(get_experiment_name)
df_rag = df_rag.sort_values(by='overall_total', ascending=False)
df_rag
# Out:
#                                     experiment  simple  medium  complex  \
# 1    SQLQueryChain - MONDIAL_GPT - GPT-4 - RAG      28      27       25
# 0  SQLQueryChain - MONDIAL_GPT - GPT-3.5 - RAG      25      20       17
#
#    total  overall_simple  overall_medium  overall_complex  overall_total  \
# 1     80          0.8485          0.8182           0.7353           0.80
# 0     62          0.7576          0.6061           0.5000           0.62
#
#    input_tokens  output_tokens  total_tokens  total_cost total_time
# 1        243519           3943        247462        0.00    0:05:38
# 0        243508           3338        246846        0.37    0:02:19
