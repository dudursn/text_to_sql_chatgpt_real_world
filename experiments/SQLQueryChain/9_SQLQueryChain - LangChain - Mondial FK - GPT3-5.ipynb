# %% [markdown]
# # SQLQUeryChain - Mondial - Foreign Key - GPT 3.5

# %%
from langchain.sql_database import SQLDatabase

from langchain.chat_models import ChatOpenAI
from langchain.chains import create_sql_query_chain
from urllib.parse import quote  
from langchain.callbacks import get_openai_callback
import time
from dotenv import load_dotenv
import os
import sys
import json
load_dotenv()

experiment_path = '..\..'
path = os.path.abspath('')
module_path = os.path.join(path, experiment_path)
print(module_path)
if module_path not in sys.path:
    sys.path.append(module_path+"\\functions")


from sqldatabase_langchain_utils import SQLDatabaseLangchainUtils

# %% [markdown]
# # Schema

# %%
SCHEMA = 'mondial_gpt'
PREFIX = 'mondial'

FILE_NAME_RESULT = f"results/9_sql_queries_chatgpt_{SCHEMA}_fk.json"

# %%
def save_queries(queries):
    data = {"queries":queries}
    with open(FILE_NAME_RESULT, "w") as arquivo_json:
        json.dump(data, arquivo_json, indent=4) 

def read_queries():
    with open(FILE_NAME_RESULT, encoding='utf-8', errors='ignore') as json_data:
        data = json.load(json_data, strict=False)
    queries = data["queries"]
    return queries

# %% [markdown]
# ## Conexão

# %%
json_file_path = f"../../datasets/{SCHEMA}_db_connection.json"
with open(json_file_path, encoding='utf-8', errors='ignore') as json_data:
    db_connection = json.load(json_data, strict=False)

db_connection

# %% [markdown]
# ### Utilizando o SQLDatabase para pegar todas as informações do database

# %%
db = SQLDatabaseLangchainUtils(db_connection=db_connection)

exclusao = [
    f"{SCHEMA}_tmdp",
    f"{SCHEMA}_tmdpmap",
    f"{SCHEMA}_tmds",
    f"{SCHEMA}_tmjmap",
    f"{SCHEMA}_tpv",
    f"{SCHEMA}_tmdc",
    f"{SCHEMA}_tmdcmap",
    f"{SCHEMA}_tmdej",
    f"{SCHEMA}_log_action",
    f"{SCHEMA}_log_error",
    f"{SCHEMA}_favorite_item", 
    f"{SCHEMA}_favorite_query",
    f"{SCHEMA}_favorite_tag",
    f"{SCHEMA}_favorite_tag_item",
    f"{SCHEMA}_favorite_visualization",
    f"{SCHEMA}_dashboard",
    f"{SCHEMA}_history",
    "teste_cliente",
    "teste_fornecedor",
    "teste_funcionario"
]

include_tables = [s for s in db.get_table_names() if not s.startswith(PREFIX) and s not in exclusao]
db = SQLDatabaseLangchainUtils(db_connection=db_connection, include_tables=include_tables)
db.get_table_names()
# Out:
# c:\Users\rogerrsn\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain\utilities\sql_database.py:112: SAWarning: Did not recognize type 'GEOCOORD' of column 'coordinates'
#   self._metadata.reflect(
# c:\Users\rogerrsn\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain\utilities\sql_database.py:112: SAWarning: Did not recognize type 'GEOCOORD' of column 'source'
#   self._metadata.reflect(
# c:\Users\rogerrsn\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain\utilities\sql_database.py:112: SAWarning: Did not recognize type 'GEOCOORD' of column 'estuary'
#   self._metadata.reflect(
# ['airport',
#  'borders',
#  'city',
#  'citylocalname',
#  'cityothername',
#  'citypops',
#  'continent',
#  'country',
#  'countrylocalname',
#  'countryothername',
#  'countrypops',
#  'desert',
#  'economy',
#  'encompasses',
#  'ethnicgroup',
#  'geo_desert',
#  'geo_estuary',
#  'geo_island',
#  'geo_lake',
#  'geo_mountain',
#  'geo_river',
#  'geo_sea',
#  'geo_source',
#  'island',
#  'islandin',
#  'ismember',
#  'lake',
#  'lakeonisland',
#  'language',
#  'located',
#  'locatedon',
#  'mergeswith',
#  'mountain',
#  'mountainonisland',
#  'organization',
#  'politics',
#  'population',
#  'province',
#  'provincelocalname',
#  'provinceothername',
#  'provpops',
#  'religion',
#  'river',
#  'riveronisland',
#  'riverthrough',
#  'sea']

# %%
len(include_tables)
# Out:
# 46

# %% [markdown]
# ## Criando o prompt

# %%
from langchain.prompts.prompt import PromptTemplate

f = open(f"prompts/prompt_template_sql_query_chain.txt", "r")
prompt_template = f.read()
f.close()


PROMPT = PromptTemplate(
    input_variables=["input", "table_info", "top_k"], template=prompt_template
)

print(PROMPT)
# Out:
# input_variables=['input', 'table_info', 'top_k'] output_parser=None partial_variables={} template='You are an Oracle SQL expert. Given an input question, first create a syntactically correct Oracle SQL query to run, then look at the results of the query and return the answer to the input question.\nUnless the user specifies in the question a specific number of examples to obtain, don\'t query for at {top_k} most results or any using the FETCH FIRST n ROWS ONLY clause as per Oracle SQL. You can order the results to return the most informative data in the database.\nNever query for all columns from a table. You must query only the columns that are needed to answer the question.\nPay attention to use only the column names you can see in the tables below. Be careful to not query for columns that do not exist. Also, pay attention to which column is in which table.\nPay attention to use TRUNC(SYSDATE) function to get the current date, if the question involves "today". \n\nSome hints:\n- Don\'t use double quotes in column name\n- \nExample:\n`SELECT "column_name" FROM table` should be `SELECT column_name FROM table`\n- Don\'t use LEFT JOIN, only JOIN\n\nUse the following format:\n\nQuestion: Question here\nSQLQuery: SQL Query to run\nSQLResult: Result of the SQLQuery\nAnswer: Final answer here\n\nOnly use the following tables:\n{table_info}\n\nQuestion: {input}' template_format='f-string' validate_template=True

# %% [markdown]
# ## Criando o Chain para gerar SQL

# %%
query_chain  = create_sql_query_chain(ChatOpenAI(temperature=0, model_name='gpt-3.5-turbo-16k'), db.db, prompt=PROMPT)

# %% [markdown]
# ### Teste: consulta e Numero de Tokens

# %%
with get_openai_callback() as cb:
    sql_query = query_chain.invoke({"question":"What are the provinces with an area more than 10000?"})
    
    print(cb.total_tokens)
    print(cb.prompt_tokens)
    print(cb.completion_tokens)
    print(cb.total_cost)
sql_query
# Out:
# c:\Users\rogerrsn\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain\utilities\sql_database.py:307: SAWarning: Cannot correctly sort tables; there are unresolvable cycles between tables "lake, river", which is usually caused by mutually dependent foreign key constraints.  Foreign key constraints involving these tables will not be considered; this warning may raise an error in a future release.
#   for tbl in self._metadata.sorted_tables
# 5707
# 5695
# 12
# 0.017133
# 'SELECT name\nFROM province\nWHERE area > 10000'

# %%
with get_openai_callback() as cb:
    sql_query = query_chain.invoke({"question":"What are the languages spoken in Poland?"})
    print(cb.total_tokens)
    print(cb.prompt_tokens)
    print(cb.completion_tokens)
    print(cb.total_cost)
sql_query
# Out:
# 5700
# 5690
# 10
# 0.01711
# "SELECT name FROM language WHERE country = 'POL'"

# %% [markdown]
# ## Preparando as consultas em linguagem natural para rodar no LLM

# %%
json_file_path = f"../../datasets/{PREFIX}/queries_{PREFIX}.json"
with open(json_file_path, encoding='utf-8', errors='ignore') as json_data:
    queries = json.load(json_data, strict=False)
queries = queries['queries']
queries
# Out:
# [{'id': '1',
#   'question': 'What is the area of Thailand?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '2',
#   'question': 'What are the provinces with an area greater than 10000?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '3',
#   'question': 'What are the languages spoken in Poland?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '4',
#   'question': 'How deep is Lake Kariba?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '5',
#   'question': 'What is the total of provinces of Netherlands?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '6',
#   'question': 'What is the percentage of religious people are hindu in thailand?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '7',
#   'question': 'List the number of provinces each river flows through.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '8',
#   'question': 'Find all countries that became independent between 8/1/1910 and 8/1/1950.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '9',
#   'question': 'What are the cities of Cuba?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '10',
#   'question': 'What is the capital of Georgia?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '11',
#   'question': 'How many provinces have areas greater than 1000 in Niger?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '12',
#   'question': 'Tell me about the country with the area largest.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '13',
#   'question': 'What is the host province and year of establishment of the organization "International Energy Agency"?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '14',
#   'question': 'Find the name of all mountains whose elevation is higher than 1000.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '15',
#   'question': 'Tell me the economy of the Caribbean Sea.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '16',
#   'question': 'Show the cities with longitude between 0 and 6.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '17',
#   'question': 'Select cities whose population is greater than 100000, altitude greater than 2500, and the country you belong to has population growth greater than 1.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '18',
#   'question': 'Show all the different types of government.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '19',
#   'question': 'List all provinces in Germany',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '20',
#   'question': 'What is the percentage of mulatto ethnicity in Brazil?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '21',
#   'question': 'How many cities have populations less than 1000?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '22',
#   'question': 'What is the average elevation of airports in America?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '23',
#   'question': 'How many countries are adjacent to (or ecompassed by) the Caribbean Sea?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '24',
#   'question': 'How much area do the countries that are adjacent to (or encompassed by) the Caribbean Sea cover in total?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '25',
#   'question': 'For all countries, give the sum of the population of all its neighbors',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '26',
#   'question': 'What mountains are on the island of Borneo?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '27',
#   'question': 'Provide the name and total population of the country with the smallest area.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '28',
#   'question': 'The codes of all countries for which at least one river that originates in this country has its estuary in a neighboring country.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '29',
#   'question': 'The codes of all countries where at least one mountain is located in each of their provinces',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '30',
#   'question': 'The code and total border lengths of all countries with at least one border.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '31',
#   'question': 'The names and codes of all countries in which at least one river originates.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '32',
#   'question': 'What is the area and country of the Chatanga River?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '33',
#   'question': 'Show the Airports with elevation more than 3000',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '34',
#   'question': 'What are the religions practiced in Mexico?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '35',
#   'question': 'Show all rivers that do not flow into the sea.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '36',
#   'question': 'List African countries by number of neighbors.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '37',
#   'question': 'What is the average infant mortality rate for each continent?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '38',
#   'question': 'What is the average mortality rate of the countries in America without considering Brazil?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '39',
#   'question': 'List seas with area greater than 8000 and depth less than 100.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '40',
#   'question': 'How many mountains are there in Asia?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '41',
#   'question': 'How many countries that are close to the Mediterranean Sea?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '42',
#   'question': 'Show the total for each type of government.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '43',
#   'question': 'Which province has the largest desert in the world?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '44',
#   'question': 'What is the largest desert in the world?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '45',
#   'question': 'List, for all continents, the amount of deserts on each.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '46',
#   'question': 'What are the neighboring seas of the Banda Sea?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '47',
#   'question': 'List all the capitals of European countries.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '48',
#   'question': 'What percentage of people speak French in Andorra?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '49',
#   'question': 'Which rivers are longer than 1000 kilometers?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '50',
#   'question': 'Which country had the lowest population growth?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '51',
#   'question': 'List the name of capital cities for which we do not have data about the city in located',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '52',
#   'question': 'What is the capital of the provice Andalucía?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '53',
#   'question': 'What is the abbreviation for the organization whose name is "General Confederation of Trade Unions"?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '54',
#   'question': 'In which city is the organization with the abbreviation "UPU" ?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '55',
#   'question': 'List the names of countries which are members of only one organization',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '56',
#   'question': 'List the name of countries which are not a member of NATO.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '57',
#   'question': 'List the name of countries which are a member of NATO.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '58',
#   'question': 'List the rivers with length less than 50',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '59',
#   'question': 'What are the area, elevation and type of lakes in country Italy?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '60',
#   'question': ' List the names of capital cities which are the base for organizations in alphabetical order',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '61',
#   'question': 'List the name of organizations that do not have countries with an area smaller than 4000 and of the member type',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '62',
#   'question': 'List the name of organizations that do not have countries with  an area greater than 10000 and population smaller than 3000 and of the member type',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '63',
#   'question': 'Show the inflation rate of countries that are washed by the Arabian Sea',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '64',
#   'question': 'List all the capitals of the countries that belong to the continent Africa?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '65',
#   'question': 'Show the inflation rate of the countries bathed by the Arabian Sea and there is no inflation with null value',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '66',
#   'question': 'How many countries are in Africa?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '67',
#   'question': 'List the name of countries that are not members of NATO and UNESCO',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '68',
#   'question': 'What is the area of the continent Europe?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '69',
#   'question': 'What is the area of continent America?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '70',
#   'question': 'What is the area of continent Asia?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '71',
#   'question': 'What is the area of Africa?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '72',
#   'question': 'How many countries are in America?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '73',
#   'question': 'What area is the largest continent?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '74',
#   'question': 'List the countries that belong to the continent with the largest area',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '75',
#   'question': 'List the countries that belong to the continent with the largest area and whose language is English',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '76',
#   'question': 'List the names of cities, along with the name of their country for cities with a population greater than 5 million.  Display the results in descending order by population.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '77',
#   'question': 'Show the name of the deserts in the province of Algeria',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '78',
#   'question': 'Show the name and area of the deserts in the province of California',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '79',
#   'question': 'List the country names and percentage of use of language where  French are used as languages.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '80',
#   'question': 'What are the cities where �Portuguese� is spoken?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '81',
#   'question': 'What is the total area of the provinces in Canada?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '82',
#   'question': 'What is the length of the Tigres River?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '83',
#   'question': 'List the Airports with elevation more than 1000',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '84',
#   'question': 'List airports in the United States with an elevation below 200 feet',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '85',
#   'question': 'What are the mountains with altitudes above 8000 meters?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '86',
#   'question': 'What are the 3 airports with the largest name?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '87',
#   'question': 'List lakes with an area of less than 5000 square kilometers.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '88',
#   'question': 'What is the total area of the seas with a depth greater than 1000 meters?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '89',
#   'question': 'Find the countries whose name starts with the letter "B" and have a population greater than 10 million',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '90',
#   'question': 'List cities with another name in Brazil',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '91',
#   'question': 'List all cities that are at a latitude greater than 45 degrees.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '92',
#   'question': 'Show the number of cities with another name in countries with an area greater than 30000',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '93',
#   'question': 'Show the deserts with area greater than 10000',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '94',
#   'question': 'List the islands that belong to a lake with an elevation greater than 100',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '95',
#   'question': 'List all mountains located on islands with an area greater than 100,000 square kilometers',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '96',
#   'question': 'List the countries and the sum of their provincial areas.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '97',
#   'question': 'Show the name of the countries, the average elevation and sum of the population of their cities',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '98',
#   'question': "What was Germany's inflation?",
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '99',
#   'question': 'What type of government is Iran?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '100',
#   'question': "What is the percentage of industries in relation to Japan's economy?",
#   'query_string': '',
#   'type': 'medium'}]

# %% [markdown]
# # Rodando as consultas no LLM para gerar SQL

# %%
# A cada X consultas, vai ser gerado um delay de 10s para evitar o bloqueio da API.
number_of_queries_to_delay = 25
count = 0
for instance in queries:
    if count == number_of_queries_to_delay:
        count = 0
        time.sleep(10)
    with get_openai_callback() as cb:
        start_time = time.time()
        sql_query = query_chain.invoke({"question":instance["question"]})
        end_time = time.time()
        instance["query_string"] = sql_query
        instance['total_tokens'] = cb.total_tokens
        instance['prompt_tokens'] = cb.prompt_tokens
        instance['completion_tokens'] = cb.completion_tokens
        instance['total_cost'] = cb.total_cost
        instance['time'] = end_time - start_time
        print(instance['id'], instance['question'], instance["query_string"], instance['time'], instance['total_cost'])
    save_queries(queries)
    count += 1
queries
# Out:
# c:\Users\rogerrsn\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain\utilities\sql_database.py:307: SAWarning: Cannot correctly sort tables; there are unresolvable cycles between tables "lake, river", which is usually caused by mutually dependent foreign key constraints.  Foreign key constraints involving these tables will not be considered; this warning may raise an error in a future release.
#   for tbl in self._metadata.sorted_tables
# 1 What is the area of Thailand? SELECT area FROM country WHERE name = 'Thailand' 1.6230106353759766 0.017117
# 2 What are the provinces with an area greater than 10000? SELECT name
# FROM province
# WHERE area > 10000 1.0047950744628906 0.017139
# 3 What are the languages spoken in Poland? SELECT name FROM language WHERE country = 'POL' 1.1618280410766602 0.017116
# 4 How deep is Lake Kariba? SELECT depth FROM lake WHERE name = 'Lake Kariba' 1.0164403915405273 0.017121
# 5 What is the total of provinces of Netherlands? SELECT COUNT(*) FROM province WHERE country = 'NLD' 1.0510685443878174 0.017127
# 6 What is the percentage of religious people are hindu in thailand? SELECT percentage
# FROM religion
# WHERE country = 'THA' AND name = 'Hindu' 1.1624281406402588 0.017178000000000002
# 7 List the number of provinces each river flows through. SELECT r.name, COUNT(DISTINCT p.province) AS num_provinces
# FROM river r
# JOIN located l ON r.name = l.river
# JOIN province p ON l.province = p.name AND l.country = p.country
# GROUP BY r.name
# ORDER BY num_provinces DESC 1.9213452339172363 0.017322
# 8 Find all countries that became independent between 8/1/1910 and 8/1/1950. SELECT name
# FROM politics
# WHERE independence BETWEEN TO_DATE('8/1/1910', 'MM/DD/YYYY') AND TO_DATE('8/1/1950', 'MM/DD/YYYY') 1.6855340003967285 0.017281
# 9 What are the cities of Cuba? SELECT name FROM city WHERE country = 'CUB' 1.0731205940246582 0.017117
# 10 What is the capital of Georgia? SELECT capital FROM country WHERE name = 'Georgia' 1.123682975769043 0.017113
# 11 How many provinces have areas greater than 1000 in Niger? SELECT COUNT(*)
# FROM province
# WHERE country = 'NER' AND area > 1000 0.8599991798400879 0.017167
# 12 Tell me about the country with the area largest. SELECT name, area
# FROM country
# ORDER BY area DESC
# FETCH FIRST 1 ROWS ONLY 1.2825095653533936 0.017162
# 13 What is the host province and year of establishment of the organization "International Energy Agency"? SELECT province, established
# FROM organization
# WHERE name = 'International Energy Agency' 1.0980401039123535 0.01717
# 14 Find the name of all mountains whose elevation is higher than 1000. SELECT name
# FROM mountain
# WHERE elevation > 1000 1.2511374950408936 0.017145
# 15 Tell me the economy of the Caribbean Sea. SELECT e.gdp, e.agriculture, e.service, e.industry, e.inflation, e.unemployment
# FROM economy e
# JOIN sea s ON e.country = s.name
# WHERE s.name = 'Caribbean Sea' 1.9413444995880127 0.017271
# 16 Show the cities with longitude between 0 and 6. SELECT name, longitude
# FROM city
# WHERE longitude BETWEEN 0 AND 6 1.2257921695709229 0.017152
# 17 Select cities whose population is greater than 100000, altitude greater than 2500, and the country you belong to has population growth greater than 1. SELECT city.name, city.population, city.elevation, country.population_growth
# FROM city
# JOIN country ON city.country = country.code
# WHERE city.population > 100000 AND city.elevation > 2500 AND country.population_growth > 1 1.7366678714752197 0.017344000000000002
# 18 Show all the different types of government. SELECT DISTINCT government FROM politics 0.9171895980834961 0.017096
# 19 List all provinces in Germany SELECT name
# FROM province
# WHERE country = 'DEU' 0.9191858768463135 0.017122000000000002
# 20 What is the percentage of mulatto ethnicity in Brazil? SELECT percentage
# FROM ethnicgroup
# WHERE country = 'BRA' AND name = 'Mulatto' 1.0803380012512207 0.017169
# 21 How many cities have populations less than 1000? SELECT COUNT(*) FROM city WHERE population < 1000 0.8557603359222412 0.017129
# 22 What is the average elevation of airports in America? SELECT AVG(elevation) FROM airport WHERE country = 'USA' 0.9182734489440918 0.017134
# 23 How many countries are adjacent to (or ecompassed by) the Caribbean Sea? SELECT COUNT(*)
# FROM encompasses
# WHERE continent = 'Caribbean' AND percentage = 100 1.328660011291504 0.017179
# 24 How much area do the countries that are adjacent to (or encompassed by) the Caribbean Sea cover in total? SELECT SUM(c.area)
# FROM country c
# JOIN encompasses e ON c.code = e.country
# JOIN sea s ON e.continent = s.name
# WHERE s.name = 'Caribbean Sea' 1.388012170791626 0.017281
# 25 For all countries, give the sum of the population of all its neighbors SELECT c.name, SUM(cp.population) AS total_population
# FROM country c
# JOIN borders b ON c.code = b.country1
# JOIN country cp ON b.country2 = cp.code
# GROUP BY c.name
# ORDER BY total_population DESC 1.6772501468658447 0.017289000000000002
# 26 What mountains are on the island of Borneo? SELECT mountain.name
# FROM mountain
# JOIN mountainonisland ON mountain.name = mountainonisland.mountain
# JOIN island ON mountainonisland.island = island.name
# WHERE island.name = 'Borneo' 1.8747901916503906 0.017253
# 27 Provide the name and total population of the country with the smallest area. SELECT name, population
# FROM country
# WHERE area = (SELECT MIN(area) FROM country) 1.2068185806274414 0.01717
# 28 The codes of all countries for which at least one river that originates in this country has its estuary in a neighboring country. SELECT DISTINCT c.code
# FROM country c
# JOIN river r ON c.code = r.country
# JOIN geo_estuary ge ON r.name = ge.river
# JOIN country nc ON ge.country = nc.code
# WHERE nc.code <> c.code
# ORDER BY c.code 1.724363088607788 0.017343
# 29 The codes of all countries where at least one mountain is located in each of their provinces SELECT DISTINCT c.code
# FROM country c
# JOIN province p ON c.code = p.country
# JOIN geo_mountain gm ON p.name = gm.province AND c.code = gm.country
# GROUP BY c.code
# HAVING COUNT(DISTINCT p.name) = (SELECT COUNT(DISTINCT province) FROM geo_mountain) 2.0417771339416504 0.01737
# 30 The code and total border lengths of all countries with at least one border. SELECT c.name, SUM(b.length) AS total_border_length
# FROM country c
# JOIN borders b ON c.code = b.country1
# GROUP BY c.name 1.6793437004089355 0.017225
# 31 The names and codes of all countries in which at least one river originates. SELECT c.name, c.code
# FROM country c
# JOIN river r ON c.code = r.country
# GROUP BY c.name, c.code
# ORDER BY c.name ASC 1.5175902843475342 0.017233000000000002
# 32 What is the area and country of the Chatanga River? SELECT area, country
# FROM river
# WHERE name = 'Chatanga' 0.8265070915222168 0.017148
# 33 Show the Airports with elevation more than 3000 SELECT name, elevation
# FROM airport
# WHERE elevation > 3000 1.0078189373016357 0.017144
# 34 What are the religions practiced in Mexico? SELECT name FROM religion WHERE country = 'MEX' 1.0196940898895264 0.01712
# 35 Show all rivers that do not flow into the sea. SELECT name
# FROM river
# WHERE sea IS NULL 0.9182412624359131 0.017124999999999998
# 36 List African countries by number of neighbors. SELECT c.name, COUNT(b.country2) AS num_neighbors
# FROM country c
# JOIN borders b ON c.code = b.country1
# WHERE c.continent = 'Africa'
# GROUP BY c.name
# ORDER BY num_neighbors DESC; 1.9414105415344238 0.017264
# 37 What is the average infant mortality rate for each continent? SELECT c.name AS continent, AVG(p.infant_mortality) AS average_infant_mortality
# FROM continent c
# JOIN country co ON c.name = co.continent
# JOIN population p ON co.code = p.country
# GROUP BY c.name 2.454505681991577 0.017281
# 38 What is the average mortality rate of the countries in America without considering Brazil? SELECT AVG(infant_mortality)
# FROM population
# WHERE country IN (
#     SELECT code
#     FROM country
#     WHERE continent = 'America'
#     AND name != 'Brazil'
# ) 1.668269157409668 0.017253
# 39 List seas with area greater than 8000 and depth less than 100. SELECT name
# FROM sea
# WHERE area > 8000 AND depth < 100 1.086005687713623 0.017168
# 40 How many mountains are there in Asia? SELECT COUNT(*) FROM mountain
# JOIN geo_mountain ON mountain.name = geo_mountain.mountain
# JOIN province ON geo_mountain.province = province.name
# JOIN country ON province.country = country.code
# JOIN encompasses ON country.code = encompasses.country
# JOIN continent ON encompasses.continent = continent.name
# WHERE continent.name = 'Asia' 2.3152520656585693 0.017344000000000002
# 41 What are the countries that are close to the Mediterranean Sea? SELECT DISTINCT c.name
# FROM country c
# JOIN geo_sea gs ON c.code = gs.country
# JOIN sea s ON gs.sea = s.name
# WHERE s.name = 'Mediterranean Sea' 1.6816942691802979 0.017259999999999998
# 42 Show the total for each type of government. SELECT government, COUNT(*) AS total
# FROM politics
# GROUP BY government 1.0314934253692627 0.017135
# 43 Which province has the largest desert in the world? SELECT p.name
# FROM province p
# JOIN geo_desert gd ON p.name = gd.province
# JOIN desert d ON gd.desert = d.name
# WHERE d.area = (SELECT MAX(area) FROM desert) 1.6145787239074707 0.017258
# 44 What is the largest desert in the world? SELECT name
# FROM desert
# ORDER BY area DESC
# FETCH FIRST 1 ROWS ONLY 0.9174802303314209 0.017151
# 45 List, for all continents, the amount of deserts on each. SELECT c.name AS continent, COUNT(d.name) AS desert_count
# FROM continent c
# JOIN geo_desert gd ON c.name = gd.continent
# JOIN desert d ON gd.desert = d.name
# GROUP BY c.name
# ORDER BY c.name ASC 2.2501211166381836 0.017302
# 46 What are the neighboring seas of the Banda Sea? SELECT sea
# FROM geo_sea
# WHERE country = 'ID' AND province = 'Maluku' AND sea != 'Banda Sea' 1.2230052947998047 0.017201
# 47 List all the capitals of European countries. SELECT capital
# FROM country
# WHERE continent = 'Europe' 0.918236255645752 0.017124
# 48 What percentage of people speak French in Andorra? SELECT percentage
# FROM language
# WHERE country = 'AND' AND name = 'French' 1.0362563133239746 0.017154
# 49 Which rivers are longer than 1000 kilometers? SELECT name
# FROM river
# WHERE length > 1000 1.3857061862945557 0.01713
# 50 Which country had the lowest population growth? SELECT country
# FROM population
# WHERE population_growth = (SELECT MIN(population_growth) FROM population) 1.3536913394927979 0.017156
# 51 List the name of capital cities for which we do not have data about the city in located SELECT c.capital
# FROM country c
# LEFT JOIN located l ON c.capital = l.city
# WHERE l.city IS NULL 1.349297046661377 0.017213000000000003
# 52 What is the capital of the provice Andaluc�a? SELECT capital
# FROM province
# WHERE name = 'Andalucía' 3.3778955936431885 0.017154000000000003
# 53 What is the abbreviation for the organization whose name is "General Confederation of Trade Unions"? SELECT abbreviation FROM organization WHERE name = 'General Confederation of Trade Unions' 1.021207571029663 0.017176
# 54 In which city is the organization with the abbreviation "UPU" ? SELECT city FROM organization WHERE abbreviation = 'UPU' 1.0179624557495117 0.017138
# 55 List the names of countries which are members of only one organization SELECT c.name
# FROM country c
# JOIN ismember i ON c.code = i.country
# GROUP BY c.name
# HAVING COUNT(i.organization) = 1 1.53145432472229 0.017223000000000002
# 56 List the name of countries which are not a member of NATO. SELECT name
# FROM country
# WHERE code NOT IN (SELECT country FROM ismember WHERE organization = 'NATO') 1.431535243988037 0.017183
# 57 List the name of countries which are a member of NATO. SELECT name
# FROM country
# WHERE code IN (SELECT country
#                FROM ismember
#                WHERE organization = 'NATO') 1.3251023292541504 0.017192
# 58 List the rivers with length less than 50 SELECT name
# FROM river
# WHERE length < 50 0.9173018932342529 0.017126
# 59 What are the area, elevation and type of lakes in country Italy? SELECT area, elevation, type
# FROM lake
# WHERE country = 'ITA' 1.122220754623413 0.017158000000000003
# 60 List the names of capital cities which are the base for organizations SELECT city.name
# FROM city
# JOIN organization ON city.name = organization.city
# WHERE city.country = organization.country AND city.province = organization.province 1.3278007507324219 0.017211
# 61 List the name of organizations that do not have countries with an area smaller than 4000 and of the member type SELECT o.name
# FROM organization o
# WHERE NOT EXISTS (
#     SELECT 1
#     FROM country c
#     WHERE c.code = o.country
#     AND c.area < 4000
# )
# AND o.type = 'member' 1.7355804443359375 0.017316
# 62 List the name of organizations that do not have countries with  an area greater than 10000 and population smaller than 3000 and of the member type SELECT o.name
# FROM organization o
# WHERE NOT EXISTS (
#     SELECT 1
#     FROM country c
#     WHERE c.code = o.country
#     AND c.area > 10000
#     AND c.population < 3000
# )
# AND o.type = 'member' 1.8367853164672852 0.017372
# 63 Show the inflation rate of countries that are washed by the Arabian Sea SELECT c.name, e.inflation
# FROM country c
# JOIN economy e ON c.code = e.country
# JOIN geo_sea gs ON c.code = gs.country
# JOIN sea s ON gs.sea = s.name
# WHERE s.name = 'Arabian Sea' 1.8794004917144775 0.017314000000000003
# 64 List all the capitals of the countries that belong to the continent Africa? SELECT c.capital
# FROM country c
# JOIN encompasses e ON c.code = e.country
# JOIN continent co ON e.continent = co.name
# WHERE co.name = 'Africa' 1.4916772842407227 0.017242
# 65 Show the inflation rate of the countries bathed by the Arabian Sea and there is no inflation with null value SELECT c.name, e.inflation
# FROM country c
# JOIN economy e ON c.code = e.country
# JOIN geo_sea gs ON c.code = gs.country
# JOIN sea s ON gs.sea = s.name
# WHERE s.name = 'Arabian Sea' AND e.inflation IS NOT NULL 1.8686270713806152 0.017366000000000003
# 66 How many countries are in Africa? SELECT COUNT(*) FROM continent WHERE name = 'Africa' 0.8210573196411133 0.017117
# 67 List the name of countries that are not members of NATO and UNESCO SELECT name
# FROM country
# WHERE code NOT IN (
#     SELECT country
#     FROM ismember
#     WHERE organization IN ('NATO', 'UNESCO')
# ) 1.5196359157562256 0.017226
# 68 What is the area of the continent Europe? SELECT area FROM continent WHERE name = 'Europe' 1.0132970809936523 0.017119
# 69 What is the area of continent America? SELECT area FROM continent WHERE name = 'America' 0.8903071880340576 0.017116
# 70 What is the area of continent Asia? SELECT area FROM continent WHERE name = 'Asia' 0.7546088695526123 0.017116
# 71 What is the area of Africa? SELECT area FROM continent WHERE name = 'Africa' 0.7943153381347656 0.017113
# 72 How many countries are in America? SELECT COUNT(*) FROM continent WHERE name = 'America' 0.7969555854797363 0.017117
# 73 Which continent has the largest area? SELECT name
# FROM continent
# ORDER BY area DESC
# FETCH FIRST 1 ROWS ONLY 1.057915210723877 0.017145
# 74 List the countries that belong to the continent with the largest area SELECT c.name
# FROM country c
# JOIN encompasses e ON c.code = e.country
# JOIN continent co ON e.continent = co.name
# WHERE co.area = (SELECT MAX(area) FROM continent) 1.9045937061309814 0.017255000000000003
# 75 List the countries that belong to the continent with the largest area and whose language is English SELECT c.name
# FROM country c
# JOIN encompasses e ON c.code = e.country
# JOIN continent con ON e.continent = con.name
# JOIN language l ON c.code = l.country
# WHERE con.area = (SELECT MAX(area) FROM continent)
# AND l.name = 'English' 2.2488503456115723 0.017342
# 76 List the names of cities, along with the name of their country for cities with a population greater than 5 million.  Display the results in descending order by population. SELECT c.name AS city, co.name AS country
# FROM city c
# JOIN country co ON c.country = co.code
# WHERE c.population > 5000000
# ORDER BY c.population DESC 1.7579667568206787 0.017314
# 77 Show the name of the deserts in the province of Algeria SELECT d.name
# FROM desert d
# JOIN geo_desert gd ON d.name = gd.desert
# JOIN province p ON gd.province = p.name
# JOIN country c ON p.country = c.code
# WHERE c.name = 'Algeria' 1.83815336227417 0.017295
# 78 Show the name and area of the deserts in the province of California SELECT name, area
# FROM desert
# JOIN geo_desert ON desert.name = geo_desert.desert
# JOIN province ON geo_desert.province = province.name
# WHERE province.name = 'California' 1.7238380908966064 0.017261000000000002
# 79 List the country names and percentage of use of language where  French are used as languages. SELECT c.name, l.percentage
# FROM country c
# JOIN language l ON c.code = l.country
# WHERE l.name = 'French' 1.3387796878814697 0.017222
# 80 What are the cities where �Portuguese� is spoken? SELECT city.name
# FROM city
# JOIN language ON city.country = language.country
# WHERE language.name = 'Portuguese' 1.1215100288391113 0.017191
# 81 What is the total area of the provinces in Canada? SELECT SUM(area) FROM province WHERE country = 'CAN' 1.121924638748169 0.017133
# 82 What is the length of the Tigres River? SELECT length FROM river WHERE name = 'Tigres' 0.9168517589569092 0.01713
# 83 List the Airports with elevation more than 1000 SELECT name, elevation
# FROM airport
# WHERE elevation > 1000 1.4295215606689453 0.017144
# 84 List airports in the United States with an elevation below 200 feet SELECT name
# FROM airport
# WHERE country = 'USA' AND elevation < 200 1.017580509185791 0.017162
# 85 What are the mountains with altitudes above 8000 meters? SELECT name
# FROM mountain
# WHERE elevation > 8000 1.1221272945404053 0.017139
# 86 What are the 3 airports with the shortest name? SELECT name
# FROM airport
# ORDER BY LENGTH(name)
# FETCH FIRST 3 ROWS ONLY 1.2257580757141113 0.017157
# 87 List lakes with an area of less than 5000 square kilometers. SELECT name
# FROM lake
# WHERE area < 5000 1.0305192470550537 0.017142
# 88 What is the total area of the seas with a depth greater than 1000 meters? SELECT SUM(area)
# FROM sea
# WHERE depth > 1000 1.1118006706237793 0.017162
# 89 Find the countries whose name starts with the letter "B" and have a population greater than 10 million SELECT name
# FROM country
# WHERE name LIKE 'B%' AND population > 10000000 1.0178046226501465 0.017194
# 90 List cities with another name in Brazil SELECT city.name, cityothername.othername
# FROM city
# JOIN cityothername ON city.name = cityothername.city AND city.country = cityothername.country
# WHERE city.country = 'BRAZ' 1.6819133758544922 0.017248
# 91 List all cities that are at a latitude greater than 45 degrees. SELECT name
# FROM city
# WHERE latitude > 45 0.9717559814453125 0.017138
# 92 Show the number of cities with another name in countries with an area greater than 30000 SELECT COUNT(DISTINCT city)
# FROM cityothername co
# JOIN city c ON co.city = c.name AND co.country = c.country
# JOIN country cn ON c.country = cn.code
# WHERE cn.area > 30000 1.6317999362945557 0.017297000000000003
# 93 Show the deserts with area greater than 10000 SELECT name
# FROM desert
# WHERE area > 10000 0.9169082641601562 0.017136
# 94 List the islands that belong to a lake with an elevation greater than 100 SELECT i.name
# FROM island i
# JOIN lakeonisland loi ON i.name = loi.island
# JOIN lake l ON loi.lake = l.name
# WHERE l.elevation > 100 1.3992974758148193 0.017256
# 95 List all mountains located on islands with an area greater than 100,000 square kilometers SELECT m.name
# FROM mountain m
# JOIN mountainonisland moi ON m.name = moi.mountain
# JOIN island i ON moi.island = i.name
# WHERE i.area > 100000 2.240450382232666 0.017262
# 96 List the countries and the sum of their provincial areas. SELECT country, SUM(area) AS total_area
# FROM province
# GROUP BY country 1.0484609603881836 0.017149
# 97 Show the name of the countries, the average elevation and sum of the population of their cities SELECT c.name AS country_name, AVG(ci.elevation) AS average_elevation, SUM(ci.population) AS total_population
# FROM country c
# JOIN city ci ON c.code = ci.country
# GROUP BY c.name 1.984118938446045 0.017281
# 98 What was Germany's inflation? SELECT inflation FROM economy WHERE country = 'DEU' 0.960559606552124 0.017114
# 99 What type of government is Iran? SELECT government
# FROM politics
# WHERE country = 'IRN' 0.940014123916626 0.017125
# 100 What is the percentage of industries in relation to Japan's economy? SELECT industry FROM economy WHERE country = 'JPN' 1.018362283706665 0.017135
# [{'id': '1',
#   'question': 'What is the area of Thailand?',
#   'query_string': "SELECT area FROM country WHERE name = 'Thailand'",
#   'type': 'simple',
#   'total_tokens': 5702,
#   'prompt_tokens': 5691,
#   'completion_tokens': 11,
#   'total_cost': 0.017117,
#   'time': 1.6230106353759766},
#  {'id': '2',
#   'question': 'What are the provinces with an area greater than 10000?',
#   'query_string': 'SELECT name\nFROM province\nWHERE area > 10000',
#   'type': 'simple',
#   'total_tokens': 5709,
#   'prompt_tokens': 5697,
#   'completion_tokens': 12,
#   'total_cost': 0.017139,
#   'time': 1.0047950744628906},
#  {'id': '3',
#   'question': 'What are the languages spoken in Poland?',
#   'query_string': "SELECT name FROM language WHERE country = 'POL'",
#   'type': 'medium',
#   'total_tokens': 5702,
#   'prompt_tokens': 5692,
#   'completion_tokens': 10,
#   'total_cost': 0.017116,
#   'time': 1.1618280410766602},
#  {'id': '4',
#   'question': 'How deep is Lake Kariba?',
#   'query_string': "SELECT depth FROM lake WHERE name = 'Lake Kariba'",
#   'type': 'simple',
#   'total_tokens': 5703,
#   'prompt_tokens': 5691,
#   'completion_tokens': 12,
#   'total_cost': 0.017121,
#   'time': 1.0164403915405273},
#  {'id': '5',
#   'question': 'What is the total of provinces of Netherlands?',
#   'query_string': "SELECT COUNT(*) FROM province WHERE country = 'NLD'",
#   'type': 'complex',
#   'total_tokens': 5705,
#   'prompt_tokens': 5693,
#   'completion_tokens': 12,
#   'total_cost': 0.017127,
#   'time': 1.0510685443878174},
#  {'id': '6',
#   'question': 'What is the percentage of religious people are hindu in thailand?',
#   'query_string': "SELECT percentage\nFROM religion\nWHERE country = 'THA' AND name = 'Hindu'",
#   'type': 'complex',
#   'total_tokens': 5719,
#   'prompt_tokens': 5698,
#   'completion_tokens': 21,
#   'total_cost': 0.017178000000000002,
#   'time': 1.1624281406402588},
#  {'id': '7',
#   'question': 'List the number of provinces each river flows through.',
#   'query_string': 'SELECT r.name, COUNT(DISTINCT p.province) AS num_provinces\nFROM river r\nJOIN located l ON r.name = l.river\nJOIN province p ON l.province = p.name AND l.country = p.country\nGROUP BY r.name\nORDER BY num_provinces DESC',
#   'type': 'medium',
#   'total_tokens': 5754,
#   'prompt_tokens': 5694,
#   'completion_tokens': 60,
#   'total_cost': 0.017322,
#   'time': 1.9213452339172363},
#  {'id': '8',
#   'question': 'Find all countries that became independent between 8/1/1910 and 8/1/1950.',
#   'query_string': "SELECT name\nFROM politics\nWHERE independence BETWEEN TO_DATE('8/1/1910', 'MM/DD/YYYY') AND TO_DATE('8/1/1950', 'MM/DD/YYYY')",
#   'type': 'complex',
#   'total_tokens': 5747,
#   'prompt_tokens': 5707,
#   'completion_tokens': 40,
#   'total_cost': 0.017281,
#   'time': 1.6855340003967285},
#  {'id': '9',
#   'question': 'What are the cities of Cuba?',
#   'query_string': "SELECT name FROM city WHERE country = 'CUB'",
#   'type': 'medium',
#   'total_tokens': 5702,
#   'prompt_tokens': 5691,
#   'completion_tokens': 11,
#   'total_cost': 0.017117,
#   'time': 1.0731205940246582},
#  {'id': '10',
#   'question': 'What is the capital of Georgia?',
#   'query_string': "SELECT capital FROM country WHERE name = 'Georgia'",
#   'type': 'medium',
#   'total_tokens': 5701,
#   'prompt_tokens': 5691,
#   'completion_tokens': 10,
#   'total_cost': 0.017113,
#   'time': 1.123682975769043},
#  {'id': '11',
#   'question': 'How many provinces have areas greater than 1000 in Niger?',
#   'query_string': "SELECT COUNT(*) \nFROM province \nWHERE country = 'NER' AND area > 1000",
#   'type': 'complex',
#   'total_tokens': 5716,
#   'prompt_tokens': 5697,
#   'completion_tokens': 19,
#   'total_cost': 0.017167,
#   'time': 0.8599991798400879},
#  {'id': '12',
#   'question': 'Tell me about the country with the area largest.',
#   'query_string': 'SELECT name, area\nFROM country\nORDER BY area DESC\nFETCH FIRST 1 ROWS ONLY',
#   'type': 'medium',
#   'total_tokens': 5714,
#   'prompt_tokens': 5694,
#   'completion_tokens': 20,
#   'total_cost': 0.017162,
#   'time': 1.2825095653533936},
#  {'id': '13',
#   'question': 'What is the host province and year of establishment of the organization "International Energy Agency"?',
#   'query_string': "SELECT province, established\nFROM organization\nWHERE name = 'International Energy Agency'",
#   'type': 'medium',
#   'total_tokens': 5718,
#   'prompt_tokens': 5702,
#   'completion_tokens': 16,
#   'total_cost': 0.01717,
#   'time': 1.0980401039123535},
#  {'id': '14',
#   'question': 'Find the name of all mountains whose elevation is higher than 1000.',
#   'query_string': 'SELECT name\nFROM mountain\nWHERE elevation > 1000',
#   'type': 'medium',
#   'total_tokens': 5711,
#   'prompt_tokens': 5699,
#   'completion_tokens': 12,
#   'total_cost': 0.017145,
#   'time': 1.2511374950408936},
#  {'id': '15',
#   'question': 'Tell me the economy of the Caribbean Sea.',
#   'query_string': "SELECT e.gdp, e.agriculture, e.service, e.industry, e.inflation, e.unemployment\nFROM economy e\nJOIN sea s ON e.country = s.name\nWHERE s.name = 'Caribbean Sea'",
#   'type': 'medium',
#   'total_tokens': 5741,
#   'prompt_tokens': 5693,
#   'completion_tokens': 48,
#   'total_cost': 0.017271,
#   'time': 1.9413444995880127},
#  {'id': '16',
#   'question': 'Show the cities with longitude between 0 and 6.',
#   'query_string': 'SELECT name, longitude\nFROM city\nWHERE longitude BETWEEN 0 AND 6',
#   'type': 'simple',
#   'total_tokens': 5712,
#   'prompt_tokens': 5696,
#   'completion_tokens': 16,
#   'total_cost': 0.017152,
#   'time': 1.2257921695709229},
#  {'id': '17',
#   'question': 'Select cities whose population is greater than 100000, altitude greater than 2500, and the country you belong to has population growth greater than 1.',
#   'query_string': 'SELECT city.name, city.population, city.elevation, country.population_growth\nFROM city\nJOIN country ON city.country = country.code\nWHERE city.population > 100000 AND city.elevation > 2500 AND country.population_growth > 1',
#   'type': 'complex',
#   'total_tokens': 5765,
#   'prompt_tokens': 5716,
#   'completion_tokens': 49,
#   'total_cost': 0.017344000000000002,
#   'time': 1.7366678714752197},
#  {'id': '18',
#   'question': 'Show all the different types of government.',
#   'query_string': 'SELECT DISTINCT government FROM politics',
#   'type': 'simple',
#   'total_tokens': 5697,
#   'prompt_tokens': 5692,
#   'completion_tokens': 5,
#   'total_cost': 0.017096,
#   'time': 0.9171895980834961},
#  {'id': '19',
#   'question': 'List all provinces in Germany',
#   'query_string': "SELECT name\nFROM province\nWHERE country = 'DEU'",
#   'type': 'medium',
#   'total_tokens': 5703,
#   'prompt_tokens': 5690,
#   'completion_tokens': 13,
#   'total_cost': 0.017122000000000002,
#   'time': 0.9191858768463135},
#  {'id': '20',
#   'question': 'What is the percentage of mulatto ethnicity in Brazil?',
#   'query_string': "SELECT percentage\nFROM ethnicgroup\nWHERE country = 'BRA' AND name = 'Mulatto'",
#   'type': 'complex',
#   'total_tokens': 5716,
#   'prompt_tokens': 5695,
#   'completion_tokens': 21,
#   'total_cost': 0.017169,
#   'time': 1.0803380012512207},
#  {'id': '21',
#   'question': 'How many cities have populations less than 1000?',
#   'query_string': 'SELECT COUNT(*) FROM city WHERE population < 1000',
#   'type': 'simple',
#   'total_tokens': 5706,
#   'prompt_tokens': 5695,
#   'completion_tokens': 11,
#   'total_cost': 0.017129,
#   'time': 0.8557603359222412},
#  {'id': '22',
#   'question': 'What is the average elevation of airports in America?',
#   'query_string': "SELECT AVG(elevation) FROM airport WHERE country = 'USA'",
#   'type': 'complex',
#   'total_tokens': 5707,
#   'prompt_tokens': 5694,
#   'completion_tokens': 13,
#   'total_cost': 0.017134,
#   'time': 0.9182734489440918},
#  {'id': '23',
#   'question': 'How many countries are adjacent to (or ecompassed by) the Caribbean Sea?',
#   'query_string': "SELECT COUNT(*) \nFROM encompasses \nWHERE continent = 'Caribbean' AND percentage = 100",
#   'type': 'medium',
#   'total_tokens': 5720,
#   'prompt_tokens': 5701,
#   'completion_tokens': 19,
#   'total_cost': 0.017179,
#   'time': 1.328660011291504},
#  {'id': '24',
#   'question': 'How much area do the countries that are adjacent to (or encompassed by) the Caribbean Sea cover in total?',
#   'query_string': "SELECT SUM(c.area) \nFROM country c \nJOIN encompasses e ON c.code = e.country \nJOIN sea s ON e.continent = s.name \nWHERE s.name = 'Caribbean Sea'",
#   'type': 'complex',
#   'total_tokens': 5747,
#   'prompt_tokens': 5707,
#   'completion_tokens': 40,
#   'total_cost': 0.017281,
#   'time': 1.388012170791626},
#  {'id': '25',
#   'question': 'For all countries, give the sum of the population of all its neighbors',
#   'query_string': 'SELECT c.name, SUM(cp.population) AS total_population\nFROM country c\nJOIN borders b ON c.code = b.country1\nJOIN country cp ON b.country2 = cp.code\nGROUP BY c.name\nORDER BY total_population DESC',
#   'type': 'medium',
#   'total_tokens': 5747,
#   'prompt_tokens': 5699,
#   'completion_tokens': 48,
#   'total_cost': 0.017289000000000002,
#   'time': 1.6772501468658447},
#  {'id': '26',
#   'question': 'What mountains are on the island of Borneo?',
#   'query_string': "SELECT mountain.name \nFROM mountain \nJOIN mountainonisland ON mountain.name = mountainonisland.mountain \nJOIN island ON mountainonisland.island = island.name \nWHERE island.name = 'Borneo'",
#   'type': 'simple',
#   'total_tokens': 5737,
#   'prompt_tokens': 5695,
#   'completion_tokens': 42,
#   'total_cost': 0.017253,
#   'time': 1.8747901916503906},
#  {'id': '27',
#   'question': 'Provide the name and total population of the country with the smallest area.',
#   'query_string': 'SELECT name, population\nFROM country\nWHERE area = (SELECT MIN(area) FROM country)',
#   'type': 'simple',
#   'total_tokens': 5717,
#   'prompt_tokens': 5698,
#   'completion_tokens': 19,
#   'total_cost': 0.01717,
#   'time': 1.2068185806274414},
#  {'id': '28',
#   'question': 'The codes of all countries for which at least one river that originates in this country has its estuary in a neighboring country.',
#   'query_string': 'SELECT DISTINCT c.code\nFROM country c\nJOIN river r ON c.code = r.country\nJOIN geo_estuary ge ON r.name = ge.river\nJOIN country nc ON ge.country = nc.code\nWHERE nc.code <> c.code\nORDER BY c.code',
#   'type': 'complex',
#   'total_tokens': 5763,
#   'prompt_tokens': 5709,
#   'completion_tokens': 54,
#   'total_cost': 0.017343,
#   'time': 1.724363088607788},
#  {'id': '29',
#   'question': 'The codes of all countries where at least one mountain is located in each of their provinces',
#   'query_string': 'SELECT DISTINCT c.code\nFROM country c\nJOIN province p ON c.code = p.country\nJOIN geo_mountain gm ON p.name = gm.province AND c.code = gm.country\nGROUP BY c.code\nHAVING COUNT(DISTINCT p.name) = (SELECT COUNT(DISTINCT province) FROM geo_mountain)',
#   'type': 'complex',
#   'total_tokens': 5768,
#   'prompt_tokens': 5702,
#   'completion_tokens': 66,
#   'total_cost': 0.01737,
#   'time': 2.0417771339416504},
#  {'id': '30',
#   'question': 'The code and total border lengths of all countries with at least one border.',
#   'query_string': 'SELECT c.name, SUM(b.length) AS total_border_length\nFROM country c\nJOIN borders b ON c.code = b.country1\nGROUP BY c.name',
#   'type': 'complex',
#   'total_tokens': 5731,
#   'prompt_tokens': 5699,
#   'completion_tokens': 32,
#   'total_cost': 0.017225,
#   'time': 1.6793437004089355},
#  {'id': '31',
#   'question': 'The names and codes of all countries in which at least one river originates.',
#   'query_string': 'SELECT c.name, c.code\nFROM country c\nJOIN river r ON c.code = r.country\nGROUP BY c.name, c.code\nORDER BY c.name ASC',
#   'type': 'medium',
#   'total_tokens': 5733,
#   'prompt_tokens': 5699,
#   'completion_tokens': 34,
#   'total_cost': 0.017233000000000002,
#   'time': 1.5175902843475342},
#  {'id': '32',
#   'question': 'What is the area and country of the Chatanga River?',
#   'query_string': "SELECT area, country\nFROM river\nWHERE name = 'Chatanga'",
#   'type': 'simple',
#   'total_tokens': 5711,
#   'prompt_tokens': 5696,
#   'completion_tokens': 15,
#   'total_cost': 0.017148,
#   'time': 0.8265070915222168},
#  {'id': '33',
#   'question': 'Show the Airports with elevation more than 3000',
#   'query_string': 'SELECT name, elevation\nFROM airport\nWHERE elevation > 3000',
#   'type': 'simple',
#   'total_tokens': 5710,
#   'prompt_tokens': 5696,
#   'completion_tokens': 14,
#   'total_cost': 0.017144,
#   'time': 1.0078189373016357},
#  {'id': '34',
#   'question': 'What are the religions practiced in Mexico?',
#   'query_string': "SELECT name FROM religion WHERE country = 'MEX'",
#   'type': 'medium',
#   'total_tokens': 5703,
#   'prompt_tokens': 5692,
#   'completion_tokens': 11,
#   'total_cost': 0.01712,
#   'time': 1.0196940898895264},
#  {'id': '35',
#   'question': 'Show all rivers that do not flow into the sea.',
#   'query_string': 'SELECT name\nFROM river\nWHERE sea IS NULL',
#   'type': 'medium',
#   'total_tokens': 5705,
#   'prompt_tokens': 5695,
#   'completion_tokens': 10,
#   'total_cost': 0.017124999999999998,
#   'time': 0.9182412624359131},
#  {'id': '36',
#   'question': 'List African countries by number of neighbors.',
#   'query_string': "SELECT c.name, COUNT(b.country2) AS num_neighbors\nFROM country c\nJOIN borders b ON c.code = b.country1\nWHERE c.continent = 'Africa'\nGROUP BY c.name\nORDER BY num_neighbors DESC;",
#   'type': 'complex',
#   'total_tokens': 5739,
#   'prompt_tokens': 5692,
#   'completion_tokens': 47,
#   'total_cost': 0.017264,
#   'time': 1.9414105415344238},
#  {'id': '37',
#   'question': 'What is the average infant mortality rate for each continent?',
#   'query_string': 'SELECT c.name AS continent, AVG(p.infant_mortality) AS average_infant_mortality\nFROM continent c\nJOIN country co ON c.name = co.continent\nJOIN population p ON co.code = p.country\nGROUP BY c.name',
#   'type': 'simple',
#   'total_tokens': 5744,
#   'prompt_tokens': 5695,
#   'completion_tokens': 49,
#   'total_cost': 0.017281,
#   'time': 2.454505681991577},
#  {'id': '38',
#   'question': 'What is the average mortality rate of the countries in America without considering Brazil?',
#   'query_string': "SELECT AVG(infant_mortality) \nFROM population \nWHERE country IN (\n    SELECT code \n    FROM country \n    WHERE continent = 'America' \n    AND name != 'Brazil'\n)",
#   'type': 'complex',
#   'total_tokens': 5738,
#   'prompt_tokens': 5699,
#   'completion_tokens': 39,
#   'total_cost': 0.017253,
#   'time': 1.668269157409668},
#  {'id': '39',
#   'question': 'List seas with area greater than 8000 and depth less than 100.',
#   'query_string': 'SELECT name\nFROM sea\nWHERE area > 8000 AND depth < 100',
#   'type': 'simple',
#   'total_tokens': 5717,
#   'prompt_tokens': 5700,
#   'completion_tokens': 17,
#   'total_cost': 0.017168,
#   'time': 1.086005687713623},
#  {'id': '40',
#   'question': 'How many mountains are there in Asia?',
#   'query_string': "SELECT COUNT(*) FROM mountain\nJOIN geo_mountain ON mountain.name = geo_mountain.mountain\nJOIN province ON geo_mountain.province = province.name\nJOIN country ON province.country = country.code\nJOIN encompasses ON country.code = encompasses.country\nJOIN continent ON encompasses.continent = continent.name\nWHERE continent.name = 'Asia'",
#   'type': 'complex',
#   'total_tokens': 5759,
#   'prompt_tokens': 5692,
#   'completion_tokens': 67,
#   'total_cost': 0.017344000000000002,
#   'time': 2.3152520656585693},
#  {'id': '41',
#   'question': 'What are the countries that are close to the Mediterranean Sea?',
#   'query_string': "SELECT DISTINCT c.name\nFROM country c\nJOIN geo_sea gs ON c.code = gs.country\nJOIN sea s ON gs.sea = s.name\nWHERE s.name = 'Mediterranean Sea'",
#   'type': 'complex',
#   'total_tokens': 5739,
#   'prompt_tokens': 5696,
#   'completion_tokens': 43,
#   'total_cost': 0.017259999999999998,
#   'time': 1.6816942691802979},
#  {'id': '42',
#   'question': 'Show the total for each type of government.',
#   'query_string': 'SELECT government, COUNT(*) AS total\nFROM politics\nGROUP BY government',
#   'type': 'simple',
#   'total_tokens': 5707,
#   'prompt_tokens': 5693,
#   'completion_tokens': 14,
#   'total_cost': 0.017135,
#   'time': 1.0314934253692627},
#  {'id': '43',
#   'question': 'Which province has the largest desert in the world?',
#   'query_string': 'SELECT p.name\nFROM province p\nJOIN geo_desert gd ON p.name = gd.province\nJOIN desert d ON gd.desert = d.name\nWHERE d.area = (SELECT MAX(area) FROM desert)',
#   'type': 'simple',
#   'total_tokens': 5738,
#   'prompt_tokens': 5694,
#   'completion_tokens': 44,
#   'total_cost': 0.017258,
#   'time': 1.6145787239074707},
#  {'id': '44',
#   'question': 'What is the largest desert in the world?',
#   'query_string': 'SELECT name \nFROM desert \nORDER BY area DESC \nFETCH FIRST 1 ROWS ONLY',
#   'type': 'simple',
#   'total_tokens': 5711,
#   'prompt_tokens': 5693,
#   'completion_tokens': 18,
#   'total_cost': 0.017151,
#   'time': 0.9174802303314209},
#  {'id': '45',
#   'question': 'List, for all continents, the amount of deserts on each.',
#   'query_string': 'SELECT c.name AS continent, COUNT(d.name) AS desert_count\nFROM continent c\nJOIN geo_desert gd ON c.name = gd.continent\nJOIN desert d ON gd.desert = d.name\nGROUP BY c.name\nORDER BY c.name ASC',
#   'type': 'complex',
#   'total_tokens': 5750,
#   'prompt_tokens': 5698,
#   'completion_tokens': 52,
#   'total_cost': 0.017302,
#   'time': 2.2501211166381836},
#  {'id': '46',
#   'question': 'What are the neighboring seas of the Banda Sea?',
#   'query_string': "SELECT sea \nFROM geo_sea \nWHERE country = 'ID' AND province = 'Maluku' AND sea != 'Banda Sea'",
#   'type': 'medium',
#   'total_tokens': 5724,
#   'prompt_tokens': 5695,
#   'completion_tokens': 29,
#   'total_cost': 0.017201,
#   'time': 1.2230052947998047},
#  {'id': '47',
#   'question': 'List all the capitals of European countries.',
#   'query_string': "SELECT capital \nFROM country \nWHERE continent = 'Europe'",
#   'type': 'medium',
#   'total_tokens': 5704,
#   'prompt_tokens': 5692,
#   'completion_tokens': 12,
#   'total_cost': 0.017124,
#   'time': 0.918236255645752},
#  {'id': '48',
#   'question': 'What percentage of people speak French in Andorra?',
#   'query_string': "SELECT percentage\nFROM language\nWHERE country = 'AND' AND name = 'French'",
#   'type': 'complex',
#   'total_tokens': 5712,
#   'prompt_tokens': 5694,
#   'completion_tokens': 18,
#   'total_cost': 0.017154,
#   'time': 1.0362563133239746},
#  {'id': '49',
#   'question': 'Which rivers are longer than 1000 kilometers?',
#   'query_string': 'SELECT name\nFROM river\nWHERE length > 1000',
#   'type': 'complex',
#   'total_tokens': 5706,
#   'prompt_tokens': 5694,
#   'completion_tokens': 12,
#   'total_cost': 0.01713,
#   'time': 1.3857061862945557},
#  {'id': '50',
#   'question': 'Which country had the lowest population growth?',
#   'query_string': 'SELECT country\nFROM population\nWHERE population_growth = (SELECT MIN(population_growth) FROM population)',
#   'type': 'simple',
#   'total_tokens': 5712,
#   'prompt_tokens': 5692,
#   'completion_tokens': 20,
#   'total_cost': 0.017156,
#   'time': 1.3536913394927979},
#  {'id': '51',
#   'question': 'List the name of capital cities for which we do not have data about the city in located',
#   'query_string': 'SELECT c.capital\nFROM country c\nLEFT JOIN located l ON c.capital = l.city\nWHERE l.city IS NULL',
#   'type': 'complex',
#   'total_tokens': 5729,
#   'prompt_tokens': 5703,
#   'completion_tokens': 26,
#   'total_cost': 0.017213000000000003,
#   'time': 1.349297046661377},
#  {'id': '52',
#   'question': 'What is the capital of the provice Andaluc�a?',
#   'query_string': "SELECT capital \nFROM province \nWHERE name = 'Andalucía'",
#   'type': 'simple',
#   'total_tokens': 5713,
#   'prompt_tokens': 5698,
#   'completion_tokens': 15,
#   'total_cost': 0.017154000000000003,
#   'time': 3.3778955936431885},
#  {'id': '53',
#   'question': 'What is the abbreviation for the organization whose name is "General Confederation of Trade Unions"?',
#   'query_string': "SELECT abbreviation FROM organization WHERE name = 'General Confederation of Trade Unions'",
#   'type': 'simple',
#   'total_tokens': 5720,
#   'prompt_tokens': 5704,
#   'completion_tokens': 16,
#   'total_cost': 0.017176,
#   'time': 1.021207571029663},
#  {'id': '54',
#   'question': 'In which city is the organization with the abbreviation "UPU" ?',
#   'query_string': "SELECT city FROM organization WHERE abbreviation = 'UPU'",
#   'type': 'simple',
#   'total_tokens': 5709,
#   'prompt_tokens': 5698,
#   'completion_tokens': 11,
#   'total_cost': 0.017138,
#   'time': 1.0179624557495117},
#  {'id': '55',
#   'question': 'List the names of countries which are members of only one organization',
#   'query_string': 'SELECT c.name\nFROM country c\nJOIN ismember i ON c.code = i.country\nGROUP BY c.name\nHAVING COUNT(i.organization) = 1',
#   'type': 'complex',
#   'total_tokens': 5730,
#   'prompt_tokens': 5697,
#   'completion_tokens': 33,
#   'total_cost': 0.017223000000000002,
#   'time': 1.53145432472229},
#  {'id': '56',
#   'question': 'List the name of countries which are not a member of NATO.',
#   'query_string': "SELECT name\nFROM country\nWHERE code NOT IN (SELECT country FROM ismember WHERE organization = 'NATO')",
#   'type': 'complex',
#   'total_tokens': 5720,
#   'prompt_tokens': 5697,
#   'completion_tokens': 23,
#   'total_cost': 0.017183,
#   'time': 1.431535243988037},
#  {'id': '57',
#   'question': 'List the name of countries which are a member of NATO.',
#   'query_string': "SELECT name\nFROM country\nWHERE code IN (SELECT country\n               FROM ismember\n               WHERE organization = 'NATO')",
#   'type': 'medium',
#   'total_tokens': 5722,
#   'prompt_tokens': 5696,
#   'completion_tokens': 26,
#   'total_cost': 0.017192,
#   'time': 1.3251023292541504},
#  {'id': '58',
#   'question': 'List the rivers with length less than 50',
#   'query_string': 'SELECT name\nFROM river\nWHERE length < 50',
#   'type': 'simple',
#   'total_tokens': 5705,
#   'prompt_tokens': 5694,
#   'completion_tokens': 11,
#   'total_cost': 0.017126,
#   'time': 0.9173018932342529},
#  {'id': '59',
#   'question': 'What are the area, elevation and type of lakes in country Italy?',
#   'query_string': "SELECT area, elevation, type \nFROM lake \nWHERE country = 'ITA'",
#   'type': 'simple',
#   'total_tokens': 5714,
#   'prompt_tokens': 5698,
#   'completion_tokens': 16,
#   'total_cost': 0.017158000000000003,
#   'time': 1.122220754623413},
#  {'id': '60',
#   'question': 'List the names of capital cities which are the base for organizations',
#   'query_string': 'SELECT city.name \nFROM city \nJOIN organization ON city.name = organization.city \nWHERE city.country = organization.country AND city.province = organization.province',
#   'type': 'complex',
#   'total_tokens': 5727,
#   'prompt_tokens': 5697,
#   'completion_tokens': 30,
#   'total_cost': 0.017211,
#   'time': 1.3278007507324219},
#  {'id': '61',
#   'question': 'List the name of organizations that do not have countries with an area smaller than 4000 and of the member type',
#   'query_string': "SELECT o.name \nFROM organization o \nWHERE NOT EXISTS (\n    SELECT 1 \n    FROM country c \n    WHERE c.code = o.country \n    AND c.area < 4000\n) \nAND o.type = 'member'",
#   'type': 'complex',
#   'total_tokens': 5756,
#   'prompt_tokens': 5708,
#   'completion_tokens': 48,
#   'total_cost': 0.017316,
#   'time': 1.7355804443359375},
#  {'id': '62',
#   'question': 'List the name of organizations that do not have countries with  an area greater than 10000 and population smaller than 3000 and of the member type',
#   'query_string': "SELECT o.name \nFROM organization o\nWHERE NOT EXISTS (\n    SELECT 1\n    FROM country c\n    WHERE c.code = o.country\n    AND c.area > 10000\n    AND c.population < 3000\n)\nAND o.type = 'member'",
#   'type': 'complex',
#   'total_tokens': 5772,
#   'prompt_tokens': 5716,
#   'completion_tokens': 56,
#   'total_cost': 0.017372,
#   'time': 1.8367853164672852},
#  {'id': '63',
#   'question': 'Show the inflation rate of countries that are washed by the Arabian Sea',
#   'query_string': "SELECT c.name, e.inflation\nFROM country c\nJOIN economy e ON c.code = e.country\nJOIN geo_sea gs ON c.code = gs.country\nJOIN sea s ON gs.sea = s.name\nWHERE s.name = 'Arabian Sea'",
#   'type': 'complex',
#   'total_tokens': 5753,
#   'prompt_tokens': 5698,
#   'completion_tokens': 55,
#   'total_cost': 0.017314000000000003,
#   'time': 1.8794004917144775},
#  {'id': '64',
#   'question': 'List all the capitals of the countries that belong to the continent Africa?',
#   'query_string': "SELECT c.capital\nFROM country c\nJOIN encompasses e ON c.code = e.country\nJOIN continent co ON e.continent = co.name\nWHERE co.name = 'Africa'",
#   'type': 'medium',
#   'total_tokens': 5735,
#   'prompt_tokens': 5698,
#   'completion_tokens': 37,
#   'total_cost': 0.017242,
#   'time': 1.4916772842407227},
#  {'id': '65',
#   'question': 'Show the inflation rate of the countries bathed by the Arabian Sea and there is no inflation with null value',
#   'query_string': "SELECT c.name, e.inflation\nFROM country c\nJOIN economy e ON c.code = e.country\nJOIN geo_sea gs ON c.code = gs.country\nJOIN sea s ON gs.sea = s.name\nWHERE s.name = 'Arabian Sea' AND e.inflation IS NOT NULL",
#   'type': 'complex',
#   'total_tokens': 5768,
#   'prompt_tokens': 5706,
#   'completion_tokens': 62,
#   'total_cost': 0.017366000000000003,
#   'time': 1.8686270713806152},
#  {'id': '66',
#   'question': 'How many countries are in Africa?',
#   'query_string': "SELECT COUNT(*) FROM continent WHERE name = 'Africa'",
#   'type': 'complex',
#   'total_tokens': 5702,
#   'prompt_tokens': 5691,
#   'completion_tokens': 11,
#   'total_cost': 0.017117,
#   'time': 0.8210573196411133},
#  {'id': '67',
#   'question': 'List the name of countries that are not members of NATO and UNESCO',
#   'query_string': "SELECT name\nFROM country\nWHERE code NOT IN (\n    SELECT country\n    FROM ismember\n    WHERE organization IN ('NATO', 'UNESCO')\n)",
#   'type': 'complex',
#   'total_tokens': 5731,
#   'prompt_tokens': 5698,
#   'completion_tokens': 33,
#   'total_cost': 0.017226,
#   'time': 1.5196359157562256},
#  {'id': '68',
#   'question': 'What is the area of the continent Europe?',
#   'query_string': "SELECT area FROM continent WHERE name = 'Europe'",
#   'type': 'simple',
#   'total_tokens': 5703,
#   'prompt_tokens': 5693,
#   'completion_tokens': 10,
#   'total_cost': 0.017119,
#   'time': 1.0132970809936523},
#  {'id': '69',
#   'question': 'What is the area of continent America?',
#   'query_string': "SELECT area FROM continent WHERE name = 'America'",
#   'type': 'simple',
#   'total_tokens': 5702,
#   'prompt_tokens': 5692,
#   'completion_tokens': 10,
#   'total_cost': 0.017116,
#   'time': 0.8903071880340576},
#  {'id': '70',
#   'question': 'What is the area of continent Asia?',
#   'query_string': "SELECT area FROM continent WHERE name = 'Asia'",
#   'type': 'simple',
#   'total_tokens': 5702,
#   'prompt_tokens': 5692,
#   'completion_tokens': 10,
#   'total_cost': 0.017116,
#   'time': 0.7546088695526123},
#  {'id': '71',
#   'question': 'What is the area of Africa?',
#   'query_string': "SELECT area FROM continent WHERE name = 'Africa'",
#   'type': 'simple',
#   'total_tokens': 5701,
#   'prompt_tokens': 5691,
#   'completion_tokens': 10,
#   'total_cost': 0.017113,
#   'time': 0.7943153381347656},
#  {'id': '72',
#   'question': 'How many countries are in America?',
#   'query_string': "SELECT COUNT(*) FROM continent WHERE name = 'America'",
#   'type': 'complex',
#   'total_tokens': 5702,
#   'prompt_tokens': 5691,
#   'completion_tokens': 11,
#   'total_cost': 0.017117,
#   'time': 0.7969555854797363},
#  {'id': '73',
#   'question': 'Which continent has the largest area?',
#   'query_string': 'SELECT name\nFROM continent\nORDER BY area DESC\nFETCH FIRST 1 ROWS ONLY',
#   'type': 'medium',
#   'total_tokens': 5709,
#   'prompt_tokens': 5691,
#   'completion_tokens': 18,
#   'total_cost': 0.017145,
#   'time': 1.057915210723877},
#  {'id': '74',
#   'question': 'List the countries that belong to the continent with the largest area',
#   'query_string': 'SELECT c.name\nFROM country c\nJOIN encompasses e ON c.code = e.country\nJOIN continent co ON e.continent = co.name\nWHERE co.area = (SELECT MAX(area) FROM continent)',
#   'type': 'complex',
#   'total_tokens': 5738,
#   'prompt_tokens': 5697,
#   'completion_tokens': 41,
#   'total_cost': 0.017255000000000003,
#   'time': 1.9045937061309814},
#  {'id': '75',
#   'question': 'List the countries that belong to the continent with the largest area and whose language is English',
#   'query_string': "SELECT c.name \nFROM country c \nJOIN encompasses e ON c.code = e.country \nJOIN continent con ON e.continent = con.name \nJOIN language l ON c.code = l.country \nWHERE con.area = (SELECT MAX(area) FROM continent) \nAND l.name = 'English'",
#   'type': 'complex',
#   'total_tokens': 5761,
#   'prompt_tokens': 5702,
#   'completion_tokens': 59,
#   'total_cost': 0.017342,
#   'time': 2.2488503456115723},
#  {'id': '76',
#   'question': 'List the names of cities, along with the name of their country for cities with a population greater than 5 million.  Display the results in descending order by population.',
#   'query_string': 'SELECT c.name AS city, co.name AS country\nFROM city c\nJOIN country co ON c.country = co.code\nWHERE c.population > 5000000\nORDER BY c.population DESC',
#   'type': 'medium',
#   'total_tokens': 5758,
#   'prompt_tokens': 5718,
#   'completion_tokens': 40,
#   'total_cost': 0.017314,
#   'time': 1.7579667568206787},
#  {'id': '77',
#   'question': 'Show the name of the deserts in the province of Algeria',
#   'query_string': "SELECT d.name\nFROM desert d\nJOIN geo_desert gd ON d.name = gd.desert\nJOIN province p ON gd.province = p.name\nJOIN country c ON p.country = c.code\nWHERE c.name = 'Algeria'",
#   'type': 'simple',
#   'total_tokens': 5748,
#   'prompt_tokens': 5697,
#   'completion_tokens': 51,
#   'total_cost': 0.017295,
#   'time': 1.83815336227417},
#  {'id': '78',
#   'question': 'Show the name and area of the deserts in the province of California',
#   'query_string': "SELECT name, area\nFROM desert\nJOIN geo_desert ON desert.name = geo_desert.desert\nJOIN province ON geo_desert.province = province.name\nWHERE province.name = 'California'",
#   'type': 'simple',
#   'total_tokens': 5740,
#   'prompt_tokens': 5699,
#   'completion_tokens': 41,
#   'total_cost': 0.017261000000000002,
#   'time': 1.7238380908966064},
#  {'id': '79',
#   'question': 'List the country names and percentage of use of language where  French are used as languages.',
#   'query_string': "SELECT c.name, l.percentage\nFROM country c\nJOIN language l ON c.code = l.country\nWHERE l.name = 'French'",
#   'type': 'simple',
#   'total_tokens': 5731,
#   'prompt_tokens': 5702,
#   'completion_tokens': 29,
#   'total_cost': 0.017222,
#   'time': 1.3387796878814697},
#  {'id': '80',
#   'question': 'What are the cities where �Portuguese� is spoken?',
#   'query_string': "SELECT city.name \nFROM city \nJOIN language ON city.country = language.country \nWHERE language.name = 'Portuguese'",
#   'type': 'medium',
#   'total_tokens': 5722,
#   'prompt_tokens': 5697,
#   'completion_tokens': 25,
#   'total_cost': 0.017191,
#   'time': 1.1215100288391113},
#  {'id': '81',
#   'question': 'What is the total area of the provinces in Canada?',
#   'query_string': "SELECT SUM(area) FROM province WHERE country = 'CAN'",
#   'type': 'complex',
#   'total_tokens': 5707,
#   'prompt_tokens': 5695,
#   'completion_tokens': 12,
#   'total_cost': 0.017133,
#   'time': 1.121924638748169},
#  {'id': '82',
#   'question': 'What is the length of the Tigres River?',
#   'query_string': "SELECT length FROM river WHERE name = 'Tigres'",
#   'type': 'simple',
#   'total_tokens': 5706,
#   'prompt_tokens': 5694,
#   'completion_tokens': 12,
#   'total_cost': 0.01713,
#   'time': 0.9168517589569092},
#  {'id': '83',
#   'question': 'List the Airports with elevation more than 1000',
#   'query_string': 'SELECT name, elevation\nFROM airport\nWHERE elevation > 1000',
#   'type': 'medium',
#   'total_tokens': 5710,
#   'prompt_tokens': 5696,
#   'completion_tokens': 14,
#   'total_cost': 0.017144,
#   'time': 1.4295215606689453},
#  {'id': '84',
#   'question': 'List airports in the United States with an elevation below 200 feet',
#   'query_string': "SELECT name \nFROM airport \nWHERE country = 'USA' AND elevation < 200",
#   'type': 'complex',
#   'total_tokens': 5715,
#   'prompt_tokens': 5698,
#   'completion_tokens': 17,
#   'total_cost': 0.017162,
#   'time': 1.017580509185791},
#  {'id': '85',
#   'question': 'What are the mountains with altitudes above 8000 meters?',
#   'query_string': 'SELECT name\nFROM mountain\nWHERE elevation > 8000',
#   'type': 'medium',
#   'total_tokens': 5709,
#   'prompt_tokens': 5697,
#   'completion_tokens': 12,
#   'total_cost': 0.017139,
#   'time': 1.1221272945404053},
#  {'id': '86',
#   'question': 'What are the 3 airports with the shortest name?',
#   'query_string': 'SELECT name\nFROM airport\nORDER BY LENGTH(name)\nFETCH FIRST 3 ROWS ONLY',
#   'type': 'simple',
#   'total_tokens': 5713,
#   'prompt_tokens': 5695,
#   'completion_tokens': 18,
#   'total_cost': 0.017157,
#   'time': 1.2257580757141113},
#  {'id': '87',
#   'question': 'List lakes with an area of less than 5000 square kilometers.',
#   'query_string': 'SELECT name\nFROM lake\nWHERE area < 5000',
#   'type': 'medium',
#   'total_tokens': 5710,
#   'prompt_tokens': 5698,
#   'completion_tokens': 12,
#   'total_cost': 0.017142,
#   'time': 1.0305192470550537},
#  {'id': '88',
#   'question': 'What is the total area of the seas with a depth greater than 1000 meters?',
#   'query_string': 'SELECT SUM(area) \nFROM sea \nWHERE depth > 1000',
#   'type': 'medium',
#   'total_tokens': 5716,
#   'prompt_tokens': 5702,
#   'completion_tokens': 14,
#   'total_cost': 0.017162,
#   'time': 1.1118006706237793},
#  {'id': '89',
#   'question': 'Find the countries whose name starts with the letter "B" and have a population greater than 10 million',
#   'query_string': "SELECT name \nFROM country \nWHERE name LIKE 'B%' AND population > 10000000",
#   'type': 'complex',
#   'total_tokens': 5725,
#   'prompt_tokens': 5706,
#   'completion_tokens': 19,
#   'total_cost': 0.017194,
#   'time': 1.0178046226501465},
#  {'id': '90',
#   'question': 'List cities with another name in Brazil',
#   'query_string': "SELECT city.name, cityothername.othername\nFROM city\nJOIN cityothername ON city.name = cityothername.city AND city.country = cityothername.country\nWHERE city.country = 'BRAZ'",
#   'type': 'medium',
#   'total_tokens': 5735,
#   'prompt_tokens': 5692,
#   'completion_tokens': 43,
#   'total_cost': 0.017248,
#   'time': 1.6819133758544922},
#  {'id': '91',
#   'question': 'List all cities that are at a latitude greater than 45 degrees.',
#   'query_string': 'SELECT name \nFROM city \nWHERE latitude > 45',
#   'type': 'medium',
#   'total_tokens': 5709,
#   'prompt_tokens': 5698,
#   'completion_tokens': 11,
#   'total_cost': 0.017138,
#   'time': 0.9717559814453125},
#  {'id': '92',
#   'question': 'Show the number of cities with another name in countries with an area greater than 30000',
#   'query_string': 'SELECT COUNT(DISTINCT city) \nFROM cityothername co\nJOIN city c ON co.city = c.name AND co.country = c.country\nJOIN country cn ON c.country = cn.code\nWHERE cn.area > 30000',
#   'type': 'medium',
#   'total_tokens': 5750,
#   'prompt_tokens': 5703,
#   'completion_tokens': 47,
#   'total_cost': 0.017297000000000003,
#   'time': 1.6317999362945557},
#  {'id': '93',
#   'question': 'Show the deserts with area greater than 10000',
#   'query_string': 'SELECT name\nFROM desert\nWHERE area > 10000',
#   'type': 'simple',
#   'total_tokens': 5708,
#   'prompt_tokens': 5696,
#   'completion_tokens': 12,
#   'total_cost': 0.017136,
#   'time': 0.9169082641601562},
#  {'id': '94',
#   'question': 'List the islands that belong to a lake with an elevation greater than 100',
#   'query_string': 'SELECT i.name\nFROM island i\nJOIN lakeonisland loi ON i.name = loi.island\nJOIN lake l ON loi.lake = l.name\nWHERE l.elevation > 100',
#   'type': 'simple',
#   'total_tokens': 5739,
#   'prompt_tokens': 5700,
#   'completion_tokens': 39,
#   'total_cost': 0.017256,
#   'time': 1.3992974758148193},
#  {'id': '95',
#   'question': 'List all mountains located on islands with an area greater than 100,000 square kilometers',
#   'query_string': 'SELECT m.name\nFROM mountain m\nJOIN mountainonisland moi ON m.name = moi.mountain\nJOIN island i ON moi.island = i.name\nWHERE i.area > 100000',
#   'type': 'medium',
#   'total_tokens': 5741,
#   'prompt_tokens': 5702,
#   'completion_tokens': 39,
#   'total_cost': 0.017262,
#   'time': 2.240450382232666},
#  {'id': '96',
#   'question': 'List the countries and the sum of their provincial areas.',
#   'query_string': 'SELECT country, SUM(area) AS total_area\nFROM province\nGROUP BY country',
#   'type': 'simple',
#   'total_tokens': 5711,
#   'prompt_tokens': 5695,
#   'completion_tokens': 16,
#   'total_cost': 0.017149,
#   'time': 1.0484609603881836},
#  {'id': '97',
#   'question': 'Show the name of the countries, the average elevation and sum of the population of their cities',
#   'query_string': 'SELECT c.name AS country_name, AVG(ci.elevation) AS average_elevation, SUM(ci.population) AS total_population\nFROM country c\nJOIN city ci ON c.code = ci.country\nGROUP BY c.name',
#   'type': 'medium',
#   'total_tokens': 5746,
#   'prompt_tokens': 5703,
#   'completion_tokens': 43,
#   'total_cost': 0.017281,
#   'time': 1.984118938446045},
#  {'id': '98',
#   'question': "What was Germany's inflation?",
#   'query_string': "SELECT inflation FROM economy WHERE country = 'DEU'",
#   'type': 'medium',
#   'total_tokens': 5701,
#   'prompt_tokens': 5690,
#   'completion_tokens': 11,
#   'total_cost': 0.017114,
#   'time': 0.960559606552124},
#  {'id': '99',
#   'question': 'What type of government is Iran?',
#   'query_string': "SELECT government \nFROM politics \nWHERE country = 'IRN'",
#   'type': 'medium',
#   'total_tokens': 5704,
#   'prompt_tokens': 5691,
#   'completion_tokens': 13,
#   'total_cost': 0.017125,
#   'time': 0.940014123916626},
#  {'id': '100',
#   'question': "What is the percentage of industries in relation to Japan's economy?",
#   'query_string': "SELECT industry FROM economy WHERE country = 'JPN'",
#   'type': 'medium',
#   'total_tokens': 5708,
#   'prompt_tokens': 5697,
#   'completion_tokens': 11,
#   'total_cost': 0.017135,
#   'time': 1.018362283706665}]

# %%
queries=read_queries()
queries
# Out:
# [{'id': '1',
#   'question': 'What is the area of Thailand?',
#   'query_string': "SELECT area\nFROM country\nWHERE name = 'Thailand'",
#   'type': 'simple',
#   'total_tokens': 5698,
#   'prompt_tokens': 5685,
#   'completion_tokens': 13,
#   'total_cost': 0.017107},
#  {'id': '2',
#   'question': 'What are the provinces with an area greater than 10000?',
#   'query_string': 'SELECT name\nFROM province\nWHERE area > 10000',
#   'type': 'simple',
#   'total_tokens': 5703,
#   'prompt_tokens': 5691,
#   'completion_tokens': 12,
#   'total_cost': 0.017121},
#  {'id': '3',
#   'question': 'What are the languages spoken in Poland?',
#   'query_string': "SELECT name\nFROM language\nWHERE country = 'POL'",
#   'type': 'medium',
#   'total_tokens': 5698,
#   'prompt_tokens': 5686,
#   'completion_tokens': 12,
#   'total_cost': 0.017106},
#  {'id': '4',
#   'question': 'How deep is Lake Kariba?',
#   'query_string': "SELECT depth\nFROM lake\nWHERE name = 'Lake Kariba'",
#   'type': 'simple',
#   'total_tokens': 5699,
#   'prompt_tokens': 5685,
#   'completion_tokens': 14,
#   'total_cost': 0.017111},
#  {'id': '5',
#   'question': 'What is the total of provinces of Netherlands?',
#   'query_string': "SELECT COUNT(*) FROM province WHERE country = 'NLD'",
#   'type': 'medium',
#   'total_tokens': 5699,
#   'prompt_tokens': 5687,
#   'completion_tokens': 12,
#   'total_cost': 0.017109},
#  {'id': '6',
#   'question': 'What is the percentage of religious people are hindu in thailand?',
#   'query_string': "SELECT percentage\nFROM religion\nWHERE country = 'THA' AND name = 'Hindu'",
#   'type': 'medium',
#   'total_tokens': 5713,
#   'prompt_tokens': 5692,
#   'completion_tokens': 21,
#   'total_cost': 0.01716},
#  {'id': '7',
#   'question': 'List the number of provinces each river flows through.',
#   'query_string': 'SELECT r.name, COUNT(DISTINCT p.province) AS num_provinces\nFROM river r\nJOIN located l ON r.name = l.river\nJOIN province p ON l.province = p.name AND l.country = p.country\nGROUP BY r.name\nORDER BY num_provinces DESC',
#   'type': 'complex',
#   'total_tokens': 5748,
#   'prompt_tokens': 5688,
#   'completion_tokens': 60,
#   'total_cost': 0.017304},
#  {'id': '8',
#   'question': 'Find all countries that became independent between 8/1/1910 and 8/1/1950.',
#   'query_string': "SELECT name\nFROM politics\nWHERE independence BETWEEN TO_DATE('8/1/1910', 'MM/DD/YYYY') AND TO_DATE('8/1/1950', 'MM/DD/YYYY')",
#   'type': 'medium',
#   'total_tokens': 5741,
#   'prompt_tokens': 5701,
#   'completion_tokens': 40,
#   'total_cost': 0.017263},
#  {'id': '9',
#   'question': 'What are the cities of Cuba?',
#   'query_string': "SELECT name \nFROM city \nWHERE country = 'CUB'",
#   'type': 'medium',
#   'total_tokens': 5698,
#   'prompt_tokens': 5685,
#   'completion_tokens': 13,
#   'total_cost': 0.017107},
#  {'id': '10',
#   'question': 'What is the capital of Georgia?',
#   'query_string': "SELECT capital FROM country WHERE name = 'Georgia'",
#   'type': 'simple',
#   'total_tokens': 5695,
#   'prompt_tokens': 5685,
#   'completion_tokens': 10,
#   'total_cost': 0.017095},
#  {'id': '11',
#   'question': 'How many provinces have areas greater than 1000 in Niger?',
#   'query_string': "SELECT COUNT(*) \nFROM province \nWHERE country = 'NER' AND area > 1000",
#   'type': 'medium',
#   'total_tokens': 5710,
#   'prompt_tokens': 5691,
#   'completion_tokens': 19,
#   'total_cost': 0.017149},
#  {'id': '12',
#   'question': 'Tell me about the country with the area largest.',
#   'query_string': 'SELECT name, area\nFROM country\nORDER BY area DESC\nFETCH FIRST 1 ROWS ONLY',
#   'type': 'medium',
#   'total_tokens': 5708,
#   'prompt_tokens': 5688,
#   'completion_tokens': 20,
#   'total_cost': 0.017144},
#  {'id': '13',
#   'question': 'What is the host province and year of establishment of the organization "International Energy Agency"?',
#   'query_string': "SELECT province, established\nFROM organization\nWHERE name = 'International Energy Agency'",
#   'type': 'simple',
#   'total_tokens': 5712,
#   'prompt_tokens': 5696,
#   'completion_tokens': 16,
#   'total_cost': 0.017152},
#  {'id': '14',
#   'question': 'Find the name of all mountains whose elevation is higher than 1000.',
#   'query_string': 'SELECT name\nFROM mountain\nWHERE elevation > 1000',
#   'type': 'simple',
#   'total_tokens': 5705,
#   'prompt_tokens': 5693,
#   'completion_tokens': 12,
#   'total_cost': 0.017127},
#  {'id': '15',
#   'question': 'Tell me the economy of the Caribbean Sea.',
#   'query_string': "SELECT e.gdp, e.agriculture, e.service, e.industry, e.inflation, e.unemployment\nFROM economy e\nJOIN sea s ON e.country = s.name\nWHERE s.name = 'Caribbean Sea'",
#   'type': 'complex',
#   'total_tokens': 5735,
#   'prompt_tokens': 5687,
#   'completion_tokens': 48,
#   'total_cost': 0.017253},
#  {'id': '16',
#   'question': 'Shows me cities with longitude between 0 and 6.',
#   'query_string': 'SELECT name, longitude\nFROM city\nWHERE longitude BETWEEN 0 AND 6',
#   'type': 'simple',
#   'total_tokens': 5706,
#   'prompt_tokens': 5690,
#   'completion_tokens': 16,
#   'total_cost': 0.017134000000000003},
#  {'id': '17',
#   'question': 'Select cities whose population is greater than 100000, altitude greater than 2500, and the country you belong to has population growth greater than 1.',
#   'query_string': 'SELECT city.name, city.population, city.elevation, country.population_growth\nFROM city\nJOIN country ON city.country = country.code\nWHERE city.population > 100000 AND city.elevation > 2500 AND country.population_growth > 1',
#   'type': 'complex',
#   'total_tokens': 5759,
#   'prompt_tokens': 5710,
#   'completion_tokens': 49,
#   'total_cost': 0.017326},
#  {'id': '18',
#   'question': 'Show all the different types of government.',
#   'query_string': 'SELECT DISTINCT government\nFROM politics',
#   'type': 'simple',
#   'total_tokens': 5692,
#   'prompt_tokens': 5686,
#   'completion_tokens': 6,
#   'total_cost': 0.017082},
#  {'id': '19',
#   'question': 'List all provinces in Germany',
#   'query_string': "SELECT name\nFROM province\nWHERE country = 'DEU'",
#   'type': 'medium',
#   'total_tokens': 5697,
#   'prompt_tokens': 5684,
#   'completion_tokens': 13,
#   'total_cost': 0.017104},
#  {'id': '20',
#   'question': 'What is the percentage of mulatto ethnicity in Brazil?',
#   'query_string': "SELECT percentage\nFROM ethnicgroup\nWHERE country = 'BRA' AND name = 'Mulatto'",
#   'type': 'medium',
#   'total_tokens': 5710,
#   'prompt_tokens': 5689,
#   'completion_tokens': 21,
#   'total_cost': 0.017151},
#  {'id': '21',
#   'question': 'How many cities have populations less than 1000?',
#   'query_string': 'SELECT COUNT(*) FROM city WHERE population < 1000',
#   'type': 'simple',
#   'total_tokens': 5700,
#   'prompt_tokens': 5689,
#   'completion_tokens': 11,
#   'total_cost': 0.017110999999999998},
#  {'id': '22',
#   'question': 'What is the average elevation of airports in America?',
#   'query_string': "SELECT AVG(elevation) FROM airport WHERE country = 'USA'",
#   'type': 'complex',
#   'total_tokens': 5701,
#   'prompt_tokens': 5688,
#   'completion_tokens': 13,
#   'total_cost': 0.017116},
#  {'id': '23',
#   'question': 'How many countries are adjacent to (or ecompassed by) the the Caribbean Sea?',
#   'query_string': "SELECT COUNT(*) \nFROM encompasses \nWHERE continent = 'Caribbean' AND percentage = 100",
#   'type': 'medium',
#   'total_tokens': 5715,
#   'prompt_tokens': 5696,
#   'completion_tokens': 19,
#   'total_cost': 0.017164},
#  {'id': '24',
#   'question': 'How much area do the countries that are adjacent to (or encompassed by) the Caribbean Sea cover in total?',
#   'query_string': "SELECT SUM(c.area) \nFROM country c \nJOIN encompasses e ON c.code = e.country \nJOIN sea s ON e.continent = s.name \nWHERE s.name = 'Caribbean Sea'",
#   'type': 'complex',
#   'total_tokens': 5741,
#   'prompt_tokens': 5701,
#   'completion_tokens': 40,
#   'total_cost': 0.017263},
#  {'id': '25',
#   'question': 'For all countries, give the sum of the population of all its neighbors',
#   'query_string': 'SELECT c.name, SUM(cp.population) AS total_population\nFROM country c\nJOIN borders b ON c.code = b.country1\nJOIN country cp ON b.country2 = cp.code\nGROUP BY c.name\nORDER BY total_population DESC',
#   'type': 'complex',
#   'total_tokens': 5741,
#   'prompt_tokens': 5693,
#   'completion_tokens': 48,
#   'total_cost': 0.017271},
#  {'id': '26',
#   'question': 'What mountains are on the island of Borneo?',
#   'query_string': "SELECT mountain.name \nFROM mountain \nJOIN mountainonisland ON mountain.name = mountainonisland.mountain \nJOIN island ON mountainonisland.island = island.name \nWHERE island.name = 'Borneo'",
#   'type': 'simple',
#   'total_tokens': 5731,
#   'prompt_tokens': 5689,
#   'completion_tokens': 42,
#   'total_cost': 0.017235},
#  {'id': '27',
#   'question': 'Provide the name and total population of the country with the smallest area.',
#   'query_string': 'SELECT name, population\nFROM country\nORDER BY area ASC\nFETCH FIRST 1 ROWS ONLY;',
#   'type': 'simple',
#   'total_tokens': 5713,
#   'prompt_tokens': 5692,
#   'completion_tokens': 21,
#   'total_cost': 0.01716},
#  {'id': '28',
#   'question': 'The codes of all countries for which at least one river that originates in this country has its estuary in a neighboring country.',
#   'query_string': 'SELECT DISTINCT r.country\nFROM river r\nJOIN geo_river gr ON r.name = gr.river\nJOIN country c ON r.country = c.code\nJOIN geo_estuary ge ON r.name = ge.river\nWHERE ge.country <> r.country\nORDER BY r.country',
#   'type': 'complex',
#   'total_tokens': 5759,
#   'prompt_tokens': 5703,
#   'completion_tokens': 56,
#   'total_cost': 0.017333},
#  {'id': '29',
#   'question': 'The codes of all countries where at least one mountain is located in each of their provinces',
#   'query_string': 'SELECT DISTINCT c.code\nFROM country c\nJOIN province p ON c.code = p.country\nJOIN geo_mountain gm ON p.name = gm.province AND c.code = gm.country\nGROUP BY c.code\nHAVING COUNT(DISTINCT p.name) = (SELECT COUNT(DISTINCT province) FROM geo_mountain)',
#   'type': 'complex',
#   'total_tokens': 5762,
#   'prompt_tokens': 5696,
#   'completion_tokens': 66,
#   'total_cost': 0.017352},
#  {'id': '30',
#   'question': 'The code and total border lengths of all countries with at least one border.',
#   'query_string': 'SELECT c.name, SUM(b.length) AS total_border_length\nFROM country c\nJOIN borders b ON c.code = b.country1\nGROUP BY c.name',
#   'type': 'complex',
#   'total_tokens': 5725,
#   'prompt_tokens': 5693,
#   'completion_tokens': 32,
#   'total_cost': 0.017207},
#  {'id': '31',
#   'question': 'The names and codes of all countries in which at least one river originates.',
#   'query_string': 'SELECT DISTINCT c.name, c.code\nFROM country c\nJOIN river r ON c.code = r.country',
#   'type': 'medium',
#   'total_tokens': 5714,
#   'prompt_tokens': 5693,
#   'completion_tokens': 21,
#   'total_cost': 0.017163},
#  {'id': '32',
#   'question': 'What is the area and country of the Chatanga River?',
#   'query_string': "SELECT area, country\nFROM river\nWHERE name = 'Chatanga'",
#   'type': 'complex',
#   'total_tokens': 5705,
#   'prompt_tokens': 5690,
#   'completion_tokens': 15,
#   'total_cost': 0.017130000000000003},
#  {'id': '33',
#   'question': 'Shows me Airports with elevation more than 3000',
#   'query_string': 'SELECT name, elevation\nFROM airport\nWHERE elevation > 3000',
#   'type': 'simple',
#   'total_tokens': 5704,
#   'prompt_tokens': 5690,
#   'completion_tokens': 14,
#   'total_cost': 0.017126000000000002},
#  {'id': '34',
#   'question': 'What are the religions practiced in Mexico?',
#   'query_string': "SELECT name FROM religion WHERE country = 'MEX'",
#   'type': 'medium',
#   'total_tokens': 5697,
#   'prompt_tokens': 5686,
#   'completion_tokens': 11,
#   'total_cost': 0.017102},
#  {'id': '35',
#   'question': 'Show all rivers that do not flow into the sea.',
#   'query_string': 'SELECT name\nFROM river\nWHERE sea IS NULL',
#   'type': 'simple',
#   'total_tokens': 5699,
#   'prompt_tokens': 5689,
#   'completion_tokens': 10,
#   'total_cost': 0.017106999999999997},
#  {'id': '36',
#   'question': 'List African countries by number of neighbors.',
#   'query_string': "SELECT c.name, COUNT(b.country2) AS num_neighbors\nFROM country c\nJOIN borders b ON c.code = b.country1\nWHERE c.continent = 'Africa'\nGROUP BY c.name\nORDER BY num_neighbors DESC;",
#   'type': 'complex',
#   'total_tokens': 5733,
#   'prompt_tokens': 5686,
#   'completion_tokens': 47,
#   'total_cost': 0.017246},
#  {'id': '37',
#   'question': 'What is the average infant mortality rate for each continent?',
#   'query_string': 'SELECT c.name AS continent, AVG(p.infant_mortality) AS average_infant_mortality\nFROM continent c\nJOIN country co ON c.name = co.continent\nJOIN population p ON co.code = p.country\nGROUP BY c.name',
#   'type': 'complex',
#   'total_tokens': 5738,
#   'prompt_tokens': 5689,
#   'completion_tokens': 49,
#   'total_cost': 0.017263},
#  {'id': '38',
#   'question': 'What is the average mortality rate of the countries in America without considering Brazil?',
#   'query_string': "SELECT AVG(infant_mortality) \nFROM population \nWHERE country IN (\n    SELECT code \n    FROM country \n    WHERE continent = 'America' \n    AND name != 'Brazil'\n)",
#   'type': 'complex',
#   'total_tokens': 5732,
#   'prompt_tokens': 5693,
#   'completion_tokens': 39,
#   'total_cost': 0.017235},
#  {'id': '39',
#   'question': 'List seas with area greater than 8000 and depth less than 100.',
#   'query_string': 'SELECT name\nFROM sea\nWHERE area > 8000 AND depth < 100',
#   'type': 'simple',
#   'total_tokens': 5711,
#   'prompt_tokens': 5694,
#   'completion_tokens': 17,
#   'total_cost': 0.01715},
#  {'id': '40',
#   'question': 'How many mountains are there in Asia?',
#   'query_string': "SELECT COUNT(*) FROM mountain WHERE mountains = 'Asia'",
#   'type': 'complex',
#   'total_tokens': 5697,
#   'prompt_tokens': 5686,
#   'completion_tokens': 11,
#   'total_cost': 0.017102},
#  {'id': '41',
#   'question': 'What are the countries that are close to the Mediterranean Sea?',
#   'query_string': "SELECT c.name\nFROM country c\nJOIN geo_sea gs ON c.code = gs.country\nJOIN sea s ON gs.sea = s.name\nWHERE s.name = 'Mediterranean Sea'",
#   'type': 'complex',
#   'total_tokens': 5732,
#   'prompt_tokens': 5690,
#   'completion_tokens': 42,
#   'total_cost': 0.017238000000000003},
#  {'id': '42',
#   'question': 'Show the total for each type of government.',
#   'query_string': 'SELECT government, COUNT(*) AS total\nFROM politics\nGROUP BY government',
#   'type': 'medium',
#   'total_tokens': 5701,
#   'prompt_tokens': 5687,
#   'completion_tokens': 14,
#   'total_cost': 0.017117},
#  {'id': '43',
#   'question': 'Which province has the largest desert in the world?',
#   'query_string': 'SELECT p.name\nFROM province p\nJOIN geo_desert gd ON p.name = gd.province\nJOIN desert d ON gd.desert = d.name\nWHERE d.area = (SELECT MAX(area) FROM desert)',
#   'type': 'medium',
#   'total_tokens': 5732,
#   'prompt_tokens': 5688,
#   'completion_tokens': 44,
#   'total_cost': 0.01724},
#  {'id': '44',
#   'question': 'What is the largest desert in the world?',
#   'query_string': 'SELECT name\nFROM desert\nORDER BY area DESC\nFETCH FIRST 1 ROWS ONLY',
#   'type': 'simple',
#   'total_tokens': 5705,
#   'prompt_tokens': 5687,
#   'completion_tokens': 18,
#   'total_cost': 0.017133},
#  {'id': '45',
#   'question': 'List, for all continents, the amount of deserts on each.',
#   'query_string': 'SELECT c.name AS continent, COUNT(d.name) AS desert_count\nFROM continent c\nJOIN geo_desert gd ON c.name = gd.continent\nJOIN desert d ON gd.desert = d.name\nGROUP BY c.name\nORDER BY desert_count DESC;',
#   'type': 'complex',
#   'total_tokens': 5745,
#   'prompt_tokens': 5692,
#   'completion_tokens': 53,
#   'total_cost': 0.017288},
#  {'id': '46',
#   'question': 'What are the neighboring seas of the Banda Sea?',
#   'query_string': "SELECT sea.name\nFROM sea\nJOIN borders ON sea.name = borders.country2\nWHERE borders.country1 = 'BAND'",
#   'type': 'simple',
#   'total_tokens': 5715,
#   'prompt_tokens': 5689,
#   'completion_tokens': 26,
#   'total_cost': 0.017171},
#  {'id': '47',
#   'question': 'List all the capitals of European countries.',
#   'query_string': "SELECT c.capital\nFROM country c\nJOIN encompasses e ON c.code = e.country\nJOIN continent co ON e.continent = co.name\nWHERE co.name = 'Europe'",
#   'type': 'complex',
#   'total_tokens': 5723,
#   'prompt_tokens': 5686,
#   'completion_tokens': 37,
#   'total_cost': 0.017206},
#  {'id': '48',
#   'question': 'What percentage of people speak French in Andorra?',
#   'query_string': "SELECT percentage\nFROM language\nWHERE country = 'AND' AND name = 'French'",
#   'type': 'medium',
#   'total_tokens': 5706,
#   'prompt_tokens': 5688,
#   'completion_tokens': 18,
#   'total_cost': 0.017136},
#  {'id': '49',
#   'question': 'Which rivers are longer than 1000 kilometers?',
#   'query_string': 'SELECT name\nFROM river\nWHERE length > 1000\nORDER BY length DESC\nFETCH FIRST 5 ROWS ONLY',
#   'type': 'simple',
#   'total_tokens': 5713,
#   'prompt_tokens': 5688,
#   'completion_tokens': 25,
#   'total_cost': 0.017164},
#  {'id': '50',
#   'question': 'Which country had the lowest population growth?',
#   'query_string': 'SELECT country\nFROM population\nWHERE population_growth = (SELECT MIN(population_growth) FROM population)',
#   'type': 'medium',
#   'total_tokens': 5706,
#   'prompt_tokens': 5686,
#   'completion_tokens': 20,
#   'total_cost': 0.017138}]

# %% [markdown]
# ## Prompt Gerado pelo Langchain

# %%
sql_query_chain_prompt = query_chain.middle[0].template.format(table_info=db.get_table_info(), top_k=0, input="{input}")
print(sql_query_chain_prompt)
# Out:
# You are an Oracle SQL expert. Given an input question, first create a syntactically correct Oracle SQL query to run, then look at the results of the query and return the answer to the input question.
# Unless the user specifies in the question a specific number of examples to obtain, query for at most 0 results using the FETCH FIRST n ROWS ONLY clause as per Oracle SQL. You can order the results to return the most informative data in the database.
# Never query for all columns from a table. You must query only the columns that are needed to answer the question.
# Pay attention to use only the column names you can see in the tables below. Be careful to not query for columns that do not exist. Also, pay attention to which column is in which table.
# Pay attention to use TRUNC(SYSDATE) function to get the current date, if the question involves "today".
#
# Some hints:
# - Don't use dounle quotes in column name
# Example:
# `SELECT "column_name" FROM table` should be `SELECT column_name FROM table`
# - Don't use LEFT JOIN, only JOIN
#
# Use the following format:
#
# Question: Question here
# SQLQuery: SQL Query to run
# SQLResult: Result of the SQLQuery
# Answer: Final answer here
#
# Only use the following tables:
#
# CREATE TABLE airport (
# 	iatacode VARCHAR(3 CHAR) NOT NULL,
# 	name VARCHAR(100 CHAR),
# 	country VARCHAR(4 CHAR),
# 	city VARCHAR(50 CHAR),
# 	province VARCHAR(50 CHAR),
# 	island VARCHAR(50 CHAR),
# 	latitude NUMBER,
# 	longitude NUMBER,
# 	elevation NUMBER,
# 	gmtoffset NUMBER,
# 	CONSTRAINT sys_c00163097 PRIMARY KEY (iatacode),
# 	CONSTRAINT airport_country_fk FOREIGN KEY(country) REFERENCES country (code),
# 	CONSTRAINT airport_island_fk FOREIGN KEY(island) REFERENCES island (name),
# 	CONSTRAINT airport_province_country_fk FOREIGN KEY(province, country) REFERENCES province (name, country),
# 	CONSTRAINT city_city_province_fk FOREIGN KEY(city, country, province) REFERENCES city (name, country, province),
# 	CONSTRAINT airplat CHECK ((Latitude >= -90) AND (Latitude <= 90)),
# 	CONSTRAINT airplon CHECK ((Longitude >= -180) AND (Longitude <= 180))
# )
#
#
# CREATE TABLE borders (
# 	country1 VARCHAR(4 CHAR) NOT NULL,
# 	country2 VARCHAR(4 CHAR) NOT NULL,
# 	length NUMBER,
# 	CONSTRAINT borderkey PRIMARY KEY (country1, country2),
# 	CONSTRAINT borders_country1_fk FOREIGN KEY(country1) REFERENCES country (code),
# 	CONSTRAINT borders_country2_fk FOREIGN KEY(country2) REFERENCES country (code),
# 	CONSTRAINT sys_c00162792 CHECK (Length > 0)
# )
#
#
# CREATE TABLE city (
# 	name VARCHAR(50 CHAR) NOT NULL,
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	province VARCHAR(50 CHAR) NOT NULL,
# 	population NUMBER,
# 	latitude NUMBER,
# 	longitude NUMBER,
# 	elevation NUMBER,
# 	CONSTRAINT citykey PRIMARY KEY (name, country, province),
# 	CONSTRAINT city_country_fk FOREIGN KEY(country) REFERENCES country (code),
# 	CONSTRAINT city_province_country_fk FOREIGN KEY(province, country) REFERENCES province (name, country),
# 	CONSTRAINT citylat CHECK ((Latitude >= -90) AND (Latitude <= 90)),
# 	CONSTRAINT citylon CHECK ((Longitude >= -180) AND (Longitude <= 180)),
# 	CONSTRAINT citypop CHECK (Population >= 0)
# )
#
#
# CREATE TABLE citylocalname (
# 	city VARCHAR(50 CHAR) NOT NULL,
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	province VARCHAR(50 CHAR) NOT NULL,
# 	localname VARCHAR(300 CHAR),
# 	CONSTRAINT citylocalnamekey PRIMARY KEY (country, province, city),
# 	CONSTRAINT citylocalname_city_province_fk FOREIGN KEY(city, country, province) REFERENCES city (name, country, province),
# 	CONSTRAINT citylocalname_country_fk FOREIGN KEY(country) REFERENCES country (code),
# 	CONSTRAINT citylocalname_province_country_fk FOREIGN KEY(province, country) REFERENCES province (name, country)
# )
#
#
# CREATE TABLE cityothername (
# 	city VARCHAR(50 CHAR) NOT NULL,
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	province VARCHAR(50 CHAR) NOT NULL,
# 	othername VARCHAR(50 CHAR) NOT NULL,
# 	CONSTRAINT cityothernamekey PRIMARY KEY (country, province, city, othername),
# 	CONSTRAINT cityothername_city_province_fk FOREIGN KEY(city, country, province) REFERENCES city (name, country, province),
# 	CONSTRAINT cityothername_country_fk FOREIGN KEY(country) REFERENCES country (code),
# 	CONSTRAINT cityothername_province_country_fk FOREIGN KEY(province, country) REFERENCES province (name, country)
# )
#
#
# CREATE TABLE citypops (
# 	city VARCHAR(50 CHAR) NOT NULL,
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	province VARCHAR(50 CHAR) NOT NULL,
# 	year NUMBER NOT NULL,
# 	population NUMBER,
# 	CONSTRAINT citypopkey PRIMARY KEY (country, province, city, year),
# 	CONSTRAINT citypops_city_province_fk FOREIGN KEY(city, country, province) REFERENCES city (name, country, province),
# 	CONSTRAINT citypops_country_fk FOREIGN KEY(country) REFERENCES country (code),
# 	CONSTRAINT citypops_province_country_fk FOREIGN KEY(province, country) REFERENCES province (name, country),
# 	CONSTRAINT citypopspop CHECK (Population >= 0),
# 	CONSTRAINT citypopsyear CHECK (Year >= 0)
# )
#
#
# CREATE TABLE continent (
# 	name VARCHAR(20 CHAR) NOT NULL,
# 	area NUMBER(10, 0),
# 	CONSTRAINT continentkey PRIMARY KEY (name)
# )
#
#
# CREATE TABLE country (
# 	name VARCHAR(50 CHAR) NOT NULL,
# 	code VARCHAR(4 CHAR) NOT NULL,
# 	capital VARCHAR(50 CHAR),
# 	province VARCHAR(50 CHAR),
# 	area NUMBER,
# 	population NUMBER,
# 	CONSTRAINT countrykey PRIMARY KEY (code),
# 	CONSTRAINT countryarea CHECK (Area >= 0),
# 	CONSTRAINT countrypop CHECK (Population >= 0)
# )
#
#
# CREATE TABLE countrylocalname (
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	localname VARCHAR(300 CHAR),
# 	CONSTRAINT countrylocalnamekey PRIMARY KEY (country),
# 	CONSTRAINT countrylocalname_country_fk FOREIGN KEY(country) REFERENCES country (code)
# )
#
#
# CREATE TABLE countryothername (
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	othername VARCHAR(50 CHAR) NOT NULL,
# 	CONSTRAINT countryothernamekey PRIMARY KEY (country, othername),
# 	CONSTRAINT countryothername_country_fk FOREIGN KEY(country) REFERENCES country (code)
# )
#
#
# CREATE TABLE countrypops (
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	year NUMBER NOT NULL,
# 	population NUMBER,
# 	CONSTRAINT countrypopskey PRIMARY KEY (country, year),
# 	CONSTRAINT countrypops_country_fk FOREIGN KEY(country) REFERENCES country (code),
# 	CONSTRAINT countrypopspop CHECK (Population >= 0),
# 	CONSTRAINT countrypopsyear CHECK (Year >= 0)
# )
#
#
# CREATE TABLE desert (
# 	name VARCHAR(50 CHAR) NOT NULL,
# 	area NUMBER,
# 	CONSTRAINT desertkey PRIMARY KEY (name),
# 	CONSTRAINT descoord CHECK ((Coordinates.Latitude >= -90) AND
#             (Coordinates.Latitude <= 90) AND
#             (Coordinates.Longitude > -180) AND
#             (Coordinates.Longitude <= 180)),
# 	CONSTRAINT descoord CHECK ((Coordinates.Latitude >= -90) AND
#             (Coordinates.Latitude <= 90) AND
#             (Coordinates.Longitude > -180) AND
#             (Coordinates.Longitude <= 180))
# )
#
#
# CREATE TABLE economy (
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	gdp NUMBER,
# 	agriculture NUMBER,
# 	service NUMBER,
# 	industry NUMBER,
# 	inflation NUMBER,
# 	unemployment NUMBER,
# 	CONSTRAINT economykey PRIMARY KEY (country),
# 	CONSTRAINT economy_country_fk FOREIGN KEY(country) REFERENCES country (code),
# 	CONSTRAINT economygdp CHECK (GDP >= 0)
# )
#
#
# CREATE TABLE encompasses (
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	continent VARCHAR(20 CHAR) NOT NULL,
# 	percentage NUMBER,
# 	CONSTRAINT encompasseskey PRIMARY KEY (country, continent),
# 	CONSTRAINT encompasses_continent_fk FOREIGN KEY(continent) REFERENCES continent (name),
# 	CONSTRAINT encompasses_country_fk FOREIGN KEY(country) REFERENCES country (code),
# 	CONSTRAINT sys_c00162796 CHECK ((Percentage > 0) AND (Percentage <= 100))
# )
#
#
# CREATE TABLE ethnicgroup (
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	name VARCHAR(50 CHAR) NOT NULL,
# 	percentage NUMBER,
# 	CONSTRAINT ethnickey PRIMARY KEY (name, country),
# 	CONSTRAINT ethnic_group_country_fk FOREIGN KEY(country) REFERENCES country (code),
# 	CONSTRAINT ethnicpercent CHECK ((Percentage > 0) AND (Percentage <= 100))
# )
#
#
# CREATE TABLE geo_desert (
# 	desert VARCHAR(50 CHAR) NOT NULL,
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	province VARCHAR(50 CHAR) NOT NULL,
# 	CONSTRAINT gdesertkey PRIMARY KEY (province, country, desert),
# 	CONSTRAINT geo_desert_country_fk FOREIGN KEY(country) REFERENCES country (code),
# 	CONSTRAINT geo_desert_desert_fk FOREIGN KEY(desert) REFERENCES desert (name),
# 	CONSTRAINT geo_desert_province_country_fk FOREIGN KEY(province, country) REFERENCES province (name, country)
# )
#
#
# CREATE TABLE geo_estuary (
# 	river VARCHAR(50 CHAR) NOT NULL,
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	province VARCHAR(50 CHAR) NOT NULL,
# 	CONSTRAINT gestuarykey PRIMARY KEY (province, country, river),
# 	CONSTRAINT geo_estuary_country_fk FOREIGN KEY(country) REFERENCES country (code),
# 	CONSTRAINT geo_estuary_province_country_fk FOREIGN KEY(province, country) REFERENCES province (name, country),
# 	CONSTRAINT geo_estuary_river_fk FOREIGN KEY(river) REFERENCES river (name)
# )
#
#
# CREATE TABLE geo_island (
# 	island VARCHAR(50 CHAR) NOT NULL,
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	province VARCHAR(50 CHAR) NOT NULL,
# 	CONSTRAINT gislandkey PRIMARY KEY (province, country, island),
# 	CONSTRAINT geo_island_country_fk FOREIGN KEY(country) REFERENCES country (code),
# 	CONSTRAINT geo_island_island_fk FOREIGN KEY(island) REFERENCES island (name),
# 	CONSTRAINT geo_island_province_country_fk FOREIGN KEY(province, country) REFERENCES province (name, country)
# )
#
#
# CREATE TABLE geo_lake (
# 	lake VARCHAR(50 CHAR) NOT NULL,
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	province VARCHAR(50 CHAR) NOT NULL,
# 	CONSTRAINT glakekey PRIMARY KEY (province, country, lake),
# 	CONSTRAINT geo_lake_country_fk FOREIGN KEY(country) REFERENCES country (code),
# 	CONSTRAINT geo_lake_lake_fk FOREIGN KEY(lake) REFERENCES lake (name),
# 	CONSTRAINT geo_lake_province_country_fk FOREIGN KEY(province, country) REFERENCES province (name, country)
# )
#
#
# CREATE TABLE geo_mountain (
# 	mountain VARCHAR(50 CHAR) NOT NULL,
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	province VARCHAR(50 CHAR) NOT NULL,
# 	CONSTRAINT gmountainkey PRIMARY KEY (province, country, mountain),
# 	CONSTRAINT geo_mountain_country_fk FOREIGN KEY(country) REFERENCES country (code),
# 	CONSTRAINT geo_mountain_mountain_fk FOREIGN KEY(mountain) REFERENCES mountain (name),
# 	CONSTRAINT geo_mountain_province_country_fk FOREIGN KEY(province, country) REFERENCES province (name, country)
# )
#
#
# CREATE TABLE geo_river (
# 	river VARCHAR(50 CHAR) NOT NULL,
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	province VARCHAR(50 CHAR) NOT NULL,
# 	CONSTRAINT griverkey PRIMARY KEY (province, country, river),
# 	CONSTRAINT geo_river_country_fk FOREIGN KEY(country) REFERENCES country (code),
# 	CONSTRAINT geo_river_province_country_fk FOREIGN KEY(province, country) REFERENCES province (name, country),
# 	CONSTRAINT geo_river_river_fk FOREIGN KEY(river) REFERENCES river (name)
# )
#
#
# CREATE TABLE geo_sea (
# 	sea VARCHAR(50 CHAR) NOT NULL,
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	province VARCHAR(50 CHAR) NOT NULL,
# 	CONSTRAINT gseakey PRIMARY KEY (province, country, sea),
# 	CONSTRAINT geo_sea_country_fk FOREIGN KEY(country) REFERENCES country (code),
# 	CONSTRAINT geo_sea_province_country_fk FOREIGN KEY(province, country) REFERENCES province (name, country),
# 	CONSTRAINT geo_sea_sea_fk FOREIGN KEY(sea) REFERENCES sea (name)
# )
#
#
# CREATE TABLE geo_source (
# 	river VARCHAR(50 CHAR) NOT NULL,
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	province VARCHAR(50 CHAR) NOT NULL,
# 	CONSTRAINT gsourcekey PRIMARY KEY (province, country, river),
# 	CONSTRAINT geo_source_country_fk FOREIGN KEY(country) REFERENCES country (code),
# 	CONSTRAINT geo_source_province_country_fk FOREIGN KEY(province, country) REFERENCES province (name, country),
# 	CONSTRAINT geo_source_river_fk FOREIGN KEY(river) REFERENCES river (name)
# )
#
#
# CREATE TABLE island (
# 	name VARCHAR(50 CHAR) NOT NULL,
# 	islands VARCHAR(50 CHAR),
# 	area NUMBER,
# 	elevation NUMBER,
# 	type VARCHAR(15 CHAR),
# 	CONSTRAINT islandkey PRIMARY KEY (name),
# 	CONSTRAINT islandar CHECK (Area >= 0),
# 	CONSTRAINT islandcoord CHECK ((Coordinates.Latitude >= -90) AND
#             (Coordinates.Latitude <= 90) AND
#             (Coordinates.Longitude > -180) AND
#             (Coordinates.Longitude <= 180)),
# 	CONSTRAINT islandcoord CHECK ((Coordinates.Latitude >= -90) AND
#             (Coordinates.Latitude <= 90) AND
#             (Coordinates.Longitude > -180) AND
#             (Coordinates.Longitude <= 180))
# )
#
#
# CREATE TABLE islandin (
# 	island VARCHAR(50 CHAR),
# 	sea VARCHAR(50 CHAR),
# 	lake VARCHAR(50 CHAR),
# 	river VARCHAR(50 CHAR),
# 	CONSTRAINT islandin_island_fk FOREIGN KEY(island) REFERENCES island (name),
# 	CONSTRAINT islandin_lake_fk FOREIGN KEY(lake) REFERENCES lake (name),
# 	CONSTRAINT islandin_river_fk FOREIGN KEY(river) REFERENCES river (name),
# 	CONSTRAINT islandin_sea_fk FOREIGN KEY(sea) REFERENCES sea (name)
# )
#
#
# CREATE TABLE ismember (
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	organization VARCHAR(12 CHAR) NOT NULL,
# 	type VARCHAR(60 CHAR) DEFAULT 'member',
# 	CONSTRAINT memberkey PRIMARY KEY (country, organization),
# 	CONSTRAINT ismember_country_fk FOREIGN KEY(country) REFERENCES country (code),
# 	CONSTRAINT ismember_organization_fk FOREIGN KEY(organization) REFERENCES organization (abbreviation)
# )
#
#
# CREATE TABLE lake (
# 	name VARCHAR(50 CHAR) NOT NULL,
# 	river VARCHAR(50 CHAR),
# 	area NUMBER,
# 	elevation NUMBER,
# 	depth NUMBER,
# 	height NUMBER,
# 	type VARCHAR(12 CHAR),
# 	CONSTRAINT lakekey PRIMARY KEY (name),
# 	CONSTRAINT lake_river_fk FOREIGN KEY(river) REFERENCES river (name),
# 	CONSTRAINT damheight CHECK (Height > 0),
# 	CONSTRAINT lakear CHECK (Area >= 0),
# 	CONSTRAINT lakecoord CHECK ((Coordinates.Latitude >= -90) AND
#             (Coordinates.Latitude <= 90) AND
#             (Coordinates.Longitude > -180) AND
#             (Coordinates.Longitude <= 180)),
# 	CONSTRAINT lakecoord CHECK ((Coordinates.Latitude >= -90) AND
#             (Coordinates.Latitude <= 90) AND
#             (Coordinates.Longitude > -180) AND
#             (Coordinates.Longitude <= 180)),
# 	CONSTRAINT lakedpth CHECK (Depth >= 0)
# )
#
#
# CREATE TABLE lakeonisland (
# 	lake VARCHAR(50 CHAR) NOT NULL,
# 	island VARCHAR(50 CHAR) NOT NULL,
# 	CONSTRAINT lakeislkey PRIMARY KEY (lake, island),
# 	CONSTRAINT lakeonisland_island_fk FOREIGN KEY(island) REFERENCES island (name),
# 	CONSTRAINT lakeonisland_lake_fk FOREIGN KEY(lake) REFERENCES lake (name)
# )
#
#
# CREATE TABLE language (
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	name VARCHAR(50 CHAR) NOT NULL,
# 	percentage NUMBER,
# 	CONSTRAINT languagekey PRIMARY KEY (name, country),
# 	CONSTRAINT language_country_fk FOREIGN KEY(country) REFERENCES country (code),
# 	CONSTRAINT languagepercent CHECK ((Percentage > 0) AND (Percentage <= 100))
# )
#
#
# CREATE TABLE located (
# 	city VARCHAR(50 CHAR),
# 	province VARCHAR(50 CHAR),
# 	country VARCHAR(4 CHAR),
# 	river VARCHAR(50 CHAR),
# 	lake VARCHAR(50 CHAR),
# 	sea VARCHAR(50 CHAR),
# 	CONSTRAINT located_city_province_fk FOREIGN KEY(city, country, province) REFERENCES city (name, country, province),
# 	CONSTRAINT located_country_fk FOREIGN KEY(country) REFERENCES country (code),
# 	CONSTRAINT located_lake_fk FOREIGN KEY(lake) REFERENCES lake (name),
# 	CONSTRAINT located_province_country_fk FOREIGN KEY(province, country) REFERENCES province (name, country),
# 	CONSTRAINT located_river_fk FOREIGN KEY(river) REFERENCES river (name),
# 	CONSTRAINT located_sea_fk FOREIGN KEY(sea) REFERENCES sea (name)
# )
#
#
# CREATE TABLE locatedon (
# 	city VARCHAR(50 CHAR) NOT NULL,
# 	province VARCHAR(50 CHAR) NOT NULL,
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	island VARCHAR(50 CHAR) NOT NULL,
# 	CONSTRAINT locatedonkey PRIMARY KEY (city, province, country, island),
# 	CONSTRAINT locatedon_city_province_fk FOREIGN KEY(city, country, province) REFERENCES city (name, country, province),
# 	CONSTRAINT locatedon_country_fk FOREIGN KEY(country) REFERENCES country (code),
# 	CONSTRAINT locatedon_island_fk FOREIGN KEY(island) REFERENCES island (name),
# 	CONSTRAINT locatedon_province_country_fk FOREIGN KEY(province, country) REFERENCES province (name, country)
# )
#
#
# CREATE TABLE mergeswith (
# 	sea1 VARCHAR(50 CHAR) NOT NULL,
# 	sea2 VARCHAR(50 CHAR) NOT NULL,
# 	CONSTRAINT mergeswithkey PRIMARY KEY (sea1, sea2),
# 	CONSTRAINT mergeswith_sea1_fk FOREIGN KEY(sea1) REFERENCES sea (name),
# 	CONSTRAINT mergeswith_sea2_fk FOREIGN KEY(sea2) REFERENCES sea (name)
# )
#
#
# CREATE TABLE mountain (
# 	name VARCHAR(50 CHAR) NOT NULL,
# 	mountains VARCHAR(50 CHAR),
# 	elevation NUMBER,
# 	type VARCHAR(10 CHAR),
# 	CONSTRAINT mountainkey PRIMARY KEY (name),
# 	CONSTRAINT mountaincoord CHECK ((Coordinates.Latitude >= -90) AND
#             (Coordinates.Latitude <= 90) AND
#             (Coordinates.Longitude > -180) AND
#             (Coordinates.Longitude <= 180)),
# 	CONSTRAINT mountaincoord CHECK ((Coordinates.Latitude >= -90) AND
#             (Coordinates.Latitude <= 90) AND
#             (Coordinates.Longitude > -180) AND
#             (Coordinates.Longitude <= 180))
# )
#
#
# CREATE TABLE mountainonisland (
# 	mountain VARCHAR(50 CHAR) NOT NULL,
# 	island VARCHAR(50 CHAR) NOT NULL,
# 	CONSTRAINT mountainislkey PRIMARY KEY (mountain, island),
# 	CONSTRAINT mountainonisland_island_fk FOREIGN KEY(island) REFERENCES island (name),
# 	CONSTRAINT mountainonisland_mountain_fk FOREIGN KEY(mountain) REFERENCES mountain (name)
# )
#
#
# CREATE TABLE organization (
# 	abbreviation VARCHAR(12 CHAR) NOT NULL,
# 	name VARCHAR(100 CHAR) NOT NULL,
# 	city VARCHAR(50 CHAR),
# 	country VARCHAR(4 CHAR),
# 	province VARCHAR(50 CHAR),
# 	established DATE,
# 	CONSTRAINT orgkey PRIMARY KEY (abbreviation),
# 	CONSTRAINT organization_city_province_fk FOREIGN KEY(city, country, province) REFERENCES city (name, country, province),
# 	CONSTRAINT organization_country_fk FOREIGN KEY(country) REFERENCES country (code),
# 	CONSTRAINT organization_province_country_fk FOREIGN KEY(province, country) REFERENCES province (name, country)
# )
#
#
# CREATE TABLE politics (
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	independence DATE,
# 	wasdependent VARCHAR(50 CHAR),
# 	dependent VARCHAR(4 CHAR),
# 	government VARCHAR(120 CHAR),
# 	CONSTRAINT politicskey PRIMARY KEY (country),
# 	CONSTRAINT politics_country_fk FOREIGN KEY(country) REFERENCES country (code)
# )
#
#
# CREATE TABLE population (
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	population_growth NUMBER,
# 	infant_mortality NUMBER,
# 	CONSTRAINT popkey PRIMARY KEY (country),
# 	CONSTRAINT population_country_fk FOREIGN KEY(country) REFERENCES country (code)
# )
#
#
# CREATE TABLE province (
# 	name VARCHAR(50 CHAR) NOT NULL,
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	population NUMBER,
# 	area NUMBER,
# 	capital VARCHAR(50 CHAR),
# 	capprov VARCHAR(50 CHAR),
# 	CONSTRAINT prkey PRIMARY KEY (name, country),
# 	CONSTRAINT province_country_fk FOREIGN KEY(country) REFERENCES country (code),
# 	CONSTRAINT prar CHECK (Area >= 0),
# 	CONSTRAINT prpop CHECK (Population >= 0)
# )
#
#
# CREATE TABLE provincelocalname (
# 	province VARCHAR(50 CHAR) NOT NULL,
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	localname VARCHAR(300 CHAR),
# 	CONSTRAINT provlocalnamekey PRIMARY KEY (country, province),
# 	CONSTRAINT provincelocalname_country_fk FOREIGN KEY(country) REFERENCES country (code),
# 	CONSTRAINT provincelocalname_province_country_fk FOREIGN KEY(province, country) REFERENCES province (name, country)
# )
#
#
# CREATE TABLE provinceothername (
# 	province VARCHAR(50 CHAR) NOT NULL,
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	othername VARCHAR(50 CHAR) NOT NULL,
# 	CONSTRAINT provothernamekey PRIMARY KEY (country, province, othername),
# 	CONSTRAINT provinceothername_country_fk FOREIGN KEY(country) REFERENCES country (code),
# 	CONSTRAINT provinceothername_province_country_fk FOREIGN KEY(province, country) REFERENCES province (name, country)
# )
#
#
# CREATE TABLE provpops (
# 	province VARCHAR(50 CHAR) NOT NULL,
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	year NUMBER NOT NULL,
# 	population NUMBER,
# 	CONSTRAINT provpopkey PRIMARY KEY (country, province, year),
# 	CONSTRAINT provpops_country_fk FOREIGN KEY(country) REFERENCES country (code),
# 	CONSTRAINT provpops_province_country_fk FOREIGN KEY(province, country) REFERENCES province (name, country),
# 	CONSTRAINT provpopspop CHECK (Population >= 0),
# 	CONSTRAINT provpopsyear CHECK (Year >= 0)
# )
#
#
# CREATE TABLE religion (
# 	country VARCHAR(4 CHAR) NOT NULL,
# 	name VARCHAR(50 CHAR) NOT NULL,
# 	percentage NUMBER,
# 	CONSTRAINT religionkey PRIMARY KEY (name, country),
# 	CONSTRAINT religion_country_fk FOREIGN KEY(country) REFERENCES country (code),
# 	CONSTRAINT religionpercent CHECK ((Percentage > 0) AND (Percentage <= 100))
# )
#
#
# CREATE TABLE river (
# 	name VARCHAR(50 CHAR) NOT NULL,
# 	river VARCHAR(50 CHAR),
# 	lake VARCHAR(50 CHAR),
# 	sea VARCHAR(50 CHAR),
# 	length NUMBER,
# 	area NUMBER,
# 	mountains VARCHAR(50 CHAR),
# 	sourceelevation NUMBER,
# 	estuaryelevation NUMBER,
# 	CONSTRAINT riverkey PRIMARY KEY (name),
# 	CONSTRAINT river_lake_fk FOREIGN KEY(lake) REFERENCES lake (name),
# 	CONSTRAINT river_sea_fk FOREIGN KEY(sea) REFERENCES sea (name),
# 	CONSTRAINT estcoord CHECK ((Estuary.Latitude >= -90) AND
#             (Estuary.Latitude <= 90) AND
#             (Estuary.Longitude > -180) AND
#             (Estuary.Longitude <= 180)),
# 	CONSTRAINT estcoord CHECK ((Estuary.Latitude >= -90) AND
#             (Estuary.Latitude <= 90) AND
#             (Estuary.Longitude > -180) AND
#             (Estuary.Longitude <= 180)),
# 	CONSTRAINT riverarea CHECK (Area >= 0),
# 	CONSTRAINT riverlength CHECK (Length >= 0),
# 	CONSTRAINT rivflowsinto CHECK ((River IS NULL AND Lake IS NULL)
#             OR (River IS NULL AND Sea IS NULL)
#             OR (Lake IS NULL AND Sea is NULL)),
# 	CONSTRAINT rivflowsinto CHECK ((River IS NULL AND Lake IS NULL)
#             OR (River IS NULL AND Sea IS NULL)
#             OR (Lake IS NULL AND Sea is NULL)),
# 	CONSTRAINT rivflowsinto CHECK ((River IS NULL AND Lake IS NULL)
#             OR (River IS NULL AND Sea IS NULL)
#             OR (Lake IS NULL AND Sea is NULL)),
# 	CONSTRAINT sourcecoord CHECK ((Source.Latitude >= -90) AND
#             (Source.Latitude <= 90) AND
#             (Source.Longitude > -180) AND
#             (Source.Longitude <= 180)),
# 	CONSTRAINT sourcecoord CHECK ((Source.Latitude >= -90) AND
#             (Source.Latitude <= 90) AND
#             (Source.Longitude > -180) AND
#             (Source.Longitude <= 180))
# )
#
#
# CREATE TABLE riveronisland (
# 	river VARCHAR(50 CHAR) NOT NULL,
# 	island VARCHAR(50 CHAR) NOT NULL,
# 	CONSTRAINT riverislkey PRIMARY KEY (river, island),
# 	CONSTRAINT riveronisland_island_fk FOREIGN KEY(island) REFERENCES island (name),
# 	CONSTRAINT riveronisland_river_fk FOREIGN KEY(river) REFERENCES river (name)
# )
#
#
# CREATE TABLE riverthrough (
# 	river VARCHAR(50 CHAR) NOT NULL,
# 	lake VARCHAR(50 CHAR) NOT NULL,
# 	CONSTRAINT rthroughkey PRIMARY KEY (river, lake),
# 	CONSTRAINT riverthrough_lake_fk FOREIGN KEY(lake) REFERENCES lake (name),
# 	CONSTRAINT riverthrough_river_fk FOREIGN KEY(river) REFERENCES river (name)
# )
#
#
# CREATE TABLE sea (
# 	name VARCHAR(50 CHAR) NOT NULL,
# 	area NUMBER,
# 	depth NUMBER,
# 	CONSTRAINT seakey PRIMARY KEY (name),
# 	CONSTRAINT seaar CHECK (Area >= 0),
# 	CONSTRAINT seadepth CHECK (Depth >= 0)
# )
#
# Question: {input}

# %%
f = open(f"prompt_generated_by_langchain_{SCHEMA}_fk.txt", "w")
f.write(sql_query_chain_prompt)
f.close()

# %% [markdown]
# #### Fixing queries

# %%
to_fix = [40,59,62,72,85,99]
for pos in to_fix:
    instance = queries[pos]
    q = read_queries()
    with get_openai_callback() as cb:
            start_time = time.time()
            sql_query = query_chain.invoke({"question":instance["question"]})
            end_time = time.time()
            instance["query_string"] = sql_query
            instance['total_tokens'] = cb.total_tokens
            instance['prompt_tokens'] = cb.prompt_tokens
            instance['completion_tokens'] = cb.completion_tokens
            instance['total_cost'] = cb.total_cost
            instance['time'] = end_time - start_time
            q[pos] = instance
            print(instance['id'], instance['question'], instance["query_string"], instance['time'], instance['total_cost'])
            save_queries(q)
# Out:
# 41 How many countries that are close to the Mediterranean Sea? SELECT COUNT(*)
# FROM encompasses
# WHERE continent = 'Europe' AND percentage >= 10 1.1704304218292236 0.017151
# 60  List the names of capital cities which are the base for organizations in alphabetical order SELECT city.name
# FROM city
# JOIN organization ON city.name = organization.city
# ORDER BY city.name ASC 1.3115789890289307 0.017181000000000002
# 63 Show the inflation rate of countries that are washed by the Arabian Sea SELECT c.name, e.inflation
# FROM country c
# JOIN geo_sea gs ON c.code = gs.country
# JOIN sea s ON gs.sea = s.name
# JOIN economy e ON c.code = e.country
# WHERE s.name = 'Arabian Sea' 2.0416371822357178 0.017308
# 73 What area is the largest continent? SELECT name, area FROM continent ORDER BY area DESC 0.8098440170288086 0.017106999999999997
# 86 What are the 3 airports with the largest name? SELECT name FROM airport ORDER BY LENGTH(name) DESC FETCH FIRST 3 ROWS ONLY 1.012031078338623 0.017147
# 100 What is the percentage of industries in relation to Japan's economy? SELECT industry FROM economy WHERE country = 'JPN' 0.8485252857208252 0.017129
