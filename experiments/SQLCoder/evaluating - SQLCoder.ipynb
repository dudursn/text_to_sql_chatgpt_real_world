# %%
from dotenv import load_dotenv
import os
import sys
import json
import pandas as pd
import time
import datetime
load_dotenv()
path = os.path.abspath('')
module_path = os.path.join(path,'..\..')
print(module_path)
if module_path not in sys.path:
    sys.path.append(module_path+"\\functions")


from dataset_utils import DatasetEvaluator

# %%
DEFAULT_PATH = "results/"
EXPERIMENT = "SQLCoder"
TARGET_PATH = f"evaluator_results/{EXPERIMENT}_results.csv"

# %% [markdown]
# Funções úteis

# %%
def save_queries(queries, FILE_NAME_PATH):
    data = {"queries":queries}
    with open(FILE_NAME_PATH, "w") as arquivo_json:
        json.dump(data, arquivo_json, indent=4) 

def read_queries(FILE_NAME_PATH):
    with open(FILE_NAME_PATH, encoding="utf-8", errors="ignore") as json_data:
        data = json.load(json_data, strict=False)
    queries = data["queries"]
    return queries

def get_schema(FILE_NAME_PATH):
    if "mondial_gpt" in FILE_NAME_PATH:
        return "mondial_gpt"
    elif "mondial" in FILE_NAME_PATH:
        return "mondial"
    return ""

def get_count_query_type(queries):
    count_types = {}
    for item in queries:
        type = item["type"]
        if type in count_types:
            count_types[type] += 1
        else:
            count_types[type] = 1
    count_types['total'] = len(queries)
    return count_types

def get_dataset_evaluator(FILE_NAME_PATH):
    SCHEMA = get_schema(FILE_NAME_PATH)  
    PREFIX = SCHEMA  
    if SCHEMA == "mondial_gpt":
        PREFIX = "mondial"
    print(PREFIX)
    print(SCHEMA)
    dataset_eval = DatasetEvaluator(dataset_file_path=f"../../datasets/{PREFIX}/{PREFIX}_dataset.json",
                                dataset_tables_path=f"../../datasets/{PREFIX}/result_tables/",
                                db_connection_file=f"../../datasets/{SCHEMA}_db_connection.json",
                                dataset_name=SCHEMA)
    return dataset_eval

def get_files_in_folder():
    files = []
    for r, d, f in os.walk(DEFAULT_PATH):
        for file in f:
            if '.json' in file and 'erro' not in file:
                files.append(os.path.join(r, file))
    return sorted(files)

def evaluate_query(queries, dataset_eval, FILE_NAME_PATH):
    result = {'simple': 0, 'medium': 0, 'complex': 0, 'total': 0}

    for q in queries:
        evaluate_result = False
        q['similarity'] = 0
        try:
            if q["query_string"].strip() != "":
                evaluate_result, similarity, column_matching_index = dataset_eval.evaluate_dataset_query(q["query_string"], q["id"], query_type="sql")
                q['column_matching_index'] = column_matching_index
                q['similarity']=similarity
            
        except Exception as e:
            print(str(e))
            
        q['result'] = evaluate_result
        
        if evaluate_result==True:
            result['total'] += 1
            result[q["type"]] += 1
        
    save_queries(queries, FILE_NAME_PATH)   
    return result

def get_file_name(FILE_NAME_PATH):
    parts = FILE_NAME_PATH.split("/")
    last_element = parts[-1]
    file_name = last_element.replace(".json", "")
    return file_name

def get_experiment_name(filename):
    schema = get_schema(filename).upper()
    experiment_name = f"{EXPERIMENT} - {schema}"
    if "chatgpt4" in filename:
        experiment_name += " - GPT-4"
    elif "chatgpt_" in filename:
        experiment_name += " - GPT-3.5"
    elif "llama" in filename:
        experiment_name += " - LLAMA"
    
        
    return experiment_name


def compute_cost(filename):
    queries = read_queries(filename)
    total_costs = 0
    total_tokens = 0
    input_tokens = 0
    output_tokens = 0
    for q in queries:
        total_tokens += q.get('total_tokens', 0)
        total_costs += q.get('total_cost', 0)
        input_tokens += q.get('prompt_tokens', 0)
        output_tokens += q.get('completion_tokens', 0)

    print(total_tokens)
    print(round(total_costs, 2))
    print(input_tokens, output_tokens)
    return total_tokens, round(total_costs, 2), input_tokens, output_tokens

def compute_time(filename):
    queries = read_queries(filename)
    total_time = 0
    for q in queries:
        total_time += q.get('time', 0)
    print(total_time)
    return str(datetime.timedelta(seconds=round(total_time)))

# %%
def run(result_files = [], result_final = [], compute_costs = True):
    
    if result_files == [] :
        result_files = get_files_in_folder()
    else:
        result_files = sorted(result_files)
        
    
    for file in result_files:
        queries = read_queries(file)
        dataset_eval = get_dataset_evaluator(file)
        count_query_type = get_count_query_type(queries)
        result = evaluate_query(queries, dataset_eval, file)
        
        overall_by_type = {}
        for item in result:
            overall_by_type[f"overall_{item}"] = round(result[item] / count_query_type[item], 4)
        
        result['experiment'] = get_file_name(file)
        result = {**result, **overall_by_type}
        result['total_tokens'], result['total_cost'], result['average_tokens_by_query'] = 0, 0, 0
        if compute_costs:
            result['total_tokens'], result['total_cost'], result['input_tokens'], result['output_tokens'] = compute_cost(file)

        result['total_time'] = compute_time(file)
        
        result_final.append(result)
        time.sleep(5)
    return result_final

# %%
path = "results/1_sql_coder_mondial_gpt.json"

# %%
get_experiment_name(path)
# Out:
# 'SQLCoder - MONDIAL'

# %%
results_no_fk = run([path], [], compute_costs=False)
# Out:
# mondial
# mondial
# SELECT max(area) FROM mondial_country where name  = 'Thailand'
# SELECT MONDIAL_COUNTRY.AREA
# FROM MONDIAL_COUNTRY
# WHERE UPPER(MONDIAL_COUNTRY.NAME) LIKE UPPER('%Thailand%')
# True cols: Index(['MAX(AREA)'], dtype='object')
# Adj. True cols: Index(['MAX(AREA)'], dtype='object')
# Predicted cols: Index(['AREA'], dtype='object')
# Adj. Predicted cols: Index(['AREA'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name FROM mondial_province where area > 10000
# SELECT SUM(AREA) AS total_area
# FROM MONDIAL_GPT.MONDIAL_PROVINCE
# WHERE AREA > 10000
# Error: Execution failed on sql 'SELECT SUM(AREA) AS total_area
# FROM MONDIAL_GPT.MONDIAL_PROVINCE
# WHERE AREA > 10000': ORA-00942: table or view does not exist
# SELECT mondial_language.name FROM mondial_language INNER JOIN mondial_country ON mondial_language.country = mondial_country.code WHERE mondial_country.name = 'Poland'
# SELECT name
# FROM mondial_gpt.mondial_country
# WHERE UPPER(name) LIKE '%POLAND%'
# Error: Execution failed on sql 'SELECT name
# FROM mondial_gpt.mondial_country
# WHERE UPPER(name) LIKE '%POLAND%'': ORA-00942: table or view does not exist
# SELECT depth FROM mondial_lake where name LIKE '%Lake Kariba%'
# SELECT DEPTH
# FROM MONDIAL_GPT.MONDIAL_LAKE
# WHERE LOWER(NAME) LIKE '%lake%kariba%'
# Error: Execution failed on sql 'SELECT DEPTH
# FROM MONDIAL_GPT.MONDIAL_LAKE
# WHERE LOWER(NAME) LIKE '%lake%kariba%'': ORA-00942: table or view does not exist
# SELECT count(*) FROM mondial_province p INNER JOIN mondial_country c ON p.country = c.code WHERE c.name = 'Netherlands'
# SELECT COUNT(*) AS total_provinces
# FROM MONDIAL_GPT.MONDIAL_PROVINCE
# WHERE COUNTRY = 'NL';
# Error: Execution failed on sql 'SELECT COUNT(*) AS total_provinces
# FROM MONDIAL_GPT.MONDIAL_PROVINCE
# WHERE COUNTRY = 'NL'': ORA-00942: table or view does not exist
# SELECT r.percentage FROM mondial_religion r INNER JOIN mondial_country c ON r.country = c.code WHERE c.name = 'Thailand' AND r.name LIKE '%Hindu%'
# SELECT MONDIAL_RELIGION.PERCENTAGE
# FROM MONDIAL_RELIGION
# WHERE MONDIAL_RELIGION.COUNTRY = 'THA'
#   AND MONDIAL_RELIGION.NAME = 'Hindu';
# True cols: Index(['PERCENTAGE'], dtype='object')
# Adj. True cols: Index(['PERCENTAGE'], dtype='object')
# Predicted cols: Index(['PERCENTAGE'], dtype='object')
# Adj. Predicted cols: Index(['PERCENTAGE'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT river.name, COUNT(DISTINCT geo_river.province) FROM river JOIN geo_river ON river.name = geo_river.river GROUP BY river.name
# Execution failed on sql 'SELECT river.name, COUNT(DISTINCT geo_river.province) FROM river JOIN geo_river ON river.name = geo_river.river GROUP BY river.name': ORA-00942: table or view does not exist
# SELECT c.name FROM mondial_country c
# INNER JOIN mondial_politics p ON c.code = p.country
# WHERE independence > DATE '1910-08-01' AND independence < DATE '1950-08-01'
# SELECT name
# FROM mondial_gpt.mondial_country
# WHERE independence BETWEEN TO_DATE('1910-08-01', 'YYYY-MM-DD') AND TO_DATE('1950-08-01', 'YYYY-MM-DD')
# ORDER BY name NULLS LAST;
# Error: Execution failed on sql 'SELECT name
# FROM mondial_gpt.mondial_country
# WHERE independence BETWEEN TO_DATE('1910-08-01', 'YYYY-MM-DD') AND TO_DATE('1950-08-01', 'YYYY-MM-DD')
# ORDER BY name NULLS LAST': ORA-00942: table or view does not exist
# SELECT * FROM mondial_city ci INNER JOIN mondial_country c on ci.country = c.code where c.name = 'Cuba'
# SELECT MONDIAL_GPT.MONDIAL_CITY.NAME
# FROM MONDIAL_GPT.MONDIAL_CITY
# WHERE MONDIAL_GPT.MONDIAL_CITY.COUNTRY = 'Cuba'
# Error: Execution failed on sql 'SELECT MONDIAL_GPT.MONDIAL_CITY.NAME
# FROM MONDIAL_GPT.MONDIAL_CITY
# WHERE MONDIAL_GPT.MONDIAL_CITY.COUNTRY = 'Cuba'': ORA-00942: table or view does not exist
# SELECT capital FROM mondial_country WHERE name = 'Georgia'
# SELECT CAPITAL
# FROM MONDIAL_GPT.MONDIAL_COUNTRY
# WHERE UPPER(NAME) LIKE '%GEORGIA%'
# Error: Execution failed on sql 'SELECT CAPITAL
# FROM MONDIAL_GPT.MONDIAL_COUNTRY
# WHERE UPPER(NAME) LIKE '%GEORGIA%'': ORA-00942: table or view does not exist
# SELECT count(p.name) FROM mondial_province p INNER JOIN mondial_country c on p.country = c.code where c.name = 'Niger' AND p.area > 1000
# SELECT COUNT(*)
# FROM MONDIAL_GPT.MONDIAL_PROVINCE
# WHERE AREA > 1000
#   AND COUNTRY = 'NG'
# Error: Execution failed on sql 'SELECT COUNT(*)
# FROM MONDIAL_GPT.MONDIAL_PROVINCE
# WHERE AREA > 1000
#   AND COUNTRY = 'NG'': ORA-00942: table or view does not exist
# SELECT name FROM mondial_country GROUP BY name ORDER BY max(area) DESC FETCH FIRST 1 ROWS ONLY;
# SELECT MAX(AREA)
# FROM MONDIAL_GPT.MONDIAL_COUNTRY
# WHERE UPPER(NAME) LIKE UPPER('%Thailand%')
# Error: Execution failed on sql 'SELECT MAX(AREA)
# FROM MONDIAL_GPT.MONDIAL_COUNTRY
# WHERE UPPER(NAME) LIKE UPPER('%Thailand%')': ORA-00942: table or view does not exist
# SELECT o.province, o.established  FROM mondial_organization o WHERE o.name LIKE '%International Energy Agency%'
# SELECT MONDIAL_ORGANIZATION.PROVINCE,
#        EXTRACT(YEAR FROM MONDIAL_ORGANIZATION.ESTABLISHED) AS YEAR_ESTABLISHED
# FROM MONDIAL_ORGANIZATION
# WHERE MONDIAL_ORGANIZATION.NAME = 'International Energy Agency';
# True cols: Index(['PROVINCE', 'ESTABLISHED'], dtype='object')
# Adj. True cols: Index(['PROVINCE'], dtype='object')
# Predicted cols: Index(['PROVINCE', 'YEAR_ESTABLISHED'], dtype='object')
# Adj. Predicted cols: Index(['PROVINCE'], dtype='object')
# False: no match found
# SELECT name FROM mondial_mountain WHERE elevation > 1000.0
# SELECT name
# FROM MONDIAL_GPT.MONDIAL_MOUNTAIN
# WHERE elevation > 1000;
# Error: Execution failed on sql 'SELECT name
# FROM MONDIAL_GPT.MONDIAL_MOUNTAIN
# WHERE elevation > 1000': ORA-00942: table or view does not exist
# SELECT DISTINCT e.* FROM mondial_economy e
# INNER JOIN mondial_country c ON e.country = c.code
# INNER JOIN mondial_geo_sea gs ON gs.country = c.code
# INNER JOIN mondial_sea s ON s.name = gs.sea
# WHERE s.name LIKE '%Caribbean Sea%'
# SELECT MONDIAL_ECONOMY.GDP
# FROM MONDIAL_ECONOMY
# INNER JOIN MONDIAL_GEO_SEA ON MONDIAL_ECONOMY.COUNTRY = MONDIAL_GEO_SEA.COUNTRY
# WHERE MONDIAL_GEO_SEA.SEA = 'Caribbean Sea'
# True cols: Index(['COUNTRY', 'GDP', 'AGRICULTURE', 'SERVICE', 'INDUSTRY', 'INFLATION',
#        'UNEMPLOYMENT', 'META_REPCOL'],
#       dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['GDP'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT name FROM mondial_city WHERE longitude BETWEEN 0 AND 6
# SELECT NAME
# FROM MONDIAL_GPT.MONDIAL_CITY
# WHERE LONGITUDE BETWEEN 0 AND 6;
# Error: Execution failed on sql 'SELECT NAME
# FROM MONDIAL_GPT.MONDIAL_CITY
# WHERE LONGITUDE BETWEEN 0 AND 6': ORA-00942: table or view does not exist
# SELECT ci.name FROM mondial_city ci
# INNER JOIN mondial_country c ON c.code = ci.country
# INNER JOIN mondial_population p ON p.country = c.code
# WHERE ci.population > 100000 AND ci.elevation > 2500 AND
# p.population_growth > 1
# SELECT MONDIAL_CITY.NAME
# FROM MONDIAL_CITY
# INNER JOIN MONDIAL_COUNTRY ON MONDIAL_CITY.COUNTRY = MONDIAL_COUNTRY.CODE
# INNER JOIN MONDIAL_POPULATION ON MONDIAL_COUNTRY.CODE = MONDIAL_POPULATION.COUNTRY
# WHERE MONDIAL_CITY.POPULATION > 100000
#   AND MONDIAL_CITY.ELEVATION > 2500
#   AND MONDIAL_POPULATION.POPULATION_GROWTH > 1;
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT DISTINCT government FROM mondial_politics
# SELECT DISTINCT MONDIAL_POLITICS.GOVERNMENT
# FROM MONDIAL_POLITICS
# WHERE MONDIAL_POLITICS.COUNTRY = 'THA'
# ORDER BY CASE WHEN MONDIAL_POLITICS.GOVERNMENT IS NULL THEN 1 ELSE 0 END, MONDIAL_POLITICS.GOVERNMENT;
# True cols: Index(['GOVERNMENT'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['GOVERNMENT'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT p.name FROM mondial_province p INNER JOIN mondial_country c ON p.country = c.code  WHERE c.name = 'Germany'
# SELECT MONDIAL_GPT.MONDIAL_PROVINCE.name
# FROM MONDIAL_GPT.MONDIAL_PROVINCE
# WHERE MONDIAL_GPT.MONDIAL_PROVINCE.country = 'Germany'
# ORDER BY CASE WHEN MONDIAL_GPT.MONDIAL_PROVINCE.name IS NULL THEN 1 ELSE 0 END, MONDIAL_GPT.MONDIAL_PROVINCE.name;
# Error: Execution failed on sql 'SELECT MONDIAL_GPT.MONDIAL_PROVINCE.name
# FROM MONDIAL_GPT.MONDIAL_PROVINCE
# WHERE MONDIAL_GPT.MONDIAL_PROVINCE.country = 'Germany'
# ORDER BY CASE WHEN MONDIAL_GPT.MONDIAL_PROVINCE.name IS NULL THEN 1 ELSE 0 END, MONDIAL_GPT.MONDIAL_PROVINCE.name': ORA-00942: table or view does not exist
# SELECT eg.percentage FROM mondial_ethnicgroup eg INNER JOIN mondial_country c ON c.code = eg.country WHERE c.name = 'Brazil' AND eg.name LIKE '%Mulatto%'
# SELECT MONDIAL_ETHNICGROUP.PERCENTAGE
# FROM MONDIAL_ETHNICGROUP
# WHERE MONDIAL_ETHNICGROUP.COUNTRY = 'BR'
#   AND UPPER(MONDIAL_ETHNICGROUP.NAME) LIKE UPPER('%mulatto%')
# True cols: Index(['PERCENTAGE'], dtype='object')
# Adj. True cols: Index(['PERCENTAGE'], dtype='object')
# Predicted cols: Index(['PERCENTAGE'], dtype='object')
# Adj. Predicted cols: Index(['PERCENTAGE'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT count(*) FROM mondial_city WHERE population < 1000
# SELECT COUNT(*)
# FROM MONDIAL_CITY
# WHERE POPULATION < 1000;
# True cols: Index(['COUNT(*)'], dtype='object')
# Adj. True cols: Index(['COUNT(*)'], dtype='object')
# Predicted cols: Index(['COUNT(*)'], dtype='object')
# Adj. Predicted cols: Index(['COUNT(*)'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT avg(a.elevation) FROM mondial_airport a
# INNER JOIN mondial_country c ON c.code = a.country
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# WHERE co.name = 'America'
# SELECT AVG(ELEVATION) AS average_elevation
# FROM MONDIAL_AIRPORT
# WHERE UPPER(COUNTRY) LIKE '%AMERICA%';
# True cols: Index(['AVG(A.ELEVATION)'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['AVERAGE_ELEVATION'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT COUNT(DISTINCT ec.country) AS number_of_countries
# FROM mondial_geo_sea gs
# JOIN mondial_encompasses ec ON gs.country = ec.country
# WHERE gs.sea = 'Caribbean Sea';
# SELECT COUNT(DISTINCT MONDIAL_GEO_SEA.COUNTRY) AS adjacent_countries
# FROM MONDIAL_GEO_SEA
# WHERE MONDIAL_GEO_SEA.SEA = 'Caribbean Sea';
# True cols: Index(['NUMBER_OF_COUNTRIES'], dtype='object')
# Adj. True cols: Index(['NUMBER_OF_COUNTRIES'], dtype='object')
# Predicted cols: Index(['ADJACENT_COUNTRIES'], dtype='object')
# Adj. Predicted cols: Index(['ADJACENT_COUNTRIES'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT SUM(DISTINCT c.area) AS total_area
# FROM mondial_Country c
# JOIN mondial_encompasses e ON c.code = e.country
# JOIN mondial_geo_sea gs ON e.country = gs.country
# WHERE gs.sea = 'Caribbean Sea';
# SELECT MONDIAL_COUNTRY.name, SUM(MONDIAL_COUNTRY.population) AS total_population FROM MONDIAL_COUNTRY JOIN MONDIAL_GEO_SEA ON MONDIAL_COUNTRY.code = MONDIAL_GEO_SEA.country WHERE MONDIAL_GEO_SEA.sea = 'Caribbean Sea' GROUP BY MONDIAL_COUNTRY.name ORDER BY total_population DESC NULLS LAST;
#
# True cols: Index(['TOTAL_AREA'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME', 'TOTAL_POPULATION'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT c.name AS country_name, SUM(c1.population) AS total_neighbor_population
# FROM mondial_Country c
# JOIN mondial_Borders b ON c.code = b.country1
# JOIN mondial_Country c1 ON b.country2 = c1.code
# GROUP BY c.name;
# SELECT MONDIAL_COUNTRY.name, SUM(MONDIAL_COUNTRY.population) AS total_population FROM MONDIAL_COUNTRY JOIN MONDIAL_BORDERS ON (MONDIAL_COUNTRY.code = MONDIAL_BORDERS.country1 OR MONDIAL_COUNTRY.code = MONDIAL_BORDERS.country2) GROUP BY MONDIAL_COUNTRY.name ORDER BY total_population DESC NULLS LAST;
# True cols: Index(['COUNTRY_NAME', 'TOTAL_NEIGHBOR_POPULATION'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME', 'TOTAL_POPULATION'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT mountain FROM mondial_mountainonisland WHERE island LIKE '%Borneo%'
# SELECT MONDIAL_GPT.MONDIAL_MOUNTAINONISLAND.MOUNTAIN
# FROM MONDIAL_GPT.MONDIAL_MOUNTAINONISLAND
# WHERE MONDIAL_GPT.MONDIAL_MOUNTAINONISLAND.ISLAND = 'Borneo'
# ORDER BY CASE WHEN MONDIAL_GPT.MONDIAL_MOUNTAINONISLAND.MOUNTAIN IS NULL THEN 1 ELSE 0 END, MONDIAL_GPT.MONDIAL_MOUNTAINONISLAND.MOUNTAIN;
# Error: Execution failed on sql 'SELECT MONDIAL_GPT.MONDIAL_MOUNTAINONISLAND.MOUNTAIN
# FROM MONDIAL_GPT.MONDIAL_MOUNTAINONISLAND
# WHERE MONDIAL_GPT.MONDIAL_MOUNTAINONISLAND.ISLAND = 'Borneo'
# ORDER BY CASE WHEN MONDIAL_GPT.MONDIAL_MOUNTAINONISLAND.MOUNTAIN IS NULL THEN 1 ELSE 0 END, MONDIAL_GPT.MONDIAL_MOUNTAINONISLAND.MOUNTAIN': ORA-00942: table or view does not exist
# SELECT name, population FROM mondial_country ORDER BY area ASC FETCH FIRST 1 ROWS ONLY;
# SELECT name, population
# FROM MONDIAL_COUNTRY
# WHERE LOWER(name) LIKE LOWER('%Thailand%')
# ORDER BY NVL(area,0) ASC
# FETCH FIRST 1 ROWS ONLY;
# True cols: Index(['NAME', 'POPULATION'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME', 'POPULATION'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT DISTINCT s.country
# FROM mondial_geo_estuary e, mondial_borders b, mondial_geo_source s
# WHERE ((e.country = b.country1 AND s.country = b.country2)
# OR (e.country = b.country2 AND s.country = b.country1))
# AND e.river = s.river;
# SELECT e.COUNTRY
# FROM MONDIAL_GEO_ESTUARY e
# WHERE e.RIVER IN
#     (SELECT r.RIVER
#      FROM MONDIAL_GEO_RIVER r
#      WHERE r.COUNTRY = 'THA');
# True cols: Index(['COUNTRY'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['COUNTRY'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT code FROM mondial_country
# WHERE code NOT IN (
# SELECT p.country FROM (
# SELECT name, country
# FROM mondial_province
# WHERE (name, country) NOT IN (SELECT province, country FROM mondial_geo_mountain)) p);
# SELECT MONDIAL_COUNTRY.CODE
# FROM MONDIAL_COUNTRY
# JOIN MONDIAL_GEO_MOUNTAIN ON MONDIAL_COUNTRY.CODE = MONDIAL_GEO_MOUNTAIN.COUNTRY
# GROUP BY MONDIAL_COUNTRY.CODE;
# True cols: Index(['CODE'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['CODE'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT b.country1, sum(b.length)
# FROM (SELECT country1, length FROM mondial_borders
# UNION ALL
# SELECT country2, length FROM mondial_borders
# ) b
# GROUP BY b.country1;
# SELECT MONDIAL_BORDERS.COUNTRY1,
#        SUM(MONDIAL_BORDERS.LENGTH) AS total_border_length
# FROM MONDIAL_BORDERS
# GROUP BY MONDIAL_BORDERS.COUNTRY1
# HAVING COUNT(MONDIAL_BORDERS.COUNTRY1) >= 1;
# True cols: Index(['COUNTRY1', 'SUM(B.LENGTH)'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['COUNTRY1', 'TOTAL_BORDER_LENGTH'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT DISTINCT c.name, c.code
# FROM mondial_country c, mondial_geo_source g
# WHERE c.code = g.country;
# SELECT MONDIAL_GPT.MONDIAL_COUNTRY.NAME,
#        MONDIAL_GPT.MONDIAL_COUNTRY.CODE
# FROM MONDIAL_GPT.MONDIAL_COUNTRY
# WHERE UPPER(MONDIAL_GPT.MONDIAL_COUNTRY.NAME) LIKE UPPER('%Thailand%')
# Error: Execution failed on sql 'SELECT MONDIAL_GPT.MONDIAL_COUNTRY.NAME,
#        MONDIAL_GPT.MONDIAL_COUNTRY.CODE
# FROM MONDIAL_GPT.MONDIAL_COUNTRY
# WHERE UPPER(MONDIAL_GPT.MONDIAL_COUNTRY.NAME) LIKE UPPER('%Thailand%')': ORA-00942: table or view does not exist
# SELECT c.name, r.area FROM mondial_geo_river gr
# INNER JOIN mondial_country c ON c.code = gr.country
# INNER JOIN mondial_river r ON r.name = gr.river
# WHERE r.name = 'Chatanga'
# SELECT AREA
# FROM MONDIAL_GPT.MONDIAL_COUNTRY
# WHERE UPPER(NAME) LIKE UPPER('%Thailand%')
# Error: Execution failed on sql 'SELECT AREA
# FROM MONDIAL_GPT.MONDIAL_COUNTRY
# WHERE UPPER(NAME) LIKE UPPER('%Thailand%')': ORA-00942: table or view does not exist
# SELECT name FROM mondial_airport WHERE elevation > 3000.0
# SELECT COUNT(*)
# FROM MONDIAL_GPT.MONDIAL_AIRPORT
# WHERE ELEVATION > 3000
# Error: Execution failed on sql 'SELECT COUNT(*)
# FROM MONDIAL_GPT.MONDIAL_AIRPORT
# WHERE ELEVATION > 3000': ORA-00942: table or view does not exist
# SELECT r.name FROM mondial_religion r INNER JOIN mondial_country c ON c.code = r.country WHERE c.name = 'Mexico'
# SELECT MONDIAL_GPT.MONDIAL_RELIGION.NAME
# FROM MONDIAL_GPT.MONDIAL_RELIGION
# WHERE MONDIAL_GPT.MONDIAL_RELIGION.COUNTRY = 'MEX'
# Error: Execution failed on sql 'SELECT MONDIAL_GPT.MONDIAL_RELIGION.NAME
# FROM MONDIAL_GPT.MONDIAL_RELIGION
# WHERE MONDIAL_GPT.MONDIAL_RELIGION.COUNTRY = 'MEX'': ORA-00942: table or view does not exist
# SELECT name FROM mondial_River WHERE sea IS NULL;
# SELECT NAME
# FROM MONDIAL_GPT.MONDIAL_RIVER
# WHERE SEA IS NULL;
# Error: Execution failed on sql 'SELECT NAME
# FROM MONDIAL_GPT.MONDIAL_RIVER
# WHERE SEA IS NULL': ORA-00942: table or view does not exist
# SELECT c.name, COUNT(b.country2) AS num_neighbors FROM mondial_country c INNER JOIN mondial_borders b ON c.code = b.country1
# INNER JOIN mondial_encompasses e ON c.code = e.country
# INNER JOIN mondial_continent co ON e.continent = co.name
# WHERE co.name = 'Africa' GROUP BY c.name ORDER BY num_neighbors DESC;
# SELECT MONDIAL_COUNTRY.name,
#        COUNT(DISTINCT MONDIAL_BORDERS.country2) AS neighbor_count
# FROM MONDIAL_COUNTRY
# JOIN MONDIAL_BORDERS ON MONDIAL_COUNTRY.code = MONDIAL_BORDERS.country1
# WHERE MONDIAL_COUNTRY.continent = 'Africa'
# GROUP BY MONDIAL_COUNTRY.name
# ORDER BY CASE WHEN neighbor_count IS NULL THEN 1 ELSE 0 END, neighbor_count DESC;
# Error: Execution failed on sql 'SELECT MONDIAL_COUNTRY.name,
#        COUNT(DISTINCT MONDIAL_BORDERS.country2) AS neighbor_count
# FROM MONDIAL_COUNTRY
# JOIN MONDIAL_BORDERS ON MONDIAL_COUNTRY.code = MONDIAL_BORDERS.country1
# WHERE MONDIAL_COUNTRY.continent = 'Africa'
# GROUP BY MONDIAL_COUNTRY.name
# ORDER BY CASE WHEN neighbor_count IS NULL THEN 1 ELSE 0 END, neighbor_count DESC': ORA-00904: "MONDIAL_COUNTRY"."CONTINENT": invalid identifier
# SELECT c.name AS continent, AVG(p.infant_mortality) AS avg_infant_mortality
# FROM mondial_continent c
# JOIN mondial_encompasses e ON c.name = e.continent
# JOIN mondial_population p ON e.country = p.country
# GROUP BY c.name;
# SELECT MONDIAL_GPT.MONDIAL_CONTINENT.name,
#        AVG(MONDIAL_GPT.MONDIAL_POPULATION.infant_mortality) AS average_infant_mortality
# FROM MONDIAL_GPT.MONDIAL_CONTINENT
# JOIN MONDIAL_GPT.MONDIAL_ENCOMPASSES ON MONDIAL_GPT.MONDIAL_CONTINENT.name = MONDIAL_GPT.MONDIAL_ENCOMPASSES.continent
# JOIN MONDIAL_GPT.MONDIAL_POPULATION ON MONDIAL_GPT.MONDIAL_ENCOMPASSES.country = MONDIAL_GPT.MONDIAL_POPULATION.country
# GROUP BY MONDIAL_GPT.MONDIAL_CONTINENT.name
# ORDER BY AVG(MONDIAL_GPT.MONDIAL_POPULATION.infant_mortality) DESC NULLS LAST;
# Error: Execution failed on sql 'SELECT MONDIAL_GPT.MONDIAL_CONTINENT.name,
#        AVG(MONDIAL_GPT.MONDIAL_POPULATION.infant_mortality) AS average_infant_mortality
# FROM MONDIAL_GPT.MONDIAL_CONTINENT
# JOIN MONDIAL_GPT.MONDIAL_ENCOMPASSES ON MONDIAL_GPT.MONDIAL_CONTINENT.name = MONDIAL_GPT.MONDIAL_ENCOMPASSES.continent
# JOIN MONDIAL_GPT.MONDIAL_POPULATION ON MONDIAL_GPT.MONDIAL_ENCOMPASSES.country = MONDIAL_GPT.MONDIAL_POPULATION.country
# GROUP BY MONDIAL_GPT.MONDIAL_CONTINENT.name
# ORDER BY AVG(MONDIAL_GPT.MONDIAL_POPULATION.infant_mortality) DESC NULLS LAST': ORA-00942: table or view does not exist
# SELECT AVG(p.infant_mortality) AS avg_infant_mortality
# FROM mondial_Country c
# JOIN mondial_Population p ON c.code = p.country
# JOIN mondial_encompasses e ON c.code = e.country
# JOIN mondial_Continent ct ON e.continent = ct.name
# WHERE ct.name = 'America' AND c.name != 'Brazil';
# SELECT AVG(MONDIAL_POPULATION.INFANT_MORTALITY) AS average_mortality_rate
# FROM MONDIAL_COUNTRY
# JOIN MONDIAL_ENCOMPASSES ON MONDIAL_COUNTRY.CODE = MONDIAL_ENCOMPASSES.COUNTRY
# WHERE MONDIAL_COUNTRY.CONTINENT = 'America'
#   AND MONDIAL_COUNTRY.NAME<> 'Brazil';
# Error: Execution failed on sql 'SELECT AVG(MONDIAL_POPULATION.INFANT_MORTALITY) AS average_mortality_rate
# FROM MONDIAL_COUNTRY
# JOIN MONDIAL_ENCOMPASSES ON MONDIAL_COUNTRY.CODE = MONDIAL_ENCOMPASSES.COUNTRY
# WHERE MONDIAL_COUNTRY.CONTINENT = 'America'
#   AND MONDIAL_COUNTRY.NAME<> 'Brazil'': ORA-00904: "MONDIAL_COUNTRY"."CONTINENT": invalid identifier
# SELECT name FROM mondial_sea WHERE area > 8000 AND depth < 100
# SELECT AREA
# FROM MONDIAL_GPT.MONDIAL_SEA
# WHERE AREA > 8000
#   AND DEPTH < 100
# Error: Execution failed on sql 'SELECT AREA
# FROM MONDIAL_GPT.MONDIAL_SEA
# WHERE AREA > 8000
#   AND DEPTH < 100': ORA-00942: table or view does not exist
# SELECT count(DISTINCT m.name) FROM mondial_mountain m
# INNER JOIN mondial_geo_mountain gm ON m.name = gm.mountain
# INNER JOIN mondial_country c ON c.code = gm.country
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# WHERE co.name = 'Asia'
# SELECT COUNT(*)
# FROM mondial_geo_mountain
# WHERE country = 'AS';
# True cols: Index(['COUNT(DISTINCTM.NAME)'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['COUNT(*)'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT count(DISTINCT c.name) FROM mondial_country c
# INNER JOIN mondial_geo_sea gs ON gs.country = c.code
# INNER JOIN mondial_sea s ON gs.sea = s.name
# WHERE s.name = 'Mediterranean Sea'
# SELECT COUNT(DISTINCT MONDIAL_COUNTRY.COUNTRY) AS number_of_countries
# FROM MONDIAL_COUNTRY
# INNER JOIN MONDIAL_GEO_SEA ON MONDIAL_COUNTRY.COUNTRY = MONDIAL_GEO_SEA.COUNTRY
# WHERE MONDIAL_GEO_SEA.SEA = 'Mediterranean Sea';
# Error: Execution failed on sql 'SELECT COUNT(DISTINCT MONDIAL_COUNTRY.COUNTRY) AS number_of_countries
# FROM MONDIAL_COUNTRY
# INNER JOIN MONDIAL_GEO_SEA ON MONDIAL_COUNTRY.COUNTRY = MONDIAL_GEO_SEA.COUNTRY
# WHERE MONDIAL_GEO_SEA.SEA = 'Mediterranean Sea'': ORA-00904: "MONDIAL_COUNTRY"."COUNTRY": invalid identifier
# SELECT government, count(government) FROM mondial_politics GROUP BY government
# SELECT MONDIAL_POLITICS.GOVERNMENT,
#        COUNT(*) AS COUNT
# FROM MONDIAL_POLITICS
# WHERE MONDIAL_POLITICS.COUNTRY = 'THA'
# GROUP BY MONDIAL_POLITICS.GOVERNMENT
# ORDER BY COUNT(*) DESC;
# True cols: Index(['GOVERNMENT', 'COUNT(GOVERNMENT)'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['GOVERNMENT', 'COUNT'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT province FROM mondial_geo_desert gd
# INNER JOIN mondial_desert d ON gd.desert = d.name ORDER BY d.area DESC FETCH FIRST 1 ROWS ONLY;
# SELECT MONDIAL_GEO_DESERT.PROVINCE
# FROM MONDIAL_GEO_DESERT
# WHERE MONDIAL_GEO_DESERT.DESERT = 'Desert'
# ORDER BY DECODE(MONDIAL_GEO_DESERT.AREA, NULL, 1, 0), MONDIAL_GEO_DESERT.AREA DESC
# FETCH FIRST 1 ROWS ONLY;
# Error: Execution failed on sql 'SELECT MONDIAL_GEO_DESERT.PROVINCE
# FROM MONDIAL_GEO_DESERT
# WHERE MONDIAL_GEO_DESERT.DESERT = 'Desert'
# ORDER BY DECODE(MONDIAL_GEO_DESERT.AREA, NULL, 1, 0), MONDIAL_GEO_DESERT.AREA DESC
# FETCH FIRST 1 ROWS ONLY': ORA-00904: "MONDIAL_GEO_DESERT"."AREA": invalid identifier
# SELECT name FROM mondial_desert ORDER BY area DESC FETCH FIRST 1 ROWS ONLY;
# SELECT MAX(AREA)
# FROM MONDIAL_GPT.MONDIAL_DESERT;
# Error: Execution failed on sql 'SELECT MAX(AREA)
# FROM MONDIAL_GPT.MONDIAL_DESERT': ORA-00942: table or view does not exist
# SELECT co.name, count(gd.desert) FROM mondial_geo_desert gd
# INNER JOIN mondial_country c ON c.code = gd.country
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# GROUP BY co.name
# SELECT mgd.continent,
#        COUNT(mgd.desert) AS NUMBER_OF_DESERTS
# FROM mondial_geo_desert mgd
# GROUP BY mgd.continent;
# Error: Execution failed on sql 'SELECT mgd.continent,
#        COUNT(mgd.desert) AS NUMBER_OF_DESERTS
# FROM mondial_geo_desert mgd
# GROUP BY mgd.continent': ORA-00904: "MGD"."CONTINENT": invalid identifier
# SELECT sea2 FROM mergeswith WHERE sea1 = 'Banda Sea' UNION SELECT sea1 FROM mergeswith WHERE sea2 = 'Banda Sea'
# Execution failed on sql 'SELECT sea2 FROM mergeswith WHERE sea1 = 'Banda Sea' UNION SELECT sea1 FROM mergeswith WHERE sea2 = 'Banda Sea'': ORA-00942: table or view does not exist
# SELECT c.capital FROM mondial_country c
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# WHERE co.name = 'Europe'
# SELECT MONDIAL_COUNTRY.CAPITAL
# FROM MONDIAL_COUNTRY
# WHERE MONDIAL_COUNTRY.CONTINENT = 'Europe'
# ORDER BY CASE WHEN MONDIAL_COUNTRY.CAPITAL IS NULL THEN 1 ELSE 0 END, MONDIAL_COUNTRY.CAPITAL;
# Error: Execution failed on sql 'SELECT MONDIAL_COUNTRY.CAPITAL
# FROM MONDIAL_COUNTRY
# WHERE MONDIAL_COUNTRY.CONTINENT = 'Europe'
# ORDER BY CASE WHEN MONDIAL_COUNTRY.CAPITAL IS NULL THEN 1 ELSE 0 END, MONDIAL_COUNTRY.CAPITAL': ORA-00904: "MONDIAL_COUNTRY"."CONTINENT": invalid identifier
# SELECT l.percentage FROM mondial_language l
# INNER JOIN mondial_country c ON l.country = c.code
# WHERE l.name LIKE '%French%' AND c.name = 'Andorra'
# SELECT MONDIAL_LANGUAGE.PERCENTAGE
# FROM MONDIAL_LANGUAGE
# WHERE MONDIAL_LANGUAGE.COUNTRY = 'AD'
#   AND MONDIAL_LANGUAGE.NAME = 'French'
# True cols: Index(['PERCENTAGE'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['PERCENTAGE'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT name FROM mondial_river WHERE length > 1000
# SELECT RIVER
# FROM MONDIAL_GPT.MONDIAL_RIVER
# WHERE LENGTH > 1000
# Error: Execution failed on sql 'SELECT RIVER
# FROM MONDIAL_GPT.MONDIAL_RIVER
# WHERE LENGTH > 1000': ORA-00942: table or view does not exist
# SELECT c.name FROM mondial_country c
# INNER JOIN mondial_population p ON p.country = c.code
# ORDER BY p.population_growth ASC FETCH FIRST 1 ROWS ONLY
# SELECT MONDIAL_COUNTRY.name
# FROM MONDIAL_COUNTRY
# JOIN MONDIAL_POPULATION ON MONDIAL_COUNTRY.code = MONDIAL_POPULATION.country
# ORDER BY NVL(MONDIAL_POPULATION.population_growth, -9999999) ASC
# FETCH FIRST 1 ROWS ONLY;
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT c.capital FROM mondial_country c WHERE c.capital NOT IN (SELECT lo.city FROM mondial_located lo )
# SELECT MONDIAL_COUNTRY.CAPITAL
# FROM MONDIAL_COUNTRY
# LEFT JOIN MONDIAL_LOCATED ON MONDIAL_COUNTRY.CAPITAL = MONDIAL_LOCATED.CITY
# WHERE MONDIAL_LOCATED.CITY IS NULL;
# True cols: Index(['CAPITAL'], dtype='object')
# Adj. True cols: Index(['CAPITAL'], dtype='object')
# Predicted cols: Index(['CAPITAL'], dtype='object')
# Adj. Predicted cols: Index(['CAPITAL'], dtype='object')
# True: query matches sql (Similarity: 0.9846153846153847, column match: 1.0)
# SELECT p.CAPITAL
# FROM MONDIAL_PROVINCE p
# WHERE p.name like '%Andalucía%'
# SELECT CAPITAL
# FROM MONDIAL_GPT.MONDIAL_PROVINCE
# WHERE UPPER(NAME) LIKE UPPER('%Andalucía%')
# Error: Execution failed on sql 'SELECT CAPITAL
# FROM MONDIAL_GPT.MONDIAL_PROVINCE
# WHERE UPPER(NAME) LIKE UPPER('%Andalucía%')': ORA-00942: table or view does not exist
# SELECT abbreviation FROM mondial_organization WHERE name='General Confederation of Trade Unions'
# SELECT ABBREVIATION
# FROM MONDIAL_GPT.MONDIAL_ORGANIZATION
# WHERE UPPER(NAME) LIKE UPPER('%General%Confederation%of%Trade%Unions%')
# Error: Execution failed on sql 'SELECT ABBREVIATION
# FROM MONDIAL_GPT.MONDIAL_ORGANIZATION
# WHERE UPPER(NAME) LIKE UPPER('%General%Confederation%of%Trade%Unions%')': ORA-00942: table or view does not exist
# SELECT city FROM mondial_organization WHERE abbreviation='UPU'
# SELECT MONDIAL_ORGANIZATION.CITY
# FROM MONDIAL_ORGANIZATION
# WHERE MONDIAL_ORGANIZATION.ABBREVIATION = 'UPU'
# True cols: Index(['CITY'], dtype='object')
# Adj. True cols: Index(['CITY'], dtype='object')
# Predicted cols: Index(['CITY'], dtype='object')
# Adj. Predicted cols: Index(['CITY'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT c.name
# FROM mondial_country c
# JOIN mondial_ismember m
# ON c.code=m.country
# WHERE m.organization=ALL(SELECT organization
# FROM mondial_ismember m
# WHERE
# m.country=c.code)
# SELECT MONDIAL_COUNTRY.name
# FROM MONDIAL_COUNTRY
# JOIN MONDIAL_ISMEMBER ON MONDIAL_COUNTRY.code = MONDIAL_ISMEMBER.country
# GROUP BY MONDIAL_COUNTRY.name
# HAVING COUNT(DISTINCT MONDIAL_ISMEMBER.organization) = 1;
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT c.name
# FROM mondial_country c
# WHERE c.code NOT IN (SELECT m.country
# FROM mondial_ismember m
# WHERE organization='NATO')
# SELECT MONDIAL_COUNTRY.name
# FROM MONDIAL_COUNTRY
# WHERE MONDIAL_COUNTRY.name NOT IN
#     (SELECT MONDIAL_ISMEMBER.COUNTRY
#      FROM MONDIAL_ISMEMBER
#      WHERE MONDIAL_ISMEMBER.ORGANIZATION = 'NATO');
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT c.name
# FROM mondial_country c
# JOIN mondial_ismember m
# ON c.code=m.country
# WHERE organization='NATO'
# SELECT MONDIAL_COUNTRY.name
# FROM MONDIAL_COUNTRY
# JOIN MONDIAL_ISMEMBER ON MONDIAL_COUNTRY.code = MONDIAL_ISMEMBER.country
# WHERE MONDIAL_ISMEMBER.organization = 'NATO'
# ORDER BY CASE WHEN MONDIAL_COUNTRY.name IS NULL THEN 1 ELSE 0 END, MONDIAL_COUNTRY.name;
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index(['NAME'], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name FROM mondial_river WHERE length < 50
# SELECT NAME
# FROM MONDIAL_GPT.MONDIAL_RIVER
# WHERE LENGTH < 50
# Error: Execution failed on sql 'SELECT NAME
# FROM MONDIAL_GPT.MONDIAL_RIVER
# WHERE LENGTH < 50': ORA-00942: table or view does not exist
# SELECT l.area, l.elevation, l.type FROM MONDIAL_GEO_LAKE gl , MONDIAL_LAKE l, MONDIAL_COUNTRY c
# WHERE (gl.LAKE = l.NAME)
# AND (gl.COUNTRY = c.CODE)
# AND  c.name = 'Italy'
# SELECT LAKE,
#        COUNTRY,
#        PROVINCE,
#        META_REPCOL
# FROM MONDIAL_GPT.MONDIAL_GEO_LAKE
# WHERE UPPER(COUNTRY) LIKE '%ITALY%'
# Error: Execution failed on sql 'SELECT LAKE,
#        COUNTRY,
#        PROVINCE,
#        META_REPCOL
# FROM MONDIAL_GPT.MONDIAL_GEO_LAKE
# WHERE UPPER(COUNTRY) LIKE '%ITALY%'': ORA-00942: table or view does not exist
# SELECT c.capital
# FROM mondial_country c
# WHERE c.capital IN (SELECT o.city
# FROM mondial_organization o) ORDER BY c.capital ASC
# SELECT MONDIAL_COUNTRY.CAPITAL
# FROM MONDIAL_COUNTRY
# WHERE MONDIAL_COUNTRY.COUNTRY = 'THA'
# ORDER BY MONDIAL_COUNTRY.CAPITAL ASC;
# Error: Execution failed on sql 'SELECT MONDIAL_COUNTRY.CAPITAL
# FROM MONDIAL_COUNTRY
# WHERE MONDIAL_COUNTRY.COUNTRY = 'THA'
# ORDER BY MONDIAL_COUNTRY.CAPITAL ASC': ORA-00904: "MONDIAL_COUNTRY"."COUNTRY": invalid identifier
# SELECT o.name
# FROM mondial_organization o
# WHERE NOT EXISTS (SELECT *
# FROM mondial_ismember m
# JOIN mondial_country c
# ON m.country=c.code
# WHERE m.organization=o.abbreviation
# AND c.area <=4000
# AND m.type= 'member')
# SELECT mondial_gpt.mondial_organization.name
# FROM mondial_gpt.mondial_organization
# JOIN mondial_gpt.mondial_ismember ON mondial_gpt.mondial_organization.name = mondial_gpt.mondial_ismember.organization
# JOIN mondial_gpt.mondial_country ON mondial_gpt.mondial_ismember.country = mondial_gpt.mondial_country.code
# WHERE mondial_gpt.mondial_country.area < 4000
#   AND UPPER(mondial_gpt.mondial_ismember.type) LIKE UPPER('%member%')
# ORDER BY mondial_gpt.mondial_organization.name NULLS LAST;
# Error: Execution failed on sql 'SELECT mondial_gpt.mondial_organization.name
# FROM mondial_gpt.mondial_organization
# JOIN mondial_gpt.mondial_ismember ON mondial_gpt.mondial_organization.name = mondial_gpt.mondial_ismember.organization
# JOIN mondial_gpt.mondial_country ON mondial_gpt.mondial_ismember.country = mondial_gpt.mondial_country.code
# WHERE mondial_gpt.mondial_country.area < 4000
#   AND UPPER(mondial_gpt.mondial_ismember.type) LIKE UPPER('%member%')
# ORDER BY mondial_gpt.mondial_organization.name NULLS LAST': ORA-00942: table or view does not exist
# SELECT o.name
# FROM mondial_organization o
# WHERE NOT EXISTS (SELECT *
# FROM mondial_ismember m
# JOIN mondial_country c
# ON m.country=c.code
# WHERE m.organization=o.abbreviation
# AND c.area > 10000
# AND c.population < 3000
# AND m.type= 'member')
# SELECT MONDIAL_ORGANIZATION.NAME
# FROM MONDIAL_ORGANIZATION
# JOIN MONDIAL_ISMEMBER ON MONDIAL_ORGANIZATION.ORGANIZATION = MONDIAL_ISMEMBER.ORGANIZATION
# JOIN MONDIAL_COUNTRY ON MONDIAL_ISMEMBER.COUNTRY = MONDIAL_COUNTRY.CODE
# WHERE MONDIAL_COUNTRY.AREA > 10000
#   AND MONDIAL_COUNTRY.POPULATION < 3000
#   AND MONDIAL_ISMEMBER.TYPE ='member'
# ORDER BY NULLIF(MONDIAL_ORGANIZATION.NAME, MONDIAL_ORGANIZATION.NAME) DESC, MONDIAL_ORGANIZATION.NAME;
# Error: Execution failed on sql 'SELECT MONDIAL_ORGANIZATION.NAME
# FROM MONDIAL_ORGANIZATION
# JOIN MONDIAL_ISMEMBER ON MONDIAL_ORGANIZATION.ORGANIZATION = MONDIAL_ISMEMBER.ORGANIZATION
# JOIN MONDIAL_COUNTRY ON MONDIAL_ISMEMBER.COUNTRY = MONDIAL_COUNTRY.CODE
# WHERE MONDIAL_COUNTRY.AREA > 10000
#   AND MONDIAL_COUNTRY.POPULATION < 3000
#   AND MONDIAL_ISMEMBER.TYPE ='member'
# ORDER BY NULLIF(MONDIAL_ORGANIZATION.NAME, MONDIAL_ORGANIZATION.NAME) DESC, MONDIAL_ORGANIZATION.NAME': ORA-00904: "MONDIAL_ORGANIZATION"."ORGANIZATION": invalid identifier
# SELECT DISTINCT e.inflation FROM mondial_economy e
# INNER JOIN mondial_country c ON e.country = c.code
# INNER JOIN mondial_geo_sea gs ON gs.country = c.code
# INNER JOIN mondial_sea s ON s.name = gs.sea
# WHERE s.name LIKE '%Arabian Sea%' ORDER BY e.inflation
# SELECT MONDIAL_ECONOMY.COUNTRY,
#        MONDIAL_ECONOMY.INFLATION
# FROM MONDIAL_ECONOMY
# JOIN MONDIAL_GEO_SEA ON MONDIAL_ECONOMY.COUNTRY = MONDIAL_GEO_SEA.COUNTRY
# WHERE MONDIAL_GEO_SEA.SEA = 'Arabian Sea'
# ORDER BY CASE WHEN MONDIAL_ECONOMY.INFLATION IS NULL THEN 1 ELSE 0 END, MONDIAL_ECONOMY.INFLATION DESC;
# True cols: Index(['INFLATION'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['COUNTRY', 'INFLATION'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT c.capital FROM mondial_country c
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# WHERE co.name = 'Africa'
# SELECT MONDIAL_COUNTRY.CAPITAL
# FROM MONDIAL_COUNTRY
# JOIN MONDIAL_ENCOMPASSES ON MONDIAL_COUNTRY.CODE = MONDIAL_ENCOMPASSES.COUNTRY
# WHERE MONDIAL_ENCOMPASSES.CONTINENT = 'Africa'
# True cols: Index(['CAPITAL'], dtype='object')
# Adj. True cols: Index(['CAPITAL'], dtype='object')
# Predicted cols: Index(['CAPITAL'], dtype='object')
# Adj. Predicted cols: Index(['CAPITAL'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT DISTINCT e.inflation FROM mondial_economy e
# INNER JOIN mondial_country c ON e.country = c.code
# INNER JOIN mondial_geo_sea gs ON gs.country = c.code
# INNER JOIN mondial_sea s ON s.name = gs.sea
# WHERE s.name LIKE '%Arabian Sea%' AND e.INFLATION IS NOT NULL
# SELECT MONDIAL_ECONOMY.INFLATION
# FROM MONDIAL_ECONOMY
# JOIN MONDIAL_GEO_SEA ON MONDIAL_ECONOMY.COUNTRY = MONDIAL_GEO_SEA.COUNTRY
# WHERE MONDIAL_GEO_SEA.SEA = 'Arabian Sea'
#   AND MONDIAL_ECONOMY.INFLATION IS NOT NULL;
# True cols: Index(['INFLATION'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['INFLATION'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT count(*) FROM mondial_country c
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# WHERE co.name = 'Africa'
# SELECT COUNT(DISTINCT MONDIAL_COUNTRY.CONTINENT) AS number_of_continents
# FROM MONDIAL_COUNTRY
# WHERE MONDIAL_COUNTRY.CONTINENT = 'Africa';
# Error: Execution failed on sql 'SELECT COUNT(DISTINCT MONDIAL_COUNTRY.CONTINENT) AS number_of_continents
# FROM MONDIAL_COUNTRY
# WHERE MONDIAL_COUNTRY.CONTINENT = 'Africa'': ORA-00904: "MONDIAL_COUNTRY"."CONTINENT": invalid identifier
# SELECT name FROM country WHERE code NOT IN (SELECT country FROM ismember WHERE organization = 'NATO')
# INTERSECT SELECT name FROM country WHERE code NOT IN (SELECT country FROM ismember WHERE organization = 'UNESCO')
# Execution failed on sql 'SELECT name FROM country WHERE code NOT IN (SELECT country FROM ismember WHERE organization = 'NATO')
# INTERSECT SELECT name FROM country WHERE code NOT IN (SELECT country FROM ismember WHERE organization = 'UNESCO')': ORA-00942: table or view does not exist
# SELECT area FROM mondial_continent WHERE name = 'Europe'
# SELECT MONDIAL_CONTINENT.AREA
# FROM MONDIAL_CONTINENT
# WHERE MONDIAL_CONTINENT.NAME = 'Europe'
# True cols: Index(['AREA'], dtype='object')
# Adj. True cols: Index(['AREA'], dtype='object')
# Predicted cols: Index(['AREA'], dtype='object')
# Adj. Predicted cols: Index(['AREA'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT area FROM mondial_continent WHERE name = 'America'
# SELECT MONDIAL_CONTINENT.AREA
# FROM MONDIAL_CONTINENT
# WHERE MONDIAL_CONTINENT.NAME = 'America';
# True cols: Index(['AREA'], dtype='object')
# Adj. True cols: Index(['AREA'], dtype='object')
# Predicted cols: Index(['AREA'], dtype='object')
# Adj. Predicted cols: Index(['AREA'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT area FROM mondial_continent WHERE name = 'Asia'
# SELECT MONDIAL_GPT.MONDIAL_CONTINENT.AREA
# FROM MONDIAL_GPT.MONDIAL_CONTINENT
# WHERE MONDIAL_GPT.MONDIAL_CONTINENT.NAME = 'Asia'
# Error: Execution failed on sql 'SELECT MONDIAL_GPT.MONDIAL_CONTINENT.AREA
# FROM MONDIAL_GPT.MONDIAL_CONTINENT
# WHERE MONDIAL_GPT.MONDIAL_CONTINENT.NAME = 'Asia'': ORA-00942: table or view does not exist
# SELECT area FROM mondial_continent WHERE name = 'Africa'
# SELECT MONDIAL_CONTINENT.AREA
# FROM MONDIAL_CONTINENT
# WHERE MONDIAL_CONTINENT.NAME = 'Africa';
# True cols: Index(['AREA'], dtype='object')
# Adj. True cols: Index(['AREA'], dtype='object')
# Predicted cols: Index(['AREA'], dtype='object')
# Adj. Predicted cols: Index(['AREA'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT count(*) FROM mondial_country c
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# WHERE co.name = 'America'
# SELECT COUNT(*)
# FROM MONDIAL_GPT.MONDIAL_COUNTRY
# WHERE UPPER(CONTINENT) LIKE '%AMERICA%'
# Error: Execution failed on sql 'SELECT COUNT(*)
# FROM MONDIAL_GPT.MONDIAL_COUNTRY
# WHERE UPPER(CONTINENT) LIKE '%AMERICA%'': ORA-00942: table or view does not exist
# SELECT max(area) FROM mondial_continent
# SELECT MAX(AREA)
# FROM MONDIAL_GPT.MONDIAL_CONTINENT
# WHERE UPPER(NAME) LIKE UPPER('%Thailand%')
# Error: Execution failed on sql 'SELECT MAX(AREA)
# FROM MONDIAL_GPT.MONDIAL_CONTINENT
# WHERE UPPER(NAME) LIKE UPPER('%Thailand%')': ORA-00942: table or view does not exist
# SELECT c.name
# FROM mondial_country c
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# WHERE e.continent = (
#     SELECT name
#     FROM mondial_continent
#     GROUP BY name
#     ORDER BY MAX(area) DESC
#     FETCH FIRST 1 ROWS ONLY
# );
# SELECT MONDIAL_GPT.MONDIAL_CONTINENT.NAME
# FROM MONDIAL_GPT.MONDIAL_COUNTRY
# JOIN MONDIAL_GPT.MONDIAL_ENCOMPASSES ON MONDIAL_GPT.MONDIAL_COUNTRY.CODE = MONDIAL_GPT.MONDIAL_ENCOMPASSES.COUNTRY
# WHERE MONDIAL_GPT.MONDIAL_COUNTRY.NAME = 'Thailand'
# GROUP BY MONDIAL_GPT.MONDIAL_CONTINENT.NAME
# ORDER BY MONDIAL_GPT.MONDIAL_CONTINENT.AREA DESC NULLS LAST
# FETCH FIRST 1 ROWS ONLY;
# Error: Execution failed on sql 'SELECT MONDIAL_GPT.MONDIAL_CONTINENT.NAME
# FROM MONDIAL_GPT.MONDIAL_COUNTRY
# JOIN MONDIAL_GPT.MONDIAL_ENCOMPASSES ON MONDIAL_GPT.MONDIAL_COUNTRY.CODE = MONDIAL_GPT.MONDIAL_ENCOMPASSES.COUNTRY
# WHERE MONDIAL_GPT.MONDIAL_COUNTRY.NAME = 'Thailand'
# GROUP BY MONDIAL_GPT.MONDIAL_CONTINENT.NAME
# ORDER BY MONDIAL_GPT.MONDIAL_CONTINENT.AREA DESC NULLS LAST
# FETCH FIRST 1 ROWS ONLY': ORA-00942: table or view does not exist
# SELECT c.name
# FROM mondial_country c
# INNER JOIN mondial_encompasses e ON e.country = c.code
# INNER JOIN mondial_continent co ON co.name = e.continent
# INNER JOIN mondial_language l ON l.country = c.code
# WHERE e.continent = (
#     SELECT name
#     FROM mondial_continent
#     GROUP BY name
#     ORDER BY MAX(area) DESC
#     FETCH FIRST 1 ROWS ONLY
# ) AND l.name='English';
# SELECT MONDIAL_GPT.MONDIAL_CONTINENT.NAME
# FROM MONDIAL_GPT.MONDIAL_COUNTRY
# JOIN MONDIAL_GPT.MONDIAL_ENCOMPASSES ON MONDIAL_GPT.MONDIAL_COUNTRY.CODE = MONDIAL_GPT.MONDIAL_ENCOMPASSES.COUNTRY
# JOIN MONDIAL_GPT.MONDIAL_LANGUAGE ON MONDIAL_GPT.MONDIAL_COUNTRY.CODE = MONDIAL_GPT.MONDIAL_LANGUAGE.COUNTRY
# WHERE MONDIAL_GPT.MONDIAL_LANGUAGE.NAME = 'English'
# GROUP BY MONDIAL_GPT.MONDIAL_CONTINENT.NAME
# ORDER BY MONDIAL_GPT.MONDIAL_CONTINENT.AREA DESC NULLS LAST
# FETCH FIRST 1 ROWS ONLY;
# Error: Execution failed on sql 'SELECT MONDIAL_GPT.MONDIAL_CONTINENT.NAME
# FROM MONDIAL_GPT.MONDIAL_COUNTRY
# JOIN MONDIAL_GPT.MONDIAL_ENCOMPASSES ON MONDIAL_GPT.MONDIAL_COUNTRY.CODE = MONDIAL_GPT.MONDIAL_ENCOMPASSES.COUNTRY
# JOIN MONDIAL_GPT.MONDIAL_LANGUAGE ON MONDIAL_GPT.MONDIAL_COUNTRY.CODE = MONDIAL_GPT.MONDIAL_LANGUAGE.COUNTRY
# WHERE MONDIAL_GPT.MONDIAL_LANGUAGE.NAME = 'English'
# GROUP BY MONDIAL_GPT.MONDIAL_CONTINENT.NAME
# ORDER BY MONDIAL_GPT.MONDIAL_CONTINENT.AREA DESC NULLS LAST
# FETCH FIRST 1 ROWS ONLY': ORA-00942: table or view does not exist
# SELECT ci.name AS cityname, c.name AS countryname
# FROM mondial_city ci
# JOIN mondial_country c ON ci.country = c.code
# WHERE ci.population > 5000000
# ORDER BY ci.population DESC;
# SELECT MONDIAL_CITY.NAME,
#        MONDIAL_CITY.COUNTRY,
#        MONDIAL_CITY.POPULATION
# FROM MONDIAL_CITY
# WHERE MONDIAL_CITY.POPULATION > 5000000
# ORDER BY MONDIAL_CITY.POPULATION DESC;
# True cols: Index(['CITYNAME', 'COUNTRYNAME'], dtype='object')
# Adj. True cols: Index(['CITYNAME'], dtype='object')
# Predicted cols: Index(['NAME', 'COUNTRY', 'POPULATION'], dtype='object')
# Adj. Predicted cols: Index(['NAME'], dtype='object')
# False: no match found
# SELECT d.name FROM mondial_desert d
# INNER JOIN mondial_geo_desert gd ON gd.desert = d.name
# WHERE gd.province='Algeria'
# SELECT name
# FROM mondial_gpt_desert
# WHERE UPPER(province) LIKE '%ALGERIA%'
# Error: Execution failed on sql 'SELECT name
# FROM mondial_gpt_desert
# WHERE UPPER(province) LIKE '%ALGERIA%'': ORA-00942: table or view does not exist
# SELECT d.name, d.area FROM mondial_desert d
# INNER JOIN mondial_geo_desert gd ON gd.desert = d.name
# WHERE gd.province='California'
# SELECT MONDIAL_GPT.MONDIAL_DESERT.name,
#    MONDIAL_GPT.MONDIAL_DESERT.area
# FROM MONDIAL_GPT.MONDIAL_GEO_DESERT
# WHERE MONDIAL_GPT.MONDIAL_GEO_DESERT.province = 'California'
# ORDER BY NVL(MONDIAL_GPT.MONDIAL_DESERT.area, 0) DESC;
# Error: Execution failed on sql 'SELECT MONDIAL_GPT.MONDIAL_DESERT.name,
#    MONDIAL_GPT.MONDIAL_DESERT.area
# FROM MONDIAL_GPT.MONDIAL_GEO_DESERT
# WHERE MONDIAL_GPT.MONDIAL_GEO_DESERT.province = 'California'
# ORDER BY NVL(MONDIAL_GPT.MONDIAL_DESERT.area, 0) DESC': ORA-00942: table or view does not exist
# SELECT c.name, l.percentage FROM mondial_language l INNER JOIN mondial_country c
# ON l.country = c.code WHERE l.name = 'French'
# SELECT MONDIAL_COUNTRY.NAME,
#        SUM(MONDIAL_LANGUAGE.PERCENTAGE) AS total_percentage
# FROM MONDIAL_COUNTRY
# JOIN MONDIAL_LANGUAGE ON MONDIAL_COUNTRY.CODE = MONDIAL_LANGUAGE.COUNTRY
# WHERE MONDIAL_LANGUAGE.NAME = 'French'
# GROUP BY MONDIAL_COUNTRY.NAME;
# True cols: Index(['NAME', 'PERCENTAGE'], dtype='object')
# Adj. True cols: Index(['NAME', 'PERCENTAGE'], dtype='object')
# Predicted cols: Index(['NAME', 'TOTAL_PERCENTAGE'], dtype='object')
# Adj. Predicted cols: Index(['NAME', 'TOTAL_PERCENTAGE'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT ci.name
# FROM mondial_city ci
# INNER JOIN mondial_country co
# ON co.code = ci.country
# INNER JOIN mondial_language l
# ON l.country = co.code
# WHERE l.name = 'Portuguese';
# SELECT MONDIAL_GPT.MONDIAL_COUNTRY.AREA
# FROM MONDIAL_GPT.MONDIAL_LANGUAGE
# WHERE UPPER(MONDIAL_GPT.MONDIAL_LANGUAGE.NAME) LIKE UPPER('%Portuguese%')
# Error: Execution failed on sql 'SELECT MONDIAL_GPT.MONDIAL_COUNTRY.AREA
# FROM MONDIAL_GPT.MONDIAL_LANGUAGE
# WHERE UPPER(MONDIAL_GPT.MONDIAL_LANGUAGE.NAME) LIKE UPPER('%Portuguese%')': ORA-00942: table or view does not exist
# SELECT SUM(p.area)
# FROM mondial_province p
# INNER JOIN mondial_country c
# ON p.country = c.code
# WHERE c.name = 'Canada';
# SELECT SUM(AREA) AS total_area
# FROM MONDIAL_GPT.MONDIAL_PROVINCE
# WHERE UPPER(COUNTRY) LIKE '%CANADA%';
# Error: Execution failed on sql 'SELECT SUM(AREA) AS total_area
# FROM MONDIAL_GPT.MONDIAL_PROVINCE
# WHERE UPPER(COUNTRY) LIKE '%CANADA%'': ORA-00942: table or view does not exist
# SELECT length FROM mondial_river WHERE name LIKE '%Tigris%'
# SELECT LENGTH
# FROM MONDIAL_GPT.MONDIAL_RIVER
# WHERE UPPER(RIVER) LIKE '%TIGRES%RIVER%'
# Error: Execution failed on sql 'SELECT LENGTH
# FROM MONDIAL_GPT.MONDIAL_RIVER
# WHERE UPPER(RIVER) LIKE '%TIGRES%RIVER%'': ORA-00942: table or view does not exist
# SELECT name
# FROM mondial_airport
# WHERE elevation > 1000.0;
# SELECT NAME,
#        IATACODE,
#        COUNTRY,
#        CITY,
#        PROVINCE,
#        ISLAND,
#        LATITUDE,
#        LONGITUDE,
#        ELEVATION,
#        GMTOFFSET,
#        META_REPCOL
# FROM MONDIAL_GPT.MONDIAL_AIRPORT
# WHERE ELEVATION > '1000'
# ORDER BY DECODE(ELEVATION, NULL, 1, 0), ELEVATION DESC;
# Error: Execution failed on sql 'SELECT NAME,
#        IATACODE,
#        COUNTRY,
#        CITY,
#        PROVINCE,
#        ISLAND,
#        LATITUDE,
#        LONGITUDE,
#        ELEVATION,
#        GMTOFFSET,
#        META_REPCOL
# FROM MONDIAL_GPT.MONDIAL_AIRPORT
# WHERE ELEVATION > '1000'
# ORDER BY DECODE(ELEVATION, NULL, 1, 0), ELEVATION DESC': ORA-00942: table or view does not exist
# SELECT a.name
# FROM mondial_airport a
# INNER JOIN mondial_country c
# ON c.code = a.country
# WHERE c.name = 'United States' AND a.elevation <200;
# SELECT NAME
# FROM MONDIAL_GPT.MONDIAL_AIRPORT
# WHERE UPPER(COUNTRY) LIKE '%UNITED%STATES%'
#   AND ELEVATION < 200
# ORDER BY ELEVATION NULLS LAST;
# Error: Execution failed on sql 'SELECT NAME
# FROM MONDIAL_GPT.MONDIAL_AIRPORT
# WHERE UPPER(COUNTRY) LIKE '%UNITED%STATES%'
#   AND ELEVATION < 200
# ORDER BY ELEVATION NULLS LAST': ORA-00942: table or view does not exist
# SELECT name
# FROM mondial_mountain
# WHERE elevation > 8000;
# SELECT MOUNTAINS
# FROM MONDIAL_GPT.MONDIAL_MOUNTAIN
# WHERE ELEVATION > 8000
# Error: Execution failed on sql 'SELECT MOUNTAINS
# FROM MONDIAL_GPT.MONDIAL_MOUNTAIN
# WHERE ELEVATION > 8000': ORA-00942: table or view does not exist
# SELECT name
# FROM mondial_airport
# ORDER BY LENGTH(name) DESC
# FETCH FIRST 3 ROWS ONLY;
# SELECT NAME
# FROM MONDIAL_GPT.MONDIAL_AIRPORT
# ORDER BY NAME DESC NULLS LAST
# FETCH FIRST 3 ROWS ONLY;
# Error: Execution failed on sql 'SELECT NAME
# FROM MONDIAL_GPT.MONDIAL_AIRPORT
# ORDER BY NAME DESC NULLS LAST
# FETCH FIRST 3 ROWS ONLY': ORA-00942: table or view does not exist
# SELECT name
# FROM mondial_lake
# WHERE area < 5000;
# SELECT NAME,
#        AREA
# FROM MONDIAL_GPT.MONDIAL_LAKE
# WHERE AREA < '5000'
# ORDER BY NULLS LAST AREA;
# Error: Execution failed on sql 'SELECT NAME,
#        AREA
# FROM MONDIAL_GPT.MONDIAL_LAKE
# WHERE AREA < '5000'
# ORDER BY NULLS LAST AREA': ORA-00933: SQL command not properly ended
# SELECT SUM(area)
# FROM mondial_sea
# WHERE depth > 1000;
# SELECT SUM(AREA) AS total_area
# FROM MONDIAL_GPT.MONDIAL_SEA
# WHERE DEPTH > 1000;
# Error: Execution failed on sql 'SELECT SUM(AREA) AS total_area
# FROM MONDIAL_GPT.MONDIAL_SEA
# WHERE DEPTH > 1000': ORA-00942: table or view does not exist
# SELECT name
# FROM mondial_country
# WHERE name LIKE 'B%' AND population > 10000000;
# SELECT MONDIAL_COUNTRY.name
# FROM MONDIAL_COUNTRY
# WHERE UPPER(MONDIAL_COUNTRY.name) LIKE 'B%'
#   AND MONDIAL_COUNTRY.population > 1000000;
# True cols: Index(['NAME'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT cio.othername
# FROM mondial_cityothername cio
# INNER JOIN mondial_country c
# ON cio.country = c.code
# WHERE c.name = 'Brazil'
# SELECT MONDIAL_CITYOTHERNAME.OTHERNAME
# FROM MONDIAL_CITYOTHERNAME
# WHERE MONDIAL_CITYOTHERNAME.COUNTRY = 'BR';
# True cols: Index(['OTHERNAME'], dtype='object')
# Adj. True cols: Index(['OTHERNAME'], dtype='object')
# Predicted cols: Index(['OTHERNAME'], dtype='object')
# Adj. Predicted cols: Index(['OTHERNAME'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name
# FROM mondial_city
# WHERE latitude > 45;
# SELECT NAME
# FROM MONDIAL_GPT.MONDIAL_CITY
# WHERE LATITUDE > 45
# Error: Execution failed on sql 'SELECT NAME
# FROM MONDIAL_GPT.MONDIAL_CITY
# WHERE LATITUDE > 45': ORA-00942: table or view does not exist
# SELECT count(DISTINCT cio.city)
# FROM mondial_cityothername cio
# INNER JOIN mondial_country c
# ON cio.country = c.code
# WHERE c.area >30000
# SELECT COUNT(DISTINCT MONDIAL_CITYOTHERNAME.CITY) AS number_of_cities
# FROM MONDIAL_CITYOTHERNAME
# JOIN MONDIAL_COUNTRY ON MONDIAL_CITYOTHERNAME.COUNTRY = MONDIAL_COUNTRY.CODE
# WHERE MONDIAL_COUNTRY.AREA > 30000;
# True cols: Index(['COUNT(DISTINCTCIO.CITY)'], dtype='object')
# Adj. True cols: Index(['COUNT(DISTINCTCIO.CITY)'], dtype='object')
# Predicted cols: Index(['NUMBER_OF_CITIES'], dtype='object')
# Adj. Predicted cols: Index(['NUMBER_OF_CITIES'], dtype='object')
# True: query matches sql (Similarity: 1.0, column match: 1.0)
# SELECT name
# FROM mondial_desert
# WHERE area > 10000;
# SELECT AREA
# FROM MONDIAL_GPT.MONDIAL_DESERT
# WHERE AREA > 10000
# Error: Execution failed on sql 'SELECT AREA
# FROM MONDIAL_GPT.MONDIAL_DESERT
# WHERE AREA > 10000': ORA-00942: table or view does not exist
# SELECT island.name
# FROM island
# JOIN lakeonisland ON island.name = lakeonisland.island
# JOIN lake ON lake.name = lakeonisland.lake
# WHERE lake.elevation > 100;
# Execution failed on sql 'SELECT island.name
# FROM island
# JOIN lakeonisland ON island.name = lakeonisland.island
# JOIN lake ON lake.name = lakeonisland.lake
# WHERE lake.elevation > 100': ORA-00942: table or view does not exist
# SELECT moi.mountain
# FROM mondial_mountainonisland moi
# INNER JOIN mondial_island isl
# ON moi.island = isl.name
# WHERE isl.area > 100000
# SELECT mondial_gpt.mondial_island.area
# FROM mondial_gpt.mondial_island
# WHERE LOWER(mondial_gpt.mondial_island.name) LIKE '%thailand%'
# Error: Execution failed on sql 'SELECT mondial_gpt.mondial_island.area
# FROM mondial_gpt.mondial_island
# WHERE LOWER(mondial_gpt.mondial_island.name) LIKE '%thailand%'': ORA-00942: table or view does not exist
# SELECT c.name AS country, SUM(p.area) AS total_province_area
# FROM mondial_country c
# INNER JOIN mondial_province p
# ON c.code = p.country
# GROUP BY c.name;
# SELECT MONDIAL_GPT.MONDIAL_COUNTRY.PROVINCE,
#        SUM(MONDIAL_GPT.MONDIAL_COUNTRY.AREA) AS total_area
# FROM MONDIAL_GPT.MONDIAL_COUNTRY
# WHERE MONDIAL_GPT.MONDIAL_COUNTRY.NAME = 'Thailand'
# GROUP BY MONDIAL_GPT.MONDIAL_COUNTRY.PROVINCE;
# Error: Execution failed on sql 'SELECT MONDIAL_GPT.MONDIAL_COUNTRY.PROVINCE,
#        SUM(MONDIAL_GPT.MONDIAL_COUNTRY.AREA) AS total_area
# FROM MONDIAL_GPT.MONDIAL_COUNTRY
# WHERE MONDIAL_GPT.MONDIAL_COUNTRY.NAME = 'Thailand'
# GROUP BY MONDIAL_GPT.MONDIAL_COUNTRY.PROVINCE': ORA-00942: table or view does not exist
# SELECT c.name AS country, AVG(ci.elevation) AS average_city_population, SUM(ci.population) AS total_city_area
# FROM mondial_country c
# INNER JOIN mondial_city ci
# ON c.code = ci.country
# GROUP BY c.name;
# SELECT MONDIAL_COUNTRY.name,
#        AVG(MONDIAL_CITY.elevation) AS average_elevation,
#        SUM(MONDIAL_CITY.population) AS total_population
# FROM MONDIAL_COUNTRY
# JOIN MONDIAL_CITY ON MONDIAL_COUNTRY.code = MONDIAL_CITY.country
# WHERE LOWER(MONDIAL_COUNTRY.name) LIKE '%thailand%'
# GROUP BY MONDIAL_COUNTRY.name;
# True cols: Index(['COUNTRY', 'AVERAGE_CITY_POPULATION', 'TOTAL_CITY_AREA'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['NAME', 'AVERAGE_ELEVATION', 'TOTAL_POPULATION'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT e.inflation FROM mondial_country c JOIN mondial_economy e ON c.code=e.country WHERE c.name LIKE '%Germany%'
# SELECT MONDIAL_ECONOMY.INFLATION
# FROM MONDIAL_ECONOMY
# WHERE MONDIAL_ECONOMY.COUNTRY = 'DEU'
# True cols: Index(['INFLATION'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['INFLATION'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT p.government
# FROM mondial_country c
# INNER JOIN mondial_politics p
# ON p.country = c.code
# WHERE c.name = 'Iran'
# SELECT MONDIAL_POLITICS.GOVERNMENT
# FROM MONDIAL_POLITICS
# WHERE MONDIAL_POLITICS.COUNTRY = 'IRN'
# True cols: Index(['GOVERNMENT'], dtype='object')
# Adj. True cols: Index([], dtype='object')
# Predicted cols: Index(['GOVERNMENT'], dtype='object')
# Adj. Predicted cols: Index([], dtype='object')
# False: no match found
# SELECT e.industry
# FROM mondial_economy e
# INNER JOIN mondial_country c
# ON c.code = e.country
# WHERE c.name = 'Japan'
# SELECT industry /
#   (SELECT industry
#    FROM mondial_gpt.mondial_economy
#    WHERE country = 'Japan') * 100 AS percentage
# FROM mondial_gpt.mondial_economy
# WHERE country = 'Japan';
# Error: Execution failed on sql 'SELECT industry /
#   (SELECT industry
#    FROM mondial_gpt.mondial_economy
#    WHERE country = 'Japan') * 100 AS percentage
# FROM mondial_gpt.mondial_economy
# WHERE country = 'Japan'': ORA-00942: table or view does not exist
# 0

# %% [markdown]
# ## Exibindo os resultados

# %%
df = pd.DataFrame(results_no_fk, columns=['experiment', 'simple', 'medium', 'complex', 'total', 'overall_simple', 'overall_medium', 'overall_complex', 'overall_total','input_tokens', 'output_tokens', 'total_tokens','total_cost', 'total_time'])
df['experiment'] = df['experiment'].apply(get_experiment_name)
df = df.sort_values(by='overall_total', ascending=False)
df
# Out:
#            experiment  simple  medium  complex  total  overall_simple  \
# 0  SQLCoder - MONDIAL       7       5        5     17          0.2121
#
#    overall_medium  overall_complex  overall_total  input_tokens  \
# 0          0.1515           0.1471           0.17           NaN
#
#    output_tokens  total_tokens  total_cost total_time
# 0            NaN             0           0    0:00:00

# %% [markdown]
# ## Salvando os resultados

# %%
df.to_csv(TARGET_PATH)
