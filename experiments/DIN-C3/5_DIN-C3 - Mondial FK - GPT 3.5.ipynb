# %% [markdown]
# # Experimento: DIN/C3 - Mondial - Foreign Key - GPT 3.5

# %%
from langchain.chat_models import ChatOpenAI
from urllib.parse import quote  

from dotenv import load_dotenv
import time
import os
import sys
import json
load_dotenv()



path = os.path.abspath('')
experiment_path = '..\..'
module_path = os.path.join(path, experiment_path)
print(module_path)
if module_path not in sys.path:
    sys.path.append(module_path+"\\functions")


from sqldatabase_langchain_utils import SQLDatabaseLangchainUtils

# %%
module_path = os.path.join(path, "..\\DIN")
if module_path not in sys.path:
    sys.path.append(module_path)
    
from din_classification import classification_module
from din_self_correction import self_correction_module

# %%
from schema_linking_din_c3 import schema_linking_din_c3
from sql_generation_with_hints_din_c3 import generating_sql_with_hints

# %%
SCHEMA = 'mondial_gpt'
PREFIX = 'mondial'
FILE_NAME_RESULT = f"results/5_combining_din_c3_queries_chatgpt_{SCHEMA}_fk.json"

# %%
def save_queries(queries):
    data = {"queries":queries}
    with open(FILE_NAME_RESULT, "w") as arquivo_json:
        json.dump(data, arquivo_json, indent=4) 
        
def read_queries():
    with open(FILE_NAME_RESULT, encoding='utf-8', errors='ignore') as json_data:
        data = json.load(json_data, strict=False)
    queries = data["queries"]
    return queries

# %% [markdown]
# ## Conexão com o banco

# %%
json_file_path = f"{experiment_path}/datasets/{SCHEMA}_db_connection.json"
with open(json_file_path, encoding='utf-8', errors='ignore') as json_data:
    db_connection = json.load(json_data, strict=False)
db_connection

# %%
db = SQLDatabaseLangchainUtils(db_connection=db_connection)

exclusao = [
    f"{SCHEMA}_tmdp",
    f"{SCHEMA}_tmdpmap",
    f"{SCHEMA}_tmds",
    f"{SCHEMA}_tmjmap",
    f"{SCHEMA}_tpv",
    f"{SCHEMA}_tmdc",
    f"{SCHEMA}_tmdcmap",
    f"{SCHEMA}_tmdej",
    f"{SCHEMA}_log_action",
    f"{SCHEMA}_log_error",
    f"{SCHEMA}_favorite_item", 
    f"{SCHEMA}_favorite_query",
    f"{SCHEMA}_favorite_tag",
    f"{SCHEMA}_favorite_tag_item",
    f"{SCHEMA}_favorite_visualization",
    f"{SCHEMA}_dashboard",
    f"{SCHEMA}_history",
    "teste_cliente",
    "teste_fornecedor",
    "teste_funcionario"
]

include_tables = [s for s in db.get_table_names() if not s.startswith(PREFIX) and s not in exclusao]
db = SQLDatabaseLangchainUtils(db_connection=db_connection, include_tables=include_tables)
db.get_table_names()
# Out:
# c:\Users\rogerrsn\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain\utilities\sql_database.py:112: SAWarning: Did not recognize type 'GEOCOORD' of column 'coordinates'
#   self._metadata.reflect(
# c:\Users\rogerrsn\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain\utilities\sql_database.py:112: SAWarning: Did not recognize type 'GEOCOORD' of column 'source'
#   self._metadata.reflect(
# c:\Users\rogerrsn\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain\utilities\sql_database.py:112: SAWarning: Did not recognize type 'GEOCOORD' of column 'estuary'
#   self._metadata.reflect(
# ['airport',
#  'borders',
#  'city',
#  'citylocalname',
#  'cityothername',
#  'citypops',
#  'continent',
#  'country',
#  'countrylocalname',
#  'countryothername',
#  'countrypops',
#  'desert',
#  'economy',
#  'encompasses',
#  'ethnicgroup',
#  'geo_desert',
#  'geo_estuary',
#  'geo_island',
#  'geo_lake',
#  'geo_mountain',
#  'geo_river',
#  'geo_sea',
#  'geo_source',
#  'island',
#  'islandin',
#  'ismember',
#  'lake',
#  'lakeonisland',
#  'language',
#  'located',
#  'locatedon',
#  'mergeswith',
#  'mountain',
#  'mountainonisland',
#  'organization',
#  'politics',
#  'population',
#  'province',
#  'provincelocalname',
#  'provinceothername',
#  'provpops',
#  'religion',
#  'river',
#  'riveronisland',
#  'riverthrough',
#  'sea']

# %% [markdown]
# ## Preparando as consultas

# %%
json_file_path = f"../../datasets/{PREFIX}/queries_{PREFIX}.json"
with open(json_file_path, encoding='utf-8', errors='ignore') as json_data:
    queries = json.load(json_data, strict=False)
queries = queries['queries']
queries
# Out:
# [{'id': '1',
#   'question': 'What is the area of Thailand?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '2',
#   'question': 'What are the provinces with an area greater than 10000?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '3',
#   'question': 'What are the languages spoken in Poland?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '4',
#   'question': 'How deep is Lake Kariba?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '5',
#   'question': 'What is the total of provinces of Netherlands?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '6',
#   'question': 'What is the percentage of religious people are hindu in thailand?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '7',
#   'question': 'List the number of provinces each river flows through.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '8',
#   'question': 'Find all countries that became independent between 8/1/1910 and 8/1/1950.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '9',
#   'question': 'What are the cities of Cuba?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '10',
#   'question': 'What is the capital of Georgia?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '11',
#   'question': 'How many provinces have areas greater than 1000 in Niger?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '12',
#   'question': 'Tell me about the country with the area largest.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '13',
#   'question': 'What is the host province and year of establishment of the organization "International Energy Agency"?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '14',
#   'question': 'Find the name of all mountains whose elevation is higher than 1000.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '15',
#   'question': 'Tell me the economy of the Caribbean Sea.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '16',
#   'question': 'Show the cities with longitude between 0 and 6.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '17',
#   'question': 'Select cities whose population is greater than 100000, altitude greater than 2500, and the country you belong to has population growth greater than 1.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '18',
#   'question': 'Show all the different types of government.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '19',
#   'question': 'List all provinces in Germany',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '20',
#   'question': 'What is the percentage of mulatto ethnicity in Brazil?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '21',
#   'question': 'How many cities have populations less than 1000?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '22',
#   'question': 'What is the average elevation of airports in America?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '23',
#   'question': 'How many countries are adjacent to (or ecompassed by) the Caribbean Sea?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '24',
#   'question': 'How much area do the countries that are adjacent to (or encompassed by) the Caribbean Sea cover in total?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '25',
#   'question': 'For all countries, give the sum of the population of all its neighbors',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '26',
#   'question': 'What mountains are on the island of Borneo?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '27',
#   'question': 'Provide the name and total population of the country with the smallest area.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '28',
#   'question': 'The codes of all countries for which at least one river that originates in this country has its estuary in a neighboring country.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '29',
#   'question': 'The codes of all countries where at least one mountain is located in each of their provinces',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '30',
#   'question': 'The code and total border lengths of all countries with at least one border.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '31',
#   'question': 'The names and codes of all countries in which at least one river originates.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '32',
#   'question': 'What is the area and country of the Chatanga River?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '33',
#   'question': 'Show the Airports with elevation more than 3000',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '34',
#   'question': 'What are the religions practiced in Mexico?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '35',
#   'question': 'Show all rivers that do not flow into the sea.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '36',
#   'question': 'List African countries by number of neighbors.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '37',
#   'question': 'What is the average infant mortality rate for each continent?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '38',
#   'question': 'What is the average mortality rate of the countries in America without considering Brazil?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '39',
#   'question': 'List seas with area greater than 8000 and depth less than 100.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '40',
#   'question': 'How many mountains are there in Asia?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '41',
#   'question': 'How many countries that are close to the Mediterranean Sea?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '42',
#   'question': 'Show the total for each type of government.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '43',
#   'question': 'Which province has the largest desert in the world?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '44',
#   'question': 'What is the largest desert in the world?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '45',
#   'question': 'List, for all continents, the amount of deserts on each.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '46',
#   'question': 'What are the neighboring seas of the Banda Sea?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '47',
#   'question': 'List all the capitals of European countries.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '48',
#   'question': 'What percentage of people speak French in Andorra?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '49',
#   'question': 'Which rivers are longer than 1000 kilometers?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '50',
#   'question': 'Which country had the lowest population growth?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '51',
#   'question': 'List the name of capital cities for which we do not have data about the city in located',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '52',
#   'question': 'What is the capital of the provice Andaluc�a?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '53',
#   'question': 'What is the abbreviation for the organization whose name is "General Confederation of Trade Unions"?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '54',
#   'question': 'In which city is the organization with the abbreviation "UPU" ?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '55',
#   'question': 'List the names of countries which are members of only one organization',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '56',
#   'question': 'List the name of countries which are not a member of NATO.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '57',
#   'question': 'List the name of countries which are a member of NATO.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '58',
#   'question': 'List the rivers with length less than 50',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '59',
#   'question': 'What are the area, elevation and type of lakes in country Italy?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '60',
#   'question': ' List the names of capital cities which are the base for organizations in alphabetical order',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '61',
#   'question': 'List the name of organizations that do not have countries with an area smaller than 4000 and of the member type',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '62',
#   'question': 'List the name of organizations that do not have countries with  an area greater than 10000 and population smaller than 3000 and of the member type',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '63',
#   'question': 'Show the inflation rate of countries that are washed by the Arabian Sea',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '64',
#   'question': 'List all the capitals of the countries that belong to the continent Africa?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '65',
#   'question': 'Show the inflation rate of the countries bathed by the Arabian Sea and there is no inflation with null value',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '66',
#   'question': 'How many countries are in Africa?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '67',
#   'question': 'List the name of countries that are not members of NATO and UNESCO',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '68',
#   'question': 'What is the area of the continent Europe?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '69',
#   'question': 'What is the area of continent America?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '70',
#   'question': 'What is the area of continent Asia?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '71',
#   'question': 'What is the area of Africa?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '72',
#   'question': 'How many countries are in America?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '73',
#   'question': 'What area is the largest continent?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '74',
#   'question': 'List the countries that belong to the continent with the largest area',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '75',
#   'question': 'List the countries that belong to the continent with the largest area and whose language is English',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '76',
#   'question': 'List the names of cities, along with the name of their country for cities with a population greater than 5 million.  Display the results in descending order by population.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '77',
#   'question': 'Show the name of the deserts in the province of Algeria',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '78',
#   'question': 'Show the name and area of the deserts in the province of California',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '79',
#   'question': 'List the country names and percentage of use of language where  French are used as languages.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '80',
#   'question': 'What are the cities where �Portuguese� is spoken?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '81',
#   'question': 'What is the total area of the provinces in Canada?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '82',
#   'question': 'What is the length of the Tigres River?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '83',
#   'question': 'List the Airports with elevation more than 1000',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '84',
#   'question': 'List airports in the United States with an elevation below 200 feet',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '85',
#   'question': 'What are the mountains with altitudes above 8000 meters?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '86',
#   'question': 'What are the 3 airports with the largest name?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '87',
#   'question': 'List lakes with an area of less than 5000 square kilometers.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '88',
#   'question': 'What is the total area of the seas with a depth greater than 1000 meters?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '89',
#   'question': 'Find the countries whose name starts with the letter "B" and have a population greater than 10 million',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '90',
#   'question': 'List cities with another name in Brazil',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '91',
#   'question': 'List all cities that are at a latitude greater than 45 degrees.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '92',
#   'question': 'Show the number of cities with another name in countries with an area greater than 30000',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '93',
#   'question': 'Show the deserts with area greater than 10000',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '94',
#   'question': 'List the islands that belong to a lake with an elevation greater than 100',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '95',
#   'question': 'List all mountains located on islands with an area greater than 100,000 square kilometers',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '96',
#   'question': 'List the countries and the sum of their provincial areas.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '97',
#   'question': 'Show the name of the countries, the average elevation and sum of the population of their cities',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '98',
#   'question': "What was Germany's inflation?",
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '99',
#   'question': 'What type of government is Iran?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '100',
#   'question': "What is the percentage of industries in relation to Japan's economy?",
#   'query_string': '',
#   'type': 'medium'}]

# %% [markdown]
# ## Tracking token usage

# %%
track_token = [] 
def tracking_token(cb =None, reset = False):
    global track_token
    track_token.append(cb)
    if reset:
        track_token = []

# %%
def convert_to_dict_tracking_token():
    token_usage = {}
    for e in track_token:
        for key in e.keys():
            token_usage[key] = {}
            token_usage[key]['total_tokens'] = e[key].total_tokens
            token_usage[key]['total_cost'] = e[key].total_cost
            token_usage[key]['prompt_tokens'] = e[key].prompt_tokens
            token_usage[key]['completion_tokens'] = e[key].completion_tokens 
    return token_usage

# %% [markdown]
# ## DIN-C3 Function

# %%
def run_din_c3(question, db, model_name = 'gpt-3.5-turbo-16k', add_fk = True, callback= None):

    llm_c3 = ChatOpenAI(model_name = model_name, temperature=0.7, n=10)

    model_kwargs = {'top_p':1.0, 'frequency_penalty':0.0, 'presence_penalty':0.0}
    llm_din = ChatOpenAI(model_name = model_name, temperature=0.0, n=1, max_tokens=600, model_kwargs = model_kwargs)

    model_kwargs['stop'] = ['#', ';','\n\n']
    llm_din_fix = ChatOpenAI(model_name = model_name, temperature=0.0, n=1, max_tokens=350, model_kwargs = model_kwargs)

    #Clear prompting
    schema_links, tables = schema_linking_din_c3(question, db, llm_c3, llm_din, add_fk = add_fk, callback= callback)
    print(schema_links)    
    #Classification
    classification = classification_module(db, llm_din, question, schema_links, tables=tables, callback= callback)
    print(classification)
    #Calibration with hints and sql generation by type
    SQL = generating_sql_with_hints(db, llm_din, question, schema_links, classification, tables=tables, callback= callback)

    #Self correction
    SQL_FINAL = self_correction_module(db, llm_din_fix, question, SQL, callback= callback)
    
    return SQL_FINAL

# %% [markdown]
# ## Executando o método

# %%
tracking_token(reset=True)
errors = []
query_index = -1
queries_to_delay = 4
count = 0
for instance in queries:
    query_index +=1
    try:
        start_time = time.time()
        sql = run_din_c3(instance["question"], db, add_fk=False, callback=tracking_token)
        end_time = time.time()
        instance["query_string"] = sql
        instance["token_usage"] = convert_to_dict_tracking_token()
        instance['time'] = end_time - start_time
        save_queries(queries)
        print(instance["id"], instance["question"], sql)
    except Exception as e:
        print(str(e))
        errors.append(query_index)
        pass
    finally:
        count+=1
        if queries_to_delay==count:
            time.sleep(30)
            count = 0
        tracking_token(reset=True)

# %% [markdown]
# #### Fixing query

# %%
pos = 40
instance = queries[pos]
q = read_queries()
start_time = time.time()
sql = run_din_c3(instance["question"], db, callback=tracking_token)
end_time = time.time()
instance["query_string"] = sql
instance["token_usage"] = convert_to_dict_tracking_token()
instance['time'] = end_time - start_time
q[pos] = instance
save_queries(q)
print(instance['id'], instance['question'], instance["query_string"], instance['time'])

# %%
errors = [59,62,72,85,99]
for pos in errors:
    instance = queries[pos]
    q = read_queries()
    start_time = time.time()
    sql = run_din_c3(instance["question"], db, callback=tracking_token)
    end_time = time.time()
    instance["query_string"] = sql
    instance["token_usage"] = convert_to_dict_tracking_token()
    instance['time'] = end_time - start_time
    q[pos] = instance
    save_queries(q)
    print(instance['id'], instance['question'], instance["query_string"], instance['time'])

# %%
errors
# Out:
# []

# %% [markdown]
# ### Executar caso exista erros

# %%
if len(errors)>0:
    tracking_token(reset=True)
    queries_to_delay = 4
    count = 0
    fixed = []
    for query_index in errors:
        instance = queries[query_index]
        query_index +=1
        try:
            start_time = time.time()
            sql = run_din_c3(instance["question"], db, add_fk=False, callback=tracking_token)
            end_time = time.time()
            instance["query_string"] = sql
            instance["token_usage"] = convert_to_dict_tracking_token()
            instance['time'] = end_time - start_time
            save_queries(queries)
            print(instance["id"], instance["question"], sql)
            fixed.append(query_index)
        except Exception as e:
            print(str(e))
            pass
        finally:
            count+=1
            if queries_to_delay==count:
                time.sleep(30)
                count = 0
            tracking_token(reset=True)
            
    aux = [x for x in errors if x not in fixed]
    errors = aux

# %%
queries
# Out:
# [{'id': '1',
#   'question': 'What is the area of Thailand?',
#   'query_string': "SELECT country.area FROM country WHERE country.name = 'Thailand'",
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 5648,
#     'total_cost': 0.021871,
#     'prompt_tokens': 721,
#     'completion_tokens': 4927},
#    'column_recall': {'total_tokens': 6724,
#     'total_cost': 0.026648,
#     'prompt_tokens': 248,
#     'completion_tokens': 6476},
#    'schema_linking': {'total_tokens': 4221,
#     'total_cost': 0.012746,
#     'prompt_tokens': 4138,
#     'completion_tokens': 83},
#    'classification': {'total_tokens': 2287,
#     'total_cost': 0.006958000000000001,
#     'prompt_tokens': 2190,
#     'completion_tokens': 97},
#    'sql_generation_din_c3': {'total_tokens': 1525,
#     'total_cost': 0.004588,
#     'prompt_tokens': 1512,
#     'completion_tokens': 13},
#    'self_correction': {'total_tokens': 2193,
#     'total_cost': 0.006595,
#     'prompt_tokens': 2177,
#     'completion_tokens': 16}}},
#  {'id': '2',
#   'question': 'What are the provinces with an area greater than 10000?',
#   'query_string': 'SELECT province.name FROM province WHERE province.area > 10000',
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 2982,
#     'total_cost': 0.011201,
#     'prompt_tokens': 727,
#     'completion_tokens': 2255},
#    'column_recall': {'total_tokens': 2662,
#     'total_cost': 0.010438000000000001,
#     'prompt_tokens': 210,
#     'completion_tokens': 2452},
#    'schema_linking': {'total_tokens': 4212,
#     'total_cost': 0.012744,
#     'prompt_tokens': 4104,
#     'completion_tokens': 108},
#    'classification': {'total_tokens': 2224,
#     'total_cost': 0.006775,
#     'prompt_tokens': 2121,
#     'completion_tokens': 103},
#    'sql_generation_din_c3': {'total_tokens': 1474,
#     'total_cost': 0.0044340000000000004,
#     'prompt_tokens': 1462,
#     'completion_tokens': 12},
#    'self_correction': {'total_tokens': 2198,
#     'total_cost': 0.006608999999999999,
#     'prompt_tokens': 2183,
#     'completion_tokens': 15}}},
#  {'id': '3',
#   'question': 'What are the languages spoken in Poland?',
#   'query_string': "SELECT language.name FROM language JOIN country ON language.country = country.code WHERE country.name = 'Poland'",
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 1948,
#     'total_cost': 0.00707,
#     'prompt_tokens': 722,
#     'completion_tokens': 1226},
#    'column_recall': {'total_tokens': 3635,
#     'total_cost': 0.014328,
#     'prompt_tokens': 212,
#     'completion_tokens': 3423},
#    'schema_linking': {'total_tokens': 4215,
#     'total_cost': 0.012752,
#     'prompt_tokens': 4108,
#     'completion_tokens': 107},
#    'classification': {'total_tokens': 2230,
#     'total_cost': 0.006791,
#     'prompt_tokens': 2129,
#     'completion_tokens': 101},
#    'sql_generation_din_c3': {'total_tokens': 2075,
#     'total_cost': 0.006308,
#     'prompt_tokens': 1992,
#     'completion_tokens': 83},
#    'self_correction': {'total_tokens': 2213,
#     'total_cost': 0.006665,
#     'prompt_tokens': 2187,
#     'completion_tokens': 26}}},
#  {'id': '4',
#   'question': 'How deep is Lake Kariba?',
#   'query_string': "SELECT lake.depth FROM lake WHERE lake.name = 'Lake Kariba'",
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 4309,
#     'total_cost': 0.016515000000000002,
#     'prompt_tokens': 721,
#     'completion_tokens': 3588},
#    'column_recall': {'total_tokens': 3222,
#     'total_cost': 0.012673,
#     'prompt_tokens': 215,
#     'completion_tokens': 3007},
#    'schema_linking': {'total_tokens': 4209,
#     'total_cost': 0.012726999999999999,
#     'prompt_tokens': 4109,
#     'completion_tokens': 100},
#    'classification': {'total_tokens': 2241,
#     'total_cost': 0.006818,
#     'prompt_tokens': 2146,
#     'completion_tokens': 95},
#    'sql_generation_din_c3': {'total_tokens': 1482,
#     'total_cost': 0.0044599999999999996,
#     'prompt_tokens': 1468,
#     'completion_tokens': 14},
#    'self_correction': {'total_tokens': 2195,
#     'total_cost': 0.006602,
#     'prompt_tokens': 2178,
#     'completion_tokens': 17}}},
#  {'id': '5',
#   'question': 'What is the total of provinces of Netherlands?',
#   'query_string': "SELECT COUNT(province.name)  FROM province  JOIN country ON province.country = country.code  WHERE country.name = 'Netherlands'",
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 1853,
#     'total_cost': 0.006689,
#     'prompt_tokens': 723,
#     'completion_tokens': 1130},
#    'column_recall': {'total_tokens': 4058,
#     'total_cost': 0.016011,
#     'prompt_tokens': 221,
#     'completion_tokens': 3837},
#    'schema_linking': {'total_tokens': 4227,
#     'total_cost': 0.012797000000000001,
#     'prompt_tokens': 4111,
#     'completion_tokens': 116},
#    'classification': {'total_tokens': 2248,
#     'total_cost': 0.006847000000000001,
#     'prompt_tokens': 2145,
#     'completion_tokens': 103},
#    'sql_generation_din_c3': {'total_tokens': 2098,
#     'total_cost': 0.006384,
#     'prompt_tokens': 2008,
#     'completion_tokens': 90},
#    'self_correction': {'total_tokens': 2218,
#     'total_cost': 0.00668,
#     'prompt_tokens': 2192,
#     'completion_tokens': 26}}},
#  {'id': '6',
#   'question': 'What is the percentage of religious people are hindu in thailand?',
#   'query_string': "SELECT religion.percentage  FROM  religion  JOIN  country  ON religion.country = country.code  WHERE  religion.name = 'Hindu'  AND country.name = 'Thailand'",
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 3971,
#     'total_cost': 0.015156,
#     'prompt_tokens': 728,
#     'completion_tokens': 3243},
#    'column_recall': {'total_tokens': 3528,
#     'total_cost': 0.013884,
#     'prompt_tokens': 228,
#     'completion_tokens': 3300},
#    'schema_linking': {'total_tokens': 4261,
#     'total_cost': 0.01292,
#     'prompt_tokens': 4124,
#     'completion_tokens': 137},
#    'classification': {'total_tokens': 2271,
#     'total_cost': 0.006920000000000001,
#     'prompt_tokens': 2164,
#     'completion_tokens': 107},
#    'sql_generation_din_c3': {'total_tokens': 2130,
#     'total_cost': 0.0064930000000000005,
#     'prompt_tokens': 2027,
#     'completion_tokens': 103},
#    'self_correction': {'total_tokens': 2243,
#     'total_cost': 0.00677,
#     'prompt_tokens': 2202,
#     'completion_tokens': 41}}},
#  {'id': '7',
#   'question': 'List the number of provinces each river flows through.',
#   'query_string': 'SELECT river.name, COUNT(DISTINCT province.name)  FROM river  JOIN riverthrough ON river.name = riverthrough.river  JOIN province ON riverthrough.lake = province.name  GROUP BY river.name',
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 1998,
#     'total_cost': 0.007268,
#     'prompt_tokens': 724,
#     'completion_tokens': 1274},
#    'column_recall': {'total_tokens': 4604,
#     'total_cost': 0.01817,
#     'prompt_tokens': 246,
#     'completion_tokens': 4358},
#    'schema_linking': {'total_tokens': 4224,
#     'total_cost': 0.012771999999999999,
#     'prompt_tokens': 4124,
#     'completion_tokens': 100},
#    'classification': {'total_tokens': 2299,
#     'total_cost': 0.007004,
#     'prompt_tokens': 2192,
#     'completion_tokens': 107},
#    'sql_generation_din_c3': {'total_tokens': 2183,
#     'total_cost': 0.006677000000000001,
#     'prompt_tokens': 2055,
#     'completion_tokens': 128},
#    'self_correction': {'total_tokens': 2251,
#     'total_cost': 0.006794,
#     'prompt_tokens': 2210,
#     'completion_tokens': 41}}},
#  {'id': '8',
#   'question': 'Find all countries that became independent between 8/1/1910 and 8/1/1950.',
#   'query_string': "SELECT T1.name  FROM      country T1      JOIN politics T2 ON T1.code = T2.country  WHERE      T2.independence >= '1910-08-01'      AND T2.independence <= '1950-08-01'",
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 2760,
#     'total_cost': 0.010303,
#     'prompt_tokens': 737,
#     'completion_tokens': 2023},
#    'column_recall': {'total_tokens': 3448,
#     'total_cost': 0.013560000000000001,
#     'prompt_tokens': 232,
#     'completion_tokens': 3216},
#    'schema_linking': {'total_tokens': 4270,
#     'total_cost': 0.012954000000000002,
#     'prompt_tokens': 4126,
#     'completion_tokens': 144},
#    'classification': {'total_tokens': 2278,
#     'total_cost': 0.00695,
#     'prompt_tokens': 2162,
#     'completion_tokens': 116},
#    'sql_generation_din_c3': {'total_tokens': 2147,
#     'total_cost': 0.006562999999999999,
#     'prompt_tokens': 2025,
#     'completion_tokens': 122},
#    'self_correction': {'total_tokens': 2287,
#     'total_cost': 0.006918,
#     'prompt_tokens': 2230,
#     'completion_tokens': 57}}},
#  {'id': '9',
#   'question': 'What are the cities of Cuba?',
#   'query_string': "SELECT city.name FROM city JOIN country ON city.country = country.code WHERE country.name = 'Cuba'",
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 2530,
#     'total_cost': 0.009399000000000001,
#     'prompt_tokens': 721,
#     'completion_tokens': 1809},
#    'column_recall': {'total_tokens': 4637,
#     'total_cost': 0.018329,
#     'prompt_tokens': 219,
#     'completion_tokens': 4418},
#    'schema_linking': {'total_tokens': 4215,
#     'total_cost': 0.012751,
#     'prompt_tokens': 4109,
#     'completion_tokens': 106},
#    'classification': {'total_tokens': 2246,
#     'total_cost': 0.0068390000000000005,
#     'prompt_tokens': 2145,
#     'completion_tokens': 101},
#    'sql_generation_din_c3': {'total_tokens': 2091,
#     'total_cost': 0.006356,
#     'prompt_tokens': 2008,
#     'completion_tokens': 83},
#    'self_correction': {'total_tokens': 2212,
#     'total_cost': 0.0066619999999999995,
#     'prompt_tokens': 2186,
#     'completion_tokens': 26}}},
#  {'id': '10',
#   'question': 'What is the capital of Georgia?',
#   'query_string': "SELECT country.capital FROM country WHERE country.name = 'Georgia'",
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 1890,
#     'total_cost': 0.0068390000000000005,
#     'prompt_tokens': 721,
#     'completion_tokens': 1169},
#    'column_recall': {'total_tokens': 4616,
#     'total_cost': 0.018228,
#     'prompt_tokens': 236,
#     'completion_tokens': 4380},
#    'schema_linking': {'total_tokens': 4204,
#     'total_cost': 0.012696,
#     'prompt_tokens': 4120,
#     'completion_tokens': 84},
#    'classification': {'total_tokens': 2264,
#     'total_cost': 0.006889,
#     'prompt_tokens': 2167,
#     'completion_tokens': 97},
#    'sql_generation_din_c3': {'total_tokens': 1507,
#     'total_cost': 0.004533000000000001,
#     'prompt_tokens': 1495,
#     'completion_tokens': 12},
#    'self_correction': {'total_tokens': 2192,
#     'total_cost': 0.006592000000000001,
#     'prompt_tokens': 2176,
#     'completion_tokens': 16}}},
#  {'id': '11',
#   'question': 'How many provinces have areas greater than 1000 in Niger?',
#   'query_string': "SELECT COUNT(*)  FROM province  JOIN country ON province.country = country.code  WHERE country.name = 'Niger' AND province.area > 1000",
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 3665,
#     'total_cost': 0.013933000000000001,
#     'prompt_tokens': 727,
#     'completion_tokens': 2938},
#    'column_recall': {'total_tokens': 3628,
#     'total_cost': 0.014287000000000001,
#     'prompt_tokens': 225,
#     'completion_tokens': 3403},
#    'schema_linking': {'total_tokens': 4252,
#     'total_cost': 0.012891000000000001,
#     'prompt_tokens': 4117,
#     'completion_tokens': 135},
#    'classification': {'total_tokens': 2255,
#     'total_cost': 0.006872000000000001,
#     'prompt_tokens': 2148,
#     'completion_tokens': 107},
#    'sql_generation_din_c3': {'total_tokens': 2116,
#     'total_cost': 0.006453,
#     'prompt_tokens': 2011,
#     'completion_tokens': 105},
#    'self_correction': {'total_tokens': 2233,
#     'total_cost': 0.006729,
#     'prompt_tokens': 2203,
#     'completion_tokens': 30}}},
#  {'id': '12',
#   'question': 'Tell me about the country with the area largest.',
#   'query_string': 'SELECT country.* FROM country ORDER BY country.area DESC LIMIT 1',
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 9916,
#     'total_cost': 0.03894,
#     'prompt_tokens': 724,
#     'completion_tokens': 9192},
#    'column_recall': {'total_tokens': 4566,
#     'total_cost': 0.018018,
#     'prompt_tokens': 246,
#     'completion_tokens': 4320},
#    'schema_linking': {'total_tokens': 4219,
#     'total_cost': 0.012740000000000001,
#     'prompt_tokens': 4136,
#     'completion_tokens': 83},
#    'classification': {'total_tokens': 2278,
#     'total_cost': 0.006934,
#     'prompt_tokens': 2178,
#     'completion_tokens': 100},
#    'sql_generation_din_c3': {'total_tokens': 1523,
#     'total_cost': 0.004586000000000001,
#     'prompt_tokens': 1506,
#     'completion_tokens': 17},
#    'self_correction': {'total_tokens': 2201,
#     'total_cost': 0.006619,
#     'prompt_tokens': 2185,
#     'completion_tokens': 16}}},
#  {'id': '13',
#   'question': 'What is the host province and year of establishment of the organization "International Energy Agency"?',
#   'query_string': "SELECT T1.name AS host_province, T3.established AS year_of_establishment FROM province T1 JOIN organization T3 ON T1.name = T3.province WHERE T3.name = 'International Energy Agency'",
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 2913,
#     'total_cost': 0.010920000000000001,
#     'prompt_tokens': 732,
#     'completion_tokens': 2181},
#    'column_recall': {'total_tokens': 5254,
#     'total_cost': 0.020773,
#     'prompt_tokens': 243,
#     'completion_tokens': 5011},
#    'schema_linking': {'total_tokens': 4263,
#     'total_cost': 0.012914999999999998,
#     'prompt_tokens': 4137,
#     'completion_tokens': 126},
#    'classification': {'total_tokens': 2320,
#     'total_cost': 0.0070750000000000006,
#     'prompt_tokens': 2205,
#     'completion_tokens': 115},
#    'sql_generation_din_c3': {'total_tokens': 2215,
#     'total_cost': 0.006792,
#     'prompt_tokens': 2068,
#     'completion_tokens': 147},
#    'self_correction': {'total_tokens': 2279,
#     'total_cost': 0.0068850000000000005,
#     'prompt_tokens': 2231,
#     'completion_tokens': 48}}},
#  {'id': '14',
#   'question': 'Find the name of all mountains whose elevation is higher than 1000.',
#   'query_string': 'SELECT name FROM mountain WHERE elevation > 1000',
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 5714,
#     'total_cost': 0.022127000000000004,
#     'prompt_tokens': 729,
#     'completion_tokens': 4985},
#    'column_recall': {'total_tokens': 3709,
#     'total_cost': 0.014597000000000002,
#     'prompt_tokens': 239,
#     'completion_tokens': 3470},
#    'schema_linking': {'total_tokens': 4258,
#     'total_cost': 0.012894999999999998,
#     'prompt_tokens': 4137,
#     'completion_tokens': 121},
#    'classification': {'total_tokens': 2263,
#     'total_cost': 0.006894,
#     'prompt_tokens': 2158,
#     'completion_tokens': 105},
#    'sql_generation_din_c3': {'total_tokens': 1517,
#     'total_cost': 0.004563,
#     'prompt_tokens': 1505,
#     'completion_tokens': 12},
#    'self_correction': {'total_tokens': 2200,
#     'total_cost': 0.006615,
#     'prompt_tokens': 2185,
#     'completion_tokens': 15}}},
#  {'id': '15',
#   'question': 'Tell me the economy of the Caribbean Sea.',
#   'query_string': "SELECT economy.* FROM economy JOIN geo_sea ON economy.country = geo_sea.country JOIN sea ON geo_sea.sea = sea.name WHERE sea.name = 'Caribbean Sea'",
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 3447,
#     'total_cost': 0.013065,
#     'prompt_tokens': 723,
#     'completion_tokens': 2724},
#    'column_recall': {'total_tokens': 5247,
#     'total_cost': 0.020746,
#     'prompt_tokens': 242,
#     'completion_tokens': 5005},
#    'schema_linking': {'total_tokens': 4240,
#     'total_cost': 0.012827999999999999,
#     'prompt_tokens': 4132,
#     'completion_tokens': 108},
#    'classification': {'total_tokens': 2309,
#     'total_cost': 0.0070350000000000005,
#     'prompt_tokens': 2201,
#     'completion_tokens': 108},
#    'sql_generation_din_c3': {'total_tokens': 2185,
#     'total_cost': 0.0066760000000000005,
#     'prompt_tokens': 2064,
#     'completion_tokens': 121},
#    'self_correction': {'total_tokens': 2250,
#     'total_cost': 0.006795,
#     'prompt_tokens': 2205,
#     'completion_tokens': 45}}},
#  {'id': '16',
#   'question': 'Shows me cities with longitude between 0 and 6.',
#   'query_string': 'SELECT city.name FROM city WHERE city.longitude BETWEEN 0 AND 6',
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 3591,
#     'total_cost': 0.013638,
#     'prompt_tokens': 726,
#     'completion_tokens': 2865},
#    'column_recall': {'total_tokens': 4944,
#     'total_cost': 0.019525,
#     'prompt_tokens': 251,
#     'completion_tokens': 4693},
#    'schema_linking': {'total_tokens': 4242,
#     'total_cost': 0.012838999999999998,
#     'prompt_tokens': 4129,
#     'completion_tokens': 113},
#    'classification': {'total_tokens': 2346,
#     'total_cost': 0.007140000000000001,
#     'prompt_tokens': 2244,
#     'completion_tokens': 102},
#    'sql_generation_din_c3': {'total_tokens': 1526,
#     'total_cost': 0.004592,
#     'prompt_tokens': 1512,
#     'completion_tokens': 14},
#    'self_correction': {'total_tokens': 2201,
#     'total_cost': 0.006620000000000001,
#     'prompt_tokens': 2184,
#     'completion_tokens': 17}}},
#  {'id': '17',
#   'question': 'Select cities whose population is greater than 100000, altitude greater than 2500, and the country you belong to has population growth greater than 1.',
#   'query_string': "SELECT city.* FROM city JOIN country ON city.country = country.code WHERE city.population > 100000 AND city.elevation > 2500 AND country.code = 'your_country_code' AND country.population_growth > 1",
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 2857,
#     'total_cost': 0.010682000000000002,
#     'prompt_tokens': 746,
#     'completion_tokens': 2111},
#    'column_recall': {'total_tokens': 5615,
#     'total_cost': 0.022187,
#     'prompt_tokens': 273,
#     'completion_tokens': 5342},
#    'schema_linking': {'total_tokens': 4341,
#     'total_cost': 0.013201000000000001,
#     'prompt_tokens': 4163,
#     'completion_tokens': 178},
#    'classification': {'total_tokens': 2356,
#     'total_cost': 0.007193,
#     'prompt_tokens': 2231,
#     'completion_tokens': 125},
#    'sql_generation_din_c3': {'total_tokens': 2219,
#     'total_cost': 0.006782,
#     'prompt_tokens': 2094,
#     'completion_tokens': 125},
#    'self_correction': {'total_tokens': 2279,
#     'total_cost': 0.006884,
#     'prompt_tokens': 2232,
#     'completion_tokens': 47}}},
#  {'id': '18',
#   'question': 'Show all the different types of government.',
#   'query_string': 'SELECT DISTINCT government FROM politics',
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 2983,
#     'total_cost': 0.01121,
#     'prompt_tokens': 722,
#     'completion_tokens': 2261},
#    'column_recall': {'total_tokens': 4246,
#     'total_cost': 0.016751000000000002,
#     'prompt_tokens': 233,
#     'completion_tokens': 4013},
#    'schema_linking': {'total_tokens': 4214,
#     'total_cost': 0.012726999999999999,
#     'prompt_tokens': 4129,
#     'completion_tokens': 85},
#    'classification': {'total_tokens': 2252,
#     'total_cost': 0.006855,
#     'prompt_tokens': 2153,
#     'completion_tokens': 99},
#    'sql_generation_din_c3': {'total_tokens': 1500,
#     'total_cost': 0.004507000000000001,
#     'prompt_tokens': 1493,
#     'completion_tokens': 7},
#    'self_correction': {'total_tokens': 2179,
#     'total_cost': 0.006543,
#     'prompt_tokens': 2173,
#     'completion_tokens': 6}}},
#  {'id': '19',
#   'question': 'List all provinces in Germany',
#   'query_string': "SELECT province.name FROM province JOIN country ON province.country = country.code WHERE country.name = 'Germany'",
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 2023,
#     'total_cost': 0.007372,
#     'prompt_tokens': 720,
#     'completion_tokens': 1303},
#    'column_recall': {'total_tokens': 4306,
#     'total_cost': 0.017006,
#     'prompt_tokens': 218,
#     'completion_tokens': 4088},
#    'schema_linking': {'total_tokens': 4210,
#     'total_cost': 0.012732,
#     'prompt_tokens': 4108,
#     'completion_tokens': 102},
#    'classification': {'total_tokens': 2235,
#     'total_cost': 0.006804,
#     'prompt_tokens': 2136,
#     'completion_tokens': 99},
#    'sql_generation_din_c3': {'total_tokens': 2080,
#     'total_cost': 0.006321,
#     'prompt_tokens': 1999,
#     'completion_tokens': 81},
#    'self_correction': {'total_tokens': 2207,
#     'total_cost': 0.006644000000000001,
#     'prompt_tokens': 2184,
#     'completion_tokens': 23}}},
#  {'id': '20',
#   'question': 'What is the percentage of mulatto ethnicity in Brazil?',
#   'query_string': "SELECT percentage FROM ethnicgroup WHERE country = 'Brazil' AND name = 'mulatto'",
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 2191,
#     'total_cost': 0.008039000000000001,
#     'prompt_tokens': 725,
#     'completion_tokens': 1466},
#    'column_recall': {'total_tokens': 2820,
#     'total_cost': 0.011064,
#     'prompt_tokens': 216,
#     'completion_tokens': 2604},
#    'schema_linking': {'total_tokens': 4229,
#     'total_cost': 0.012802000000000001,
#     'prompt_tokens': 4114,
#     'completion_tokens': 115},
#    'classification': {'total_tokens': 2241,
#     'total_cost': 0.006828000000000001,
#     'prompt_tokens': 2136,
#     'completion_tokens': 105},
#    'sql_generation_din_c3': {'total_tokens': 2078,
#     'total_cost': 0.006313000000000001,
#     'prompt_tokens': 1999,
#     'completion_tokens': 79},
#    'self_correction': {'total_tokens': 2209,
#     'total_cost': 0.006648,
#     'prompt_tokens': 2188,
#     'completion_tokens': 21}}},
#  {'id': '21',
#   'question': 'How many cities have populations less than 1000?',
#   'query_string': 'SELECT COUNT(*) FROM city WHERE population < 1000',
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 2638,
#     'total_cost': 0.009826999999999999,
#     'prompt_tokens': 725,
#     'completion_tokens': 1913},
#    'column_recall': {'total_tokens': 4374,
#     'total_cost': 0.017273,
#     'prompt_tokens': 223,
#     'completion_tokens': 4151},
#    'schema_linking': {'total_tokens': 4224,
#     'total_cost': 0.012779,
#     'prompt_tokens': 4117,
#     'completion_tokens': 107},
#    'classification': {'total_tokens': 2270,
#     'total_cost': 0.006908999999999999,
#     'prompt_tokens': 2171,
#     'completion_tokens': 99},
#    'sql_generation_din_c3': {'total_tokens': 1493,
#     'total_cost': 0.004492,
#     'prompt_tokens': 1480,
#     'completion_tokens': 13},
#    'self_correction': {'total_tokens': 2194,
#     'total_cost': 0.006594,
#     'prompt_tokens': 2182,
#     'completion_tokens': 12}}},
#  {'id': '22',
#   'question': 'What is the average elevation of airports in America?',
#   'query_string': "SELECT AVG(elevation)  FROM airport  WHERE country = 'America'",
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 2212,
#     'total_cost': 0.008124,
#     'prompt_tokens': 724,
#     'completion_tokens': 1488},
#    'column_recall': {'total_tokens': 6073,
#     'total_cost': 0.024026000000000002,
#     'prompt_tokens': 266,
#     'completion_tokens': 5807},
#    'schema_linking': {'total_tokens': 4242,
#     'total_cost': 0.012827999999999999,
#     'prompt_tokens': 4140,
#     'completion_tokens': 102},
#    'classification': {'total_tokens': 2329,
#     'total_cost': 0.007087,
#     'prompt_tokens': 2229,
#     'completion_tokens': 100},
#    'sql_generation_din_c3': {'total_tokens': 1546,
#     'total_cost': 0.004653,
#     'prompt_tokens': 1531,
#     'completion_tokens': 15},
#    'self_correction': {'total_tokens': 2197,
#     'total_cost': 0.006606,
#     'prompt_tokens': 2182,
#     'completion_tokens': 15}}},
#  {'id': '23',
#   'question': 'How many countries are adjacent to (or ecompassed by) the the Caribbean Sea?',
#   'query_string': "SELECT COUNT(DISTINCT T1.country2)  FROM borders T1  JOIN encompasses T2 ON T1.country2 = T2.country  JOIN sea T3 ON T2.continent = T3.name  WHERE T3.name = 'Caribbean Sea'",
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 4118,
#     'total_cost': 0.01574,
#     'prompt_tokens': 732,
#     'completion_tokens': 3386},
#    'column_recall': {'total_tokens': 5644,
#     'total_cost': 0.022334000000000003,
#     'prompt_tokens': 242,
#     'completion_tokens': 5402},
#    'schema_linking': {'total_tokens': 4293,
#     'total_cost': 0.013034,
#     'prompt_tokens': 4138,
#     'completion_tokens': 155},
#    'classification': {'total_tokens': 2311,
#     'total_cost': 0.007044999999999999,
#     'prompt_tokens': 2199,
#     'completion_tokens': 112},
#    'sql_generation_din_c3': {'total_tokens': 2226,
#     'total_cost': 0.006842,
#     'prompt_tokens': 2062,
#     'completion_tokens': 164},
#    'self_correction': {'total_tokens': 2295,
#     'total_cost': 0.006938000000000001,
#     'prompt_tokens': 2242,
#     'completion_tokens': 53}}},
#  {'id': '24',
#   'question': 'How much area do the countries that are adjacent to (or encompassed by) the Caribbean Sea cover in total?',
#   'query_string': "SELECT SUM(country.area)  FROM country  JOIN borders ON country.code = borders.country1 OR country.code = borders.country2  JOIN encompasses ON country.code = encompasses.country  JOIN sea ON sea.name = 'Caribbean Sea'",
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 2593,
#     'total_cost': 0.009635000000000001,
#     'prompt_tokens': 737,
#     'completion_tokens': 1856},
#    'column_recall': {'total_tokens': 5226,
#     'total_cost': 0.020657,
#     'prompt_tokens': 247,
#     'completion_tokens': 4979},
#    'schema_linking': {'total_tokens': 4312,
#     'total_cost': 0.013102999999999998,
#     'prompt_tokens': 4145,
#     'completion_tokens': 167},
#    'classification': {'total_tokens': 2325,
#     'total_cost': 0.007096000000000001,
#     'prompt_tokens': 2204,
#     'completion_tokens': 121},
#    'sql_generation_din_c3': {'total_tokens': 2208,
#     'total_cost': 0.006765000000000001,
#     'prompt_tokens': 2067,
#     'completion_tokens': 141},
#    'self_correction': {'total_tokens': 2273,
#     'total_cost': 0.006864,
#     'prompt_tokens': 2228,
#     'completion_tokens': 45}}},
#  {'id': '25',
#   'question': 'For all countries, give the sum of the population of all its neighbors',
#   'query_string': 'SELECT C1.name, SUM(C2.population)  FROM country C1  JOIN borders B ON C1.code = B.country1  JOIN country C2 ON B.country2 = C2.code  GROUP BY C1.name',
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 2702,
#     'total_cost': 0.010079,
#     'prompt_tokens': 729,
#     'completion_tokens': 1973},
#    'column_recall': {'total_tokens': 3158,
#     'total_cost': 0.012411,
#     'prompt_tokens': 221,
#     'completion_tokens': 2937},
#    'schema_linking': {'total_tokens': 4260,
#     'total_cost': 0.012921,
#     'prompt_tokens': 4119,
#     'completion_tokens': 141},
#    'classification': {'total_tokens': 2265,
#     'total_cost': 0.006906,
#     'prompt_tokens': 2154,
#     'completion_tokens': 111},
#    'sql_generation_din_c3': {'total_tokens': 3629,
#     'total_cost': 0.011057,
#     'prompt_tokens': 3459,
#     'completion_tokens': 170},
#    'self_correction': {'total_tokens': 2262,
#     'total_cost': 0.006831,
#     'prompt_tokens': 2217,
#     'completion_tokens': 45}}},
#  {'id': '26',
#   'question': 'What mountains are on the island of Borneo?',
#   'query_string': "SELECT mountain.name  FROM  mountainonisland  JOIN mountain ON mountainonisland.mountain = mountain.name  JOIN island ON mountainonisland.island = island.name  WHERE island.name = 'Borneo'",
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 1660,
#     'total_cost': 0.005915,
#     'prompt_tokens': 725,
#     'completion_tokens': 935},
#    'column_recall': {'total_tokens': 4860,
#     'total_cost': 0.019211000000000002,
#     'prompt_tokens': 229,
#     'completion_tokens': 4631},
#    'schema_linking': {'total_tokens': 4262,
#     'total_cost': 0.012922000000000001,
#     'prompt_tokens': 4126,
#     'completion_tokens': 136},
#    'classification': {'total_tokens': 2281,
#     'total_cost': 0.006952000000000001,
#     'prompt_tokens': 2172,
#     'completion_tokens': 109},
#    'sql_generation_din_c3': {'total_tokens': 2158,
#     'total_cost': 0.006597,
#     'prompt_tokens': 2035,
#     'completion_tokens': 123},
#    'self_correction': {'total_tokens': 2252,
#     'total_cost': 0.0068000000000000005,
#     'prompt_tokens': 2208,
#     'completion_tokens': 44}}},
#  {'id': '27',
#   'question': 'Provide the name and total population of the country with the smallest area.',
#   'query_string': 'SELECT country.name, SUM(countrypops.population) AS total_population FROM country JOIN countrypops ON country.code = countrypops.country GROUP BY country.name ORDER BY country.area ASC LIMIT 1',
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 3214,
#     'total_cost': 0.012128000000000002,
#     'prompt_tokens': 728,
#     'completion_tokens': 2486},
#    'column_recall': {'total_tokens': 5040,
#     'total_cost': 0.01991,
#     'prompt_tokens': 250,
#     'completion_tokens': 4790},
#    'schema_linking': {'total_tokens': 4247,
#     'total_cost': 0.012852,
#     'prompt_tokens': 4136,
#     'completion_tokens': 111},
#    'classification': {'total_tokens': 2292,
#     'total_cost': 0.00698,
#     'prompt_tokens': 2188,
#     'completion_tokens': 104},
#    'sql_generation_din_c3': {'total_tokens': 1535,
#     'total_cost': 0.004624,
#     'prompt_tokens': 1516,
#     'completion_tokens': 19},
#    'self_correction': {'total_tokens': 2238,
#     'total_cost': 0.006761,
#     'prompt_tokens': 2191,
#     'completion_tokens': 47}}},
#  {'id': '28',
#   'question': 'The codes of all countries for which at least one river that originates in this country has its estuary in a neighboring country.',
#   'query_string': 'SELECT DISTINCT country.code  FROM      country  WHERE      country.code IN (         SELECT              river.source          FROM              river          WHERE              river.estuary IN (                 SELECT                      borders.country2                  FROM                      borders                  WHERE                      borders.country1 = country.code             )     )',
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 3527,
#     'total_cost': 0.013368999999999999,
#     'prompt_tokens': 739,
#     'completion_tokens': 2788},
#    'column_recall': {'total_tokens': 6213,
#     'total_cost': 0.024589999999999997,
#     'prompt_tokens': 262,
#     'completion_tokens': 5951},
#    'schema_linking': {'total_tokens': 4332,
#     'total_cost': 0.013187,
#     'prompt_tokens': 4141,
#     'completion_tokens': 191},
#    'classification': {'total_tokens': 2350,
#     'total_cost': 0.007178,
#     'prompt_tokens': 2222,
#     'completion_tokens': 128},
#    'sql_generation_din_c3': {'total_tokens': 3700,
#     'total_cost': 0.011258,
#     'prompt_tokens': 3542,
#     'completion_tokens': 158},
#    'self_correction': {'total_tokens': 2288,
#     'total_cost': 0.006932000000000001,
#     'prompt_tokens': 2220,
#     'completion_tokens': 68}}},
#  {'id': '29',
#   'question': 'The codes of all countries where at least one mountain is located in each of their provinces',
#   'query_string': 'SELECT country.code FROM country WHERE country.code IN ( SELECT province.country FROM province JOIN mountainonisland ON province.name = mountainonisland.island GROUP BY province.country HAVING COUNT(DISTINCT province.name) = (SELECT COUNT(DISTINCT mountainonisland.island) FROM mountainonisland) )',
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 3689,
#     'total_cost': 0.014024,
#     'prompt_tokens': 732,
#     'completion_tokens': 2957},
#    'column_recall': {'total_tokens': 5806,
#     'total_cost': 0.022971,
#     'prompt_tokens': 253,
#     'completion_tokens': 5553},
#    'schema_linking': {'total_tokens': 4291,
#     'total_cost': 0.013018999999999998,
#     'prompt_tokens': 4145,
#     'completion_tokens': 146},
#    'classification': {'total_tokens': 2327,
#     'total_cost': 0.0071059999999999995,
#     'prompt_tokens': 2202,
#     'completion_tokens': 125},
#    'sql_generation_din_c3': {'total_tokens': 3673,
#     'total_cost': 0.011177999999999999,
#     'prompt_tokens': 3514,
#     'completion_tokens': 159},
#    'self_correction': {'total_tokens': 2285,
#     'total_cost': 0.006928,
#     'prompt_tokens': 2212,
#     'completion_tokens': 73}}},
#  {'id': '30',
#   'question': 'The code and total border lengths of all countries with at least one border.',
#   'query_string': 'SELECT country.code, SUM(borders.length) AS total_border_length FROM country JOIN borders ON country.code = borders.country1 OR country.code = borders.country2 GROUP BY country.code',
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 1672,
#     'total_cost': 0.005959,
#     'prompt_tokens': 729,
#     'completion_tokens': 943},
#    'column_recall': {'total_tokens': 3377,
#     'total_cost': 0.013287000000000002,
#     'prompt_tokens': 221,
#     'completion_tokens': 3156},
#    'schema_linking': {'total_tokens': 4259,
#     'total_cost': 0.012917,
#     'prompt_tokens': 4119,
#     'completion_tokens': 140},
#    'classification': {'total_tokens': 2264,
#     'total_cost': 0.006900999999999999,
#     'prompt_tokens': 2155,
#     'completion_tokens': 109},
#    'sql_generation_din_c3': {'total_tokens': 2109,
#     'total_cost': 0.006417999999999999,
#     'prompt_tokens': 2018,
#     'completion_tokens': 91},
#    'self_correction': {'total_tokens': 2236,
#     'total_cost': 0.006744999999999999,
#     'prompt_tokens': 2199,
#     'completion_tokens': 37}}},
#  {'id': '31',
#   'question': 'The names and codes of all countries in which at least one river originates.',
#   'query_string': 'SELECT country.name, country.code FROM country WHERE country.code IN (SELECT DISTINCT river.source FROM river)',
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 3856,
#     'total_cost': 0.014695,
#     'prompt_tokens': 729,
#     'completion_tokens': 3127},
#    'column_recall': {'total_tokens': 4548,
#     'total_cost': 0.017951,
#     'prompt_tokens': 241,
#     'completion_tokens': 4307},
#    'schema_linking': {'total_tokens': 4233,
#     'total_cost': 0.012813,
#     'prompt_tokens': 4119,
#     'completion_tokens': 114},
#    'classification': {'total_tokens': 2272,
#     'total_cost': 0.006925,
#     'prompt_tokens': 2163,
#     'completion_tokens': 109},
#    'sql_generation_din_c3': {'total_tokens': 2104,
#     'total_cost': 0.006389999999999999,
#     'prompt_tokens': 2026,
#     'completion_tokens': 78},
#    'self_correction': {'total_tokens': 2213,
#     'total_cost': 0.006662,
#     'prompt_tokens': 2190,
#     'completion_tokens': 23}}},
#  {'id': '32',
#   'question': 'What is the area and country of the Chatanga River?',
#   'query_string': "SELECT river.area, geo_river.country  FROM  river  JOIN  geo_river ON river.name = geo_river.river  WHERE  river.name = 'Chatanga River'",
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 3025,
#     'total_cost': 0.011373999999999999,
#     'prompt_tokens': 726,
#     'completion_tokens': 2299},
#    'column_recall': {'total_tokens': 6244,
#     'total_cost': 0.024727000000000002,
#     'prompt_tokens': 249,
#     'completion_tokens': 5995},
#    'schema_linking': {'total_tokens': 4254,
#     'total_cost': 0.012887,
#     'prompt_tokens': 4129,
#     'completion_tokens': 125},
#    'classification': {'total_tokens': 2320,
#     'total_cost': 0.007067,
#     'prompt_tokens': 2213,
#     'completion_tokens': 107},
#    'sql_generation_din_c3': {'total_tokens': 2184,
#     'total_cost': 0.00666,
#     'prompt_tokens': 2076,
#     'completion_tokens': 108},
#    'self_correction': {'total_tokens': 2240,
#     'total_cost': 0.006756999999999999,
#     'prompt_tokens': 2203,
#     'completion_tokens': 37}}},
#  {'id': '33',
#   'question': 'Shows me Airports with elevation more than 3000',
#   'query_string': 'SELECT airport.* FROM airport WHERE airport.elevation > 3000',
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 3107,
#     'total_cost': 0.011701999999999999,
#     'prompt_tokens': 726,
#     'completion_tokens': 2381},
#    'column_recall': {'total_tokens': 7764,
#     'total_cost': 0.030788000000000003,
#     'prompt_tokens': 268,
#     'completion_tokens': 7496},
#    'schema_linking': {'total_tokens': 4253,
#     'total_cost': 0.012868000000000001,
#     'prompt_tokens': 4144,
#     'completion_tokens': 109},
#    'classification': {'total_tokens': 2331,
#     'total_cost': 0.007094,
#     'prompt_tokens': 2230,
#     'completion_tokens': 101},
#    'sql_generation_din_c3': {'total_tokens': 1544,
#     'total_cost': 0.0046440000000000006,
#     'prompt_tokens': 1532,
#     'completion_tokens': 12},
#    'self_correction': {'total_tokens': 2197,
#     'total_cost': 0.006606,
#     'prompt_tokens': 2182,
#     'completion_tokens': 15}}},
#  {'id': '34',
#   'question': 'What are the religions practiced in Mexico?',
#   'query_string': "SELECT religion.name FROM religion WHERE religion.country = (SELECT country.code FROM country WHERE country.name = 'Mexico')",
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 2953,
#     'total_cost': 0.01109,
#     'prompt_tokens': 722,
#     'completion_tokens': 2231},
#    'column_recall': {'total_tokens': 3601,
#     'total_cost': 0.014191999999999998,
#     'prompt_tokens': 212,
#     'completion_tokens': 3389},
#    'schema_linking': {'total_tokens': 4220,
#     'total_cost': 0.012772,
#     'prompt_tokens': 4108,
#     'completion_tokens': 112},
#    'classification': {'total_tokens': 2236,
#     'total_cost': 0.00681,
#     'prompt_tokens': 2134,
#     'completion_tokens': 102},
#    'sql_generation_din_c3': {'total_tokens': 2080,
#     'total_cost': 0.0063230000000000005,
#     'prompt_tokens': 1997,
#     'completion_tokens': 83},
#    'self_correction': {'total_tokens': 2213,
#     'total_cost': 0.006667,
#     'prompt_tokens': 2185,
#     'completion_tokens': 28}}},
#  {'id': '35',
#   'question': 'Show all rivers that do not flow into the sea.',
#   'query_string': 'SELECT river.name FROM river WHERE river.sea IS NULL',
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 3341,
#     'total_cost': 0.012639000000000001,
#     'prompt_tokens': 725,
#     'completion_tokens': 2616},
#    'column_recall': {'total_tokens': 4768,
#     'total_cost': 0.018841,
#     'prompt_tokens': 231,
#     'completion_tokens': 4537},
#    'schema_linking': {'total_tokens': 4216,
#     'total_cost': 0.012751,
#     'prompt_tokens': 4113,
#     'completion_tokens': 103},
#    'classification': {'total_tokens': 2250,
#     'total_cost': 0.006851,
#     'prompt_tokens': 2149,
#     'completion_tokens': 101},
#    'sql_generation_din_c3': {'total_tokens': 1492,
#     'total_cost': 0.004486,
#     'prompt_tokens': 1482,
#     'completion_tokens': 10},
#    'self_correction': {'total_tokens': 2193,
#     'total_cost': 0.006592999999999999,
#     'prompt_tokens': 2179,
#     'completion_tokens': 14}}},
#  {'id': '36',
#   'question': 'List African countries by number of neighbors.',
#   'query_string': 'SELECT country.name, COUNT(borders.country2) AS num_neighbors FROM country JOIN borders ON country.code = borders.country1 GROUP BY country.name ORDER BY num_neighbors DESC',
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 3843,
#     'total_cost': 0.01465,
#     'prompt_tokens': 722,
#     'completion_tokens': 3121},
#    'column_recall': {'total_tokens': 4759,
#     'total_cost': 0.018805,
#     'prompt_tokens': 231,
#     'completion_tokens': 4528},
#    'schema_linking': {'total_tokens': 4235,
#     'total_cost': 0.012813,
#     'prompt_tokens': 4127,
#     'completion_tokens': 108},
#    'classification': {'total_tokens': 2268,
#     'total_cost': 0.006905,
#     'prompt_tokens': 2167,
#     'completion_tokens': 101},
#    'sql_generation_din_c3': {'total_tokens': 2150,
#     'total_cost': 0.00657,
#     'prompt_tokens': 2030,
#     'completion_tokens': 120},
#    'self_correction': {'total_tokens': 2241,
#     'total_cost': 0.006759,
#     'prompt_tokens': 2205,
#     'completion_tokens': 36}}},
#  {'id': '37',
#   'question': 'What is the average infant mortality rate for each continent?',
#   'query_string': 'SELECT T1.name, AVG(T3.infant_mortality)  FROM  continent T1  JOIN country T2 ON T1.name = T2.continent  JOIN population T3 ON T2.code = T3.country  GROUP BY T1.name',
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 2859,
#     'total_cost': 0.010711,
#     'prompt_tokens': 725,
#     'completion_tokens': 2134},
#    'column_recall': {'total_tokens': 4236,
#     'total_cost': 0.016718999999999998,
#     'prompt_tokens': 225,
#     'completion_tokens': 4011},
#    'schema_linking': {'total_tokens': 4228,
#     'total_cost': 0.012789000000000002,
#     'prompt_tokens': 4123,
#     'completion_tokens': 105},
#    'classification': {'total_tokens': 2250,
#     'total_cost': 0.006854,
#     'prompt_tokens': 2146,
#     'completion_tokens': 104},
#    'sql_generation_din_c3': {'total_tokens': 2136,
#     'total_cost': 0.006535,
#     'prompt_tokens': 2009,
#     'completion_tokens': 127},
#    'self_correction': {'total_tokens': 2270,
#     'total_cost': 0.006862,
#     'prompt_tokens': 2218,
#     'completion_tokens': 52}}},
#  {'id': '38',
#   'question': 'What is the average mortality rate of the countries in America without considering Brazil?',
#   'query_string': "SELECT avg(infant_mortality)  FROM      population  WHERE      country != 'Brazil'      AND country IN (SELECT code FROM country WHERE continent = 'America')",
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 4996,
#     'total_cost': 0.019255000000000005,
#     'prompt_tokens': 729,
#     'completion_tokens': 4267},
#    'column_recall': {'total_tokens': 4723,
#     'total_cost': 0.018646,
#     'prompt_tokens': 246,
#     'completion_tokens': 4477},
#    'schema_linking': {'total_tokens': 4282,
#     'total_cost': 0.01299,
#     'prompt_tokens': 4138,
#     'completion_tokens': 144},
#    'classification': {'total_tokens': 2299,
#     'total_cost': 0.007006,
#     'prompt_tokens': 2190,
#     'completion_tokens': 109},
#    'sql_generation_din_c3': {'total_tokens': 3608,
#     'total_cost': 0.010939,
#     'prompt_tokens': 3493,
#     'completion_tokens': 115},
#    'self_correction': {'total_tokens': 2243,
#     'total_cost': 0.006764999999999999,
#     'prompt_tokens': 2207,
#     'completion_tokens': 36}}},
#  {'id': '39',
#   'question': 'List seas with area greater than 8000 and depth less than 100.',
#   'query_string': 'SELECT name FROM sea WHERE area > 8000 AND depth < 100',
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 1903,
#     'total_cost': 0.006882,
#     'prompt_tokens': 730,
#     'completion_tokens': 1173},
#    'column_recall': {'total_tokens': 2571,
#     'total_cost': 0.010067999999999999,
#     'prompt_tokens': 216,
#     'completion_tokens': 2355},
#    'schema_linking': {'total_tokens': 4257,
#     'total_cost': 0.012912,
#     'prompt_tokens': 4116,
#     'completion_tokens': 141},
#    'classification': {'total_tokens': 2262,
#     'total_cost': 0.0068920000000000006,
#     'prompt_tokens': 2156,
#     'completion_tokens': 106},
#    'sql_generation_din_c3': {'total_tokens': 1494,
#     'total_cost': 0.004499,
#     'prompt_tokens': 1477,
#     'completion_tokens': 17},
#    'self_correction': {'total_tokens': 2209,
#     'total_cost': 0.006645,
#     'prompt_tokens': 2191,
#     'completion_tokens': 18}}},
#  {'id': '40',
#   'question': 'How many mountains are there in Asia?',
#   'query_string': "SELECT COUNT(DISTINCT T1.name)  FROM mountain T1  JOIN geo_mountain T2 ON T1.name = T2.mountain  JOIN encompasses T3 ON T2.country = T3.country  JOIN continent T4 ON T3.continent = T4.name  WHERE T4.name = 'Asia'",
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 5844,
#     'total_cost': 0.022654,
#     'prompt_tokens': 722,
#     'completion_tokens': 5122},
#    'column_recall': {'total_tokens': 5041,
#     'total_cost': 0.019935,
#     'prompt_tokens': 229,
#     'completion_tokens': 4812},
#    'schema_linking': {'total_tokens': 4246,
#     'total_cost': 0.012857,
#     'prompt_tokens': 4127,
#     'completion_tokens': 119},
#    'classification': {'total_tokens': 2310,
#     'total_cost': 0.007040000000000001,
#     'prompt_tokens': 2200,
#     'completion_tokens': 110},
#    'sql_generation_din_c3': {'total_tokens': 2222,
#     'total_cost': 0.006825000000000001,
#     'prompt_tokens': 2063,
#     'completion_tokens': 159},
#    'self_correction': {'total_tokens': 2293,
#     'total_cost': 0.0069440000000000005,
#     'prompt_tokens': 2228,
#     'completion_tokens': 65}}},
#  {'id': '41',
#   'question': 'What are the countries that are close to the Mediterranean Sea?',
#   'query_string': "SELECT T1.name  FROM      country T1      JOIN borders T2 ON T1.code = T2.country1 OR T1.code = T2.country2      JOIN sea T3 ON T3.name = 'Mediterranean Sea'",
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 3881,
#     'total_cost': 0.014797999999999999,
#     'prompt_tokens': 726,
#     'completion_tokens': 3155},
#    'column_recall': {'total_tokens': 5377,
#     'total_cost': 0.021272,
#     'prompt_tokens': 236,
#     'completion_tokens': 5141},
#    'schema_linking': {'total_tokens': 4278,
#     'total_cost': 0.012979999999999998,
#     'prompt_tokens': 4132,
#     'completion_tokens': 146},
#    'classification': {'total_tokens': 2302,
#     'total_cost': 0.007011000000000001,
#     'prompt_tokens': 2197,
#     'completion_tokens': 105},
#    'sql_generation_din_c3': {'total_tokens': 2184,
#     'total_cost': 0.0066760000000000005,
#     'prompt_tokens': 2060,
#     'completion_tokens': 124},
#    'self_correction': {'total_tokens': 2269,
#     'total_cost': 0.0068590000000000005,
#     'prompt_tokens': 2217,
#     'completion_tokens': 52}}},
#  {'id': '42',
#   'question': 'Show the total for each type of government.',
#   'query_string': 'SELECT government, COUNT(*) as total  FROM politics  GROUP BY government',
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 4243,
#     'total_cost': 0.016249,
#     'prompt_tokens': 723,
#     'completion_tokens': 3520},
#    'column_recall': {'total_tokens': 3328,
#     'total_cost': 0.013094,
#     'prompt_tokens': 218,
#     'completion_tokens': 3110},
#    'schema_linking': {'total_tokens': 4199,
#     'total_cost': 0.012683999999999999,
#     'prompt_tokens': 4112,
#     'completion_tokens': 87},
#    'classification': {'total_tokens': 2230,
#     'total_cost': 0.00679,
#     'prompt_tokens': 2130,
#     'completion_tokens': 100},
#    'sql_generation_din_c3': {'total_tokens': 1484,
#     'total_cost': 0.0044659999999999995,
#     'prompt_tokens': 1470,
#     'completion_tokens': 14},
#    'self_correction': {'total_tokens': 2194,
#     'total_cost': 0.006595,
#     'prompt_tokens': 2181,
#     'completion_tokens': 13}}},
#  {'id': '43',
#   'question': 'Which province has the largest desert in the world?',
#   'query_string': 'SELECT province.name FROM province JOIN geo_desert ON province.name = geo_desert.province JOIN desert ON geo_desert.desert = desert.name ORDER BY desert.area DESC LIMIT 1',
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 2417,
#     'total_cost': 0.008944,
#     'prompt_tokens': 724,
#     'completion_tokens': 1693},
#    'column_recall': {'total_tokens': 4738,
#     'total_cost': 0.018724,
#     'prompt_tokens': 228,
#     'completion_tokens': 4510},
#    'schema_linking': {'total_tokens': 4228,
#     'total_cost': 0.012787999999999999,
#     'prompt_tokens': 4124,
#     'completion_tokens': 104},
#    'classification': {'total_tokens': 2280,
#     'total_cost': 0.0069489999999999994,
#     'prompt_tokens': 2171,
#     'completion_tokens': 109},
#    'sql_generation_din_c3': {'total_tokens': 2183,
#     'total_cost': 0.006698,
#     'prompt_tokens': 2034,
#     'completion_tokens': 149},
#    'self_correction': {'total_tokens': 2266,
#     'total_cost': 0.006840000000000001,
#     'prompt_tokens': 2224,
#     'completion_tokens': 42}}},
#  {'id': '44',
#   'question': 'What is the largest desert in the world?',
#   'query_string': 'SELECT desert.name FROM desert ORDER BY desert.area DESC LIMIT 1',
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 4668,
#     'total_cost': 0.017949,
#     'prompt_tokens': 723,
#     'completion_tokens': 3945},
#    'column_recall': {'total_tokens': 2936,
#     'total_cost': 0.011534,
#     'prompt_tokens': 210,
#     'completion_tokens': 2726},
#    'schema_linking': {'total_tokens': 4191,
#     'total_cost': 0.012654,
#     'prompt_tokens': 4110,
#     'completion_tokens': 81},
#    'classification': {'total_tokens': 2239,
#     'total_cost': 0.006816999999999999,
#     'prompt_tokens': 2139,
#     'completion_tokens': 100},
#    'sql_generation_din_c3': {'total_tokens': 1476,
#     'total_cost': 0.004445000000000001,
#     'prompt_tokens': 1459,
#     'completion_tokens': 17},
#    'self_correction': {'total_tokens': 2204,
#     'total_cost': 0.006632000000000001,
#     'prompt_tokens': 2184,
#     'completion_tokens': 20}}},
#  {'id': '45',
#   'question': 'List, for all continents, the amount of deserts on each.',
#   'query_string': 'SELECT T1.name AS continent, COUNT(T3.name) AS desert_count FROM continent T1 JOIN geo_desert T2 ON T1.name = T2.continent JOIN desert T3 ON T2.desert = T3.name GROUP BY T1.name',
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 2602,
#     'total_cost': 0.009680000000000001,
#     'prompt_tokens': 728,
#     'completion_tokens': 1874},
#    'column_recall': {'total_tokens': 3468,
#     'total_cost': 0.01365,
#     'prompt_tokens': 222,
#     'completion_tokens': 3246},
#    'schema_linking': {'total_tokens': 4231,
#     'total_cost': 0.012802000000000001,
#     'prompt_tokens': 4122,
#     'completion_tokens': 109},
#    'classification': {'total_tokens': 2268,
#     'total_cost': 0.006912999999999999,
#     'prompt_tokens': 2159,
#     'completion_tokens': 109},
#    'sql_generation_din_c3': {'total_tokens': 2155,
#     'total_cost': 0.006598,
#     'prompt_tokens': 2022,
#     'completion_tokens': 133},
#    'self_correction': {'total_tokens': 2276,
#     'total_cost': 0.006883,
#     'prompt_tokens': 2221,
#     'completion_tokens': 55}}},
#  {'id': '46',
#   'question': 'What are the neighboring seas of the Banda Sea?',
#   'query_string': "SELECT mergeswith.sea2 FROM mergeswith WHERE mergeswith.sea1 = 'Banda Sea'",
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 2748,
#     'total_cost': 0.010267,
#     'prompt_tokens': 725,
#     'completion_tokens': 2023},
#    'column_recall': {'total_tokens': 4758,
#     'total_cost': 0.018796,
#     'prompt_tokens': 236,
#     'completion_tokens': 4522},
#    'schema_linking': {'total_tokens': 4271,
#     'total_cost': 0.012950000000000001,
#     'prompt_tokens': 4134,
#     'completion_tokens': 137},
#    'classification': {'total_tokens': 2356,
#     'total_cost': 0.007175000000000001,
#     'prompt_tokens': 2249,
#     'completion_tokens': 107},
#    'sql_generation_din_c3': {'total_tokens': 2198,
#     'total_cost': 0.00668,
#     'prompt_tokens': 2112,
#     'completion_tokens': 86},
#    'self_correction': {'total_tokens': 2210,
#     'total_cost': 0.006653,
#     'prompt_tokens': 2187,
#     'completion_tokens': 23}}},
#  {'id': '47',
#   'question': 'List all the capitals of European countries.',
#   'query_string': "SELECT country.capital FROM country JOIN continent ON country.continent = continent.name WHERE continent.name = 'Europe'",
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 2106,
#     'total_cost': 0.0077020000000000005,
#     'prompt_tokens': 722,
#     'completion_tokens': 1384},
#    'column_recall': {'total_tokens': 4243,
#     'total_cost': 0.016735,
#     'prompt_tokens': 237,
#     'completion_tokens': 4006},
#    'schema_linking': {'total_tokens': 4203,
#     'total_cost': 0.012691000000000001,
#     'prompt_tokens': 4121,
#     'completion_tokens': 82},
#    'classification': {'total_tokens': 2264,
#     'total_cost': 0.00689,
#     'prompt_tokens': 2166,
#     'completion_tokens': 98},
#    'sql_generation_din_c3': {'total_tokens': 1506,
#     'total_cost': 0.00453,
#     'prompt_tokens': 1494,
#     'completion_tokens': 12},
#    'self_correction': {'total_tokens': 2203,
#     'total_cost': 0.006635,
#     'prompt_tokens': 2177,
#     'completion_tokens': 26}}},
#  {'id': '48',
#   'question': 'What percentage of people speak French in Andorra?',
#   'query_string': "SELECT language.percentage  FROM  language  JOIN  country ON language.country = country.code  WHERE  country.name = 'Andorra'  AND  language.name = 'French'",
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 2308,
#     'total_cost': 0.008508,
#     'prompt_tokens': 724,
#     'completion_tokens': 1584},
#    'column_recall': {'total_tokens': 3110,
#     'total_cost': 0.012226,
#     'prompt_tokens': 214,
#     'completion_tokens': 2896},
#    'schema_linking': {'total_tokens': 4226,
#     'total_cost': 0.012794000000000002,
#     'prompt_tokens': 4110,
#     'completion_tokens': 116},
#    'classification': {'total_tokens': 2235,
#     'total_cost': 0.006808000000000001,
#     'prompt_tokens': 2132,
#     'completion_tokens': 103},
#    'sql_generation_din_c3': {'total_tokens': 2093,
#     'total_cost': 0.006377000000000001,
#     'prompt_tokens': 1995,
#     'completion_tokens': 98},
#    'self_correction': {'total_tokens': 2232,
#     'total_cost': 0.006732000000000001,
#     'prompt_tokens': 2196,
#     'completion_tokens': 36}}},
#  {'id': '49',
#   'question': 'Which rivers are longer than 1000 kilometers?',
#   'query_string': 'SELECT river.name FROM river WHERE river.length > 1000',
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 2946,
#     'total_cost': 0.01106,
#     'prompt_tokens': 724,
#     'completion_tokens': 2222},
#    'column_recall': {'total_tokens': 7087,
#     'total_cost': 0.02808,
#     'prompt_tokens': 268,
#     'completion_tokens': 6819},
#    'schema_linking': {'total_tokens': 4249,
#     'total_cost': 0.012854,
#     'prompt_tokens': 4142,
#     'completion_tokens': 107},
#    'classification': {'total_tokens': 2299,
#     'total_cost': 0.0069960000000000005,
#     'prompt_tokens': 2200,
#     'completion_tokens': 99},
#    'sql_generation_din_c3': {'total_tokens': 1538,
#     'total_cost': 0.004626000000000001,
#     'prompt_tokens': 1526,
#     'completion_tokens': 12},
#    'self_correction': {'total_tokens': 2195,
#     'total_cost': 0.006600000000000001,
#     'prompt_tokens': 2180,
#     'completion_tokens': 15}}},
#  {'id': '50',
#   'question': 'Which country had the lowest population growth?',
#   'query_string': 'SELECT T1.name  FROM      country T1  JOIN      population T2  ON      T1.code = T2.country  ORDER BY      T2.population_growth ASC  LIMIT 1',
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 3375,
#     'total_cost': 0.012778,
#     'prompt_tokens': 722,
#     'completion_tokens': 2653},
#    'column_recall': {'total_tokens': 3445,
#     'total_cost': 0.013565,
#     'prompt_tokens': 215,
#     'completion_tokens': 3230},
#    'schema_linking': {'total_tokens': 4194,
#     'total_cost': 0.012663,
#     'prompt_tokens': 4113,
#     'completion_tokens': 81},
#    'classification': {'total_tokens': 2227,
#     'total_cost': 0.006782,
#     'prompt_tokens': 2126,
#     'completion_tokens': 101},
#    'sql_generation_din_c3': {'total_tokens': 2083,
#     'total_cost': 0.006343,
#     'prompt_tokens': 1989,
#     'completion_tokens': 94},
#    'self_correction': {'total_tokens': 2244,
#     'total_cost': 0.006774,
#     'prompt_tokens': 2202,
#     'completion_tokens': 42}}}]

# %% [markdown]
# ## Testes com cada módulo

# %%
question = 'What are the provinces with an area greater than 10000?'

model_name = 'gpt-3.5-turbo-16k'
llm_c3 = ChatOpenAI(model_name = 'gpt-3.5-turbo', temperature=0.7, n=10)
model_kwargs = {'top_p':1.0, 'frequency_penalty':0.0, 'presence_penalty':0.0}
llm_din = ChatOpenAI(model_name = model_name, temperature=0.0, n=1, max_tokens=600, model_kwargs = model_kwargs)

model_kwargs['stop'] = ['#', ';','\n\n']
llm_din_fix = ChatOpenAI(model_name = model_name, temperature=0.0, n=1, max_tokens=350, model_kwargs = model_kwargs)

# %%
schema_links, tables = schema_linking_din_c3(question, db, llm_c3, llm_din, add_fk = True)
# Out:
# # mondial_city (name, country, province, population, latitude, longitude, elevation, meta_repcol)
# # mondial_citypops (city, country, province, year, population, meta_repcol)
# # mondial_country (name, code, capital, province, area, population, meta_repcol)
# # mondial_province (name, country, population, area, capital, capprov, meta_repcol)

# %%
print(schema_links)
print(tables)
# Out:
# [mondial_province.name,mondial_province.area,10000]
# ['mondial_province', 'mondial_country', 'mondial_city', 'mondial_citypops']

# %%
classification = classification_module(db, llm_din, question, schema_links, tables=tables)
classification
# Out:
# {'predicted_class': '"EASY"',
#  'classification_label': 'The SQL query for the question "What are the provinces with an area greater than 10000?" needs these tables = [mondial_province], so we don\'t need JOIN.\nPlus, it doesn\'t require nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = [""].\nSo, we don\'t need JOIN and don\'t need nested queries, then the the SQL query can be classified as "EASY".\nLabel: "EASY"'}

# %%
SQL = generating_sql_with_hints(db, llm_din, question, schema_links, classification, tables=tables)
print(SQL)
# Out:
# EASY
# SQL Parcial:  SELECT name FROM mondial_province WHERE area > 10000
# SELECT name FROM mondial_province WHERE area > 10000

# %%
db.run(SQL)
# Out:
# '[(\'Oberösterreich\',), (\'Tirol\',), (\'Steiermark\',), (\'Niederösterreich\',), (\'Jihoceský\',), (\'Stredoceský\',), (\'Baden-Württemberg\',), (\'Bayern\',), (\'Brandenburg\',), (\'Hessen\',), (\'Mecklenburg-Vorpommern\',), (\'Niedersachsen\',), (\'Nordrhein-Westfalen\',), (\'Rheinland-Pfalz\',), (\'Sachsen\',), (\'Sachsen-Anhalt\',), (\'Schleswig-Holstein\',), (\'Thüringen\',), (\'Piemonte\',), (\'Lombardia\',), (\'Trentino-Alto Adige\',), (\'Veneto\',), (\'Emilia-Romagna\',), (\'Toscana\',), (\'Lazio\',), (\'Abruzzo\',), (\'Campania\',), (\'Puglia\',), (\'Calabria\',), (\'Sicilia\',), (\'Sardegna\',), (\'Slovenia\',), (\'Brest\',), (\'Vitebsk\',), (\'Gomel\',), (\'Grodno\',), (\'Mogilev\',), (\'Minsk\',), (\'Latvia\',), (\'Lithuania\',), (\'Dolnoslaskie\',), (\'Kujawsko-Pomorskie\',), (\'Lubelskie\',), (\'Lubuskie\',), (\'Lódzkie\',), (\'Malopolskie\',), (\'Mazowieckie\',), (\'Podkarpackie\',), (\'Podlaskie\',), (\'Pomorskie\',), (\'Slaskie\',), (\'Swietokrzyskie\',), (\'Warminsko-Mazurskie\',), (\'Wielkopolskie\',), (\'Zachodniopomorskie\',), (\'Cherkas´ka\',), (\'Chernihivs´ka\',), (\'Dnipropetrovs´ka\',), (\'Donets´ka\',), (\'Ivano-Frankivs´ka\',), (\'Kharkivs´ka\',), (\'Khersons´ka\',), (\'Khmel´nyts´ka\',), (\'Kyïvs´ka\',), (\'Kirovohrads´ka\',), (\'Luhans´ka\',), (\'L´vivs´ka\',), (\'Mykolaïvs´ka\',), (\'Odes´ka\',), (\'Poltavs´ka\',), (\'Rivnens´ka\',), (\'Sums´ka\',), (\'Ternopil´s´ka\',), (\'Vinnyts´ka\',), (\'Volyns´ka\',), (\'Zakarpats´ka\',), (\'Zaporiz´ka\',), (\'Zhytomyrs´ka\',), (\'Krym\',), (\'Karelia\',), (\'Komi\',), (\'Arkhangel´skaya\',), (\'Vologodskaya\',), (\'Murmanskaya\',), (\'Kaliningradskaya\',), (\'Leningradskaya\',), (\'Novgorodskaya\',), (\'Pskovskaya\',), (\'Bryanskaya\',), (\'Vladimirskaya\',), (\'Ivanovskaya\',), (\'Kaluzhskaya\',), (\'Kostromskaya\',), (\'Moskovskaya\',), (\'Orlovskaya\',), (\'Ryazanskaya\',), (\'Smolenskaya\',), (\'Tverskaya\',), (\'Tul´skaya\',), (\'Yaroslavskaya\',), (\'Mariy-El\',), (\'Mordoviya\',), (\'Chuvashia\',), (\'Kirovskaya\',), (\'Nizhnii Novgorodskaya\',), (\'Belgorodskaya\',), (\'Voronezhskaya\',), (\'Kurskaya\',), (\'Lipetskaya\',), (\'Tambovskaya\',), (\'Kalmykiya\',), (\'Tatarstan\',), (\'Astrakhanskaya\',), (\'Volgogradskaya\',), (\'Penzenskaya\',), (\'Samarskaya\',), (\'Saratovskaya\',), (\'Ul´yanovskaya\',), (\'Rostovskaya\',), (\'Bashkortostan\',), (\'Udmurtskaya\',), (\'Orenburgskaya\',), (\'Permskij\',), (\'Dagestan\',), (\'Kabardino-Balkarskaya\',), (\'Karachayevo-Cherkesskaya\',), (\'Chechenskaya\',), (\'Krasnodarskiy\',), (\'Stavropol´skiy\',), (\'Kurganskaya\',), (\'Sverdlovskaya\',), (\'Chelyabinskaya\',), (\'Altay\',), (\'Altayskiy\',), (\'Kemerovskaya\',), (\'Novosibirskaya\',), (\'Omskaya\',), (\'Tomskaya\',), (\'Tyumenskaya\',), (\'Buryatiya\',), (\'Tyva\',), (\'Khakasiya\',), (\'Krasnoyarsk\',), (\'Irkutskaya\',), (\'Zabaykalskiy\',), (\'Sakha\',), (\'Jewish Autonomous Oblast\',), (\'Syddanmark\',), (\'Estonia\',), (\'Pirkanmaa\',), (\'Pohjois-Savo\',), (\'Lappia\',), (\'Etelä-Savo\',), (\'Keski-Suomi\',), (\'Pohjols-Karjala\',), (\'Pohjois-Pohjanmaa\',), (\'Kainuu\',), (\'Varsinais-Suomi\',), (\'Etelä-Pohjanmaa\',), (\'Hedmark\',), (\'Oppland\',), (\'Buskerud\',), (\'Telemark\',), (\'Hordaland\',), (\'Sogn og Fjordane\',), (\'Møre og Romsdal\',), (\'Sør-Trøndelag\',), (\'Nord-Trøndelag\',), (\'Nordland\',), (\'Troms\',), (\'Finnmark\',), (\'Västra Götaland\',), (\'Gävleborg\',), (\'Jämtland\',), (\'Jönköping\',), (\'Kalmar\',), (\'Dalarna\',), (\'Skåne\',), (\'Norrbotten\',), (\'Östergötland\',), (\'Värmland\',), (\'Västerbotten\',), (\'Västernorrland\',), (\'Iceland\',), (\'Ireland\',), (\'Moldova\',), (\'Beja\',), (\'Svalbard\',), (\'North West\',), (\'Yorkshire and the Humber\',), (\'East Midlands\',), (\'West Midlands\',), (\'East of England\',), (\'South East\',), (\'South West\',), (\'Scotland\',), (\'Wales\',), (\'Northern Ireland\',), (\'Afghanistan\',), (\'Anhui\',), (\'Fujian\',), (\'Gansu\',), (\'Guangdong\',), (\'Guizhou\',) ...
