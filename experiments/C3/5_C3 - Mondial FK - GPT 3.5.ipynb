# %% [markdown]
# # Experimento: C3 - Mondial - Foreign Key - GPT 3.5

# %%
from langchain.chat_models import ChatOpenAI
from urllib.parse import quote  

from dotenv import load_dotenv
import time
import os
import sys
import json
load_dotenv()

from c3_clear_prompting import generate_clear_prompting
from c3_calibration_with_hints import generate_calibration_with_hints
from c3_generate_sql import generate_sql

experiment_path = '..\..'
path = os.path.abspath('')
module_path = os.path.join(path, experiment_path)
print(module_path)
if module_path not in sys.path:
    sys.path.append(module_path+"\\functions")


from sqldatabase_langchain_utils import SQLDatabaseLangchainUtils

# %%
SCHEMA = 'mondial_gpt'
PREFIX = 'mondial'
FILE_NAME_RESULT = f"results/5_c3_queries_chatgpt_{SCHEMA}_fk.json"

# %%
def save_queries(queries):
    data = {"queries":queries}
    with open(FILE_NAME_RESULT, "w") as arquivo_json:
        json.dump(data, arquivo_json, indent=4) 
        
def read_queries():
    with open(FILE_NAME_RESULT, encoding='utf-8', errors='ignore') as json_data:
        data = json.load(json_data, strict=False)
    queries = data["queries"]
    return queries

# %% [markdown]
# ## Conexão com o banco

# %%
json_file_path = f"{experiment_path}/datasets/{SCHEMA}_db_connection.json"
with open(json_file_path, encoding='utf-8', errors='ignore') as json_data:
    db_connection = json.load(json_data, strict=False)
db_connection

# %%
db = SQLDatabaseLangchainUtils(db_connection=db_connection)

exclusao = [
    f"{SCHEMA}_tmdp",
    f"{SCHEMA}_tmdpmap",
    f"{SCHEMA}_tmds",
    f"{SCHEMA}_tmjmap",
    f"{SCHEMA}_tpv",
    f"{SCHEMA}_tmdc",
    f"{SCHEMA}_tmdcmap",
    f"{SCHEMA}_tmdej",
    f"{SCHEMA}_log_action",
    f"{SCHEMA}_log_error",
    f"{SCHEMA}_favorite_item", 
    f"{SCHEMA}_favorite_query",
    f"{SCHEMA}_favorite_tag",
    f"{SCHEMA}_favorite_tag_item",
    f"{SCHEMA}_favorite_visualization",
    f"{SCHEMA}_dashboard",
    f"{SCHEMA}_history",
    "teste_cliente",
    "teste_fornecedor",
    "teste_funcionario"
]

include_tables = [s for s in db.get_table_names() if not s.startswith(PREFIX) and s not in exclusao]
db = SQLDatabaseLangchainUtils(db_connection=db_connection, include_tables=include_tables, schema=db_connection.get("SCHEMA", None))
db.get_table_names()

# %% [markdown]
# ## C3 - Function

# %%
def run_c3(question, db, model='gpt-3.5-turbo', add_fk = True, callback= None):
    llm = ChatOpenAI(model_name = model, temperature=0.7, n=10)
    clear_prompting = generate_clear_prompting(question, db, llm, add_fk=add_fk, callback=callback)
    print(clear_prompting)
    messages = generate_calibration_with_hints(clear_prompting)
    llm = ChatOpenAI(model_name = model, n=20)
    sql = generate_sql(messages, llm, db, question, callback=callback)
    return sql

# %% [markdown]
# ## Preparando as consultas

# %%
json_file_path = f"../../datasets/{PREFIX}/queries_{PREFIX}.json"
with open(json_file_path, encoding='utf-8', errors='ignore') as json_data:
    queries = json.load(json_data, strict=False)
queries = queries['queries']
queries
# Out:
# [{'id': '1',
#   'question': 'What is the area of Thailand?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '2',
#   'question': 'What are the provinces with an area greater than 10000?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '3',
#   'question': 'What are the languages spoken in Poland?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '4',
#   'question': 'How deep is Lake Kariba?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '5',
#   'question': 'What is the total of provinces of Netherlands?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '6',
#   'question': 'What is the percentage of religious people are hindu in thailand?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '7',
#   'question': 'List the number of provinces each river flows through.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '8',
#   'question': 'Find all countries that became independent between 8/1/1910 and 8/1/1950.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '9',
#   'question': 'What are the cities of Cuba?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '10',
#   'question': 'What is the capital of Georgia?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '11',
#   'question': 'How many provinces have areas greater than 1000 in Niger?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '12',
#   'question': 'Tell me about the country with the area largest.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '13',
#   'question': 'What is the host province and year of establishment of the organization "International Energy Agency"?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '14',
#   'question': 'Find the name of all mountains whose elevation is higher than 1000.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '15',
#   'question': 'Tell me the economy of the Caribbean Sea.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '16',
#   'question': 'Show the cities with longitude between 0 and 6.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '17',
#   'question': 'Select cities whose population is greater than 100000, altitude greater than 2500, and the country you belong to has population growth greater than 1.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '18',
#   'question': 'Show all the different types of government.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '19',
#   'question': 'List all provinces in Germany',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '20',
#   'question': 'What is the percentage of mulatto ethnicity in Brazil?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '21',
#   'question': 'How many cities have populations less than 1000?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '22',
#   'question': 'What is the average elevation of airports in America?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '23',
#   'question': 'How many countries are adjacent to (or ecompassed by) the Caribbean Sea?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '24',
#   'question': 'How much area do the countries that are adjacent to (or encompassed by) the Caribbean Sea cover in total?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '25',
#   'question': 'For all countries, give the sum of the population of all its neighbors',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '26',
#   'question': 'What mountains are on the island of Borneo?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '27',
#   'question': 'Provide the name and total population of the country with the smallest area.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '28',
#   'question': 'The codes of all countries for which at least one river that originates in this country has its estuary in a neighboring country.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '29',
#   'question': 'The codes of all countries where at least one mountain is located in each of their provinces',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '30',
#   'question': 'The code and total border lengths of all countries with at least one border.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '31',
#   'question': 'The names and codes of all countries in which at least one river originates.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '32',
#   'question': 'What is the area and country of the Chatanga River?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '33',
#   'question': 'Show the Airports with elevation more than 3000',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '34',
#   'question': 'What are the religions practiced in Mexico?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '35',
#   'question': 'Show all rivers that do not flow into the sea.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '36',
#   'question': 'List African countries by number of neighbors.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '37',
#   'question': 'What is the average infant mortality rate for each continent?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '38',
#   'question': 'What is the average mortality rate of the countries in America without considering Brazil?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '39',
#   'question': 'List seas with area greater than 8000 and depth less than 100.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '40',
#   'question': 'How many mountains are there in Asia?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '41',
#   'question': 'How many countries that are close to the Mediterranean Sea?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '42',
#   'question': 'Show the total for each type of government.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '43',
#   'question': 'Which province has the largest desert in the world?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '44',
#   'question': 'What is the largest desert in the world?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '45',
#   'question': 'List, for all continents, the amount of deserts on each.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '46',
#   'question': 'What are the neighboring seas of the Banda Sea?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '47',
#   'question': 'List all the capitals of European countries.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '48',
#   'question': 'What percentage of people speak French in Andorra?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '49',
#   'question': 'Which rivers are longer than 1000 kilometers?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '50',
#   'question': 'Which country had the lowest population growth?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '51',
#   'question': 'List the name of capital cities for which we do not have data about the city in located',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '52',
#   'question': 'What is the capital of the provice Andaluc�a?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '53',
#   'question': 'What is the abbreviation for the organization whose name is "General Confederation of Trade Unions"?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '54',
#   'question': 'In which city is the organization with the abbreviation "UPU" ?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '55',
#   'question': 'List the names of countries which are members of only one organization',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '56',
#   'question': 'List the name of countries which are not a member of NATO.',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '57',
#   'question': 'List the name of countries which are a member of NATO.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '58',
#   'question': 'List the rivers with length less than 50',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '59',
#   'question': 'What are the area, elevation and type of lakes in country Italy?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '60',
#   'question': ' List the names of capital cities which are the base for organizations in alphabetical order',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '61',
#   'question': 'List the name of organizations that do not have countries with an area smaller than 4000 and of the member type',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '62',
#   'question': 'List the name of organizations that do not have countries with  an area greater than 10000 and population smaller than 3000 and of the member type',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '63',
#   'question': 'Show the inflation rate of countries that are washed by the Arabian Sea',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '64',
#   'question': 'List all the capitals of the countries that belong to the continent Africa?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '65',
#   'question': 'Show the inflation rate of the countries bathed by the Arabian Sea and there is no inflation with null value',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '66',
#   'question': 'How many countries are in Africa?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '67',
#   'question': 'List the name of countries that are not members of NATO and UNESCO',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '68',
#   'question': 'What is the area of the continent Europe?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '69',
#   'question': 'What is the area of continent America?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '70',
#   'question': 'What is the area of continent Asia?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '71',
#   'question': 'What is the area of Africa?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '72',
#   'question': 'How many countries are in America?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '73',
#   'question': 'What area is the largest continent?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '74',
#   'question': 'List the countries that belong to the continent with the largest area',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '75',
#   'question': 'List the countries that belong to the continent with the largest area and whose language is English',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '76',
#   'question': 'List the names of cities, along with the name of their country for cities with a population greater than 5 million.  Display the results in descending order by population.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '77',
#   'question': 'Show the name of the deserts in the province of Algeria',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '78',
#   'question': 'Show the name and area of the deserts in the province of California',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '79',
#   'question': 'List the country names and percentage of use of language where  French are used as languages.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '80',
#   'question': 'What are the cities where �Portuguese� is spoken?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '81',
#   'question': 'What is the total area of the provinces in Canada?',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '82',
#   'question': 'What is the length of the Tigres River?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '83',
#   'question': 'List the Airports with elevation more than 1000',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '84',
#   'question': 'List airports in the United States with an elevation below 200 feet',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '85',
#   'question': 'What are the mountains with altitudes above 8000 meters?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '86',
#   'question': 'What are the 3 airports with the largest name?',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '87',
#   'question': 'List lakes with an area of less than 5000 square kilometers.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '88',
#   'question': 'What is the total area of the seas with a depth greater than 1000 meters?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '89',
#   'question': 'Find the countries whose name starts with the letter "B" and have a population greater than 10 million',
#   'query_string': '',
#   'type': 'complex'},
#  {'id': '90',
#   'question': 'List cities with another name in Brazil',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '91',
#   'question': 'List all cities that are at a latitude greater than 45 degrees.',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '92',
#   'question': 'Show the number of cities with another name in countries with an area greater than 30000',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '93',
#   'question': 'Show the deserts with area greater than 10000',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '94',
#   'question': 'List the islands that belong to a lake with an elevation greater than 100',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '95',
#   'question': 'List all mountains located on islands with an area greater than 100,000 square kilometers',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '96',
#   'question': 'List the countries and the sum of their provincial areas.',
#   'query_string': '',
#   'type': 'simple'},
#  {'id': '97',
#   'question': 'Show the name of the countries, the average elevation and sum of the population of their cities',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '98',
#   'question': "What was Germany's inflation?",
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '99',
#   'question': 'What type of government is Iran?',
#   'query_string': '',
#   'type': 'medium'},
#  {'id': '100',
#   'question': "What is the percentage of industries in relation to Japan's economy?",
#   'query_string': '',
#   'type': 'medium'}]

# %% [markdown]
# ## Tracking token usage

# %%
track_token = [] 
def tracking_token(cb =None, reset = False):
    global track_token
    track_token.append(cb)
    if reset:
        track_token = []

# %%
def convert_to_dict_tracking_token():
    token_usage = {}
    for e in track_token:
        for key in e.keys():
            token_usage[key] = {}
            token_usage[key]['total_tokens'] = e[key].total_tokens
            token_usage[key]['total_cost'] = e[key].total_cost
            token_usage[key]['prompt_tokens'] = e[key].prompt_tokens
            token_usage[key]['completion_tokens'] = e[key].completion_tokens 
    return token_usage

# %%
sql = run_c3("'What are the languages spoken in Poland?", db, callback=tracking_token)
print(convert_to_dict_tracking_token())

# %%
print(sql)
track_token
# Out:
# SELECT language.name FROM language INNER JOIN country ON language.country = country.code WHERE country.name = 'Poland';
# [{'table_recall': Tokens Used: 2760
#   	Prompt Tokens: 890
#   	Completion Tokens: 1870
#   Successful Requests: 1
#   Total Cost (USD): $0.0050750000000000005},
#  {'column_recall': Tokens Used: 3443
#   	Prompt Tokens: 238
#   	Completion Tokens: 3205
#   Successful Requests: 1
#   Total Cost (USD): $0.006767},
#  {'sql_generation': Tokens Used: 834
#   	Prompt Tokens: 506
#   	Completion Tokens: 328
#   Successful Requests: 1
#   Total Cost (USD): $0.001415}]

# %% [markdown]
# ## Executando o método

# %%
tracking_token(reset=True)
errors = []
query_index = -1
for instance in queries:
    query_index +=1
    try:
        start_time = time.time()
        sql = run_c3(instance["question"], db, callback=tracking_token)
        end_time = time.time()
        instance["query_string"] = sql
        instance["token_usage"] = convert_to_dict_tracking_token()
        instance['time'] = end_time - start_time
        save_queries(queries)
        print(instance['id'], instance['question'], instance["query_string"], instance['time'])
        print("-----")
    except:
        print("Error")
        errors.append(query_index)
        pass
    finally:
        tracking_token(reset=True)
# Out:
# 1 - Ranking the columns in each table based on relevance to the question:
#
# Table: continent
# 1. name - This column is relevant because it contains the name of the continent. Although not directly related to the question, it could be used to join tables.
# 2. area - This column is highly relevant as it directly provides the area of the continent.
#
# Table: country
# 1. name - This column is relevant as it contains the name of the country. It could be used to join tables.
# 2. code - This column is highly relevant as it is the primary key of the country table and can be used to join tables.
# 3. capital - This column is relevant as it contains the name of the capital city of the country. It could be used to join tables.
# 4. province - This column is relevant as it contains the name of the province. It could be used to join tables.
# 5. area - This column is relevant as it directly provides the area of the country.
# 6. population - This column is relevant as it provides the population of the country.
#
# Table: province
# 1. name - This column is relevant as it contains the name of the province. It could be used to join tables.
# 2. country - This column is highly relevant as it is a foreign key referencing the country code. It can be used to join tables.
# 3. population - This column is relevant as it provides the population of the province.
# 4. area - This column is relevant as it directly provides the area of the province.
# 5. capital - This column is relevant as it contains the name of the capital city of the province. It could be used to join tables.
# 6. capprov - This column is relevant as it contains information about the capital province.
#
# Table: city
# 1. name - This column is relevant as it contains the name of the city. It could be used to join tables.
# 2. country - This column is highly relevant as it is a foreign key referencing the country code. It can be used to join tables.
# 3. province - This column is relevant as it is a foreign key referencing the province name. It can be used to join tables.
# 4. population - This column is relevant as it provides the population of the city.
# 5. latitude - This column is relevant as it provides the latitude of the city.
# 6. longitude - This column is relevant as it provides the longitude of the city.
# 7. elevation - This column is relevant as it provides the elevation of the city.
#
# 2 - Outputting a JSON object with the columns in each table:
#
# {
#     "continent": ["name", "area"],
#     "country": ["name", "code", "capital", "province", "area", "population"],
#     "province": ["name", "country", "population", "area", "capital", "capprov"],
#     "city": ["name", "country", "province", "population", "latitude", "longitude", "elevation"]
# }
# 1 - Ranking the columns in each table based on relevance to the question:
#
# Table: continent
# 1. name - The name of the continent is highly relevant as it is used to identify the continent to which a country belongs.
#
# Table: country
# 1. name - The name of the country is highly relevant as it is used to identify the specific country.
# 2. code - The country code is relevant as it can be used as a reference to join with other tables.
# 3. area - The area of the country is directly related to the question.
#
# Table: province
# 1. name - The name of the province is relevant as it is used to identify the specific province.
# 2. country - The country column is a foreign key and is relevant as it is used to join with the country table.
# 3. area - The area of the province is indirectly related to the question.
#
# Table: city
# 1. name - The name of the city is relevant as it is used to identify the specific city.
# 2. country - The country column is a foreign key and is relevant as it is used to join with the country and province tables.
# 3. province - The province column is a foreign key and is relevant as it is used to join with the province table.
#
# 2 - Outputting a JSON object with the columns in each table according to the ranking:
#
# {
#     "continent": ["name", "area"],
#     "country": ["name", "code", "area"],
#     "province": ["name", "country", "area"],
#     "city": ["name", "country", "province"]
# }
# Based on the given question, "What is the area of Thailand?", we need to find the area of Thailand. For this, we need to focus on the "country" table and specifically the "area" column.
#
# Ranking the columns in each table based on relevance:
#
# Table: continent
# Columns: name, area
#
# Explanation: The "continent" table does not directly provide information about countries or their areas. Therefore, the columns in this table are not relevant to the given question.
#
# Table: country
# Columns: name, code, capital, province, area, population
#
# Explanation: In the "country" table, the "area" column is directly related to the question as it provides the area of a country. Therefore, the "area" column is the most relevant column in this table.
#
# Table: province
# Columns: name, country, population, area, capital, capprov
#
# Explanation: The "province" table contains information about provinces within a country, but it does not directly provide the area of a country. The "country" column is a foreign key that connects to the "country" table, but it does not directly answer the question. Therefore, none of the columns in this table are relevant to the given question.
#
# Table: city
# Columns: name, country, province, population, latitude, longitude, elevation
#
# Explanation: The "city" table contains information about cities within a country and province. Although the "country" and "province" columns are foreign keys, they do not directly provide the area of a country. Therefore, none of the columns in this table are relevant to the given question.
#
# Based on the above analysis, the ranking of the columns in each table based on relevance is as follows:
#
# continent: [name, area]
# country: [area, name, code, capital, province, population]
# province: [name, country, population, area, capital, capprov]
# city: [name, country, province, population, latitude, longitude, elevation]
#
# Output JSON object:
#
# {
#     "continent": ["name", "area"],
#     "country": ["area", "name", "code", "capital", "province", "population"],
#     "province": ["name", "country", "population", "area", "capital", "capprov"],
#     "city": ["name", "country", "province", "population", "latitude", "longitude", "elevation"]
# }
# 1. Ranking the columns in each table based on relevance to the question:
#
# Table: continent
# - name: This column is not relevant to the question as it does not provide any information about the area of Thailand.
# - area: This column is highly relevant as it directly provides information about the area, which is the main focus of the question.
#
# Table: country
# - name: This column is not relevant to the question as it does not provide any information about the area of Thailand.
# - code: This column is not relevant to the question as it is a unique identifier for the country.
# - capital: This column is not relevant to the question as it provides information about the capital city, not the area.
# - province: This column is not relevant to the question as it provides information about the provinces within the country, not the area.
# - area: This column is relevant as it provides information about the area of the country, including Thailand.
# - population: This column is not relevant to the question as it provides information about the population, not the area.
#
# Table: province
# - name: This column is not relevant to the question as it provides information about the province name, not the area.
# - country: This column is relevant as it links the province to the country, including Thailand.
# - population: This column is not relevant to the question as it provides information about the population, not the area.
# - area: This column is relevant as it provides information about the area of the province, including regions within Thailand.
# - capital: This column is not relevant to the question as it provides information about the capital city of the province, not the area.
# - capprov: This column is not relevant to the question as it provides information about the capital province, not the area.
#
# Table: city
# - name: This column is not relevant to the question as it provides information about the city name, not the area.
# - country: This column is relevant as it links the city to the country, including Thailand.
# - province: This column is relevant as it links the city to the province, including regions within Thailand.
# - population: This column is not relevant to the question as it provides information about the population, not the area.
# - latitude: This column is not relevant to the question as it provides information about the geographic location, not the area.
# - longitude: This column is not relevant to the question as it provides information about the geographic location, not the area.
# - elevation: This column is not relevant to the question as it provides information about the elevation, not the area.
#
# 2. Outputting a JSON object with the columns in each table:
#
# {
#     "continent": ["area"],
#     "country": ["area"],
#     "province": ["country", "area"],
#     "city": ["country", "province"]
# }
# 1 - Rank the columns in each table based on the possibility of being used in the SQL:
#
# Table: continent
# 1. name - The name column is highly relevant as it is used to identify the continent.
#
# Table: country
# 1. name - The name column is highly relevant as it is used to identify the country.
# 2. code - The code column is highly relevant as it is used as a foreign key in other tables.
# 3. area - The area column is relevant as it provides information about the country's area.
# 4. population - The population column is relevant as it provides information about the country's population.
# 5. capital - The capital column is relevant as it provides information about the country's capital.
# 6. province - The province column is relevant as it provides information about the country's provinces.
#
# Table: province
# 1. name - The name column is highly relevant as it is used to identify the province.
# 2. country - The country column is highly relevant as it is used as a foreign key in other tables.
# 3. population - The population column is relevant as it provides information about the province's population.
# 4. area - The area column is relevant as it provides information about the province's area.
# 5. capital - The capital column is relevant as it provides information about the province's capital.
# 6. capprov - The capprov column is relevant as it provides information about the province's capital province.
#
# Table: city
# 1. name - The name column is highly relevant as it is used to identify the city.
# 2. country - The country column is highly relevant as it is used as a foreign key in other tables.
# 3. province - The province column is highly relevant as it is used as a foreign key in other tables.
# 4. population - The population column is relevant as it provides information about the city's population.
# 5. latitude - The latitude column is relevant as it provides geographical information about the city.
# 6. longitude - The longitude column is relevant as it provides geographical information about the city.
# 7. elevation - The elevation column is relevant as it provides information about the city's elevation.
#
# 2 - Output a JSON object that contains all the columns in each table according to the explanation:
#
# {
#     "continent": ["name", "area"],
#     "country": ["name", "code", "capital", "province", "area", "population"],
#     "province": ["name", "country", "population", "area", "capital", "capprov"],
#     "city": ["name", "country", "province", "population", "latitude", "longitude", "elevation"]
# }
# 1. Ranking the columns in each table based on relevance to the question:
#
# Table: continent
# Columns: name, area
#
# Explanation: In the context of the question, the "area" column is highly relevant as it directly relates to the measurement of land area for a continent. The "name" column is less relevant as it does not directly provide information about the area of a specific country.
#
# Table: country
# Columns: name, code, capital, province, area, population
#
# Explanation: The "area" column is highly relevant as it directly provides the area of a country. The "name" column is also relevant as it can be used to identify the country. The "code" column is less relevant as it is not directly related to the area of a country. The "capital" column may be relevant in identifying the country, but it does not provide information about its area. The "province" column is less relevant as it pertains to sub-regions within a country. The "population" column is not directly related to the area of a country.
#
# Table: province
# Columns: name, country, population, area, capital, capprov
#
# Explanation: The "area" column is highly relevant as it directly provides the area of a province. The "country" column is relevant as it can be used to join with the "country" table to obtain the area of the corresponding country. The "name" column is less relevant as it is specific to the province. The "population" column is not directly related to the area of a province. The "capital" column may be relevant in identifying the province, but it does not provide information about its area. The "capprov" column is less relevant as it is specific to the province.
#
# Table: city
# Columns: name, country, province, population, latitude, longitude, elevation
#
# Explanation: The "country" and "province" columns are relevant as they can be used to join with the "province" table to obtain the area of the corresponding province and country. The "name" column is less relevant as it is specific to the city. The "population" column is not directly related to the area of a city. The "latitude", "longitude", and "elevation" columns are not directly related to the area of a city.
#
# 2. JSON object containing all the columns in each table according to the explanation:
#
# {
#     "continent": ["name", "area"],
#     "country": ["name", "code", "capital", "province", "area", "population"],
#     "province": ["name", "country", "population", "area", "capital", "capprov"],
#     "city": ["name", "country", "province", "population", "latitude", "longitude", "elevation"]
# }
# 1. Rank the columns in each table based on relevance to the question:
#
# Table 1: continent
# - name: This column is not relevant to the question as it does not provide information about the area of Thailand.
# - area: This column is highly relevant as it stores the area of each continent. It is directly related to the question.
#
# Table 2: country
# - name: This column is not relevant to the question as it does not provide information about the area of Thailand.
# - code: This column is not relevant to the question as it does not provide information about the area of Thailand.
# - capital: This column is not relevant to the question as it does not provide information about the area of Thailand.
# - province: This column is not relevant to the question as it does not provide information about the area of Thailand.
# - area: This column is not relevant to the question as it stores the area of each country, not specifically Thailand.
# - population: This column is not relevant to the question as it does not provide information about the area of Thailand.
#
# Table 3: province
# - name: This column is not relevant to the question as it does not provide information about the area of Thailand.
# - country: This column is not relevant to the question as it is a foreign key.
# - population: This column is not relevant to the question as it does not provide information about the area of Thailand.
# - area: This column is not relevant to the question as it does not provide information about the area of Thailand.
# - capital: This column is not relevant to the question as it does not provide information about the area of Thailand.
# - capprov: This column is not relevant to the question as it does not provide information about the area of Thailand.
#
# Table 4: city
# - name: This column is not relevant to the question as it does not provide information about the area of Thailand.
# - country: This column is not relevant to the question as it is a foreign key.
# - province: This column is not relevant to the question as it is a foreign key.
# - population: This column is not relevant to the question as it does not provide information about the area of Thailand.
# - latitude: This column is not relevant to the question as it does not provide information about the area of Thailand.
# - longitude: This column is not relevant to the question as it does not provide information about the area of Thailand.
# - elevation: This column is not relevant to the question as it does not provide information about the area of Thailand.
#
# 2. Output JSON object:
#
# {
#     "continent": ["area"],
#     "country": [],
#     "province": [],
#     "city": []
# }
# 1 - Ranking the columns in each table based on relevance to the question:
#
# Table: continent
# 1. name - The name of the continent is not relevant to the question.
# 2. area - The area of the continent is not relevant to the question.
#
# Table: country
# 1. name - The name of the country is not relevant to the question.
# 2. code - The country code is not relevant to the question.
# 3. capital - The capital of the country is not relevant to the question.
# 4. province - The province column is not relevant to the question.
# 5. area - The area of the country is not relevant to the question.
# 6. population - The population of the country is not relevant to the question.
#
# Table: province
# 1. name - The name of the province is not relevant to the question.
# 2. country - The country column is relevant as it is the foreign key to the country table.
# 3. population - The population of the province is not relevant to the question.
# 4. area - The area of the province is not relevant to the question.
# 5. capital - The capital of the province is not relevant to the question.
# 6. capprov - The capprov column is not relevant to the question.
#
# Table: city
# 1. name - The name of the city is not relevant to the question.
# 2. country - The country column is relevant as it is the foreign key to the province and country tables.
# 3. province - The province column is relevant as it is the foreign key to the province table.
# 4. population - The population of the city is not relevant to the question.
# 5. latitude - The latitude of the city is not relevant to the question.
# 6. longitude - The longitude of the city is not relevant to the question.
# 7. elevation - The elevation of the city is not relevant to the question.
#
# 2 - Outputting a JSON object that contains all the columns in each table according to the explanation:
#
# {
#     "continent": ["name", "area"],
#     "country": ["name", "code", "capital", "province", "area", "population"],
#     "province": ["name", "country", "population", "area", "capital", "capprov"],
#     "city": ["name", "country", "province", "population", "latitude", "longitude", "elevation"]
# }
# Ranking the columns in each table based on their relevance to the question:
#
# Table continent:
# 1. name: The name column is highly relevant as it is used to identify the continent.
# 2. area: The area column is also relevant as it provides information about the area of the continent.
#
# Table country:
# 1. name: The name column is relevant as it is used to identify the country.
# 2. code: The code column is relevant as it is often used as a unique identifier for the country.
# 3. capital: The capital column is relevant as it provides information about the capital city of the country.
# 4. province: The province column is relevant as it is used to identify the provinces within the country.
# 5. area: The area column is relevant as it provides information about the area of the country.
# 6. population: The population column is relevant as it provides information about the population of the country.
#
# Table province:
# 1. name: The name column is relevant as it is used to identify the province.
# 2. country: The country column is highly relevant as it is a foreign key linking the province to the country.
# 3. population: The population column is relevant as it provides information about the population of the province.
# 4. area: The area column is relevant as it provides information about the area of the province.
# 5. capital: The capital column is relevant as it provides information about the capital city of the province.
# 6. capprov: The capprov column is relevant as it provides information about the capital province.
#
# Table city:
# 1. name: The name column is relevant as it is used to identify the city.
# 2. country: The country column is highly relevant as it is a foreign key linking the city to the country and the province.
# 3. province: The province column is highly relevant as it is a foreign key linking the city to the province.
# 4. population: The population column is relevant as it provides information about the population of the city.
# 5. latitude: The latitude column may be relevant if the question involves geographic coordinates.
# 6. longitude: The longitude column may be relevant if the question involves geographic coordinates.
# 7. elevation: The elevation column may be relevant if the question involves the elevation of the city.
#
# Based on the rankings, the JSON object that contains all the columns in each table would be:
#
# {
#     "continent": ["name", "area"],
#     "country": ["name", "code", "capital", "province", "area", "population"],
#     "province": ["name", "country", "population", "area", "capital", "capprov"],
#     "city": ["name", "country", "province", "population", "latitude", "longitude", "elevation"]
# }
# 1 - Ranking of columns in each table based on relevance to the question:
#
# Table: continent
# Columns: name, area
# Explanation: Both columns are relevant as the question asks for the area of a country, and the country's area is determined by the continent it belongs to.
#
# Table: country
# Columns: name, code, capital, province, area, population
# Explanation: The relevant columns in this table are name, area, and code. Name is relevant as it identifies the country, area is directly related to the question, and code can be used as a foreign key to join with other tables.
#
# Table: province
# Columns: name, country, population, area, capital, capprov
# Explanation: The relevant columns in this table are country and area. Country is relevant as it represents the country that the province belongs to, and area is needed to calculate the total area of the country.
#
# Table: city
# Columns: name, country, province, population, latitude, longitude, elevation
# Explanation: The relevant columns in this table are country and province. Country is needed to identify the country that the city belongs to, and province is required to determine the area of the country.
#
# 2 - JSON object containing all the columns in each table according to the ranking:
#
# {
#     "continent": ["name", "area"],
#     "country": ["name", "code", "area"],
#     "province": ["country", "area"],
#     "city": ["country", "province"]
# }
#
# ### Complete oracle SQL query only and with no explanation, and do not select extra columns that are not explicitly requested in the query.
# ### Oracle SQL tables, with their properties:
# #
# # continent (area, name)
# # country (name, code, capital, province, area)
# # province (country, area, name, population)
# # city (country, province, name, population)
# # province.country=country.code
# # province.country=country.code
# # city.country=province.country
# # city.province=province.name
# # city.country=province.country
# # city.province=province.name
#
# #
# ### What is the area of Thailand?
# SELECT
# 1 What is the area of Thailand? SELECT country.area FROM country WHERE country.name = 'Thailand'; 28.70964527130127
# -----
# To rank the columns in each table based on their relevance to the given question, we need to consider the columns that directly relate to the question and can provide the required information.
#
# Table: country
# 1. area: This column directly relates to the question as it represents the area of a country. It can be used to filter countries based on their area.
# 2. province: This column represents the province(s) associated with a country. While it is not directly related to the question, it might be needed to provide additional information about provinces.
#
# Table: province
# 1. area: This column directly relates to the question as it represents the area of a province. It can be used to filter provinces based on their area.
# 2. name: This column represents the name of the province. It is not directly related to the question, but it might be needed to display the names of the provinces that meet the criteria.
# 3. country: This column represents the country to which the province belongs. It is not directly related to the question, but it might be needed to provide additional information about the provinces.
#
# Based on the relevance to the question, the columns can be ranked as follows:
#
# country table: [area, province]
# province table: [area, name, country]
#
# Now, let's output a JSON object that contains all the columns in each table according to the explanation:
#
# {
#     "country": ["area", "province"],
#     "province": ["area", "name", "country"]
# }
# 1 - Ranking the columns in each table based on relevance to the question:
#
# For the table "country":
# 1. area - This column directly corresponds to the question as it represents the area of a country.
# 2. province - This column indicates the province(s) within the country, which may have an impact on the area.
# 3. name - Although not directly related to the question, the name of the country could provide additional context.
#
# For the table "province":
# 1. area - This column directly corresponds to the question as it represents the area of a province.
# 2. country - This column represents the country to which the province belongs, which is relevant for identifying provinces.
# 3. name - Although not directly related to the question, the name of the province could provide additional context.
#
# 2 - JSON object containing the columns in each table:
# {
#     "country": ["area", "province", "name"],
#     "province": ["area", "country", "name"]
# }
# To rank the columns in each table, we will consider the relevance of each column based on their similarity to the question and their connection to foreign keys.
#
# For the "country" table, the relevant columns based on the question are "province" and "area". These columns directly relate to the question by providing information about the provinces and their respective areas. The "code" column is also relevant as it can be used as a foreign key in the "province" table. The "name", "capital", and "population" columns are less relevant to the question.
#
# For the "province" table, the relevant columns based on the question are "name", "area", and "country". The "name" column provides the name of the province, the "area" column provides information about the province's area, and the "country" column links the province to the country it belongs to. The "population" and "capital" columns are less relevant to the question. The "capprov" column is not relevant to the question.
#
# Based on this analysis, the ranking of columns in each table is as follows:
#
# For the "country" table:
# 1. province
# 2. area
# 3. code
# 4. name
# 5. capital
# 6. population
#
# For the "province" table:
# 1. name
# 2. area
# 3. country
# 4. population
# 5. capital
# 6. capprov
#
# Based on this ranking, the JSON object would be:
#
# {
#     "country": ["province", "area", "code", "name", "capital", "population"],
#     "province": ["name", "area", "country", "population", "capital", "capprov"]
# }
# Based on the given question, the relevant columns in each table can be ranked as follows:
#
# For the "country" table:
# 1. area: This column directly relates to the question as it represents the area of a country.
# 2. province: This column is relevant as it indicates the provinces within a country.
# 3. name: This column provides the name of the country, which could be useful for context.
# 4. code: This column represents the code of the country, which may be needed for identification purposes.
# 5. capital: Although not directly related to the question, it could be useful for additional information.
# 6. population: This column is not directly relevant to the question, but it could be used for further analysis if needed.
#
# For the "province" table:
# 1. area: This column directly relates to the question as it represents the area of a province.
# 2. name: This column provides the name of the province, which is essential for the question.
# 3. country: This column is a foreign key that relates the province to its respective country.
# 4. population: This column could be useful for further analysis if needed.
# 5. capital: Although not directly related to the question, it could be useful for additional information.
# 6. capprov: This column is a foreign key that connects the province to its respective country.
#
# Based on the above rankings, the JSON object would be as follows:
#
# {
#     "country": ["area", "province", "name", "code", "capital", "population"],
#     "province": ["area", "name", "country", "population", "capital", "capprov"]
# }
# 1 - Ranking the columns in each table based on relevance to the question:
#
# Table: country
# 1. name: This column is relevant because it contains the names of the countries, which may be mentioned in the question or used for filtering the provinces.
# 2. code: This column is relevant because it is the primary key of the country table and may be used in the foreign key relationship with the province table.
# 3. capital: This column is relevant because it contains the names of the capitals, which may be mentioned in the question or used for filtering the provinces.
# 4. province: This column is less relevant as it contains the names of the provinces, which may not be directly related to the question.
# 5. area: This column is less relevant as it contains the area of the countries, not the provinces.
# 6. population: This column is less relevant as it contains the population of the countries, not the provinces.
#
# Table: province
# 1. name: This column is relevant because it contains the names of the provinces, which may be mentioned in the question or used for filtering the provinces.
# 2. country: This column is relevant because it is the foreign key referencing the country table, allowing for joining the tables to get information about the provinces' countries.
# 3. population: This column is relevant because it contains the population of the provinces, which may be used for filtering provinces with a population greater than a certain value.
# 4. area: This column is relevant because it contains the area of the provinces, which is directly related to the question.
# 5. capital: This column is less relevant as it contains the names of the capitals, which may not be directly related to the question.
# 6. capprov: This column is less relevant as it is not clear what it represents and how it relates to the question.
#
# 2 - Outputting a JSON object with the columns in each table:
#
# {
#     "country": ["name", "code", "capital", "province", "area", "population"],
#     "province": ["name", "country", "population", "area", "capital", "capprov"]
# }
# 1 - Ranking the columns in each table based on relevance to the question:
#
# Table: country
# 1. name - This column is relevant because it contains the names of the countries, which might be mentioned in the question.
# 2. code - This column is relevant because it is the primary key of the country table and might be used for joining with other tables.
# 3. capital - This column is relevant because it contains the names of the capitals, which might be mentioned in the question.
# 4. province - This column might be relevant if the question involves filtering provinces based on country.
#
# Table: province
# 1. name - This column is relevant because it contains the names of the provinces, which might be mentioned in the question.
# 2. country - This column is relevant because it is the foreign key linking province to country, which might be used for joining.
# 3. population - This column might be relevant if the question involves filtering provinces based on population.
# 4. area - This column is highly relevant because it contains the area of the provinces, which is mentioned in the question's criteria.
# 5. capital - This column is relevant because it contains the names of the capitals of the provinces, which might be mentioned in the question.
# 6. capprov - This column might be relevant if the question involves filtering provinces based on their capital.
#
# 2 - Outputting the JSON object:
#
# {
#     "country": ["name", "code", "capital", "province", "area", "population"],
#     "province": ["name", "country", "population", "area", "capital", "capprov"]
# }
# 1 - Ranking the columns in each table based on relevance to the question:
#
# Table: country
# 1. name: This column is relevant as it contains the names of the countries, which may be mentioned in the question.
# 2. code: This column is relevant as it contains the country codes, which may be used to join with the province table.
# 3. capital: This column is relevant as it contains the capitals of the countries, which may be mentioned in the question.
# 4. province: This column is less relevant as it contains the provinces within the countries, but the question does not specifically ask for provinces within countries.
# 5. area: This column is less relevant as it contains the area of the countries, but the question asks for provinces' area.
# 6. population: This column is less relevant as it contains the population of the countries, but the question asks for provinces' area.
#
# Table: province
# 1. name: This column is relevant as it contains the names of the provinces, which may be mentioned in the question.
# 2. country: This column is relevant as it is the foreign key linking the province table to the country table.
# 3. population: This column is less relevant as it contains the population of the provinces, but the question asks for provinces' area.
# 4. area: This column is relevant as it contains the area of the provinces, which is directly related to the question.
# 5. capital: This column is less relevant as it contains the capitals of the provinces, but the question does not specifically ask for capitals.
# 6. capprov: This column is less relevant as it is not mentioned in the question.
#
# 2 - Outputting the JSON object:
#
# {
#     "country": ["name", "code", "capital", "province", "area", "population"],
#     "province": ["name", "country", "population", "area", "capital", "capprov"]
# }
# To rank the columns in each table based on their relevance to the given question, we need to consider the columns that are directly related to the question and can be used to filter the provinces with an area greater than 10000.
#
# For the "country" table:
# 1. area: This column directly represents the area of a country, which is relevant to finding provinces with an area greater than 10000.
# 2. population: Although not directly related to the question, population could potentially be used as an additional filter criteria.
# 3. name: This column represents the name of the country, which is not directly relevant to the question but might be needed for displaying the results.
# 4. code: This column represents the code of the country, which is not directly relevant to the question but might be needed for joining tables.
#
# For the "province" table:
# 1. area: This column directly represents the area of a province, which is relevant to finding provinces with an area greater than 10000.
# 2. country: This column represents the foreign key relationship with the "country" table and is required for joining the tables.
# 3. population: Although not directly related to the question, population could potentially be used as an additional filter criteria.
# 4. name: This column represents the name of the province, which is not directly relevant to the question but might be needed for displaying the results.
# 5. capital: This column represents the capital city of the province, which is not directly relevant to the question but might be needed for displaying the results.
# 6. capprov: This column represents the capital province, which is not directly relevant to the question.
#
# Based on the above analysis, the ranked columns for each table are as follows:
#
# {
#   "country": ["area", "population", "name", "code"],
#   "province": ["area", "country", "population", "name", "capital", "capprov"]
# }
#
# Note: The "area" column is ranked first in both tables as it is directly relevant to the question and can be used to filter the provinces with an area greater than 10000. The other columns are ranked based on their potential relevance to the question and their usefulness in joining tables or displaying the results.
# Ranking of columns in each table based on relevance to the question:
#
# Table: country
# 1. name: The name of the country may be used in the SQL query to identify the country.
# 2. code: The country code may be used in the SQL query to identify the country.
# 3. capital: The capital city of the country may be used in the SQL query to identify the country.
# 4. province: The province column is not relevant to the question as it is not directly related to the area of provinces.
# 5. area: The area of the country may be used in the SQL query to compare with the given threshold of 10000.
# 6. population: The population of the country is not directly relevant to the question.
#
# Table: province
# 1. name: The name of the province may be used in the SQL query to identify the provinces with an area greater than 10000.
# 2. country: The country column is a foreign key and is highly relevant to the question as it links the province to the country.
# 3. population: The population of the province may be used in the SQL query to filter provinces with an area greater than 10000.
# 4. area: The area of the province is directly relevant to the question as it needs to be compared with the threshold of 10000.
# 5. capital: The capital of the province is not directly relevant to the question.
# 6. capprov: The capprov column is not relevant to the question.
#
# JSON output:
#
# {
#     "country": ["name", "code", "capital", "province", "area", "population"],
#     "province": ["name", "country", "population", "area", "capital", "capprov"]
# }
# 1 - Ranking of columns in each table for the given question:
#
# Table: country
# 1. area - This column directly matches the condition of the question, as it specifies the area of the country.
# 2. province - This column might be relevant if we need to join the country table with the province table to get additional information about the provinces.
#
# Table: province
# 1. area - This column directly matches the condition of the question, as it specifies the area of the province.
# 2. country - This column is a foreign key referencing the country table and might be relevant if we need to join the tables to retrieve the country information for the provinces.
#
# 2 - JSON object containing the columns in each table according to the ranking:
#
# {
#     "country": ["area", "province"],
#     "province": ["area", "country"]
# }
#
# ### Complete oracle SQL query only and with no explanation, and do not select extra columns that are not explicitly requested in the query.
# ### Oracle SQL tables, with their properties:
# #
# # country (province, name, code, area, capital)
# # province (area, country, name, population)
# # province.country=country.code
# # province.country=country.code
#
# #
# ### What are the provinces with an area greater than 10000?
# SELECT
# 2 What are the provinces with an area greater than 10000? SELECT province.name FROM province WHERE province.area > 10000; 23.55670475959778
# -----
# list error
# Ranking of columns in each table based on relevance to the question:
#
# For the table "country":
# 1. name: The name of the country is highly relevant as the question is asking for the languages spoken in a specific country.
# 2. code: The country code is relevant as it can be used to identify the specific country.
# 3. capital: The capital city of the country may be relevant in providing additional information about the country.
# 4. province: The province information may not be directly relevant to the question.
# 5. area: The area of the country is not directly relevant to the question.
# 6. population: The population of the country is not directly relevant to the question.
#
# For the table "language":
# 1. country: The foreign key relationship between language and country tables is highly relevant as it allows us to link the language spoken to a specific country.
# 2. name: The name of the language is relevant as it directly relates to the question.
# 3. percentage: The percentage of speakers of a language may provide additional information, but it is not directly relevant to the question.
#
# Output JSON object:
# {
#     "country": ["name", "code", "capital", "province", "area", "population"],
#     "language": ["country", "name", "percentage"]
# }
# 1 - Rank the columns in each table based on the possibility of being used in the SQL:
#
# For the "country" table:
# 1. name - This column is highly relevant as it directly matches the question word "spoken" and is likely to be used in the SQL query to retrieve the languages spoken in a specific country.
# 2. code - This column is the primary key and is also relevant as it can be used in the join condition to link the "language" table.
# 3. capital - This column may not be directly related to the question, but it provides additional information about the country and may be used in the query to filter or display results.
# 4. province - This column may not be directly related to the question and is less likely to be used in the SQL query.
# 5. area - This column is not directly related to the question and is less likely to be used in the SQL query.
# 6. population - This column is not directly related to the question and is less likely to be used in the SQL query.
#
# For the "language" table:
# 1. country - This column is the foreign key that links the "language" table to the "country" table. It is highly relevant as it is necessary to retrieve the languages spoken in a specific country.
# 2. name - This column is directly related to the question and is likely to be used in the SQL query to retrieve the names of the languages spoken.
# 3. percentage - This column may not be directly related to the question, but it provides additional information about the language and may be used in the query to filter or display results.
#
# 2 - Output a JSON object that contains all the columns in each table according to the ranking:
#
# {
#     "country": ["name", "code", "capital", "province", "area", "population"],
#     "language": ["country", "name", "percentage"]
# }
# 1 - Ranking the columns in each table based on relevance to the question:
#
# Table: country
# 1. name - This column is highly relevant as it contains the name of the country, which is necessary to identify Poland.
# 2. code - This column is also relevant as it contains the country code, which can be used to join with the language table.
# 3. capital - This column is less relevant as it is not directly related to the languages spoken in Poland.
# 4. province - This column is less relevant as it is not directly related to the languages spoken in Poland.
# 5. area - This column is not relevant to the question of identifying the languages spoken in Poland.
# 6. population - This column is not relevant to the question of identifying the languages spoken in Poland.
#
# Table: language
# 1. country - This column is highly relevant as it is the foreign key linking the language table to the country table, allowing us to filter languages spoken in Poland.
# 2. name - This column is relevant as it contains the name of the language.
# 3. percentage - This column is less relevant as it provides information about the percentage of speakers, but not necessary to identify the languages spoken in Poland.
#
# 2 - Outputting a JSON object with the columns:
#
# {
#     "country": ["name", "code", "capital", "province", "area", "population"],
#     "language": ["country", "name", "percentage"]
# }
# 1 - Ranking the columns in each table based on relevance to the question:
#
# Table: country
# 1. name: This column is highly relevant as it contains the name of the country, which is mentioned in the question.
# 2. code: This column is a foreign key and is relevant as it is used to join with the language table.
# 3. capital: This column is not directly relevant to the question but may be useful in providing additional information about Poland.
# 4. province: This column is not directly relevant to the question but may be useful in providing additional information about Poland.
# 5. area: This column is not directly relevant to the question.
# 6. population: This column is not directly relevant to the question.
#
# Table: language
# 1. country: This column is a foreign key that joins with the country table and is relevant as it helps identify the languages spoken in different countries.
# 2. name: This column is relevant as it contains the name of the language.
# 3. percentage: This column is not directly relevant to the question but may provide information about the prevalence of languages in a country.
#
# 2 - Outputting the JSON object:
#
# {
#     "country": ["name", "code", "capital", "province", "area", "population"],
#     "language": ["country", "name", "percentage"]
# }
# 1 - Rank the columns in each table based on the possibility of being used in the SQL, Column that matches more with the question words or the foreign key is highly relevant and must be placed ahead. You should output them in the order of the most relevant to the least relevant. Explain why you choose each column.
#
# For the table "country":
# 1. name - This column is relevant because it contains the name of the country. Since the question specifically asks about Poland, this column is highly relevant.
# 2. code - This column is the primary key of the table and is used as a foreign key in the "language" table. It is relevant because it is used to establish the relationship between the "country" and "language" tables.
# 3. capital - This column is relevant as it contains the capital city of the country. While not directly mentioned in the question, it provides additional information about the country.
# 4. province - This column is relevant as it contains information about the provinces within the country. While not directly mentioned in the question, it provides additional information about the country.
# 5. area - This column represents the area of the country. It is not directly relevant to the question but could be used to provide additional context.
# 6. population - This column represents the population of the country. It is not directly relevant to the question but could be used to provide additional context.
#
# For the table "language":
# 1. country - This column is a foreign key that establishes a relationship with the "country" table. It is highly relevant as it is used to determine the languages spoken in a specific country.
# 2. name - This column contains the name of the language. It is relevant as it provides the information about the language being spoken.
# 3. percentage - This column represents the percentage of the country's population that speaks the language. It is not directly relevant to the question but could be used to provide additional context.
#
# 2 - Output a JSON object that contains all the columns in each table according to your explanation. The format should be like:
#
# {
#     "country": ["name", "code", "capital", "province", "area", "population"],
#     "language": ["country", "name", "percentage"]
# }
# 1 - Ranking the columns in each table based on relevance to the question:
# - For the "country" table:
# 1. name: This column is highly relevant as it contains the name of the country, which is directly related to the question.
# 2. code: This column is relevant as it is the code of the country and can be used to identify Poland.
# 3. capital: This column is relevant as it contains the capital city of the country, which may be related to the question.
# 4. province: This column is less relevant as it contains information about the provinces within the country, which may not directly answer the question.
# ...
# 5. area: This column is less relevant as it provides information about the country's area, which is not directly related to the percentage of industries in the economy.
# 6. population: This column is less relevant as it provides information about the country's population, which is not directly related to the percentage of industries in the economy.
#
# Table: economy
# 1. country: This column is relevant because it is the foreign key that links the economy table to the country table and allows us to filter the data for Japan.
# 2. gdp: This column is relevant because it provides information about the country's gross domestic product, which is necessary for calculating the percentage of industries.
# 3. agriculture: This column is less relevant as it provides information about the country's agriculture sector, which is not directly related to the percentage of industries in the economy.
# 4. service: This column is less relevant as it provides information about the country's service sector, which is not directly related to the percentage of industries in the economy.
# 5. industry: This column is relevant because it provides information about the country's industrial sector, which is necessary for calculating the percentage of industries.
# 6. inflation: This column is less relevant as it provides information about the country's inflation rate, which is not directly related to the percentage of industries in the economy.
# 7. unemployment: This column is less relevant as it provides information about the country's unemployment rate, which is not directly related to the percentage of industries in the economy.
#
# JSON object containing the columns in each table according to relevance:
#
# {
#     "country": ["name", "code", "capital", "province", "area", "population"],
#     "economy": ["country", "gdp", "agriculture", "service", "industry", "inflation", "unemployment"]
# }
# 1 - Rank the columns in each table based on the possibility of being used in the SQL:
#
# For the "country" table:
# 1. code - This column is highly relevant as it is the primary key and can be used to join with the "economy" table.
# 2. name - This column is relevant as it is the name of the country and may be used in the question.
# 3. capital - This column is relevant as it is the capital city of the country and may be used in the question.
# 4. province - This column is less relevant as it represents the province of the country and may not directly relate to the question.
# 5. area - This column is less relevant as it represents the area of the country and may not directly relate to the question.
# 6. population - This column is less relevant as it represents the population of the country and may not directly relate to the question.
#
# For the "economy" table:
# 1. country - This column is highly relevant as it is the foreign key linking the "economy" table with the "country" table.
# 2. industry - This column is highly relevant as it represents the industry data and directly relates to the question.
# 3. gdp - This column is relevant as it represents the GDP of the country and may be used in the question.
# 4. agriculture - This column is less relevant as it represents the agriculture data and may not directly relate to the question.
# 5. service - This column is less relevant as it represents the service data and may not directly relate to the question.
# 6. inflation - This column is less relevant as it represents the inflation data and may not directly relate to the question.
# 7. unemployment - This column is less relevant as it represents the unemployment data and may not directly relate to the question.
#
# 2 - Output a JSON object that contains all the columns in each table according to the ranking:
#
# {
#     "country": ["code", "name", "capital", "province", "area", "population"],
#     "economy": ["country", "industry", "gdp", "agriculture", "service", "inflation", "unemployment"]
# }
# 1 - Ranking the columns in each table based on relevance to the question:
#
# Table: country
# 1. name - This column is relevant because we need to identify the specific country (Japan) mentioned in the question.
# 2. code - This column is relevant because it is a foreign key in the economy table.
# 3. capital - This column is not directly relevant to the question, but it provides additional information about the country.
# 4. province - This column is not directly relevant to the question.
# 5. area - This column is not directly relevant to the question.
# 6. population - This column is not directly relevant to the question.
#
# Table: economy
# 1. country - This column is relevant because it is a foreign key linking to the country table, and we need to filter for Japan.
# 2. gdp - This column is not directly relevant to the question, but it provides overall economic information.
# 3. agriculture - This column is not directly relevant to the question, but it provides specific economic information.
# 4. service - This column is not directly relevant to the question, but it provides specific economic information.
# 5. industry - This column is highly relevant because it directly relates to the question and provides information about the percentage of industries.
# 6. inflation - This column is not directly relevant to the question.
# 7. unemployment - This column is not directly relevant to the question.
#
# 2 - Outputting the JSON object:
# {
#     "country": ["name", "code", "capital", "province", "area", "population"],
#     "economy": ["country", "gdp", "agriculture", "service", "industry", "inflation", "unemployment"]
# }
# 1 - Rank the columns in each table based on the possibility of being used in the SQL:
# - country table:
# 1. name: The name of the country is relevant as it is mentioned in the question.
# 2. code: The code of the country is relevant as it is a foreign key in the economy table.
# 3. capital: The capital of the country is not directly relevant to the question.
# 4. province: The province of the country is not directly relevant to the question.
# 5. area: The area of the country is not directly relevant to the question.
# 6. population: The population of the country is not directly relevant to the question.
#
# - economy table:
# 1. country: The country column is a foreign key to the country table and is directly relevant to the question.
# 2. gdp: The GDP of the country is not directly relevant to the question.
# 3. agriculture: The agriculture column is not directly relevant to the question.
# 4. service: The service column is not directly relevant to the question.
# 5. industry: The industry column is directly relevant to the question as it is related to the percentage of industries.
# 6. inflation: The inflation column is not directly relevant to the question.
# 7. unemployment: The unemployment column is not directly relevant to the question.
#
# 2 - Output a JSON object that contains all the columns in each table according to the explanation:
# {
#     "country": ["name", "code", "capital", "province", "area", "population"],
#     "economy": ["country", "gdp", "agriculture", "service", "industry", "inflation", "unemployment"]
# }
# Based on the question, the relevant columns in each table can be ranked as follows:
#
# For the "country" table:
# 1. code: The country code is necessary to identify Japan.
# 2. name: The country name is necessary to identify Japan.
# 3. capital: Although not directly related to the question, it provides additional information about Japan.
# 4. province: Although not directly related to the question, it provides additional information about Japan.
# 5. area: Although not directly related to the question, it provides additional information about Japan.
# 6. population: Although not directly related to the question, it provides additional information about Japan.
#
# For the "economy" table:
# 1. country: The foreign key that links the "economy" table to the "country" table.
# 2. industry: This column directly relates to the question as it represents the percentage of industries in the economy.
# 3. gdp: Although not directly related to the question, it provides additional information about the economy.
# 4. agriculture: Although not directly related to the question, it provides additional information about the economy.
# 5. service: Although not directly related to the question, it provides additional information about the economy.
# 6. inflation: Although not directly related to the question, it provides additional information about the economy.
# 7. unemployment: Although not directly related to the question, it provides additional information about the economy.
#
# Based on the ranking, the JSON object would be:
#
# {
#     "country": ["code", "name", "capital", "province", "area", "population"],
#     "economy": ["country", "industry", "gdp", "agriculture", "service", "inflation", "unemployment"]
# }
# 1 - Ranking the columns in each table based on relevance to the question:
#
# Table: country
# 1. code: This column is highly relevant as it is the foreign key used to join with the economy table.
# 2. name: This column is relevant as it provides the name of the country, including Japan.
# 3. capital: This column is less relevant as it provides information about the capital city, but not directly related to the question.
# 4. province: This column is less relevant as it provides information about the provinces within a country, not directly related to the question.
# 5. area: This column is less relevant as it provides information about the area of the country, not directly related to the question.
# 6. population: This column is less relevant as it provides information about the population of the country, not directly related to the question.
#
# Table: economy
# 1. country: This column is highly relevant as it is the foreign key used to join with the country table.
# 2. industry: This column is highly relevant as it provides information about the industry sector, which is directly related to the question.
# 3. gdp: This column is less relevant as it provides information about the GDP of a country, but not directly related to the question.
# 4. agriculture: This column is less relevant as it provides information about the agriculture sector, not directly related to the question.
# 5. service: This column is less relevant as it provides information about the service sector, not directly related to the question.
# 6. inflation: This column is less relevant as it provides information about the inflation rate, not directly related to the question.
# 7. unemployment: This column is less relevant as it provides information about the unemployment rate, not directly related to the question.
#
# 2 - Outputting a JSON object:
#
# {
#     "country": ["code", "name", "capital", "province", "area", "population"],
#     "economy": ["country", "industry", "gdp", "agriculture", "service", "inflation", "unemployment"]
# }
# Based on the given question, the relevant columns in each table can be ranked as follows:
#
# For the "country" table:
# 1. name: This column is relevant because it specifies the name of the country. In the question, we need to find the percentage of industries in relation to Japan's economy, so the country name is necessary to identify Japan.
# 2. code: This column is the primary key of the "country" table and is used as a foreign key in the "economy" table. It is relevant because it links the "country" and "economy" tables.
# 3. capital: This column is not directly relevant to the question, but it provides additional information about the country.
# 4. province: This column is not directly relevant to the question, but it provides additional information about the country.
# 5. area: This column is not directly relevant to the question, but it provides additional information about the country.
# 6. population: This column is not directly relevant to the question, but it provides additional information about the country.
#
# For the "economy" table:
# 1. country: This column is the foreign key that references the "country" table. It is highly relevant because it links the "economy" table to the specific country (in this case, Japan).
# 2. gdp: This column is relevant because it represents the Gross Domestic Product, which is a measure of the total value of goods and services produced in a country. It is necessary to calculate the percentage of industries in relation to Japan's economy.
# 3. agriculture: This column represents the contribution of the agricultural sector to the country's economy. It is relevant because it is one of the sectors that need to be considered when calculating the percentage of industries.
# 4. service: This column represents the contribution of the service sector to the country's economy. It is relevant because it is one of the sectors that need to be considered when calculating the percentage of industries.
# 5. industry: This column represents the contribution of the industrial sector to the country's economy. It is highly relevant because it specifically represents the industries, which is what the question is asking for.
# 6. inflation: This column is not directly relevant to the question, but it provides additional information about the country's economy.
# 7. unemployment: This column is not directly relevant to the question, but it provides additional information about the country's economy.
#
# Based on the rankings above, the JSON object would be:
# {
#     "country": ["name", "code", "capital", "province", "area", "population"],
#     "economy": ["country", "gdp", "agriculture", "service", "industry", "inflation", "unemployment"]
# }
# To rank the columns in each table based on their relevance to the question, we need to consider the information required to calculate the percentage of industries in relation to Japan's economy.
#
# 1. country table:
# - code: This column is highly relevant as it is the primary key and can be used to join the country table with the economy table.
# - name: Although not explicitly mentioned in the question, the country's name can be useful for identifying Japan.
# - province: This column is not directly relevant to the question.
# - capital: This column is not directly relevant to the question.
# - area: This column is not directly relevant to the question.
# - population: This column is not directly relevant to the question.
#
# 2. economy table:
# - country: This column is a foreign key that links to the code column in the country table. It is highly relevant as it is used to identify the country.
# - industry: This column is directly relevant to the question as it contains information about industries.
# - gdp: This column is not directly relevant to the question.
# - agriculture: This column is not directly relevant to the question.
# - service: This column is not directly relevant to the question.
# - inflation: This column is not directly relevant to the question.
# - unemployment: This column is not directly relevant to the question.
#
# Based on the above analysis, the ranking of columns in each table in order of relevance to the question is as follows:
#
# country table: [code, name, province, capital, area, population]
# economy table: [country, industry, gdp, agriculture, service, inflation, unemployment]
#
# The JSON object representing the columns in each table would be:
#
# {
#     "country": ["code", "name", "province", "capital", "area", "population"],
#     "economy": ["country", "industry", "gdp", "agriculture", "service", "inflation", "unemployment"]
# }
#
# ### Complete oracle SQL query only and with no explanation, and do not select extra columns that are not explicitly requested in the query.
# ### Oracle SQL tables, with their properties:
# #
# # country (code, name, capital, province)
# # economy (country, gdp, agriculture, industry, service)
# # economy.country=country.code
#
# #
# ### What is the percentage of industries in relation to Japan's economy?
# SELECT
# 100 What is the percentage of industries in relation to Japan's economy? SELECT ROUND((industry / (agriculture + industry + service)) * 100, 2) AS percentage_industry FROM economy WHERE country = 'JP'; 35.82979345321655
# -----

# %%
errors
# Out:
# []

# %% [markdown]
# #### Fixing query

# %%
pos = 40
instance = queries[pos]
q = read_queries()
start_time = time.time()
sql = run_c3(instance["question"], db, callback=tracking_token)
end_time = time.time()
instance["query_string"] = sql
instance["token_usage"] = convert_to_dict_tracking_token()
instance['time'] = end_time - start_time
q[pos] = instance
save_queries(q)
print(instance['id'], instance['question'], instance["query_string"], instance['time'])
# Out:
# Column recall attempt: 1
#
# ### Complete oracle SQL query only and with no explanation, and do not select extra columns that are not explicitly requested in the query.
# ### Oracle SQL tables, with their properties:
# #
# # country (name, code, capital, province)
# # sea (name, area, depth)
# # borders (country1, country2, length)
# # borders.country1=country.code
# # borders.country2=country.code
#
# #
# ### How many countries that are close to the Mediterranean Sea?
# SELECT
# 41 How many countries that are close to the Mediterranean Sea? SELECT COUNT(DISTINCT country.name) FROM country JOIN borders ON country.code = borders.country1 JOIN sea ON borders.country2 = sea.name WHERE sea.name = 'Mediterranean Sea'; 42.66082406044006

# %%
to_fix = [59,62,72,85,99]
for pos in to_fix:
    instance = queries[pos]
    q = read_queries()
    start_time = time.time()
    sql = run_c3(instance["question"], db, callback=tracking_token)
    end_time = time.time()
    instance["query_string"] = sql
    instance["token_usage"] = convert_to_dict_tracking_token()
    instance['time'] = end_time - start_time
    q[pos] = instance
    save_queries(q)
    print(instance['id'], instance['question'], instance["query_string"], instance['time'])

# %%
queries
# Out:
# [{'id': '1',
#   'question': 'What is the area of Thailand?',
#   'query_string': "SELECT area FROM country WHERE name = 'Thailand';",
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 3784,
#     'total_cost': 0.0072075,
#     'prompt_tokens': 721,
#     'completion_tokens': 3063},
#    'column_recall': {'total_tokens': 5752,
#     'total_cost': 0.011373499999999998,
#     'prompt_tokens': 261,
#     'completion_tokens': 5491},
#    'sql_generation': {'total_tokens': 798,
#     'total_cost': 0.001329,
#     'prompt_tokens': 534,
#     'completion_tokens': 264}}},
#  {'id': '2',
#   'question': 'What are the provinces with an area greater than 10000?',
#   'query_string': 'SELECT province.name FROM province WHERE province.area > 10000;',
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 2289,
#     'total_cost': 0.0042144999999999995,
#     'prompt_tokens': 727,
#     'completion_tokens': 1562},
#    'column_recall': {'total_tokens': 4013,
#     'total_cost': 0.0079085,
#     'prompt_tokens': 235,
#     'completion_tokens': 3778},
#    'sql_generation': {'total_tokens': 796,
#     'total_cost': 0.0013340000000000001,
#     'prompt_tokens': 516,
#     'completion_tokens': 280}}},
#  {'id': '3',
#   'question': 'What are the languages spoken in Poland?',
#   'query_string': "SELECT language.name FROM language WHERE language.country = 'Poland';",
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 2909,
#     'total_cost': 0.005456999999999999,
#     'prompt_tokens': 722,
#     'completion_tokens': 2187},
#    'column_recall': {'total_tokens': 5012,
#     'total_cost': 0.009894,
#     'prompt_tokens': 260,
#     'completion_tokens': 4752},
#    'sql_generation': {'total_tokens': 894,
#     'total_cost': 0.0015165,
#     'prompt_tokens': 543,
#     'completion_tokens': 351}}},
#  {'id': '4',
#   'question': 'How deep is Lake Kariba?',
#   'query_string': "SELECT depth FROM lake WHERE name = 'Lake Kariba';",
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 4576,
#     'total_cost': 0.0087915,
#     'prompt_tokens': 721,
#     'completion_tokens': 3855},
#    'column_recall': {'total_tokens': 5496,
#     'total_cost': 0.0108415,
#     'prompt_tokens': 301,
#     'completion_tokens': 5195},
#    'sql_generation': {'total_tokens': 838,
#     'total_cost': 0.001386,
#     'prompt_tokens': 580,
#     'completion_tokens': 258}}},
#  {'id': '5',
#   'question': 'What is the total of provinces of Netherlands?',
#   'query_string': "SELECT COUNT(*) FROM province WHERE country = 'Netherlands';",
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 2092,
#     'total_cost': 0.0038225,
#     'prompt_tokens': 723,
#     'completion_tokens': 1369},
#    'column_recall': {'total_tokens': 4254,
#     'total_cost': 0.008392499999999999,
#     'prompt_tokens': 231,
#     'completion_tokens': 4023},
#    'sql_generation': {'total_tokens': 751,
#     'total_cost': 0.001248,
#     'prompt_tokens': 508,
#     'completion_tokens': 243}}},
#  {'id': '6',
#   'question': 'What is the percentage of religious people are hindu in thailand?',
#   'query_string': "SELECT religion.percentage FROM religion WHERE religion.name = 'hindu' AND religion.country = 'thailand';",
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 1991,
#     'total_cost': 0.003618,
#     'prompt_tokens': 728,
#     'completion_tokens': 1263},
#    'column_recall': {'total_tokens': 2949,
#     'total_cost': 0.005784000000000001,
#     'prompt_tokens': 228,
#     'completion_tokens': 2721},
#    'sql_generation': {'total_tokens': 1032,
#     'total_cost': 0.0018075,
#     'prompt_tokens': 513,
#     'completion_tokens': 519}}},
#  {'id': '7',
#   'question': 'List the number of provinces each river flows through.',
#   'query_string': 'SELECT river, COUNT(DISTINCT province) AS num_provinces FROM river JOIN riverthrough ON river.river = riverthrough.river JOIN province ON riverthrough.lake = province.name GROUP BY river;',
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 2291,
#     'total_cost': 0.00422,
#     'prompt_tokens': 724,
#     'completion_tokens': 1567},
#    'column_recall': {'total_tokens': 5330,
#     'total_cost': 0.010515,
#     'prompt_tokens': 290,
#     'completion_tokens': 5040},
#    'sql_generation': {'total_tokens': 1201,
#     'total_cost': 0.0021255000000000002,
#     'prompt_tokens': 553,
#     'completion_tokens': 648}}},
#  {'id': '8',
#   'question': 'Find all countries that became independent between 8/1/1910 and 8/1/1950.',
#   'query_string': "SELECT country.name FROM country JOIN politics ON country.code = politics.country WHERE politics.independence >= TO_DATE('8/1/1910', 'MM/DD/YYYY') AND politics.independence <= TO_DATE('8/1/1950', 'MM/DD/YYYY');",
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 2292,
#     'total_cost': 0.0042155,
#     'prompt_tokens': 737,
#     'completion_tokens': 1555},
#    'column_recall': {'total_tokens': 4114,
#     'total_cost': 0.008107,
#     'prompt_tokens': 242,
#     'completion_tokens': 3872},
#    'sql_generation': {'total_tokens': 1430,
#     'total_cost': 0.0025985,
#     'prompt_tokens': 523,
#     'completion_tokens': 907}}},
#  {'id': '9',
#   'question': 'What are the cities of Cuba?',
#   'query_string': "SELECT city.name FROM city WHERE city.country = 'Cuba';",
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 2393,
#     'total_cost': 0.0044255,
#     'prompt_tokens': 721,
#     'completion_tokens': 1672},
#    'column_recall': {'total_tokens': 6308,
#     'total_cost': 0.0124645,
#     'prompt_tokens': 303,
#     'completion_tokens': 6005},
#    'sql_generation': {'total_tokens': 870,
#     'total_cost': 0.001452,
#     'prompt_tokens': 576,
#     'completion_tokens': 294}}},
#  {'id': '10',
#   'question': 'What is the capital of Georgia?',
#   'query_string': "SELECT capital FROM country WHERE name = 'Georgia';",
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 2110,
#     'total_cost': 0.0038595,
#     'prompt_tokens': 721,
#     'completion_tokens': 1389},
#    'column_recall': {'total_tokens': 6014,
#     'total_cost': 0.011876500000000002,
#     'prompt_tokens': 303,
#     'completion_tokens': 5711},
#    'sql_generation': {'total_tokens': 824,
#     'total_cost': 0.00136,
#     'prompt_tokens': 576,
#     'completion_tokens': 248}}},
#  {'id': '11',
#   'question': 'How many provinces have areas greater than 1000 in Niger?',
#   'query_string': "SELECT COUNT(*) FROM province WHERE area > 1000 AND country = 'Niger';",
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 1839,
#     'total_cost': 0.0033145,
#     'prompt_tokens': 727,
#     'completion_tokens': 1112},
#    'column_recall': {'total_tokens': 3933,
#     'total_cost': 0.0077485,
#     'prompt_tokens': 235,
#     'completion_tokens': 3698},
#    'sql_generation': {'total_tokens': 919,
#     'total_cost': 0.001581,
#     'prompt_tokens': 514,
#     'completion_tokens': 405}}},
#  {'id': '12',
#   'question': 'Tell me about the country with the area largest.',
#   'query_string': 'SELECT country.name FROM country WHERE country.area = (SELECT MAX(area) FROM country);',
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 3827,
#     'total_cost': 0.007292000000000001,
#     'prompt_tokens': 724,
#     'completion_tokens': 3103},
#    'column_recall': {'total_tokens': 5424,
#     'total_cost': 0.01073,
#     'prompt_tokens': 236,
#     'completion_tokens': 5188},
#    'sql_generation': {'total_tokens': 878,
#     'total_cost': 0.001495,
#     'prompt_tokens': 522,
#     'completion_tokens': 356}}},
#  {'id': '13',
#   'question': 'What is the host province and year of establishment of the organization "International Energy Agency"?',
#   'query_string': "SELECT province.name, organization.established FROM organization JOIN province ON organization.province = province.name WHERE organization.name = 'International Energy Agency';",
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 1756,
#     'total_cost': 0.003146,
#     'prompt_tokens': 732,
#     'completion_tokens': 1024},
#    'column_recall': {'total_tokens': 4269,
#     'total_cost': 0.008407,
#     'prompt_tokens': 262,
#     'completion_tokens': 4007},
#    'sql_generation': {'total_tokens': 1145,
#     'total_cost': 0.0020175,
#     'prompt_tokens': 545,
#     'completion_tokens': 600}}},
#  {'id': '14',
#   'question': 'Find the name of all mountains whose elevation is higher than 1000.',
#   'query_string': 'SELECT name FROM mountain WHERE elevation > 1000;',
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 5533,
#     'total_cost': 0.010701500000000001,
#     'prompt_tokens': 729,
#     'completion_tokens': 4804},
#    'column_recall': {'total_tokens': 3365,
#     'total_cost': 0.0066105,
#     'prompt_tokens': 239,
#     'completion_tokens': 3126},
#    'sql_generation': {'total_tokens': 759,
#     'total_cost': 0.0012555,
#     'prompt_tokens': 525,
#     'completion_tokens': 234}}},
#  {'id': '15',
#   'question': 'Tell me the economy of the Caribbean Sea.',
#   'query_string': "SELECT economy.gdp FROM economy JOIN geo_sea ON economy.country = geo_sea.country JOIN sea ON geo_sea.sea = sea.name WHERE sea.name = 'Caribbean Sea';",
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 3020,
#     'total_cost': 0.0056784999999999995,
#     'prompt_tokens': 723,
#     'completion_tokens': 2297},
#    'column_recall': {'total_tokens': 6572,
#     'total_cost': 0.013003500000000001,
#     'prompt_tokens': 281,
#     'completion_tokens': 6291},
#    'sql_generation': {'total_tokens': 1476,
#     'total_cost': 0.002673,
#     'prompt_tokens': 558,
#     'completion_tokens': 918}}},
#  {'id': '16',
#   'question': 'Shows me cities with longitude between 0 and 6.',
#   'query_string': 'SELECT city.name FROM city WHERE city.longitude BETWEEN 0 AND 6;',
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 4733,
#     'total_cost': 0.009103,
#     'prompt_tokens': 726,
#     'completion_tokens': 4007},
#    'column_recall': {'total_tokens': 7562,
#     'total_cost': 0.0149275,
#     'prompt_tokens': 393,
#     'completion_tokens': 7169},
#    'sql_generation': {'total_tokens': 969,
#     'total_cost': 0.0016090000000000002,
#     'prompt_tokens': 658,
#     'completion_tokens': 311}}},
#  {'id': '17',
#   'question': 'Select cities whose population is greater than 100000, altitude greater than 2500, and the country you belong to has population growth greater than 1.',
#   'query_string': 'SELECT city.name FROM city JOIN population ON city.country = population.country JOIN country ON city.country = country.code WHERE city.population > 100000 AND city.elevation > 2500 AND population.population_growth > 1;',
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 1680,
#     'total_cost': 0.002987,
#     'prompt_tokens': 746,
#     'completion_tokens': 934},
#    'column_recall': {'total_tokens': 5650,
#     'total_cost': 0.0111475,
#     'prompt_tokens': 305,
#     'completion_tokens': 5345},
#    'sql_generation': {'total_tokens': 1610,
#     'total_cost': 0.0029300000000000003,
#     'prompt_tokens': 580,
#     'completion_tokens': 1030}}},
#  {'id': '18',
#   'question': 'Show all the different types of government.',
#   'query_string': 'SELECT DISTINCT government FROM politics;',
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 2653,
#     'total_cost': 0.004945,
#     'prompt_tokens': 722,
#     'completion_tokens': 1931},
#    'column_recall': {'total_tokens': 4380,
#     'total_cost': 0.0086385,
#     'prompt_tokens': 243,
#     'completion_tokens': 4137},
#    'sql_generation': {'total_tokens': 653,
#     'total_cost': 0.001043,
#     'prompt_tokens': 526,
#     'completion_tokens': 127}}},
#  {'id': '19',
#   'question': 'List all provinces in Germany',
#   'query_string': "SELECT province.name FROM province JOIN country ON province.country = country.code WHERE country.name = 'Germany';",
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 2986,
#     'total_cost': 0.005612000000000001,
#     'prompt_tokens': 720,
#     'completion_tokens': 2266},
#    'column_recall': {'total_tokens': 4087,
#     'total_cost': 0.00806,
#     'prompt_tokens': 228,
#     'completion_tokens': 3859},
#    'sql_generation': {'total_tokens': 931,
#     'total_cost': 0.0016085000000000001,
#     'prompt_tokens': 507,
#     'completion_tokens': 424}}},
#  {'id': '20',
#   'question': 'What is the percentage of mulatto ethnicity in Brazil?',
#   'query_string': "SELECT percentage FROM ethnicgroup WHERE country = 'BRA' AND name = 'Mulatto';",
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 3297,
#     'total_cost': 0.0062315,
#     'prompt_tokens': 725,
#     'completion_tokens': 2572},
#    'column_recall': {'total_tokens': 4063,
#     'total_cost': 0.0079935,
#     'prompt_tokens': 265,
#     'completion_tokens': 3798},
#    'sql_generation': {'total_tokens': 1086,
#     'total_cost': 0.0018970000000000002,
#     'prompt_tokens': 550,
#     'completion_tokens': 536}}},
#  {'id': '21',
#   'question': 'How many cities have populations less than 1000?',
#   'query_string': 'SELECT COUNT(*) FROM city WHERE population < 1000;',
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 1905,
#     'total_cost': 0.0034475,
#     'prompt_tokens': 725,
#     'completion_tokens': 1180},
#    'column_recall': {'total_tokens': 3459,
#     'total_cost': 0.0067835000000000005,
#     'prompt_tokens': 269,
#     'completion_tokens': 3190},
#    'sql_generation': {'total_tokens': 774,
#     'total_cost': 0.001274,
#     'prompt_tokens': 548,
#     'completion_tokens': 226}}},
#  {'id': '22',
#   'question': 'What is the average elevation of airports in America?',
#   'query_string': "SELECT AVG(elevation) FROM airport WHERE country = 'America';",
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 2292,
#     'total_cost': 0.004222,
#     'prompt_tokens': 724,
#     'completion_tokens': 1568},
#    'column_recall': {'total_tokens': 8428,
#     'total_cost': 0.0166955,
#     'prompt_tokens': 321,
#     'completion_tokens': 8107},
#    'sql_generation': {'total_tokens': 850,
#     'total_cost': 0.001409,
#     'prompt_tokens': 582,
#     'completion_tokens': 268}}},
#  {'id': '23',
#   'question': 'How many countries are adjacent to (or ecompassed by) the the Caribbean Sea?',
#   'query_string': "SELECT COUNT(DISTINCT country) FROM borders WHERE country1 IN (SELECT code FROM country WHERE province = 'Caribbean Sea') OR country2 IN (SELECT code FROM country WHERE province = 'Caribbean Sea') OR country IN (SELECT country FROM encompasses WHERE continent = 'Caribbean Sea');",
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 2649,
#     'total_cost': 0.004932000000000001,
#     'prompt_tokens': 732,
#     'completion_tokens': 1917},
#    'column_recall': {'total_tokens': 5776,
#     'total_cost': 0.011413999999999999,
#     'prompt_tokens': 276,
#     'completion_tokens': 5500},
#    'sql_generation': {'total_tokens': 1851,
#     'total_cost': 0.0034225,
#     'prompt_tokens': 559,
#     'completion_tokens': 1292}}},
#  {'id': '24',
#   'question': 'How much area do the countries that are adjacent to (or encompassed by) the Caribbean Sea cover in total?',
#   'query_string': "SELECT SUM(country.area) FROM country JOIN borders ON country.code = borders.country1 JOIN sea ON sea.name = 'Caribbean Sea' WHERE borders.country2 = sea.name UNION SELECT SUM(country.area) FROM country JOIN encompasses ON country.code = encompasses.country JOIN sea ON sea.name = 'Caribbean Sea' WHERE encompasses.continent = sea.name;",
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 3518,
#     'total_cost': 0.0066675,
#     'prompt_tokens': 737,
#     'completion_tokens': 2781},
#    'column_recall': {'total_tokens': 4931,
#     'total_cost': 0.009721500000000001,
#     'prompt_tokens': 281,
#     'completion_tokens': 4650},
#    'sql_generation': {'total_tokens': 2098,
#     'total_cost': 0.003913,
#     'prompt_tokens': 566,
#     'completion_tokens': 1532}}},
#  {'id': '25',
#   'question': 'For all countries, give the sum of the population of all its neighbors',
#   'query_string': 'SELECT SUM(c.population) FROM country c JOIN borders b ON c.code = b.country1 GROUP BY c.code;',
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 2564,
#     'total_cost': 0.0047635,
#     'prompt_tokens': 729,
#     'completion_tokens': 1835},
#    'column_recall': {'total_tokens': 3533,
#     'total_cost': 0.006946000000000001,
#     'prompt_tokens': 240,
#     'completion_tokens': 3293},
#    'sql_generation': {'total_tokens': 1170,
#     'total_cost': 0.0020775000000000004,
#     'prompt_tokens': 525,
#     'completion_tokens': 645}}},
#  {'id': '26',
#   'question': 'What mountains are on the island of Borneo?',
#   'query_string': "SELECT mountain.name FROM mountainonisland JOIN mountain ON mountainonisland.mountain = mountain.name JOIN island ON mountainonisland.island = island.name WHERE island.name = 'Borneo';",
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 3139,
#     'total_cost': 0.005915500000000001,
#     'prompt_tokens': 725,
#     'completion_tokens': 2414},
#    'column_recall': {'total_tokens': 5194,
#     'total_cost': 0.0102615,
#     'prompt_tokens': 253,
#     'completion_tokens': 4941},
#    'sql_generation': {'total_tokens': 1371,
#     'total_cost': 0.002473,
#     'prompt_tokens': 538,
#     'completion_tokens': 833}}},
#  {'id': '27',
#   'question': 'Provide the name and total population of the country with the smallest area.',
#   'query_string': 'SELECT name, population FROM country WHERE area = (SELECT MIN(area) FROM country);',
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 1932,
#     'total_cost': 0.0035,
#     'prompt_tokens': 728,
#     'completion_tokens': 1204},
#    'column_recall': {'total_tokens': 2687,
#     'total_cost': 0.005266,
#     'prompt_tokens': 216,
#     'completion_tokens': 2471},
#    'sql_generation': {'total_tokens': 943,
#     'total_cost': 0.001634,
#     'prompt_tokens': 504,
#     'completion_tokens': 439}}},
#  {'id': '28',
#   'question': 'The codes of all countries for which at least one river that originates in this country has its estuary in a neighboring country.',
#   'query_string': 'SELECT country.code FROM country INNER JOIN river ON country.code = river.source INNER JOIN borders ON country.code = borders.country1 AND river.estuary = borders.country2;',
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 2889,
#     'total_cost': 0.0054085,
#     'prompt_tokens': 739,
#     'completion_tokens': 2150},
#    'column_recall': {'total_tokens': 5121,
#     'total_cost': 0.0100935,
#     'prompt_tokens': 297,
#     'completion_tokens': 4824},
#    'sql_generation': {'total_tokens': 1447,
#     'total_cost': 0.0026125000000000002,
#     'prompt_tokens': 563,
#     'completion_tokens': 884}}},
#  {'id': '29',
#   'question': 'The codes of all countries where at least one mountain is located in each of their provinces',
#   'query_string': 'SELECT country.code FROM country WHERE EXISTS ( SELECT province.name FROM province WHERE province.country = country.code GROUP BY province.name HAVING COUNT(DISTINCT province.capital) = COUNT(DISTINCT province.name) )',
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 3629,
#     'total_cost': 0.006892,
#     'prompt_tokens': 732,
#     'completion_tokens': 2897},
#    'column_recall': {'total_tokens': 5066,
#     'total_cost': 0.009989999999999999,
#     'prompt_tokens': 284,
#     'completion_tokens': 4782},
#    'sql_generation': {'total_tokens': 2219,
#     'total_cost': 0.0041565,
#     'prompt_tokens': 563,
#     'completion_tokens': 1656}}},
#  {'id': '30',
#   'question': 'The code and total border lengths of all countries with at least one border.',
#   'query_string': 'SELECT country.code, SUM(borders.length) FROM country JOIN borders ON borders.country1 = country.code OR borders.country2 = country.code GROUP BY country.code;',
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 2239,
#     'total_cost': 0.0041135,
#     'prompt_tokens': 729,
#     'completion_tokens': 1510},
#    'column_recall': {'total_tokens': 3718,
#     'total_cost': 0.0073160000000000005,
#     'prompt_tokens': 240,
#     'completion_tokens': 3478},
#    'sql_generation': {'total_tokens': 1252,
#     'total_cost': 0.0022425,
#     'prompt_tokens': 523,
#     'completion_tokens': 729}}},
#  {'id': '31',
#   'question': 'The names and codes of all countries in which at least one river originates.',
#   'query_string': 'SELECT country.name, country.code FROM country INNER JOIN river ON country.code = river.source;',
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 2997,
#     'total_cost': 0.0056295,
#     'prompt_tokens': 729,
#     'completion_tokens': 2268},
#    'column_recall': {'total_tokens': 4824,
#     'total_cost': 0.009505000000000001,
#     'prompt_tokens': 286,
#     'completion_tokens': 4538},
#    'sql_generation': {'total_tokens': 945,
#     'total_cost': 0.0016145,
#     'prompt_tokens': 551,
#     'completion_tokens': 394}}},
#  {'id': '32',
#   'question': 'What is the area and country of the Chatanga River?',
#   'query_string': "SELECT area, country FROM river WHERE name = 'Chatanga River';",
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 3232,
#     'total_cost': 0.006101,
#     'prompt_tokens': 726,
#     'completion_tokens': 2506},
#    'column_recall': {'total_tokens': 5604,
#     'total_cost': 0.0110795,
#     'prompt_tokens': 257,
#     'completion_tokens': 5347},
#    'sql_generation': {'total_tokens': 859,
#     'total_cost': 0.001456,
#     'prompt_tokens': 524,
#     'completion_tokens': 335}}},
#  {'id': '33',
#   'question': 'Shows me Airports with elevation more than 3000',
#   'query_string': 'SELECT airport.name FROM airport WHERE airport.elevation > 3000;',
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 6507,
#     'total_cost': 0.012650999999999999,
#     'prompt_tokens': 726,
#     'completion_tokens': 5781},
#    'column_recall': {'total_tokens': 6798,
#     'total_cost': 0.0134345,
#     'prompt_tokens': 323,
#     'completion_tokens': 6475},
#    'sql_generation': {'total_tokens': 878,
#     'total_cost': 0.001465,
#     'prompt_tokens': 582,
#     'completion_tokens': 296}}},
#  {'id': '34',
#   'question': 'What are the religions practiced in Mexico?',
#   'query_string': "SELECT religion.name FROM religion WHERE religion.country = 'Mexico';",
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 4756,
#     'total_cost': 0.009151000000000001,
#     'prompt_tokens': 722,
#     'completion_tokens': 4034},
#    'column_recall': {'total_tokens': 4954,
#     'total_cost': 0.009778,
#     'prompt_tokens': 260,
#     'completion_tokens': 4694},
#    'sql_generation': {'total_tokens': 835,
#     'total_cost': 0.0013975,
#     'prompt_tokens': 545,
#     'completion_tokens': 290}}},
#  {'id': '35',
#   'question': 'Show all rivers that do not flow into the sea.',
#   'query_string': 'SELECT river.name FROM river LEFT JOIN riverthrough ON river.name = riverthrough.river WHERE riverthrough.river IS NULL;',
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 4759,
#     'total_cost': 0.0091555,
#     'prompt_tokens': 725,
#     'completion_tokens': 4034},
#    'column_recall': {'total_tokens': 5647,
#     'total_cost': 0.011141499999999999,
#     'prompt_tokens': 305,
#     'completion_tokens': 5342},
#    'sql_generation': {'total_tokens': 1000,
#     'total_cost': 0.0017130000000000001,
#     'prompt_tokens': 574,
#     'completion_tokens': 426}}},
#  {'id': '36',
#   'question': 'List African countries by number of neighbors.',
#   'query_string': 'SELECT country.name, COUNT(borders.country2) AS num_neighbors FROM country JOIN borders ON borders.country1 = country.code GROUP BY country.name ORDER BY num_neighbors DESC;',
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 2686,
#     'total_cost': 0.005011,
#     'prompt_tokens': 722,
#     'completion_tokens': 1964},
#    'column_recall': {'total_tokens': 3876,
#     'total_cost': 0.0076355,
#     'prompt_tokens': 233,
#     'completion_tokens': 3643},
#    'sql_generation': {'total_tokens': 1250,
#     'total_cost': 0.002241,
#     'prompt_tokens': 518,
#     'completion_tokens': 732}}},
#  {'id': '37',
#   'question': 'What is the average infant mortality rate for each continent?',
#   'query_string': 'SELECT continent, AVG(infant_mortality) AS average_infant_mortality FROM population JOIN country ON population.country = country.code JOIN continent ON country.continent = continent.name GROUP BY continent;',
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 2479,
#     'total_cost': 0.004595500000000001,
#     'prompt_tokens': 725,
#     'completion_tokens': 1754},
#    'column_recall': {'total_tokens': 3908,
#     'total_cost': 0.0076985000000000005,
#     'prompt_tokens': 235,
#     'completion_tokens': 3673},
#    'sql_generation': {'total_tokens': 1335,
#     'total_cost': 0.00241,
#     'prompt_tokens': 520,
#     'completion_tokens': 815}}},
#  {'id': '38',
#   'question': 'What is the average mortality rate of the countries in America without considering Brazil?',
#   'query_string': "SELECT AVG(infant_mortality) FROM population WHERE country IN ( SELECT code FROM country WHERE continent = 'America' AND code != 'BRA' );",
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 3101,
#     'total_cost': 0.0058375,
#     'prompt_tokens': 729,
#     'completion_tokens': 2372},
#    'column_recall': {'total_tokens': 4044,
#     'total_cost': 0.0079565,
#     'prompt_tokens': 263,
#     'completion_tokens': 3781},
#    'sql_generation': {'total_tokens': 1347,
#     'total_cost': 0.0024200000000000003,
#     'prompt_tokens': 548,
#     'completion_tokens': 799}}},
#  {'id': '39',
#   'question': 'List seas with area greater than 8000 and depth less than 100.',
#   'query_string': 'SELECT sea.name FROM sea WHERE sea.area > 8000 AND sea.depth < 100;',
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 3116,
#     'total_cost': 0.005867000000000001,
#     'prompt_tokens': 730,
#     'completion_tokens': 2386},
#    'column_recall': {'total_tokens': 2673,
#     'total_cost': 0.005222,
#     'prompt_tokens': 248,
#     'completion_tokens': 2425},
#    'sql_generation': {'total_tokens': 931,
#     'total_cost': 0.0015945,
#     'prompt_tokens': 535,
#     'completion_tokens': 396}}},
#  {'id': '40',
#   'question': 'How many mountains are there in Asia?',
#   'query_string': "SELECT COUNT(*) FROM mountain m JOIN encompasses e ON m.name = e.mountain JOIN continent c ON e.continent = c.name WHERE c.name = 'Asia';",
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 2897,
#     'total_cost': 0.0054329999999999995,
#     'prompt_tokens': 722,
#     'completion_tokens': 2175},
#    'column_recall': {'total_tokens': 4531,
#     'total_cost': 0.008937,
#     'prompt_tokens': 250,
#     'completion_tokens': 4281},
#    'sql_generation': {'total_tokens': 1085,
#     'total_cost': 0.0019045,
#     'prompt_tokens': 531,
#     'completion_tokens': 554}}},
#  {'id': '41',
#   'question': 'What are the countries that are close to the Mediterranean Sea?',
#   'query_string': "SELECT country.name FROM country JOIN borders ON borders.country1 = country.code JOIN sea ON sea.name = 'Mediterranean Sea' WHERE borders.country2 = country.code;",
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 3668,
#     'total_cost': 0.006973,
#     'prompt_tokens': 726,
#     'completion_tokens': 2942},
#    'column_recall': {'total_tokens': 6145,
#     'total_cost': 0.012136000000000001,
#     'prompt_tokens': 308,
#     'completion_tokens': 5837},
#    'sql_generation': {'total_tokens': 1409,
#     'total_cost': 0.0025234999999999997,
#     'prompt_tokens': 589,
#     'completion_tokens': 820}}},
#  {'id': '42',
#   'question': 'Show the total for each type of government.',
#   'query_string': 'SELECT government, COUNT(*) as total FROM politics GROUP BY government;',
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 1967,
#     'total_cost': 0.0035725,
#     'prompt_tokens': 723,
#     'completion_tokens': 1244},
#    'column_recall': {'total_tokens': 3598,
#     'total_cost': 0.007082000000000001,
#     'prompt_tokens': 228,
#     'completion_tokens': 3370},
#    'sql_generation': {'total_tokens': 796,
#     'total_cost': 0.0013365,
#     'prompt_tokens': 511,
#     'completion_tokens': 285}}},
#  {'id': '43',
#   'question': 'Which province has the largest desert in the world?',
#   'query_string': 'SELECT province FROM province WHERE area = ( SELECT MAX(area) FROM desert )',
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 1985,
#     'total_cost': 0.003608,
#     'prompt_tokens': 724,
#     'completion_tokens': 1261},
#    'column_recall': {'total_tokens': 4774,
#     'total_cost': 0.009414,
#     'prompt_tokens': 268,
#     'completion_tokens': 4506},
#    'sql_generation': {'total_tokens': 1441,
#     'total_cost': 0.0026075,
#     'prompt_tokens': 549,
#     'completion_tokens': 892}}},
#  {'id': '44',
#   'question': 'What is the largest desert in the world?',
#   'query_string': 'SELECT desert.name FROM desert ORDER BY area DESC FETCH FIRST 1 ROWS ONLY;',
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 4424,
#     'total_cost': 0.008486500000000001,
#     'prompt_tokens': 723,
#     'completion_tokens': 3701},
#    'column_recall': {'total_tokens': 4712,
#     'total_cost': 0.009291500000000001,
#     'prompt_tokens': 265,
#     'completion_tokens': 4447},
#    'sql_generation': {'total_tokens': 950,
#     'total_cost': 0.0016250000000000001,
#     'prompt_tokens': 550,
#     'completion_tokens': 400}}},
#  {'id': '45',
#   'question': 'List, for all continents, the amount of deserts on each.',
#   'query_string': 'SELECT continent.name, COUNT(desert.name) AS desert_count FROM continent LEFT JOIN geo_desert ON continent.name = geo_desert.continent LEFT JOIN desert ON geo_desert.desert = desert.name GROUP BY continent.name;',
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 2940,
#     'total_cost': 0.005516000000000001,
#     'prompt_tokens': 728,
#     'completion_tokens': 2212},
#    'column_recall': {'total_tokens': 3147,
#     'total_cost': 0.0061665,
#     'prompt_tokens': 255,
#     'completion_tokens': 2892},
#    'sql_generation': {'total_tokens': 1363,
#     'total_cost': 0.002455,
#     'prompt_tokens': 542,
#     'completion_tokens': 821}}},
#  {'id': '46',
#   'question': 'What are the neighboring seas of the Banda Sea?',
#   'query_string': "SELECT sea2 FROM mergeswith WHERE sea1 = 'Banda Sea';",
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 2199,
#     'total_cost': 0.0040355,
#     'prompt_tokens': 725,
#     'completion_tokens': 1474},
#    'column_recall': {'total_tokens': 5449,
#     'total_cost': 0.010730499999999999,
#     'prompt_tokens': 335,
#     'completion_tokens': 5114},
#    'sql_generation': {'total_tokens': 1058,
#     'total_cost': 0.001806,
#     'prompt_tokens': 620,
#     'completion_tokens': 438}}},
#  {'id': '47',
#   'question': 'List all the capitals of European countries.',
#   'query_string': "SELECT country.capital FROM country WHERE country.continent = 'Europe';",
#   'type': 'complex',
#   'token_usage': {'table_recall': {'total_tokens': 2937,
#     'total_cost': 0.005513,
#     'prompt_tokens': 722,
#     'completion_tokens': 2215},
#    'column_recall': {'total_tokens': 5095,
#     'total_cost': 0.010059,
#     'prompt_tokens': 262,
#     'completion_tokens': 4833},
#    'sql_generation': {'total_tokens': 852,
#     'total_cost': 0.0014365,
#     'prompt_tokens': 535,
#     'completion_tokens': 317}}},
#  {'id': '48',
#   'question': 'What percentage of people speak French in Andorra?',
#   'query_string': "SELECT language.percentage FROM language WHERE language.country = 'AND' AND language.name = 'French';",
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 2193,
#     'total_cost': 0.004024,
#     'prompt_tokens': 724,
#     'completion_tokens': 1469},
#    'column_recall': {'total_tokens': 3699,
#     'total_cost': 0.007286000000000001,
#     'prompt_tokens': 224,
#     'completion_tokens': 3475},
#    'sql_generation': {'total_tokens': 984,
#     'total_cost': 0.0017135000000000002,
#     'prompt_tokens': 509,
#     'completion_tokens': 475}}},
#  {'id': '49',
#   'question': 'Which rivers are longer than 1000 kilometers?',
#   'query_string': 'SELECT river.name FROM river WHERE river.length > 1000;',
#   'type': 'simple',
#   'token_usage': {'table_recall': {'total_tokens': 3561,
#     'total_cost': 0.00676,
#     'prompt_tokens': 724,
#     'completion_tokens': 2837},
#    'column_recall': {'total_tokens': 5399,
#     'total_cost': 0.010636000000000001,
#     'prompt_tokens': 324,
#     'completion_tokens': 5075},
#    'sql_generation': {'total_tokens': 863,
#     'total_cost': 0.0014295,
#     'prompt_tokens': 593,
#     'completion_tokens': 270}}},
#  {'id': '50',
#   'question': 'Which country had the lowest population growth?',
#   'query_string': 'SELECT country FROM population WHERE population_growth = ( SELECT MIN(population_growth) FROM population );',
#   'type': 'medium',
#   'token_usage': {'table_recall': {'total_tokens': 3512,
#     'total_cost': 0.006663,
#     'prompt_tokens': 722,
#     'completion_tokens': 2790},
#    'column_recall': {'total_tokens': 3111,
#     'total_cost': 0.0061095,
#     'prompt_tokens': 225,
#     'completion_tokens': 2886},
#    'sql_generation': {'total_tokens': 927,
#     'total_cost': 0.0015990000000000002,
#     'prompt_tokens': 510,
#     'completion_tokens': 417}}}]
